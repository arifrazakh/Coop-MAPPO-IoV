# %%
import math
import random
from collections import defaultdict
from types import SimpleNamespace
import time
import csv  # used for episode-wise CSV logging

import gymnasium as gym
from gymnasium.utils import seeding
import matplotlib.pyplot as plt
import numpy as np

# RLlib / Ray
import os
import ray
from ray.rllib.algorithms.ppo import PPOConfig   # <<< PPO
from ray.rllib.policy.policy import PolicySpec
from ray.tune.registry import register_env
from ray.rllib.env.multi_agent_env import MultiAgentEnv
from ray.rllib.algorithms.callbacks import DefaultCallbacks
import torch


# ----------------------
# Basic PHY & helper functions
# ----------------------
def rx_sensitivity_dBm(bw_hz, nf_db=7.0, snr_req_db=-5.0):
    """Thermal-noise-based RX sensitivity in dBm."""
    return -174.0 + 10.0 * np.log10(max(bw_hz, 1.0)) + nf_db + snr_req_db


MOD_ORDER = 256
BITS_PER_CODEWORD = int(np.log2(MOD_ORDER))
NR_OVERHEAD = 0.85
SNR_GAP_DB = 1.5
MAX_SE = 7.5  # peak spectral efficiency (bit/s/Hz)

# Antenna / beamforming gains per BS type
BEAM_GAIN_DB = {
    "Ma": {
        "tx_main": 8.0,   # main-lobe TX gain (dB)
        "tx_side": -3.0,  # side-lobe TX gain (dB)
        "rx": 0.0,        # UE RX gain (dB)
    }
}

UE_INTERF_RX_DB = 0.0  # interference-side RX gain at UE
MACRO_REUSE_ONE = False
MIMO_MAX_RANK = {"Ma": 4}


def spectral_efficiency_from_sinr(SINR_dB, gap_db=SNR_GAP_DB, max_se=MAX_SE):
    """Shannon-like SE with SNR gap."""
    gamma_lin = 10.0 ** (SINR_dB / 10.0) / (10.0 ** (gap_db / 10.0))
    se = np.log2(1.0 + gamma_lin)
    return float(np.clip(se, 0.0, max_se))


def mimo_rank_and_total_se(
    SINR_dB: float,
    max_layers: int,
    gap_db: float = SNR_GAP_DB,
    max_se: float = MAX_SE,
):
    """Simple MIMO rank-selection and SE aggregation."""
    sinr_lin = 10.0 ** (SINR_dB / 10.0)
    best_L = 1
    best_sum_se = spectral_efficiency_from_sinr(SINR_dB, gap_db, max_se)

    for L in range(2, max_layers + 1):
        per_layer_snr_dB = 10.0 * np.log10(max(sinr_lin / max(L, 1), 1e-12))
        se_layer = spectral_efficiency_from_sinr(
            per_layer_snr_dB, gap_db, max_se
        )
        corr_eff = max(0.5, 1.0 - 0.07 * (L - 1))  # crude correlation penalty
        sum_se = L * se_layer * corr_eff
        if sum_se > best_sum_se:
            best_sum_se = sum_se
            best_L = L

    return best_L, float(best_sum_se)


# 19-D BS observation layout (0-1 normalized)
OBS_IDX = SimpleNamespace(
    BS_TYPE=0,
    TX_NORM=1,
    CH_UTIL=2,
    COV_UTIL=3,
    LOAD_RATIO_NORM=4,
    NEARBY_POT=5,
    AVG_SPEED=6,
    REQ_P_NORM=7,
    AVG_RADIAL_V=8,
    SP_VAR=9,
    NEIGHBOR_TX_NORM=10,
    AVG_DEMAND_NORM=11,
    INTER_NORM=12,
    MEC_QUEUE_NORM=13,
    CPU_UTIL_NORM=14,
    OFFLOAD_FRAC=15,
    SERVED_RATIO_NORM=16,  # local served throughput / max possible
    BLOCK_FRAC_NORM=17,    # fraction of in-coverage users not associated
    CH_MATCH_NORM=18,      # how well channels match covered users
    OFFLOAD_MAND_FRAC=19,  # fraction of covered users with mandatory-offload tasks
)


# ----------------
# Building blocks
# ----------------
class Channel:
    def __init__(self, id, frequency, bandwidth, noise_figure_db=7.0):
        self.id = int(id)
        self.frequency = float(frequency)
        self.bandwidth = float(bandwidth)
        self.noise_figure_db = float(noise_figure_db)
        self.users = []
        self.base_station = None

    def calculate_noise_power(self):
        """Noise power in Watts for this channel."""
        k = 1.380649e-23
        T = 293.15
        N = k * T * self.bandwidth
        NF = 10.0 ** (self.noise_figure_db / 10.0)
        return N * NF


class BaseStation:
    def __init__(
        self,
        id,
        transmit_power_mW,
        height_m,
        location_xy,
        type_bs="Ma",
        mec_cpu_capacity_cycles=5e9,
    ):
        self.id = int(id)
        self.transmit_power = float(transmit_power_mW)  # total TX power in mW
        self.height = float(height_m)
        self.location = np.array(location_xy, dtype=float)
        self.type_bs = type_bs
        self.assigned_channels = []
        self.per_channel_power = {}
        self.coverage_area = float(0.0)  # coverage radius (m)

        # MEC-related attributes (compute plane)
        self.mec_cpu_capacity = float(mec_cpu_capacity_cycles)  # F_i^{max}
        self.mec_queue_cycles = 0.0     # q_t^{bs,i} [cycles]
        self.offload_frac = 1.0         # x_t^i in [0,1]
        self.cpu_util_frac = 1.0        # aggregate CPU utilization fraction
        self.last_cpu_used = 0.0        # F_used this step [cycles/s]

        # simple type-dependent caps
        self.MAX_COVERAGE = {"Ma": 2000.0}
        self.COV_MARGIN_DB = {"Ma": 3.0}
        self.SNR_REQ_DB = {"Ma": -5.0}

    # ---- 3GPP-like UMa pathloss ----
    def _pl_uma_los(self, d3d, f_ghz, h_ut=1.5):
        c = 3e8
        f_hz = f_ghz * 1e9
        h_bs = float(self.height)

        d2d = max(np.sqrt(max(d3d**2 - (h_bs - h_ut) ** 2, 1e-9)), 1.0)
        h_bs_eff = h_bs - 1.0
        h_ut_eff = h_ut - 1.0
        d_bp = 4.0 * h_bs_eff * h_ut_eff * f_hz / c

        pl1 = 28.0 + 22.0 * np.log10(d3d) + 20.0 * np.log10(f_ghz)
        if d2d <= d_bp:
            return pl1
        pl2 = (
            28.0
            + 40.0 * np.log10(d3d)
            + 20.0 * np.log10(f_ghz)
            - 9.0 * np.log10(d_bp**2 + (h_bs - h_ut) ** 2)
        )
        return pl2

    def _pl_uma_nlos(self, d3d, f_ghz, h_ut=1.5):
        pl_los = self._pl_uma_los(d3d, f_ghz, h_ut)
        pl_nlos = (
            13.54
            + 39.08 * np.log10(d3d)
            + 20.0 * np.log10(f_ghz)
            - 0.6 * (h_ut - 1.5)
        )
        return max(pl_nlos, pl_los)

    def calculate_path_loss(self, distance_m, frequency_hz, user_height=1.5):
        """Average path loss (LOS-probability weighted)."""
        d2d = float(max(distance_m, 0.1))
        f_ghz = frequency_hz / 1e9
        d3d = np.sqrt(d2d**2 + (self.height - user_height) ** 2)

        p_los = min(18.0 / d2d, 1.0) * (1.0 - np.exp(-d2d / 63.0)) + np.exp(
            -d2d / 63.0
        )
        pl_los = self._pl_uma_los(d3d, f_ghz, h_ut=user_height)
        pl_nlos = self._pl_uma_nlos(d3d, f_ghz, h_ut=user_height)

        return float(p_los * pl_los + (1.0 - p_los) * pl_nlos)

    def _eirp_dbm(self, transmit_power_mW: float) -> float:
        g = BEAM_GAIN_DB[self.type_bs]
        tx_dbm = 10.0 * np.log10(max(transmit_power_mW, 1e-15))
        return tx_dbm + g["tx_main"] + g["rx"]

    def update_coverage_area_from_power(
        self, total_transmit_power_mW, frequency_hz
    ):
        """Update coverage radius from link budget."""
        if self.per_channel_power:
            values = list(self.per_channel_power.values())
            p_ch = float(np.percentile(values, 80))
        else:
            n = max(1, len(self.assigned_channels))
            p_ch = float(total_transmit_power_mW / n)

        if self.assigned_channels:
            bw_hz = self.assigned_channels[0].bandwidth
            nf_db = self.assigned_channels[0].noise_figure_db
        else:
            bw_hz = 20e6
            nf_db = 7.0

        sens_dBm = rx_sensitivity_dBm(
            bw_hz, nf_db=nf_db, snr_req_db=self.SNR_REQ_DB[self.type_bs]
        )
        eirp_plus_grx_dbm = self._eirp_dbm(p_ch)
        path_loss_budget_dB = (
            eirp_plus_grx_dbm - sens_dBm - self.COV_MARGIN_DB[self.type_bs]
        )

        radius_m = self.find_distance_for_path_loss(
            path_loss_budget_dB, frequency_hz
        )
        cap = self.MAX_COVERAGE.get(self.type_bs, None)
        if cap is not None:
            radius_m = min(radius_m, float(cap))

        self.coverage_area = float(max(radius_m, 1.0))
        return self.coverage_area

    def find_distance_for_path_loss(self, path_loss_dB, frequency_hz):
        """Invert pathloss model via binary search."""
        d_min, d_max = 1.0, 10000.0
        tol = 0.1
        d_mid = 0.0
        for _ in range(40):
            d_mid = 0.5 * (d_min + d_max)
            PL_mid = self.calculate_path_loss(d_mid, frequency_hz)
            if abs(PL_mid - path_loss_dB) < tol:
                return d_mid
            if PL_mid < path_loss_dB:
                d_min = d_mid
            else:
                d_max = d_mid
        return d_mid

    def assign_channels(self, channels):
        self.assigned_channels = list(channels)
        for ch in self.assigned_channels:
            ch.base_station = self

    def clear_assigned_channels(self):
        for ch in self.assigned_channels:
            ch.base_station = None
            ch.users = []
        self.assigned_channels = []
        self.per_channel_power = {}

    def find_available_channel(self):
        """Find a free (unoccupied) channel, if any."""
        for ch in self.assigned_channels:
            if len(ch.users) == 0:
                return ch
        return None


class User:
    def __init__(self, id, location_xy, velocity_xy, demand_bits=1e6):
        self.id = int(id)
        self.location = np.array(location_xy, dtype=float)
        self.velocity = np.array(velocity_xy, dtype=float)
        self.height = 1.5

        # radio link properties
        self.channel = []
        self.channel_SINR = []
        self.SINR = -100.0
        self.data_rate = 0.0  # instantaneous achievable rate (Mbps)
        self.demand = float(demand_bits)  # "required" rate (Mbps-like scale)
        self.mimo_layers = []

        # service class
        self.service_class = "infotainment"

        # task model (set properly by generate_task())
        self.task_type = "light"
        self.task_cycles = 0.0
        self.task_input_Mbit = 0.0
        self.task_offload_mandatory = False

        # mobility
        self.speed = float(np.linalg.norm(self.velocity))
        self.waypoint = None
        self.pause_time = 0
        self.dir_axis = None
        self.dir_sign = 1
        self.next_intersection = None

    def clear_channel(self):
        self.channel = []
        self.channel_SINR = []
        self.SINR = -100.0
        self.mimo_layers = []
        self.data_rate = 0.0

    def calculate_data_rate(self):
        """Aggregate rate across all assigned channels with MIMO."""
        self.data_rate = 0.0
        self.mimo_layers = []

        for i, ch in enumerate(self.channel):
            bw_eff = ch.bandwidth * NR_OVERHEAD
            SINR_dB = self.channel_SINR[i]
            max_rank = MIMO_MAX_RANK[ch.base_station.type_bs]

            L, total_se = mimo_rank_and_total_se(
                SINR_dB, max_rank, gap_db=SNR_GAP_DB, max_se=MAX_SE
            )
            dr_Mbps = (bw_eff * total_se) / 1e6
            self.mimo_layers.append(L)
            self.data_rate += dr_Mbps

    def calculate_demand_from_rng(self, rng):
        """Random traffic demand model."""
        if getattr(self, "service_class", "infotainment") == "safety":
            base_mbps = rng.uniform(0.5, 2.0)
        else:
            app_types = {"video": 5.0, "gaming": 10.0, "browsing": 2.0}
            app = rng.choice(list(app_types.keys()))
            base_mbps = app_types[app] * (1.0 + rng.uniform(0.0, 0.5))
        self.demand = float(base_mbps)

    def generate_task(self, rng, heavy_ratio, ue_cpu,
                      heavy_cyc_range, heavy_data_range,
                      light_cyc_range, light_data_range):
        """
        Assign a compute task to this user.

        heavy_ratio : fraction of users that get heavy (offload-mandatory) tasks
        ue_cpu      : UE local compute budget (cycles/step)
        *_range     : (lo, hi) for task cycles / input-data Mbit
        """
        if rng.random() < heavy_ratio:
            self.task_type = "heavy"    # MUST offload
            self.task_cycles = float(rng.uniform(*heavy_cyc_range))
            self.task_input_Mbit = float(rng.uniform(*heavy_data_range))
        else:
            self.task_type = "light"    # can run locally
            self.task_cycles = float(rng.uniform(*light_cyc_range))
            self.task_input_Mbit = float(rng.uniform(*light_data_range))
        self.task_offload_mandatory = (self.task_cycles > ue_cpu)

    def calculate_latency_ms(self, num_users_on_channel: float = None):
        """Very simplified base latency model (communication-centric)."""
        if not self.channel or self.data_rate <= 0:
            return 1000.0

        avg_d = np.mean(
            [
                np.linalg.norm(self.location - ch.base_station.location)
                for ch in self.channel
            ]
        )
        prop_delay_ms = (avg_d / 3e8) * 1e3
        proc_delay = 1.0
        sched_delay = 1.0

        if num_users_on_channel is None:
            num_users_on_channel = (
                np.mean([len(ch.users) for ch in self.channel])
                if self.channel
                else 1.0
            )

        queue_delay = 1.0 + num_users_on_channel / (self.data_rate + 1e-6)

        return float(
            np.clip(
                prop_delay_ms + proc_delay + sched_delay + queue_delay,
                0.0,
                1000.0,
            )
        )


# -----------------------
# Main environment class
# -----------------------
class MultiAgentMobileNetwork(MultiAgentEnv):
    """Multi-agent cellular + MEC environment (Gymnasium-style MA API)."""

    metadata = {"render_modes": ["human"], "render_fps": 30}

    def __init__(
        self,
        num_base_stations=4,
        num_users=80,
        num_channels_per_carrier=50,
        area_size=2000.0,
        bs_loc=None,
        max_steps=200,
        mobility_model="manhattan",
        seed=42,
        step_duration_s=1.0,
        deadline_ms=100.0,
        safety_traffic_ratio=0.3,
    ):
        super().__init__()

        # RNGs
        self.seed(seed)

        # topology / sim parameters
        self.num_base_stations = int(num_base_stations)
        self.num_users = int(num_users)
        self.num_channels_per_carrier = int(num_channels_per_carrier)
        self.area_size = float(area_size)
        self.max_steps = int(max_steps)
        self.mobility_model = mobility_model

        # time / QoS
        self.step_duration_s = float(step_duration_s)
        self.deadline_ms = float(deadline_ms)
        self.safety_traffic_ratio = float(
            np.clip(safety_traffic_ratio, 0.0, 1.0)
        )

        # radio parameters
        self.ma_transmission_power = 40000.0  # mW (40 W)
        self.max_ma_channels = int(num_channels_per_carrier)
        self.macro_carrier_frequencies = (
            [3.5e9] if MACRO_REUSE_ONE else [3.4e9, 3.5e9, 3.6e9, 3.7e9]
        )
        self.macro_channel_bw = 180e3  # Hz

        # MEC / compute parameters
        self.mec_cpu_capacity_cycles = 50e9
        self.cycles_per_Mbit = 5e7
        self.cpu_kappa = 1e-27
        self.max_user_demand_Mbps = 10.0

        # ---- Task-model parameters (heterogeneous compute requirements) ----
        # Each user generates a task per step with compute_cycles & input_data.
        # "heavy" tasks EXCEED local UE capacity -> MUST offload to MEC.
        # "light" tasks fit on UE -> can run locally or be offloaded.
        self.heavy_task_ratio = 0.70          # 70% users get heavy tasks
        self.ue_local_cpu_cycles = 0.5e9      # UE compute budget per step (0.5 GHz)
        # Heavy tasks: 1-5 Gcycles  (well above UE capacity)
        self.heavy_task_cycles_range = (0.5e9, 2.5e9)
        self.heavy_task_data_range = (2.0, 8.0)     # input data in Mbit
        # Light tasks: 0.05-0.4 Gcycles (fit on UE)
        self.light_task_cycles_range = (0.05e9, 0.4e9)
        self.light_task_data_range = (0.2, 1.5)      # input data in Mbit
        # Penalty: attempting to run a heavy task locally -> huge delay
        self.local_heavy_penalty_ms = 4000.0

        # reward weights
        self.reward_weights = SimpleNamespace(
            w_lat=0.2,
            w_thr=0.3,
            w_dead=0.2,
            w_qoe=0.3,
            w_eng=0.05,
            w_block=0.2,
            w_fair=0.1,
        )

        # objects
        self.users = []
        self.base_stations = []

        # BS placement
        if bs_loc is None:
            bs_loc = self._default_bs_locations(
                self.num_base_stations, self.area_size
            )
        assert len(bs_loc) >= self.num_base_stations

        for i in range(self.num_base_stations):
            bs = BaseStation(
                i,
                self.ma_transmission_power,
                30.0,
                bs_loc[i],
                type_bs="Ma",
                mec_cpu_capacity_cycles=self.mec_cpu_capacity_cycles,
            )
            self.base_stations.append(bs)

        # build macro channels
        self.macro_channels = []
        ch_id = 0
        for f in self.macro_carrier_frequencies:
            for _ in range(self.num_channels_per_carrier):
                self.macro_channels.append(
                    Channel(
                        ch_id,
                        f,
                        self.macro_channel_bw,
                        noise_figure_db=7.0,
                    )
                )
                ch_id += 1

        # spawn users
        rng = self.np_random
        for u_id in range(self.num_users):
            if self.mobility_model == "manhattan":
                loc, vel = self._spawn_on_grid()
            else:
                loc = rng.uniform(0, self.area_size, 2)
                vel = rng.uniform(-5.0, 5.0, 2)

            u = User(u_id, loc, vel)
            svc = (
                "safety"
                if rng.random() < self.safety_traffic_ratio
                else "infotainment"
            )
            u.service_class = svc
            u.calculate_demand_from_rng(rng)
            u.generate_task(
                rng, self.heavy_task_ratio, self.ue_local_cpu_cycles,
                self.heavy_task_cycles_range, self.heavy_task_data_range,
                self.light_task_cycles_range, self.light_task_data_range,
            )
            self.users.append(u)

            if self.mobility_model == "manhattan":
                self._init_user_manhattan(u)

        # multi-agent API ids
        self.agents = [f"agent_{i}" for i in range(self.num_base_stations)]
        self.possible_agents = list(self.agents)
        self._agent_ids = set(self.agents)

        # action: (power_frac, channel_frac, offload_frac, cpu_frac)
        self.action_spaces = {
            a: gym.spaces.Box(
                low=np.array([0.0, 0.0, 0.0, 0.0], dtype=np.float32),
                high=np.array([1.0, 1.0, 1.0, 1.0], dtype=np.float32),
                dtype=np.float32,
            )
            for a in self.agents
        }

        # 19-D observation
        obs_dim = len(vars(OBS_IDX))
        self.observation_spaces = {
            a: gym.spaces.Box(
                low=0.0, high=1.0, shape=(obs_dim,), dtype=np.float32
            )
            for a in self.agents
        }

        # simulation state
        self.num_steps = 0
        self.current_episode_reward = 0.0
        self.assigned_channels = {}
        self.bs_carrier_frequency = {}

        self._assign_frequency_subsets()
        self.reset_user_info()

        # normalization constants
        self.energy_normalization_J = (
            self.num_base_stations
            * self.ma_transmission_power
            * 1e-3
            * self.step_duration_s
        )
        self.throughput_normalization_Mbps = (
            self.num_users * self.max_user_demand_Mbps
        )

        self.fig = None
        self._panel_axes = None

        # shared spaces for RLlib
        first_agent = self.agents[0]
        self.observation_space = self.observation_spaces[first_agent]
        self.action_space = self.action_spaces[first_agent]

    # -------------
    # RNG helpers
    # -------------
    def seed(self, seed=None):
        if seed is None:
            seed = random.randrange(2**31 - 1)
        seed_int = int(seed) & 0xFFFFFFFF
        self.np_random, _ = seeding.np_random(seed_int)
        random.seed(seed_int)
        np.random.seed(seed_int)
        return [seed_int]

    # -------------
    # Topology helpers
    # -------------
    def _default_bs_locations(self, n, L):
        """Simple grid-based macro deployment."""
        coords = []
        grid = int(math.ceil(math.sqrt(n)))
        xs = np.linspace(0.2 * L, 0.8 * L, grid)
        ys = np.linspace(0.2 * L, 0.8 * L, grid)
        for x in xs:
            for y in ys:
                coords.append((float(x), float(y)))
                if len(coords) >= n:
                    return coords[:n]
        return coords[:n]

    def _assign_frequency_subsets(self):
        """Assign each BS to a carrier (reuse pattern)."""
        idx = 0
        for bs in self.base_stations:
            if MACRO_REUSE_ONE:
                self.bs_carrier_frequency[bs.id] = (
                    self.macro_carrier_frequencies[0]
                )
            else:
                self.bs_carrier_frequency[bs.id] = (
                    self.macro_carrier_frequencies[
                        idx % len(self.macro_carrier_frequencies)
                    ]
                )
                idx += 1

    # -------------
    # Manhattan mobility
    # -------------
    def _build_road_grid(self):
        L = self.area_size
        spacing = max(50.0, float(250.0))
        self.grid_xs = np.arange(0.0, L + 1e-9, spacing)
        self.grid_ys = np.arange(0.0, L + 1e-9, spacing)

    def _spawn_on_grid(self):
        if not hasattr(self, "grid_xs"):
            self._build_road_grid()

        L = self.area_size
        if self.np_random.random() < 0.5:
            # horizontal road
            y = float(self.np_random.choice(self.grid_ys))
            x = float(self.np_random.uniform(0, L))
            dir_axis, dir_sign = "x", (1 if self.np_random.random() < 0.5 else -1)
        else:
            # vertical road
            x = float(self.np_random.choice(self.grid_xs))
            y = float(self.np_random.uniform(0, L))
            dir_axis, dir_sign = "y", (1 if self.np_random.random() < 0.5 else -1)

        speed = float(max(1.0, self.np_random.normal(12.0, 3.0)))
        if dir_axis == "x":
            vel = np.array([dir_sign * speed, 0.0], dtype=float)
        else:
            vel = np.array([0.0, dir_sign * speed], dtype=float)

        return np.array([x, y], dtype=float), vel

    def _init_user_manhattan(self, u: User):
        if not hasattr(self, "grid_xs"):
            self._build_road_grid()

        u.location = self._snap_to_grid(u.location)
        if abs(u.velocity[0]) >= abs(u.velocity[1]):
            u.dir_axis = "x"
            u.dir_sign = 1 if u.velocity[0] >= 0 else -1
        else:
            u.dir_axis = "y"
            u.dir_sign = 1 if u.velocity[1] >= 0 else -1

        u.speed = float(max(1.0, np.linalg.norm(u.velocity)))

        if u.dir_axis == "x":
            candidates = (
                self.grid_xs[self.grid_xs > u.location[0]]
                if u.dir_sign > 0
                else self.grid_xs[self.grid_xs < u.location[0]]
            )
            if u.dir_sign > 0:
                coord = candidates.min() if candidates.size else self.area_size
            else:
                coord = candidates.max() if candidates.size else 0.0
            u.next_intersection = np.array(
                [coord, self._snap_to_grid(u.location)[1]], dtype=float
            )
        else:
            candidates = (
                self.grid_ys[self.grid_ys > u.location[1]]
                if u.dir_sign > 0
                else self.grid_ys[self.grid_ys < u.location[1]]
            )
            if u.dir_sign > 0:
                coord = candidates.min() if candidates.size else self.area_size
            else:
                coord = candidates.max() if candidates.size else 0.0
            u.next_intersection = np.array(
                [self._snap_to_grid(u.location)[0], coord], dtype=float
            )
        u.pause_time = 0

    def _snap_to_grid(self, p):
        if not hasattr(self, "grid_xs"):
            self._build_road_grid()
        x = self.grid_xs[np.argmin(np.abs(self.grid_xs - p[0]))]
        y = self.grid_ys[np.argmin(np.abs(self.grid_ys - p[1]))]
        return np.array([x, y], dtype=float)

    def _advance_user_manhattan(self, u: User):
        if u.pause_time > 0:
            u.pause_time -= 1
            return

        delta = u.next_intersection - u.location
        dist = float(np.linalg.norm(delta))
        step = min(dist, u.speed)
        if dist > 1e-9:
            u.location += (delta / dist) * step

        # reached intersection or step exhausted
        if (
            np.linalg.norm(u.location - u.next_intersection) <= 1e-6
            or step == dist
        ):
            # occasional pause
            if self.np_random.random() < 0.15:
                u.pause_time = int(self.np_random.integers(0, 4))

            # turn decisions
            r = self.np_random.random()
            if r < 0.25:
                u.dir_axis = "y" if u.dir_axis == "x" else "x"
                u.dir_sign = -u.dir_sign
            elif r < 0.5:
                u.dir_axis = "y" if u.dir_axis == "x" else "x"

            u.speed = float(max(1.0, self.np_random.normal(12.0, 3.0)))

            if u.dir_axis == "x":
                if u.dir_sign > 0:
                    candidates = self.grid_xs[self.grid_xs > u.location[0]]
                    x_next = candidates.min() if candidates.size > 0 else self.area_size
                else:
                    candidates = self.grid_xs[self.grid_xs < u.location[0]]
                    x_next = candidates.max() if candidates.size > 0 else 0.0
                u.next_intersection = np.array(
                    [x_next, self._snap_to_grid(u.location)[1]], dtype=float
                )
                u.velocity = np.array([u.dir_sign * u.speed, 0.0], dtype=float)
            else:
                if u.dir_sign > 0:
                    candidates = self.grid_ys[self.grid_ys > u.location[1]]
                    y_next = candidates.min() if candidates.size > 0 else self.area_size
                else:
                    candidates = self.grid_ys[self.grid_ys < u.location[1]]
                    y_next = candidates.max() if candidates.size > 0 else 0.0
                u.next_intersection = np.array(
                    [self._snap_to_grid(u.location)[0], y_next], dtype=float
                )
                u.velocity = np.array([0.0, u.dir_sign * u.speed], dtype=float)

    # -------------
    # User / BS state helpers
    # -------------
    def reset_user_info(self):
        """Per-user association / channel bookkeeping."""
        self.user_info = {
            u.id: {
                "user": u.id,
                "ma_assigned_channel": [],
                "ma_base_station": [],
                "ma_base_station_location": [],
            }
            for u in self.users
        }

    def assign_channels_on_demand(self):
        """UE association and 1-channel assignment per UE to its best BS."""
        for u in self.users:
            u.clear_channel()

        for bs in self.base_stations:
            for ch in bs.assigned_channels:
                ch.users = []

        for u in self.users:
            best_bs, _ = self._best_bs_in_cov(u, type_filter="Ma")
            if best_bs:
                ch = best_bs.find_available_channel()
                if ch:
                    u.channel.append(ch)
                    ch.users.append(u)
                    info = self.user_info[u.id]
                    info["ma_assigned_channel"].append(ch.id)
                    info["ma_base_station"].append(best_bs.id)
                    info["ma_base_station_location"].append(
                        best_bs.location.copy()
                    )

    def _per_channel_tx_power_mW(self, bs: BaseStation):
        if bs.per_channel_power:
            vals = list(bs.per_channel_power.values())
            return float(np.mean(vals))
        n = max(1, len(bs.assigned_channels))
        return bs.transmit_power / n

    def _noise_mW_for(self, bs: BaseStation):
        """Noise (mW) for BS based on reference channel bandwidth."""
        if bs.assigned_channels:
            return bs.assigned_channels[0].calculate_noise_power() * 1e3
        # fallback
        bw_hz = self.macro_channel_bw
        k = 1.380649e-23
        T = 293.15
        NF = 10 ** (7 / 10)
        return k * T * bw_hz * NF * 1e3

    def _est_rate_one_channel_Mbps(self, u: User, bs: BaseStation):
        """Estimated per-channel rate for association decisions."""
        if not bs.assigned_channels:
            return 0.0

        f = self.bs_carrier_frequency[bs.id]
        d = float(np.linalg.norm(u.location - bs.location))
        PL_dB = bs.calculate_path_loss(d, f)

        n_ch = max(1, len(bs.assigned_channels))
        p_ch = bs.transmit_power / n_ch

        g = BEAM_GAIN_DB[bs.type_bs]
        g_tx = 10 ** (g["tx_main"] / 10.0)
        g_rx = 10 ** (g["rx"] / 10.0)

        sig_mW = p_ch * g_tx * g_rx / (10.0 ** (PL_dB / 10.0))
        noise_mW = self._noise_mW_for(bs)

        # ignore inter-cell interference in this quick estimate
        SINR = sig_mW / max(noise_mW, 1e-12)
        SINR_dB = 10.0 * np.log10(max(SINR, 1e-12))

        bw = bs.assigned_channels[0].bandwidth * NR_OVERHEAD
        _, total_se = mimo_rank_and_total_se(
            SINR_dB, MIMO_MAX_RANK[bs.type_bs], gap_db=SNR_GAP_DB, max_se=MAX_SE
        )
        return (bw * total_se) / 1e6

    def _best_bs_in_cov(self, u: User, type_filter=None):
        """Select BS with best rate*fairness score among those covering user."""
        best = None
        best_score = 0.0

        for bs in self.base_stations:
            if type_filter is not None and bs.type_bs != type_filter:
                continue
            if not bs.assigned_channels:
                continue

            d = np.linalg.norm(u.location - bs.location)
            if d > bs.coverage_area:
                continue

            r = self._est_rate_one_channel_Mbps(u, bs)
            load = (
                sum(1 for c in bs.assigned_channels if len(c.users) > 0)
                / max(1, len(bs.assigned_channels))
            )
            fairness = 1.0 - 0.5 * load
            score = r * fairness
            if score > best_score:
                best_score = score
                best = bs

        return best, best_score

    def _estimate_interference_mW(self, u: User, f, exclude_bs: BaseStation):
        """Downlink inter-cell interference (mW) from co-channel BSs."""
        co_bs = [
            b
            for b in self.base_stations
            if b is not exclude_bs and self.bs_carrier_frequency[b.id] == f
        ]
        I = 0.0
        g_rx_int = 10 ** (UE_INTERF_RX_DB / 10.0)

        for bi in co_bs:
            if not bi.assigned_channels:
                continue

            p_i = self._per_channel_tx_power_mW(bi)
            d_i = np.linalg.norm(u.location - bi.location)
            PL_i = bi.calculate_path_loss(d_i, f)

            gi = BEAM_GAIN_DB[bi.type_bs]
            g_tx_i = 10 ** (gi["tx_side"] / 10.0)

            users_in_cov_bi = [
                uu
                for uu in self.users
                if np.linalg.norm(uu.location - bi.location)
                <= bi.coverage_area
            ]
            util = min(
                1.0, len(users_in_cov_bi) / max(1, len(bi.assigned_channels))
            )

            I += (
                util
                * p_i
                * g_tx_i
                * g_rx_int
                / (10.0 ** (PL_i / 10.0))
            )

        return I

    # -------------
    # Water-filling power allocation
    # -------------
    @staticmethod
    def _waterfill(P_total, h_list, n_list, p_floor_list=None, tol=1e-6, max_it=200):
        """Classical water-filling with optional minimum powers (p_floor_list)."""
        K = len(h_list)
        if K == 0:
            return []

        h = np.asarray(h_list, dtype=float)
        n = np.asarray(n_list, dtype=float)
        p_floor = (
            np.zeros(K, dtype=float)
            if p_floor_list is None
            else np.asarray(p_floor_list, dtype=float)
        )

        mask = h > 0
        if not np.any(mask):
            return [0.0] * K

        p_floor_sum = float(np.sum(np.maximum(p_floor, 0.0)))
        if p_floor_sum > P_total and p_floor_sum > 0:
            scaled = P_total * (p_floor / p_floor_sum)
            return list(np.maximum(scaled, 0.0))

        def alloc(lmbd):
            base = 1.0 / max(lmbd, 1e-18)
            out = np.maximum(p_floor, base - n / np.maximum(h, 1e-18))
            return np.maximum(out, 0.0)

        lo, hi = 0.0, 1e12
        for _ in range(max_it):
            mid = 0.5 * (lo + hi)
            p = alloc(mid)
            s = float(np.sum(p))
            if abs(s - P_total) <= tol:
                return list(np.maximum(p, 0.0))
            if s > P_total:
                lo = mid
            else:
                hi = mid

        return list(np.maximum(alloc(hi), 0.0))

    # -------------
    # Core RL API (Gymnasium-style MA)
    # -------------
    def step(self, action_dict):
        """
        Gymnasium-style multi-agent step.

        Returns:
            obs (dict): agent_id -> observation
            rewards (dict): agent_id -> reward (float)
            terminateds (dict): agent_id -> bool, plus "__all__"
            truncateds (dict): agent_id -> bool, plus "__all__"
            infos (dict): agent_id -> info dict
        """
        start_wall = time.time()
        self.num_steps += 1

        # --------- parse / clip actions ----------
        for agent in self.agents:
            if agent not in action_dict:
                action_dict[agent] = np.array(
                    [0.5, 0.5, 0.5, 0.5], dtype=float
                )
            action_dict[agent] = np.clip(
                np.array(action_dict[agent], dtype=float),
                0.0,
                1.0,
            )

        # --------- traffic demand & task update ----------
        for u in self.users:
            if self.np_random.random() < 0.05:
                u.calculate_demand_from_rng(self.np_random)
            # Re-generate task every step (new task arrival each TTI)
            u.generate_task(
                self.np_random, self.heavy_task_ratio, self.ue_local_cpu_cycles,
                self.heavy_task_cycles_range, self.heavy_task_data_range,
                self.light_task_cycles_range, self.light_task_data_range,
            )

        # --------- clear previous associations & channel assignments ----------
        for u in self.users:
            u.clear_channel()

        for bs in self.base_stations:
            bs.clear_assigned_channels()
            # keep MEC queues across steps (do not reset)

        for ch in self.macro_channels:
            ch.users = []
            ch.base_station = None

        self.assigned_channels.clear()
        self.reset_user_info()

        # --------- resource allocation per BS: power, channels, offload, CPU ----------
        for i, bs in enumerate(self.base_stations):
            agent = f"agent_{i}"
            power_frac, channel_frac, offload_frac, cpu_frac = action_dict[
                agent
            ]

            # power allocation
            bs.transmit_power = float(
                np.clip(power_frac, 0.0, 1.0)
            ) * self.ma_transmission_power

            # channel allocation
            max_cap = int(self.max_ma_channels)
            req_ch = int(
                np.rint(
                    float(np.clip(channel_frac, 0.0, 1.0)) * max_cap
                )
            )

            if req_ch == 0 and bs.transmit_power > 1e-9:
                req_ch = 1

            freq = self.bs_carrier_frequency[bs.id]
            avail = [
                c
                for c in self.macro_channels
                if c.frequency == freq and c.base_station is None
            ]
            req_ch = min(len(avail), req_ch)

            if req_ch > 0:
                chosen = avail[:req_ch]
                bs.assign_channels(chosen)
                for ch in chosen:
                    self.assigned_channels[ch] = bs.id

            # MEC-related controls
            bs.offload_frac = float(np.clip(offload_frac, 0.0, 1.0))
            bs.cpu_util_frac = float(np.clip(cpu_frac, 0.0, 1.0))
            bs.last_cpu_used = bs.cpu_util_frac * bs.mec_cpu_capacity

            bs.update_coverage_area_from_power(bs.transmit_power, freq)

        # --------- user association and 1ch-per-user assignment ----------
        self.assign_channels_on_demand()

        # --------- per-BS water-filling ----------
        for bs in self.base_stations:
            bs.per_channel_power = {}
            ch_act = []
            H = []
            N = []
            floors = []

            for ch in bs.assigned_channels:
                if not ch.users:
                    continue

                # simple single-UE-per-channel view (first user)
                u = ch.users[0]
                f = ch.frequency
                d = float(np.linalg.norm(u.location - bs.location))
                PL_dB = bs.calculate_path_loss(d, f)

                g = BEAM_GAIN_DB[bs.type_bs]
                h_linear = (
                    10 ** (g["tx_main"] / 10.0)
                    * 10 ** (g["rx"] / 10.0)
                ) / (10.0 ** (PL_dB / 10.0))

                noise_mW = ch.calculate_noise_power() * 1e3
                I_mW = self._estimate_interference_mW(u, f, bs)

                prio = float(
                    np.clip(
                        0.5 + (u.demand / self.max_user_demand_Mbps),
                        0.5,
                        2.0,
                    )
                )
                N_eff = (noise_mW + I_mW) / prio

                ch_act.append(ch)
                H.append(h_linear)
                N.append(N_eff)
                floors.append(0.0)

            if ch_act:
                P_total = float(bs.transmit_power)
                p_list = self._waterfill(
                    P_total,
                    H,
                    N,
                    p_floor_list=floors,
                    tol=1e-6,
                    max_it=120,
                )
                for ch, p in zip(ch_act, p_list):
                    bs.per_channel_power[ch.id] = float(max(p, 0.0))
            else:
                bs.per_channel_power = {}

            f = self.bs_carrier_frequency[bs.id]
            bs.update_coverage_area_from_power(bs.transmit_power, f)

        # --------- SINR & rates ----------
        for u in self.users:
            self.calculate_SINR(u)
            u.calculate_data_rate()

        # --------- MEC queue dynamics & compute delays (task-aware) ----------
        bs_to_users = defaultdict(list)
        for u in self.users:
            if u.channel:
                bs = u.channel[0].base_station
                if bs is not None:
                    bs_to_users[bs.id].append(u)

        user_comp_delay_ms = {u.id: 0.0 for u in self.users}

        for bs in self.base_stations:
            assoc_users = bs_to_users.get(bs.id, [])

            off_frac = float(np.clip(bs.offload_frac, 0.0, 1.0))
            cpu_frac = float(np.clip(bs.cpu_util_frac, 0.0, 1.0))
            F_max = bs.mec_cpu_capacity
            F_used = cpu_frac * F_max
            bs.last_cpu_used = F_used

            # ---- Partition users into offloaded vs local ----
            offloaded = []       # (user, cycles) pairs sent to MEC
            total_new_cycles = 0.0

            for u in assoc_users:
                C = u.task_cycles  # per-user task compute requirement

                if u.task_offload_mandatory:
                    # Heavy task: MUST offload regardless of off_frac
                    offloaded.append((u, C))
                    total_new_cycles += C
                else:
                    # Light task: agent's off_frac decides
                    if self.np_random.random() < off_frac:
                        offloaded.append((u, C))
                        total_new_cycles += C
                    else:
                        # Run locally on UE — fast for light tasks
                        local_delay_s = C / max(self.ue_local_cpu_cycles, 1e-9)
                        user_comp_delay_ms[u.id] += local_delay_s * 1000.0

            # ---- MEC queue update ----
            q_prev = bs.mec_queue_cycles
            mu_cycles = F_used * self.step_duration_s
            q_after_serv = max(q_prev - mu_cycles, 0.0)
            q_next = q_after_serv + total_new_cycles

            if F_used > 0.0:
                queue_delay_s = q_after_serv / F_used
            else:
                queue_delay_s = (
                    self.deadline_ms / 1000.0 * 10.0
                )

            n_off = len(offloaded)
            for (u, C_cycles) in offloaded:
                if F_used > 0.0 and n_off > 0:
                    f_share = F_used / n_off
                    T_proc_s = C_cycles / max(f_share, 1e-9)
                    T_queue_s = queue_delay_s
                else:
                    T_proc_s = self.deadline_ms / 1000.0 * 10.0
                    T_queue_s = self.deadline_ms / 1000.0 * 10.0

                comp_ms = (T_proc_s + T_queue_s) * 1000.0
                comp_ms = float(np.clip(comp_ms, 0.0, 5000.0))
                user_comp_delay_ms[u.id] += comp_ms

            bs.mec_queue_cycles = float(q_next)

        # ---------------- BS-level throughput for fairness across BSs ----------------
        bs_served = []
        for bs in self.base_stations:
            assoc_users = bs_to_users.get(bs.id, [])
            local_served = sum(
                min(u.data_rate, u.demand) for u in assoc_users
            )
            bs_served.append(local_served)
        bs_served_arr = np.asarray(bs_served, dtype=float)
        if np.any(bs_served_arr > 0):
            jain_num_bs = float(np.sum(bs_served_arr) ** 2)
            jain_den_bs = float(
                len(bs_served_arr) * np.sum(bs_served_arr**2) + 1e-9
            )
            jain_fairness_bs = float(jain_num_bs / jain_den_bs)
        else:
            jain_fairness_bs = 0.0

        # --------- QoE metrics: throughput, latency, energy, fairness ----------
        served_rates = []
        latencies = []
        qoe_list = []
        deadline_hits = 0
        deadline_candidates = 0

        svc_stats = {
            "safety": {
                "served_rates": [],
                "latencies": [],
                "qoes": [],
                "deadline_hits": 0,
                "deadline_candidates": 0,
            },
            "infotainment": {
                "served_rates": [],
                "latencies": [],
                "qoes": [],
                "deadline_hits": 0,
                "deadline_candidates": 0,
            },
        }

        for u in self.users:
            svc = getattr(u, "service_class", "infotainment")

            served = min(u.data_rate, u.demand)
            served_rates.append(served)

            bucket = svc_stats.get(svc, None)
            if bucket is not None:
                bucket["served_rates"].append(served)

            base_lat = u.calculate_latency_ms()
            lat = base_lat + user_comp_delay_ms.get(u.id, 0.0)
            latencies.append(lat)
            if bucket is not None:
                bucket["latencies"].append(lat)

            if u.demand > 0:
                deadline_candidates += 1
                if lat <= self.deadline_ms:
                    deadline_hits += 1

                if bucket is not None:
                    bucket["deadline_candidates"] += 1
                    if lat <= self.deadline_ms:
                        bucket["deadline_hits"] += 1

            if u.demand > 0:
                thr_norm = np.clip(served / u.demand, 0.0, 1.0)
            else:
                thr_norm = 0.0
            if lat <= self.deadline_ms:
                lat_factor = 1.0
            else:
                lat_factor = max(
                    0.0,
                    1.0 - (lat - self.deadline_ms) / (5 * self.deadline_ms),
                )
            qoe = 0.5 * thr_norm + 0.5 * lat_factor
            qoe_clipped = float(np.clip(qoe, 0.0, 1.0))
            qoe_list.append(qoe_clipped)
            if bucket is not None:
                bucket["qoes"].append(qoe_clipped)

        # throughput metrics (Mbps)
        total_throughput_Mbps = float(np.sum(served_rates))
        avg_throughput_Mbps = float(
            total_throughput_Mbps / max(1, self.num_users)
        )

        # latency metrics
        if latencies:
            avg_latency_ms = float(np.mean(latencies))
            p95_latency_ms = float(np.percentile(latencies, 95))
        else:
            avg_latency_ms = 0.0
            p95_latency_ms = 0.0

        # deadline satisfaction
        if deadline_candidates > 0:
            deadline_satisfaction = float(
                deadline_hits / max(1, deadline_candidates)
            )
        else:
            deadline_satisfaction = 0.0

        # fairness (Jain's index) over users (for logging only)
        served_arr = np.asarray(served_rates, dtype=float)
        if np.any(served_arr > 0):
            jain_num_users = float(np.sum(served_arr) ** 2)
            jain_den_users = float(
                len(served_arr) * np.sum(served_arr**2) + 1e-9
            )
            jain_fairness_users = float(jain_num_users / jain_den_users)
        else:
            jain_fairness_users = 0.0

        # Use BS-level fairness in the reward
        jain_fairness = jain_fairness_bs

        # energy metrics
        total_radio_power_mW = float(
            np.sum([bs.transmit_power for bs in self.base_stations])
        )
        total_cpu_power_W = float(
            np.sum(
                [self.cpu_kappa * (bs.last_cpu_used**3) for bs in self.base_stations]
            )
        )
        step_energy_J = (
            total_radio_power_mW * 1e-3 * self.step_duration_s
            + total_cpu_power_W * self.step_duration_s
        )

        satisfied_tasks = deadline_hits
        if satisfied_tasks > 0:
            energy_per_task_J = float(step_energy_J / satisfied_tasks)
        else:
            energy_per_task_J = 0.0

        # blocking rate: users without any channel
        blocked_users = [u for u in self.users if not u.channel]
        blocking_rate = float(len(blocked_users) / max(1, self.num_users))

        # QoE statistics
        if qoe_list:
            avg_qoe = float(np.mean(qoe_list))
        else:
            avg_qoe = 0.0

        # ---------------- service-class metrics (for ITS-oriented analysis) ----------------
        def _svc_metrics(bucket):
            if not bucket["served_rates"]:
                return {
                    "avg_throughput_Mbps": 0.0,
                    "avg_latency_ms": 0.0,
                    "p95_latency_ms": 0.0,
                    "deadline_satisfaction": 0.0,
                    "avg_qoe": 0.0,
                }
            s_rates = np.asarray(bucket["served_rates"], dtype=float)
            lats = np.asarray(bucket["latencies"], dtype=float)
            qoes = np.asarray(bucket["qoes"], dtype=float)

            if lats.size > 0:
                avg_lat = float(np.mean(lats))
                p95_lat = float(np.percentile(lats, 95))
            else:
                avg_lat = 0.0
                p95_lat = 0.0

            if s_rates.size > 0:
                avg_tput = float(np.mean(s_rates))
            else:
                avg_tput = 0.0

            if bucket["deadline_candidates"] > 0:
                ds = float(
                    bucket["deadline_hits"]
                    / max(1, bucket["deadline_candidates"])
                )
            else:
                ds = 0.0

            if qoes.size > 0:
                avg_qoe_svc = float(np.mean(qoes))
            else:
                avg_qoe_svc = 0.0

            return {
                "avg_throughput_Mbps": avg_tput,
                "avg_latency_ms": avg_lat,
                "p95_latency_ms": p95_lat,
                "deadline_satisfaction": ds,
                "avg_qoe": avg_qoe_svc,
            }

        svc_safety = _svc_metrics(svc_stats["safety"])
        svc_infot = _svc_metrics(svc_stats["infotainment"])

        # ---------------- Normalized components (for logging) ----------------
        U_norm = float(
            np.clip(
                total_throughput_Mbps
                / max(1e-9, self.throughput_normalization_Mbps),
                0.0,
                1.0,
            )
        )

        if latencies:
            violations = [
                max(lat - self.deadline_ms, 0.0)
                / (5.0 * max(1.0, self.deadline_ms))
                for lat in latencies
            ]
            D_norm = float(np.clip(np.mean(violations), 0.0, 1.0))
        else:
            D_norm = 0.0

        E_norm = float(
            np.clip(
                step_energy_J / max(1e-9, 2.0 * self.energy_normalization_J),
                0.0,
                1.0,
            )
        )

        # ------------- Joint latency + throughput reward ----------------
        latency_ref_ms = self.deadline_ms if self.deadline_ms > 0 else 100.0

        if latency_ref_ms > 0:
            L_mean = avg_latency_ms / latency_ref_ms
            L_p95 = p95_latency_ms / (1.5 * latency_ref_ms)
        else:
            L_mean = 0.0
            L_p95 = 0.0

        L_norm = float(np.clip(0.7 * L_mean + 0.3 * L_p95, 0.0, 1.0))

        T_norm = U_norm
        V_fair = 1.0 - jain_fairness

        w = self.reward_weights
        positive = (
            w.w_thr * T_norm
            + w.w_lat * (1.0 - D_norm)
            + w.w_dead * deadline_satisfaction
            + w.w_qoe * avg_qoe
        )
        negative = (
            w.w_eng * E_norm
            + w.w_block * blocking_rate
            + w.w_fair * V_fair
        )
        global_reward = float(np.clip(positive - negative, -1.0, 1.0))

        rewards = {agent: global_reward for agent in self.agents}

        scenario_type = "urban" if self.mobility_model == "manhattan" else "highway_like"

        # --------- per-BS infos ----------
        infos = {}
        association_fractions = []
        channel_rewards = []

        for i, bs in enumerate(self.base_stations):
            agent = f"agent_{i}"
            users_in_cov = [
                u
                for u in self.users
                if np.linalg.norm(u.location - bs.location)
                <= bs.coverage_area
            ]
            assoc_users = [
                u
                for u in users_in_cov
                if any(ch.base_station == bs for ch in u.channel)
            ]

            assoc_frac = (
                len(assoc_users) / max(1, len(users_in_cov))
                if users_in_cov
                else 0.0
            )
            association_fractions.append(assoc_frac)

            ch_num = max(1, len(bs.assigned_channels))
            usr_num = max(1, len(users_in_cov))
            channel_rewards.append(
                1.0 - abs(ch_num - usr_num) / (ch_num + usr_num)
            )

            local_served = sum(
                min(u.data_rate, u.demand) for u in assoc_users
            )
            local_demand = sum(u.demand for u in assoc_users) + 1e-9
            local_util = (
                local_served / local_demand if local_demand > 0 else 0.0
            )

            if assoc_users:
                loc_latencies = [
                    latencies[self.users.index(u)] for u in assoc_users
                ]
                loc_avg_lat_ms = float(np.mean(loc_latencies))
            else:
                loc_avg_lat_ms = 0.0

            infos[agent] = {
                "local_data_rate_Mbps": float(
                    sum(u.data_rate for u in assoc_users)
                ),
                "local_served_throughput_Mbps": float(local_served),
                "local_demand_Mbps": float(local_demand),
                "local_power_mW": float(bs.transmit_power),
                "local_channels": int(len(bs.assigned_channels)),
                "users_in_cov": int(len(users_in_cov)),
                "assoc_users": int(len(assoc_users)),
                "local_avg_latency_ms": loc_avg_lat_ms,
                "local_util": float(local_util),
                "local_mec_queue_cycles": float(bs.mec_queue_cycles),
                "local_cpu_used_cycles_per_s": float(bs.last_cpu_used),
                "local_offload_frac": float(bs.offload_frac),
                "local_cpu_util_frac": float(bs.cpu_util_frac),
            }

        if association_fractions:
            mean_assoc_frac = float(np.mean(association_fractions))
        else:
            mean_assoc_frac = 0.0

        if channel_rewards:
            mean_channel_reward = float(np.mean(channel_rewards))
        else:
            mean_channel_reward = 0.0

        global_info = {
            "total_throughput_Mbps": total_throughput_Mbps,
            "avg_throughput_Mbps": avg_throughput_Mbps,
            "avg_latency_ms": avg_latency_ms,
            "p95_latency_ms": p95_latency_ms,
            "deadline_satisfaction": deadline_satisfaction,
            "blocking_rate": blocking_rate,
            "avg_qoe": avg_qoe,
            "qoe_per_user": qoe_list,
            "total_radio_power_mW": total_radio_power_mW,
            "total_cpu_power_W": total_cpu_power_W,
            "step_energy_J": step_energy_J,
            "energy_per_task_J": energy_per_task_J,
            "jain_fairness": jain_fairness,
            "jain_fairness_bs": jain_fairness_bs,
            "jain_fairness_users": jain_fairness_users,
            "num_users": int(self.num_users),
            "num_base_stations": int(self.num_base_stations),
            "mean_assoc_frac": mean_assoc_frac,
            "mean_channel_reward": mean_channel_reward,
            "env_step_walltime_ms": float(
                (time.time() - start_wall) * 1e3
            ),
            "U_norm": U_norm,
            "D_norm": D_norm,
            "E_norm": E_norm,
            "L_norm": L_norm,
            "V_fair": V_fair,
            "global_reward": global_reward,
            "reward_w_lat": self.reward_weights.w_lat,
            "reward_w_thr": self.reward_weights.w_thr,
            "reward_w_dead": self.reward_weights.w_dead,
            "reward_w_qoe": self.reward_weights.w_qoe,
            "reward_w_eng": self.reward_weights.w_eng,
            "reward_w_block": self.reward_weights.w_block,
            "reward_w_fair": self.reward_weights.w_fair,
            "scenario_type": scenario_type,
            "svc_safety_avg_throughput_Mbps": svc_safety["avg_throughput_Mbps"],
            "svc_safety_avg_latency_ms": svc_safety["avg_latency_ms"],
            "svc_safety_p95_latency_ms": svc_safety["p95_latency_ms"],
            "svc_safety_deadline_satisfaction": svc_safety["deadline_satisfaction"],
            "svc_safety_avg_qoe": svc_safety["avg_qoe"],
            "svc_infotainment_avg_throughput_Mbps": svc_infot["avg_throughput_Mbps"],
            "svc_infotainment_avg_latency_ms": svc_infot["avg_latency_ms"],
            "svc_infotainment_p95_latency_ms": svc_infot["p95_latency_ms"],
            "svc_infotainment_deadline_satisfaction": svc_infot["deadline_satisfaction"],
            "svc_infotainment_avg_qoe": svc_infot["avg_qoe"],
            "qoe_safety": svc_stats["safety"]["qoes"],
            "qoe_infotainment": svc_stats["infotainment"]["qoes"],
        }

        for agent in self.agents:
            infos[agent].update(global_info)

        self.current_episode_reward += global_reward

        # Gymnasium-style: terminateds / truncateds
        done_all = self.num_steps >= self.max_steps

        terminateds = {agent: False for agent in self.agents}
        truncateds = {agent: done_all for agent in self.agents}
        terminateds["__all__"] = False
        truncateds["__all__"] = done_all

        obs = self.get_observation()
        self.update_user_location()

        # step() -> obs, rewards, terminateds, truncateds, infos
        return obs, rewards, terminateds, truncateds, infos

    def reset(self, *, seed=None, options=None):
        """
        Gymnasium-style reset.

        Returns:
            obs (dict): agent_id -> observation
            infos (dict): agent_id -> info dict (empty at reset)
        """
        if seed is not None:
            self.seed(seed)

        self.num_steps = 0
        self.current_episode_reward = 0.0

        # reset users
        for u in self.users:
            if self.mobility_model == "manhattan":
                loc, vel = self._spawn_on_grid()
                u.location = loc
                u.velocity = vel
                self._init_user_manhattan(u)
            else:
                u.location = self.np_random.uniform(0, self.area_size, 2)
                u.waypoint = self.np_random.uniform(0, self.area_size, 2)

            svc = (
                "safety"
                if self.np_random.random() < self.safety_traffic_ratio
                else "infotainment"
            )
            u.service_class = svc
            u.calculate_demand_from_rng(self.np_random)
            u.generate_task(
                self.np_random, self.heavy_task_ratio, self.ue_local_cpu_cycles,
                self.heavy_task_cycles_range, self.heavy_task_data_range,
                self.light_task_cycles_range, self.light_task_data_range,
            )

            u.data_rate = 0.0
            u.SINR = -100.0
            u.clear_channel()

        # reset channels & BSs
        for ch in self.macro_channels:
            ch.users = []
            ch.base_station = None

        self.assigned_channels.clear()

        for bs in self.base_stations:
            bs.clear_assigned_channels()
            bs.transmit_power = self.ma_transmission_power
            bs.mec_queue_cycles = 0.0
            bs.offload_frac = 1.0
            bs.cpu_util_frac = 1.0
            bs.last_cpu_used = bs.mec_cpu_capacity

        # simple initial allocation: 1 channel per BS if available
        for bs in self.base_stations:
            freq = self.bs_carrier_frequency[bs.id]
            avail = [
                c
                for c in self.macro_channels
                if c.frequency == freq and c.base_station is None
            ]
            if avail:
                chosen = [avail[0]]
                bs.assign_channels(chosen)
                self.assigned_channels[avail[0]] = bs.id
            bs.update_coverage_area_from_power(
                bs.transmit_power, self.bs_carrier_frequency[bs.id]
            )

        self.reset_user_info()
        self.prev_assoc_by_user = {u.id: {"Ma": None} for u in self.users}

        obs = self.get_observation()
        infos = {agent: {} for agent in self.agents}
        return obs, infos

    # -------------
    # Observation & global state
    # -------------
    def get_observation(self):
        obs = {}
        max_speed = 25.0

        for i, bs in enumerate(self.base_stations):
            agent = f"agent_{i}"
            users_in_cov = [
                u
                for u in self.users
                if np.linalg.norm(u.location - bs.location)
                <= bs.coverage_area
            ]

            max_power = self.ma_transmission_power
            max_ch_for_bs = float(max(1, self.max_ma_channels))

            bs_type = 0.5
            tx_norm = np.clip(bs.transmit_power / max_power, 0.0, 1.0)

            used = sum(1 for c in bs.assigned_channels if len(c.users) > 0)
            ch_util = np.clip(used / max_ch_for_bs, 0.0, 1.0)

            cov_util = len(users_in_cov) / max(1, self.num_users)

            load_ratio = (
                len(users_in_cov)
                / max(1, len(bs.assigned_channels))
                if bs.assigned_channels
                else 0.0
            )
            load_ratio_norm = float(np.clip(load_ratio / 2.0, 0.0, 1.0))

            nearby_pot = len(
                [
                    u
                    for u in self.users
                    if np.linalg.norm(u.location - bs.location)
                    <= bs.coverage_area * 1.5
                ]
            ) / max(1, self.num_users)

            avg_speed = np.clip(
                (
                    sum(u.speed for u in users_in_cov) / len(users_in_cov)
                    if users_in_cov
                    else 0.0
                )
                / max_speed,
                0.0,
                1.0,
            )

            # approximate required power so that edge user meets SNR target
            if users_in_cov:
                max_dist = max(
                    np.linalg.norm(u.location - bs.location)
                    for u in users_in_cov
                )
                req_p_per_ch = self.calculate_required_power_for_distance(
                    max_dist, bs
                )
                req_total = req_p_per_ch * max(
                    1, len(bs.assigned_channels)
                )
            else:
                req_total = 0.0

            req_p_norm = np.clip(
                req_total / max_power if max_power > 0 else 0.0, 0.0, 1.0
            )

            # radial velocity statistics
            avg_radial_v = 0.5
            if users_in_cov:
                comps = []
                for u in users_in_cov:
                    vec = bs.location - u.location
                    dist = np.linalg.norm(vec)
                    if dist > 1e-6:
                        comp = np.dot(u.velocity, vec / dist)
                        comps.append(comp)
                if comps:
                    avg_radial = float(np.mean(comps))
                    avg_radial_v = float(
                        np.clip((avg_radial / max_speed + 1) / 2.0, 0.0, 1.0)
                    )

            sp_var = np.clip(
                np.var([u.speed for u in users_in_cov])
                / ((max_speed**2) / 4.0)
                if len(users_in_cov) > 1
                else 0.0,
                0.0,
                1.0,
            )

            # coarse interference estimate
            f = self.bs_carrier_frequency[bs.id]
            co_bs = [
                o
                for o in self.base_stations
                if o is not bs and self.bs_carrier_frequency[o.id] == f
            ]

            sampled_users = users_in_cov[: min(len(users_in_cov), 8)]
            I_b = 0.0
            g_rx = 10.0 ** (UE_INTERF_RX_DB / 10.0)

            for b2 in co_bs:
                if not b2.assigned_channels:
                    continue
                p_i = self._per_channel_tx_power_mW(b2)
                gi = BEAM_GAIN_DB[b2.type_bs]
                g_tx_i = 10.0 ** (gi["tx_side"] / 10.0)

                users_in_cov_b2 = [
                    uu
                    for uu in self.users
                    if np.linalg.norm(uu.location - b2.location)
                    <= b2.coverage_area
                ]
                util = min(
                    1.0,
                    len(users_in_cov_b2) / max(1, len(b2.assigned_channels)),
                )

                if sampled_users:
                    acc = 0.0
                    for uu in sampled_users:
                        d_i = np.linalg.norm(uu.location - b2.location)
                        PL_i = b2.calculate_path_loss(d_i, f)
                        acc += (
                            p_i
                            * g_tx_i
                            * g_rx
                            / (10.0 ** (PL_i / 10.0))
                        )
                    I_b += util * (acc / len(sampled_users))

            I_dBm = 10.0 * np.log10(max(I_b, 1e-12))
            inter_norm = np.clip((I_dBm + 120.0) / 120.0, 0.0, 1.0)

            avg_demand_norm = (
                float(
                    np.clip(
                        np.mean(
                            [u.demand for u in users_in_cov]
                        )
                        / self.max_user_demand_Mbps,
                        0.0,
                        1.0,
                    )
                )
                if users_in_cov
                else 0.0
            )

            neigh = [
                o.transmit_power / max(1.0, self.ma_transmission_power)
                for o in self.base_stations
                if o is not bs
                and np.linalg.norm(bs.location - o.location) < 1000.0
            ]
            neighbor_tx_norm = float(np.mean(neigh)) if neigh else 0.0

            mec_queue_norm = float(
                np.clip(
                    bs.mec_queue_cycles
                    / max(
                        1.0,
                        bs.mec_cpu_capacity
                        * self.step_duration_s
                        * 10.0,
                    ),
                    0.0,
                    1.0,
                )
            )
            cpu_util_norm = float(
                np.clip(
                    bs.last_cpu_used / max(1.0, bs.mec_cpu_capacity),
                    0.0,
                    1.0,
                )
            )
            offload_norm = float(np.clip(bs.offload_frac, 0.0, 1.0))

            assoc_users = [
                u
                for u in users_in_cov
                if any(ch.base_station == bs for ch in u.channel)
            ]

            if assoc_users:
                local_served = sum(
                    min(u.data_rate, u.demand) for u in assoc_users
                )
                max_served = len(assoc_users) * self.max_user_demand_Mbps
                served_ratio_norm = float(
                    np.clip(
                        local_served / max(1e-9, max_served),
                        0.0,
                        1.0,
                    )
                )
            else:
                served_ratio_norm = 0.0

            if users_in_cov:
                blocked_local = len(
                    [
                        u
                        for u in users_in_cov
                        if not any(ch.base_station == bs for ch in u.channel)
                    ]
                )
                block_frac_norm = float(
                    np.clip(
                        blocked_local / max(1, len(users_in_cov)), 0.0, 1.0
                    )
                )
            else:
                block_frac_norm = 0.0

            ch_num = len(bs.assigned_channels)
            usr_num = len(users_in_cov)
            if ch_num + usr_num > 0:
                ch_match_norm = float(
                    1.0
                    - min(1.0, abs(ch_num - usr_num) / (ch_num + usr_num))
                )
            else:
                ch_match_norm = 1.0

            # fraction of covered users whose tasks MUST be offloaded
            if users_in_cov:
                offload_mand_frac = float(
                    np.mean([1.0 if u.task_offload_mandatory else 0.0
                             for u in users_in_cov])
                )
            else:
                offload_mand_frac = 0.0

            vec_obs = np.array(
                [
                    bs_type,
                    tx_norm,
                    ch_util,
                    cov_util,
                    load_ratio_norm,
                    nearby_pot,
                    avg_speed,
                    req_p_norm,
                    avg_radial_v,
                    sp_var,
                    neighbor_tx_norm,
                    avg_demand_norm,
                    inter_norm,
                    mec_queue_norm,
                    cpu_util_norm,
                    offload_norm,
                    served_ratio_norm,
                    block_frac_norm,
                    ch_match_norm,
                    offload_mand_frac,
                ],
                dtype=np.float32,
            )
            obs[agent] = vec_obs

        return obs

    def get_global_state(self):
        """Optional centralized critic state."""
        per_bs = []
        for bs in self.base_stations:
            users_in_cov = [
                u
                for u in self.users
                if np.linalg.norm(u.location - bs.location)
                <= bs.coverage_area
            ]
            assoc_users = [
                u
                for u in users_in_cov
                if any(ch.base_station == bs for ch in u.channel)
            ]
            mean_rate = (
                float(np.mean([u.data_rate for u in assoc_users]))
                if assoc_users
                else 0.0
            )
            served_frac = (
                float(
                    sum(
                        min(u.data_rate, u.demand) for u in assoc_users
                    )
                    / max(
                        1e-9,
                        sum(u.demand for u in assoc_users),
                    )
                )
                if assoc_users
                else 0.0
            )
            per_bs.extend(
                [
                    bs.transmit_power,
                    len(bs.assigned_channels),
                    mean_rate,
                    served_frac,
                    bs.mec_queue_cycles,
                    bs.last_cpu_used,
                ]
            )
        return np.array(per_bs, dtype=np.float32)

    # -------------
    # PHY helpers
    # -------------
    def calculate_SINR(self, user: User):
        """Populate user.channel_SINR and aggregate SINR."""
        user.channel_SINR = []
        user.SINR = -100.0

        for ch in user.channel:
            bs = ch.base_station
            if bs is None:
                user.channel_SINR.append(-100.0)
                continue

            d = np.linalg.norm(user.location - bs.location)
            PL_dB = bs.calculate_path_loss(d, ch.frequency)

            p_tx_ch = bs.per_channel_power.get(ch.id, None)
            if p_tx_ch is None:
                n = max(1, len(bs.assigned_channels))
                p_tx_ch = bs.transmit_power / n

            g = BEAM_GAIN_DB[bs.type_bs]
            g_tx_main = 10.0 ** (g["tx_main"] / 10.0)
            g_rx_sig = 10.0 ** (g["rx"] / 10.0)

            signal_mW = (
                p_tx_ch * g_tx_main * g_rx_sig / (10.0 ** (PL_dB / 10.0))
            )

            interference_mW = self._estimate_interference_mW(
                user, ch.frequency, bs
            )
            noise_mW = ch.calculate_noise_power() * 1e3

            denom = max(interference_mW + noise_mW, 1e-15)
            SINR_lin = signal_mW / denom if signal_mW > 0 else 0.0
            if SINR_lin > 0:
                SINR_dB = 10.0 * np.log10(SINR_lin)
            else:
                SINR_dB = -100.0

            SINR_dB = float(np.clip(SINR_dB, -100.0, 60.0))
            user.channel_SINR.append(SINR_dB)

        if user.channel_SINR:
            s_ma = np.mean([10.0 ** (x / 10.0) for x in user.channel_SINR])
            user.SINR = 10.0 * np.log10(s_ma) if s_ma > 0 else -100.0
        else:
            user.SINR = -100.0

    def calculate_required_power_for_distance(
        self, distance_m, base_station: BaseStation
    ):
        """Required TX power (mW) so that UE at distance_m hits target SNR."""
        f = self.bs_carrier_frequency[base_station.id]
        pl_dB = base_station.calculate_path_loss(distance_m, f)

        if base_station.assigned_channels:
            bw_hz = base_station.assigned_channels[0].bandwidth
            nf_db = base_station.assigned_channels[0].noise_figure_db
        else:
            bw_hz = self.macro_channel_bw
            nf_db = 7.0

        sens_dBm = rx_sensitivity_dBm(
            bw_hz, nf_db=nf_db, snr_req_db=-5.0
        )
        g = BEAM_GAIN_DB[base_station.type_bs]
        req_tx_dBm = sens_dBm + pl_dB - (g["tx_main"] + g["rx"])

        return 10.0 ** (req_tx_dBm / 10.0)

    # -------------
    # Mobility update
    # -------------
    def update_user_location(self):
        if self.mobility_model == "manhattan":
            if not hasattr(self, "grid_xs"):
                self._build_road_grid()
            for u in self.users:
                self._advance_user_manhattan(u)
                u.location = np.clip(u.location, 0.0, self.area_size)
        else:
            L = self.area_size
            for u in self.users:
                if u.pause_time > 0:
                    u.pause_time -= 1
                    continue

                if u.waypoint is None:
                    u.waypoint = self.np_random.uniform(0, L, 2)

                delta = u.waypoint - u.location
                dist = np.linalg.norm(delta)

                if dist <= u.speed:
                    u.location = u.waypoint
                    u.pause_time = int(self.np_random.integers(0, 10))
                    u.waypoint = self.np_random.uniform(0, L, 2)
                else:
                    direction = delta / dist if dist > 0 else np.zeros(2)
                    u.velocity = direction * u.speed
                    u.location = np.clip(u.location + u.velocity, 0.0, L)

    # -------------
    # Rendering
    # -------------
    def render(self, mode="human"):
        if mode != "human":
            return

        if self.fig is None:
            self.fig, self._panel_axes = plt.subplots(1, 1, figsize=(8, 8))

        ax = self._panel_axes
        ax.clear()

        L = self.area_size
        ax.set_xlim(0, L)
        ax.set_ylim(0, L)
        ax.set_aspect("equal")

        # BSs and coverage
        for bs in self.base_stations:
            circle = plt.Circle(
                (bs.location[0], bs.location[1]),
                bs.coverage_area,
                color="C0",
                alpha=0.12,
            )
            ax.add_patch(circle)
            ax.scatter(
                bs.location[0], bs.location[1], marker="^", c="C0", s=80
            )
            ax.text(
                bs.location[0] + 5,
                bs.location[1] + 5,
                f"BS{bs.id}",
                fontsize=8,
            )

        # users and serving links
        for u in self.users:
            ax.plot(u.location[0], u.location[1], "ro", ms=4)
            for ch in u.channel:
                bs = ch.base_station
                if bs is None:
                    continue
                ax.plot(
                    [u.location[0], bs.location[0]],
                    [u.location[1], bs.location[1]],
                    "k-",
                    lw=0.6,
                    alpha=0.6,
                )

        plt.pause(0.001)

    def close(self):
        try:
            if self.fig is not None:
                plt.close(self.fig)
        except Exception:
            pass
        self.fig = None


# ==========================
# RLlib Callbacks: Episode-wise CSV logging
# ==========================
class EpisodeCSVLogger(DefaultCallbacks):
    """
    Collect scalar 'info' fields over an episode and write episode-wise means to CSV.
    Compatible with EpisodeV2.

    - Uses episode.user_data to accumulate per-step values.
    - On episode end, writes one row to 'ppo_episode_metrics.csv'.
    - Prints total episode return (sum of global_reward over steps).

    It APPENDS to the same CSV file across multiple runs.
    """

    def __init__(self):
        super().__init__()

        # Base directory for CSV (set in __main__ via PPO_CSV_BASE_DIR),
        # default: current working directory.
        base_dir = os.environ.get("PPO_CSV_BASE_DIR", os.getcwd())
        self.csv_path = os.path.join(base_dir, "ppo_episode_metrics.csv")

        # If the file already exists and is non-empty, we reuse its header.
        self.header_written = False
        self.fieldnames = None

        if os.path.exists(self.csv_path):
            try:
                with open(self.csv_path, "r", newline="") as f:
                    reader = csv.reader(f)
                    header = next(reader, None)
                    if header:
                        self.fieldnames = header
                        self.header_written = True
            except Exception:
                # If anything goes wrong, we'll infer fieldnames from first new row.
                self.fieldnames = None
                self.header_written = os.path.getsize(self.csv_path) > 0

    def on_episode_step(
        self, *, worker, base_env, policies, episode, env_index, **kwargs
    ):
        """
        Called every environment step.

        We grab the latest info dict for one agent in the episode and
        accumulate all scalar (int/float) fields in episode.user_data.
        """
        info = None

        # Newer API: EpisodeV2
        if hasattr(episode, "get_agents") and hasattr(episode, "last_info_for"):
            agent_ids = list(episode.get_agents())
            if not agent_ids:
                return
            agent_id = agent_ids[0]
            info = episode.last_info_for(agent_id)

        # Fallback: older API
        elif hasattr(episode, "last_info_for"):
            if hasattr(episode, "agent_ids"):
                agent_ids = list(episode.agent_ids)
                if not agent_ids:
                    return
                agent_id = agent_ids[0]
                info = episode.last_info_for(agent_id)

        if not info:
            return

        # Accumulate only scalar (int/float) fields into user_data
        for k, v in info.items():
            if isinstance(v, (int, float)):
                episode.user_data.setdefault(k, []).append(float(v))

    def on_episode_end(
        self, *, worker, base_env, policies, episode, env_index, **kwargs
    ):
        """
        Called when an episode is done.

        - Computes episode means of all scalar info metrics.
        - Computes total episode return from the 'global_reward' sequence.
        - Prints the total return and logs it to CSV as 'episode_return'.
        """

        # Base row with basic episode stats
        row = {
            "episode_id": episode.episode_id,
            "episode_len": episode.length,
        }

        # Episode-wide means of all scalar info metrics
        for k, values in episode.user_data.items():
            if not values:
                continue
            mean_val = float(np.mean(values))
            row[k] = mean_val
            # Also expose as custom metric in RLlib results
            episode.custom_metrics[k] = mean_val

        # ---- Compute this episode's total return ----
        ep_return = None

        # Prefer: sum of env-provided global_reward over steps
        if "global_reward" in episode.user_data and episode.user_data["global_reward"]:
            ep_return = float(np.sum(episode.user_data["global_reward"]))

        # Optional fallback: try any built-in total_reward attribute
        if ep_return is None and hasattr(episode, "total_reward"):
            try:
                ep_return = float(episode.total_reward)
            except Exception:
                ep_return = None

        if ep_return is not None:
            row["episode_return"] = ep_return
            # Also expose as custom metric
            episode.custom_metrics["episode_return"] = ep_return
            print(
                f"[Episode {episode.episode_id}] total_reward={ep_return:.3f}"
            )

        # ------------------------------------------------------------------
        # CSV writing: always append to the SAME file.
        # ------------------------------------------------------------------

        # Initialize fieldnames from first row if needed
        if self.fieldnames is None:
            self.fieldnames = list(row.keys())

        # Make sure all header fields exist in the row (fill missing with empty)
        for h in self.fieldnames:
            row.setdefault(h, "")

        # Open file in append mode
        with open(self.csv_path, "a", newline="") as f:
            writer = csv.DictWriter(
                f,
                fieldnames=self.fieldnames,
                extrasaction="ignore",
            )
            # Write header only once if the file was empty / header not yet written
            if not self.header_written or os.path.getsize(self.csv_path) == 0:
                writer.writeheader()
                self.header_written = True
            writer.writerow(row)


# ==========================
# RLlib PPO SECTION (Multi-agent, shared policy)
# ==========================
def rllib_env_creator(env_config: dict):
    """RLlib env creator."""
    return MultiAgentMobileNetwork(
        num_base_stations=env_config.get("num_base_stations", 4),
        num_users=env_config.get("num_users", 100),
        num_channels_per_carrier=env_config.get(
            "num_channels_per_carrier", 100
        ),
        area_size=env_config.get("area_size", 5000.0),
        bs_loc=env_config.get(
            "bs_loc",
            [(1250, 1400), (3750, 1400), (1250, 3550), (3750, 3550)],
        ),
        max_steps=env_config.get("max_steps", 200),
        mobility_model=env_config.get("mobility_model", "manhattan"),
        seed=env_config.get("seed", 42),
        step_duration_s=env_config.get("step_duration_s", 1.0),
        deadline_ms=env_config.get("deadline_ms", 100.0),
        safety_traffic_ratio=env_config.get("safety_traffic_ratio", 0.3),
    )


# ==========================
# Main: config + training
# ==========================
if __name__ == "__main__":
    # --------------------------
    # Ensure CSV base dir is the current working directory
    # --------------------------
    base_dir = os.getcwd()
    os.environ["PPO_CSV_BASE_DIR"] = base_dir

    # --------------------------
    # Ray / RLlib initialization
    # --------------------------
    os.environ.setdefault("RAY_DEDUP_LOGS", "1")
    if not ray.is_initialized():
        ray.init(ignore_reinit_error=True)

    ENV_ID = "multi_agent_mobile_network"
    register_env(ENV_ID, rllib_env_creator)

    bs_locs = [(1250, 1400), (3750, 1400), (1250, 3550), (3750, 3550)]

    base_env_config = dict(
        num_base_stations=4,
        num_users=100,
        num_channels_per_carrier=100,
        area_size=5000.0,
        bs_loc=bs_locs,
        max_steps=200,              # episode length in env steps
        mobility_model="manhattan",
        seed=42,
        step_duration_s=1.0,
        deadline_ms=100.0,
        safety_traffic_ratio=0.3,
    )

    # --------------------------
    # PPOConfig for multi-agent
    # --------------------------
    config = PPOConfig()

    # Use the old API stack
    config.enable_rl_module_and_learner = False
    config.enable_env_runner_and_connector_v2 = False

    # Explicit exploration config (PPO default is stochastic sampling anyway)
    exploration_conf = {"type": "StochasticSampling"}
    config.exploration_config = exploration_conf

    # Environment
    config.environment(
        env=ENV_ID,
        env_config=base_env_config,
    )

    # Framework
    config.framework("torch")

    # Env runners (replacement for deprecated rollouts)
    # IMPORTANT: use "auto" to avoid the batch-size vs fragment-length error
    config.env_runners(
        num_env_runners=1,              # was num_rollout_workers
        rollout_fragment_length="auto", # let PPO choose a compatible value
        batch_mode="complete_episodes",
    )

    # Training: PPO-specific hyperparameters (no replay buffer)
    config.training(
        gamma=0.99,
        lr=5e-5,
        lambda_=0.95,
        clip_param=0.2,
        vf_clip_param=10.0,
        train_batch_size=1024,   # unchanged; compatible with rollout_fragment_length="auto"
        use_gae=True,
    )
    # Algorithm-specific parameters
    config.sgd_minibatch_size = 256
    config.num_sgd_iter = 10

    # Resources
    config.resources(num_gpus=0)

    # Normalize continuous actions to env [0,1] Box
    config.normalize_actions = True

    # Multi-agent shared policy
    config.multi_agent(
        policies={
            "shared_policy": PolicySpec(
                config={
                    "exploration_config": exploration_conf,
                }
            )
        },
        policy_mapping_fn=lambda agent_id, *args, **kwargs: "shared_policy",
        policies_to_train=["shared_policy"],
    )

    # Callbacks: episode-wise CSV logging + per-episode reward printing
    config.callbacks(EpisodeCSVLogger)

    # --------------------------
    # Build PPO algorithm (compatible with multiple Ray versions)
    # --------------------------
    if hasattr(config, "build_algo"):
        algo = config.build_algo()
    else:
        algo = config.build()

    # --------------------------
    # Helpers for robust metric extraction
    # --------------------------
    def get_total_env_steps(result_dict):
        """Try several keys used in different RLlib versions for total env steps."""
        for k in [
            "num_env_steps_sampled",
            "num_env_steps_sampled_lifetime",
            "timesteps_total",
        ]:
            v = result_dict.get(k, None)
            if v is not None:
                return int(v)
        return 0

    def get_mean_return_and_len(result_dict):
        """
        Extract mean episode return/length, checking both top-level and env_runners.
        """
        mean_ret = result_dict.get("episode_return_mean", None)
        if mean_ret is None:
            mean_ret = result_dict.get("episode_reward_mean", None)

        mean_len = result_dict.get("episode_len_mean", None)

        env_runners = result_dict.get("env_runners", {})
        if isinstance(env_runners, dict):
            if mean_ret is None or (isinstance(mean_ret, float) and math.isnan(mean_ret)):
                mean_ret = env_runners.get(
                    "episode_return_mean",
                    env_runners.get("episode_reward_mean", mean_ret),
                )
            if mean_len is None or (isinstance(mean_len, float) and math.isnan(mean_len)):
                mean_len = env_runners.get("episode_len_mean", mean_len)

        if mean_ret is None:
            mean_ret = float("nan")
        if mean_len is None:
            mean_len = float("nan")

        return float(mean_ret), float(mean_len)

    # --------------------------
    # Simple training loop
    # --------------------------
    total_target_env_steps = 500_000  # total env steps across all agents
    log_every_iter = 1
    save_every_iter = 10

    total_env_steps = 0
    iter_idx = 0

    while total_env_steps < total_target_env_steps:
        result = algo.train()
        iter_idx += 1

        total_env_steps = get_total_env_steps(result)
        mean_reward, mean_len = get_mean_return_and_len(result)

        if iter_idx % log_every_iter == 0:
            print(
                f"[Iter {iter_idx:04d}] "
                f"env_steps={total_env_steps} | "
                f"episode_return_mean={mean_reward:.3f} | "
                f"episode_len_mean={mean_len:.1f}"
            )

        if iter_idx % save_every_iter == 0:
            chkpt = algo.save()
            # checkpoint object format differs slightly across RLlib versions
            if hasattr(chkpt, "path"):
                chkpt_path = chkpt.path
            elif isinstance(chkpt, dict) and "checkpoint" in chkpt:
                chkpt_path = chkpt["checkpoint"]
            else:
                chkpt_path = str(chkpt)
            # print(f"Checkpoint saved at: {chkpt_path}")

    print("\n✅ Training finished.")
    ray.shutdown()
# Out:
# /home/umb/miniconda3/envs/wr/lib/python3.11/site-packages/ray/rllib/algorithms/algorithm.py:525: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# `UnifiedLogger` will be removed in Ray 2.7.
#   return UnifiedLogger(config, logdir, loggers=None)
# /home/umb/miniconda3/envs/wr/lib/python3.11/site-packages/ray/tune/logger/unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `JsonLogger interface is deprecated in favor of the `ray.tune.json.JsonLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# /home/umb/miniconda3/envs/wr/lib/python3.11/site-packages/ray/tune/logger/unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `CSVLogger interface is deprecated in favor of the `ray.tune.csv.CSVLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# /home/umb/miniconda3/envs/wr/lib/python3.11/site-packages/ray/tune/logger/unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `TBXLogger interface is deprecated in favor of the `ray.tune.tensorboardx.TBXLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# [Iter 0001] env_steps=1200 | episode_return_mean=-78.135 | episode_len_mean=200.0
# [Iter 0002] env_steps=2400 | episode_return_mean=-77.138 | episode_len_mean=200.0
# [Iter 0003] env_steps=3600 | episode_return_mean=-72.329 | episode_len_mean=200.0
# [Iter 0004] env_steps=4800 | episode_return_mean=-66.999 | episode_len_mean=200.0
# [Iter 0005] env_steps=6000 | episode_return_mean=-61.675 | episode_len_mean=200.0
# [Iter 0006] env_steps=7200 | episode_return_mean=-56.528 | episode_len_mean=200.0
# [Iter 0007] env_steps=8400 | episode_return_mean=-52.373 | episode_len_mean=200.0
# [Iter 0008] env_steps=9600 | episode_return_mean=-48.598 | episode_len_mean=200.0
# [Iter 0009] env_steps=10800 | episode_return_mean=-43.674 | episode_len_mean=200.0
# [Iter 0010] env_steps=12000 | episode_return_mean=-39.255 | episode_len_mean=200.0
# [Iter 0011] env_steps=13200 | episode_return_mean=-34.845 | episode_len_mean=200.0
# [Iter 0012] env_steps=14400 | episode_return_mean=-30.612 | episode_len_mean=200.0
# [Iter 0013] env_steps=15600 | episode_return_mean=-26.566 | episode_len_mean=200.0
# [Iter 0014] env_steps=16800 | episode_return_mean=-22.873 | episode_len_mean=200.0
# [Iter 0015] env_steps=18000 | episode_return_mean=-19.385 | episode_len_mean=200.0
# [Iter 0016] env_steps=19200 | episode_return_mean=-16.099 | episode_len_mean=200.0
# [Iter 0017] env_steps=20400 | episode_return_mean=-11.560 | episode_len_mean=200.0
# [Iter 0018] env_steps=21600 | episode_return_mean=-4.380 | episode_len_mean=200.0
# [Iter 0019] env_steps=22800 | episode_return_mean=2.515 | episode_len_mean=200.0
# [Iter 0020] env_steps=24000 | episode_return_mean=8.957 | episode_len_mean=200.0
# [Iter 0021] env_steps=25200 | episode_return_mean=14.539 | episode_len_mean=200.0
# [Iter 0022] env_steps=26400 | episode_return_mean=20.097 | episode_len_mean=200.0
# [Iter 0023] env_steps=27600 | episode_return_mean=25.345 | episode_len_mean=200.0
# [Iter 0024] env_steps=28800 | episode_return_mean=30.108 | episode_len_mean=200.0
# [Iter 0025] env_steps=30000 | episode_return_mean=34.666 | episode_len_mean=200.0
# [Iter 0026] env_steps=31200 | episode_return_mean=38.445 | episode_len_mean=200.0
# [Iter 0027] env_steps=32400 | episode_return_mean=42.292 | episode_len_mean=200.0
# [Iter 0028] env_steps=33600 | episode_return_mean=45.642 | episode_len_mean=200.0
# [Iter 0029] env_steps=34800 | episode_return_mean=48.470 | episode_len_mean=200.0
# [Iter 0030] env_steps=36000 | episode_return_mean=51.454 | episode_len_mean=200.0
# [Iter 0031] env_steps=37200 | episode_return_mean=54.285 | episode_len_mean=200.0
# [Iter 0032] env_steps=38400 | episode_return_mean=56.945 | episode_len_mean=200.0
# [Iter 0033] env_steps=39600 | episode_return_mean=59.309 | episode_len_mean=200.0
# [Iter 0034] env_steps=40800 | episode_return_mean=61.312 | episode_len_mean=200.0
# [Iter 0035] env_steps=42000 | episode_return_mean=63.499 | episode_len_mean=200.0
# [Iter 0036] env_steps=43200 | episode_return_mean=65.368 | episode_len_mean=200.0
# [Iter 0037] env_steps=44400 | episode_return_mean=67.431 | episode_len_mean=200.0
# [Iter 0038] env_steps=45600 | episode_return_mean=69.201 | episode_len_mean=200.0
# [Iter 0039] env_steps=46800 | episode_return_mean=70.968 | episode_len_mean=200.0
# [Iter 0040] env_steps=48000 | episode_return_mean=72.633 | episode_len_mean=200.0
# [Iter 0041] env_steps=49200 | episode_return_mean=74.743 | episode_len_mean=200.0
# [Iter 0042] env_steps=50400 | episode_return_mean=76.440 | episode_len_mean=200.0
# [Iter 0043] env_steps=51600 | episode_return_mean=78.165 | episode_len_mean=200.0
# [Iter 0044] env_steps=52800 | episode_return_mean=79.504 | episode_len_mean=200.0
# [Iter 0045] env_steps=54000 | episode_return_mean=81.155 | episode_len_mean=200.0
# [Iter 0046] env_steps=55200 | episode_return_mean=82.291 | episode_len_mean=200.0
# [Iter 0047] env_steps=56400 | episode_return_mean=83.615 | episode_len_mean=200.0
# [Iter 0048] env_steps=57600 | episode_return_mean=83.994 | episode_len_mean=200.0
# [Iter 0049] env_steps=58800 | episode_return_mean=84.930 | episode_len_mean=200.0
# [Iter 0050] env_steps=60000 | episode_return_mean=85.884 | episode_len_mean=200.0
# [Iter 0051] env_steps=61200 | episode_return_mean=86.609 | episode_len_mean=200.0
# [Iter 0052] env_steps=62400 | episode_return_mean=87.311 | episode_len_mean=200.0
# [Iter 0053] env_steps=63600 | episode_return_mean=88.333 | episode_len_mean=200.0
# [Iter 0054] env_steps=64800 | episode_return_mean=88.811 | episode_len_mean=200.0
# [Iter 0055] env_steps=66000 | episode_return_mean=89.298 | episode_len_mean=200.0
# [Iter 0056] env_steps=67200 | episode_return_mean=89.717 | episode_len_mean=200.0
# [Iter 0057] env_steps=68400 | episode_return_mean=89.997 | episode_len_mean=200.0
# [Iter 0058] env_steps=69600 | episode_return_mean=90.285 | episode_len_mean=200.0
# [Iter 0059] env_steps=70800 | episode_return_mean=90.339 | episode_len_mean=200.0
# [Iter 0060] env_steps=72000 | episode_return_mean=90.458 | episode_len_mean=200.0
# [Iter 0061] env_steps=73200 | episode_return_mean=90.370 | episode_len_mean=200.0
# [Iter 0062] env_steps=74400 | episode_return_mean=90.329 | episode_len_mean=200.0
# [Iter 0063] env_steps=75600 | episode_return_mean=90.612 | episode_len_mean=200.0
# [Iter 0064] env_steps=76800 | episode_return_mean=90.938 | episode_len_mean=200.0
# [Iter 0065] env_steps=78000 | episode_return_mean=91.694 | episode_len_mean=200.0
# [Iter 0066] env_steps=79200 | episode_return_mean=91.918 | episode_len_mean=200.0
# [Iter 0067] env_steps=80400 | episode_return_mean=92.096 | episode_len_mean=200.0
# [Iter 0068] env_steps=81600 | episode_return_mean=92.444 | episode_len_mean=200.0
# [Iter 0069] env_steps=82800 | episode_return_mean=92.533 | episode_len_mean=200.0
# [Iter 0070] env_steps=84000 | episode_return_mean=92.830 | episode_len_mean=200.0
# [Iter 0071] env_steps=85200 | episode_return_mean=92.746 | episode_len_mean=200.0
# [Iter 0072] env_steps=86400 | episode_return_mean=92.730 | episode_len_mean=200.0
# [Iter 0073] env_steps=87600 | episode_return_mean=92.739 | episode_len_mean=200.0
# [Iter 0074] env_steps=88800 | episode_return_mean=93.084 | episode_len_mean=200.0
# [Iter 0075] env_steps=90000 | episode_return_mean=93.292 | episode_len_mean=200.0
# [Iter 0076] env_steps=91200 | episode_return_mean=93.266 | episode_len_mean=200.0
# [Iter 0077] env_steps=92400 | episode_return_mean=93.781 | episode_len_mean=200.0
# [Iter 0078] env_steps=93600 | episode_return_mean=94.335 | episode_len_mean=200.0
# [Iter 0079] env_steps=94800 | episode_return_mean=94.661 | episode_len_mean=200.0
# [Iter 0080] env_steps=96000 | episode_return_mean=94.937 | episode_len_mean=200.0
# [Iter 0081] env_steps=97200 | episode_return_mean=95.160 | episode_len_mean=200.0
# [Iter 0082] env_steps=98400 | episode_return_mean=95.204 | episode_len_mean=200.0
# [Iter 0083] env_steps=99600 | episode_return_mean=95.474 | episode_len_mean=200.0
# [Iter 0084] env_steps=100800 | episode_return_mean=95.666 | episode_len_mean=200.0
# [Iter 0085] env_steps=102000 | episode_return_mean=96.094 | episode_len_mean=200.0
# [Iter 0086] env_steps=103200 | episode_return_mean=96.267 | episode_len_mean=200.0
# [Iter 0087] env_steps=104400 | episode_return_mean=96.713 | episode_len_mean=200.0
# [Iter 0088] env_steps=105600 | episode_return_mean=97.144 | episode_len_mean=200.0
# [Iter 0089] env_steps=106800 | episode_return_mean=97.540 | episode_len_mean=200.0
# [Iter 0090] env_steps=108000 | episode_return_mean=97.894 | episode_len_mean=200.0
# [Iter 0091] env_steps=109200 | episode_return_mean=98.194 | episode_len_mean=200.0
# [Iter 0092] env_steps=110400 | episode_return_mean=98.148 | episode_len_mean=200.0
# [Iter 0093] env_steps=111600 | episode_return_mean=98.616 | episode_len_mean=200.0
# [Iter 0094] env_steps=112800 | episode_return_mean=98.635 | episode_len_mean=200.0
# [Iter 0095] env_steps=114000 | episode_return_mean=98.418 | episode_len_mean=200.0
# [Iter 0096] env_steps=115200 | episode_return_mean=98.719 | episode_len_mean=200.0
# [Iter 0097] env_steps=116400 | episode_return_mean=98.768 | episode_len_mean=200.0
# [Iter 0098] env_steps=117600 | episode_return_mean=98.780 | episode_len_mean=200.0
# [Iter 0099] env_steps=118800 | episode_return_mean=98.577 | episode_len_mean=200.0
# [Iter 0100] env_steps=120000 | episode_return_mean=98.616 | episode_len_mean=200.0
# [Iter 0101] env_steps=121200 | episode_return_mean=98.666 | episode_len_mean=200.0
# [Iter 0102] env_steps=122400 | episode_return_mean=98.795 | episode_len_mean=200.0
# [Iter 0103] env_steps=123600 | episode_return_mean=99.031 | episode_len_mean=200.0
# [Iter 0104] env_steps=124800 | episode_return_mean=99.142 | episode_len_mean=200.0
# [Iter 0105] env_steps=126000 | episode_return_mean=99.261 | episode_len_mean=200.0
# [Iter 0106] env_steps=127200 | episode_return_mean=99.324 | episode_len_mean=200.0
# [Iter 0107] env_steps=128400 | episode_return_mean=99.245 | episode_len_mean=200.0
# [Iter 0108] env_steps=129600 | episode_return_mean=99.353 | episode_len_mean=200.0
# [Iter 0109] env_steps=130800 | episode_return_mean=99.376 | episode_len_mean=200.0
# [Iter 0110] env_steps=132000 | episode_return_mean=99.183 | episode_len_mean=200.0
# [Iter 0111] env_steps=133200 | episode_return_mean=99.414 | episode_len_mean=200.0
# [Iter 0112] env_steps=134400 | episode_return_mean=99.616 | episode_len_mean=200.0
# [Iter 0113] env_steps=135600 | episode_return_mean=99.388 | episode_len_mean=200.0
# [Iter 0114] env_steps=136800 | episode_return_mean=99.384 | episode_len_mean=200.0
# [Iter 0115] env_steps=138000 | episode_return_mean=99.749 | episode_len_mean=200.0
# [Iter 0116] env_steps=139200 | episode_return_mean=99.904 | episode_len_mean=200.0
# [Iter 0117] env_steps=140400 | episode_return_mean=100.006 | episode_len_mean=200.0
# [Iter 0118] env_steps=141600 | episode_return_mean=100.261 | episode_len_mean=200.0
# [Iter 0119] env_steps=142800 | episode_return_mean=100.282 | episode_len_mean=200.0
# [Iter 0120] env_steps=144000 | episode_return_mean=100.013 | episode_len_mean=200.0
# [Iter 0121] env_steps=145200 | episode_return_mean=99.965 | episode_len_mean=200.0
# [Iter 0122] env_steps=146400 | episode_return_mean=99.945 | episode_len_mean=200.0
# [Iter 0123] env_steps=147600 | episode_return_mean=100.102 | episode_len_mean=200.0
# [Iter 0124] env_steps=148800 | episode_return_mean=100.078 | episode_len_mean=200.0
# [Iter 0125] env_steps=150000 | episode_return_mean=100.172 | episode_len_mean=200.0
# [Iter 0126] env_steps=151200 | episode_return_mean=100.520 | episode_len_mean=200.0
# [Iter 0127] env_steps=152400 | episode_return_mean=100.325 | episode_len_mean=200.0
# [Iter 0128] env_steps=153600 | episode_return_mean=100.263 | episode_len_mean=200.0
# [Iter 0129] env_steps=154800 | episode_return_mean=100.492 | episode_len_mean=200.0
# [Iter 0130] env_steps=156000 | episode_return_mean=100.424 | episode_len_mean=200.0
# [Iter 0131] env_steps=157200 | episode_return_mean=100.520 | episode_len_mean=200.0
# [Iter 0132] env_steps=158400 | episode_return_mean=100.406 | episode_len_mean=200.0
# [Iter 0133] env_steps=159600 | episode_return_mean=100.506 | episode_len_mean=200.0
# [Iter 0134] env_steps=160800 | episode_return_mean=100.394 | episode_len_mean=200.0
# [Iter 0135] env_steps=162000 | episode_return_mean=100.122 | episode_len_mean=200.0
# [Iter 0136] env_steps=163200 | episode_return_mean=100.061 | episode_len_mean=200.0
# [Iter 0137] env_steps=164400 | episode_return_mean=100.004 | episode_len_mean=200.0
# [Iter 0138] env_steps=165600 | episode_return_mean=100.256 | episode_len_mean=200.0
# [Iter 0139] env_steps=166800 | episode_return_mean=100.337 | episode_len_mean=200.0
# [Iter 0140] env_steps=168000 | episode_return_mean=100.205 | episode_len_mean=200.0
# [Iter 0141] env_steps=169200 | episode_return_mean=100.133 | episode_len_mean=200.0
# [Iter 0142] env_steps=170400 | episode_return_mean=100.356 | episode_len_mean=200.0
# [Iter 0143] env_steps=171600 | episode_return_mean=100.249 | episode_len_mean=200.0
# [Iter 0144] env_steps=172800 | episode_return_mean=100.294 | episode_len_mean=200.0
# [Iter 0145] env_steps=174000 | episode_return_mean=100.295 | episode_len_mean=200.0
# [Iter 0146] env_steps=175200 | episode_return_mean=100.251 | episode_len_mean=200.0
# [Iter 0147] env_steps=176400 | episode_return_mean=100.124 | episode_len_mean=200.0
# [Iter 0148] env_steps=177600 | episode_return_mean=100.330 | episode_len_mean=200.0
# [Iter 0149] env_steps=178800 | episode_return_mean=100.303 | episode_len_mean=200.0
# [Iter 0150] env_steps=180000 | episode_return_mean=100.204 | episode_len_mean=200.0
# [Iter 0151] env_steps=181200 | episode_return_mean=100.349 | episode_len_mean=200.0
# [Iter 0152] env_steps=182400 | episode_return_mean=100.857 | episode_len_mean=200.0
# [Iter 0153] env_steps=183600 | episode_return_mean=100.983 | episode_len_mean=200.0
# [Iter 0154] env_steps=184800 | episode_return_mean=101.007 | episode_len_mean=200.0
# [Iter 0155] env_steps=186000 | episode_return_mean=101.125 | episode_len_mean=200.0
# [Iter 0156] env_steps=187200 | episode_return_mean=101.233 | episode_len_mean=200.0
# [Iter 0157] env_steps=188400 | episode_return_mean=101.468 | episode_len_mean=200.0
# [Iter 0158] env_steps=189600 | episode_return_mean=101.367 | episode_len_mean=200.0
# [Iter 0159] env_steps=190800 | episode_return_mean=101.136 | episode_len_mean=200.0
# [Iter 0160] env_steps=192000 | episode_return_mean=101.428 | episode_len_mean=200.0
# [Iter 0161] env_steps=193200 | episode_return_mean=101.530 | episode_len_mean=200.0
# [Iter 0162] env_steps=194400 | episode_return_mean=101.775 | episode_len_mean=200.0
# [Iter 0163] env_steps=195600 | episode_return_mean=101.830 | episode_len_mean=200.0
# [Iter 0164] env_steps=196800 | episode_return_mean=102.007 | episode_len_mean=200.0
# [Iter 0165] env_steps=198000 | episode_return_mean=101.731 | episode_len_mean=200.0
# [Iter 0166] env_steps=199200 | episode_return_mean=101.861 | episode_len_mean=200.0
# [Iter 0167] env_steps=200400 | episode_return_mean=101.820 | episode_len_mean=200.0
# [Iter 0168] env_steps=201600 | episode_return_mean=101.785 | episode_len_mean=200.0
# [Iter 0169] env_steps=202800 | episode_return_mean=101.878 | episode_len_mean=200.0
# [Iter 0170] env_steps=204000 | episode_return_mean=101.683 | episode_len_mean=200.0
# [Iter 0171] env_steps=205200 | episode_return_mean=101.870 | episode_len_mean=200.0
# [Iter 0172] env_steps=206400 | episode_return_mean=101.700 | episode_len_mean=200.0
# [Iter 0173] env_steps=207600 | episode_return_mean=101.791 | episode_len_mean=200.0
# [Iter 0174] env_steps=208800 | episode_return_mean=101.881 | episode_len_mean=200.0
# [Iter 0175] env_steps=210000 | episode_return_mean=101.751 | episode_len_mean=200.0
# [Iter 0176] env_steps=211200 | episode_return_mean=101.948 | episode_len_mean=200.0
# [Iter 0177] env_steps=212400 | episode_return_mean=102.291 | episode_len_mean=200.0
# [Iter 0178] env_steps=213600 | episode_return_mean=102.186 | episode_len_mean=200.0
# [Iter 0179] env_steps=214800 | episode_return_mean=102.226 | episode_len_mean=200.0
# [Iter 0180] env_steps=216000 | episode_return_mean=102.336 | episode_len_mean=200.0
# [Iter 0181] env_steps=217200 | episode_return_mean=102.628 | episode_len_mean=200.0
# [Iter 0182] env_steps=218400 | episode_return_mean=102.598 | episode_len_mean=200.0
# [Iter 0183] env_steps=219600 | episode_return_mean=102.626 | episode_len_mean=200.0
# [Iter 0184] env_steps=220800 | episode_return_mean=102.401 | episode_len_mean=200.0
# [Iter 0185] env_steps=222000 | episode_return_mean=102.555 | episode_len_mean=200.0
# [Iter 0186] env_steps=223200 | episode_return_mean=102.709 | episode_len_mean=200.0
# [Iter 0187] env_steps=224400 | episode_return_mean=102.460 | episode_len_mean=200.0
# [Iter 0188] env_steps=225600 | episode_return_mean=102.375 | episode_len_mean=200.0
# [Iter 0189] env_steps=226800 | episode_return_mean=102.553 | episode_len_mean=200.0
# [Iter 0190] env_steps=228000 | episode_return_mean=102.212 | episode_len_mean=200.0
# [Iter 0191] env_steps=229200 | episode_return_mean=102.300 | episode_len_mean=200.0
# [Iter 0192] env_steps=230400 | episode_return_mean=102.473 | episode_len_mean=200.0
# [Iter 0193] env_steps=231600 | episode_return_mean=102.312 | episode_len_mean=200.0
# [Iter 0194] env_steps=232800 | episode_return_mean=101.943 | episode_len_mean=200.0
# [Iter 0195] env_steps=234000 | episode_return_mean=101.752 | episode_len_mean=200.0
# [Iter 0196] env_steps=235200 | episode_return_mean=101.712 | episode_len_mean=200.0
# [Iter 0197] env_steps=236400 | episode_return_mean=101.501 | episode_len_mean=200.0
# [Iter 0198] env_steps=237600 | episode_return_mean=101.346 | episode_len_mean=200.0
# [Iter 0199] env_steps=238800 | episode_return_mean=101.303 | episode_len_mean=200.0
# [Iter 0200] env_steps=240000 | episode_return_mean=101.346 | episode_len_mean=200.0
# [Iter 0201] env_steps=241200 | episode_return_mean=101.639 | episode_len_mean=200.0
# [Iter 0202] env_steps=242400 | episode_return_mean=101.600 | episode_len_mean=200.0
# [Iter 0203] env_steps=243600 | episode_return_mean=101.444 | episode_len_mean=200.0
# [Iter 0204] env_steps=244800 | episode_return_mean=101.713 | episode_len_mean=200.0
# [Iter 0205] env_steps=246000 | episode_return_mean=101.679 | episode_len_mean=200.0
# [Iter 0206] env_steps=247200 | episode_return_mean=101.874 | episode_len_mean=200.0
# [Iter 0207] env_steps=248400 | episode_return_mean=102.151 | episode_len_mean=200.0
# [Iter 0208] env_steps=249600 | episode_return_mean=102.009 | episode_len_mean=200.0
# [Iter 0209] env_steps=250800 | episode_return_mean=101.802 | episode_len_mean=200.0
# [Iter 0210] env_steps=252000 | episode_return_mean=101.905 | episode_len_mean=200.0
# [Iter 0211] env_steps=253200 | episode_return_mean=102.088 | episode_len_mean=200.0
# [Iter 0212] env_steps=254400 | episode_return_mean=102.397 | episode_len_mean=200.0
# [Iter 0213] env_steps=255600 | episode_return_mean=102.461 | episode_len_mean=200.0
# [Iter 0214] env_steps=256800 | episode_return_mean=102.683 | episode_len_mean=200.0
# [Iter 0215] env_steps=258000 | episode_return_mean=102.779 | episode_len_mean=200.0
# [Iter 0216] env_steps=259200 | episode_return_mean=103.205 | episode_len_mean=200.0
# [Iter 0217] env_steps=260400 | episode_return_mean=103.143 | episode_len_mean=200.0
# [Iter 0218] env_steps=261600 | episode_return_mean=103.140 | episode_len_mean=200.0
# [Iter 0219] env_steps=262800 | episode_return_mean=103.137 | episode_len_mean=200.0
# [Iter 0220] env_steps=264000 | episode_return_mean=103.334 | episode_len_mean=200.0
# [Iter 0221] env_steps=265200 | episode_return_mean=103.412 | episode_len_mean=200.0
# [Iter 0222] env_steps=266400 | episode_return_mean=103.631 | episode_len_mean=200.0
# [Iter 0223] env_steps=267600 | episode_return_mean=103.738 | episode_len_mean=200.0
# [Iter 0224] env_steps=268800 | episode_return_mean=103.967 | episode_len_mean=200.0
# [Iter 0225] env_steps=270000 | episode_return_mean=103.906 | episode_len_mean=200.0
# [Iter 0226] env_steps=271200 | episode_return_mean=103.933 | episode_len_mean=200.0
# [Iter 0227] env_steps=272400 | episode_return_mean=104.017 | episode_len_mean=200.0
# [Iter 0228] env_steps=273600 | episode_return_mean=103.924 | episode_len_mean=200.0
# [Iter 0229] env_steps=274800 | episode_return_mean=103.892 | episode_len_mean=200.0
# [Iter 0230] env_steps=276000 | episode_return_mean=104.045 | episode_len_mean=200.0
# [Iter 0231] env_steps=277200 | episode_return_mean=104.060 | episode_len_mean=200.0
# [Iter 0232] env_steps=278400 | episode_return_mean=103.996 | episode_len_mean=200.0
# [Iter 0233] env_steps=279600 | episode_return_mean=103.862 | episode_len_mean=200.0
# [Iter 0234] env_steps=280800 | episode_return_mean=103.884 | episode_len_mean=200.0
# [Iter 0235] env_steps=282000 | episode_return_mean=103.842 | episode_len_mean=200.0
# [Iter 0236] env_steps=283200 | episode_return_mean=103.843 | episode_len_mean=200.0
# [Iter 0237] env_steps=284400 | episode_return_mean=103.791 | episode_len_mean=200.0
# [Iter 0238] env_steps=285600 | episode_return_mean=103.705 | episode_len_mean=200.0
# [Iter 0239] env_steps=286800 | episode_return_mean=103.417 | episode_len_mean=200.0
# [Iter 0240] env_steps=288000 | episode_return_mean=103.245 | episode_len_mean=200.0
# [Iter 0241] env_steps=289200 | episode_return_mean=102.896 | episode_len_mean=200.0
# [Iter 0242] env_steps=290400 | episode_return_mean=103.307 | episode_len_mean=200.0
# [Iter 0243] env_steps=291600 | episode_return_mean=103.523 | episode_len_mean=200.0
# [Iter 0244] env_steps=292800 | episode_return_mean=103.503 | episode_len_mean=200.0
# [Iter 0245] env_steps=294000 | episode_return_mean=103.670 | episode_len_mean=200.0
# [Iter 0246] env_steps=295200 | episode_return_mean=103.411 | episode_len_mean=200.0
# [Iter 0247] env_steps=296400 | episode_return_mean=103.229 | episode_len_mean=200.0
# [Iter 0248] env_steps=297600 | episode_return_mean=103.263 | episode_len_mean=200.0
# [Iter 0249] env_steps=298800 | episode_return_mean=103.302 | episode_len_mean=200.0
# [Iter 0250] env_steps=300000 | episode_return_mean=103.058 | episode_len_mean=200.0
# [Iter 0251] env_steps=301200 | episode_return_mean=103.133 | episode_len_mean=200.0
# [Iter 0252] env_steps=302400 | episode_return_mean=103.192 | episode_len_mean=200.0
# [Iter 0253] env_steps=303600 | episode_return_mean=103.143 | episode_len_mean=200.0
# [Iter 0254] env_steps=304800 | episode_return_mean=103.047 | episode_len_mean=200.0
# [Iter 0255] env_steps=306000 | episode_return_mean=103.110 | episode_len_mean=200.0
# [Iter 0256] env_steps=307200 | episode_return_mean=103.175 | episode_len_mean=200.0
# [Iter 0257] env_steps=308400 | episode_return_mean=103.424 | episode_len_mean=200.0
# [Iter 0258] env_steps=309600 | episode_return_mean=103.599 | episode_len_mean=200.0
# [Iter 0259] env_steps=310800 | episode_return_mean=103.344 | episode_len_mean=200.0
# [Iter 0260] env_steps=312000 | episode_return_mean=103.174 | episode_len_mean=200.0
# [Iter 0261] env_steps=313200 | episode_return_mean=103.257 | episode_len_mean=200.0
# [Iter 0262] env_steps=314400 | episode_return_mean=103.436 | episode_len_mean=200.0
# [Iter 0263] env_steps=315600 | episode_return_mean=103.508 | episode_len_mean=200.0
# [Iter 0264] env_steps=316800 | episode_return_mean=103.627 | episode_len_mean=200.0
# [Iter 0265] env_steps=318000 | episode_return_mean=103.883 | episode_len_mean=200.0
# [Iter 0266] env_steps=319200 | episode_return_mean=103.986 | episode_len_mean=200.0
# [Iter 0267] env_steps=320400 | episode_return_mean=104.135 | episode_len_mean=200.0
# [Iter 0268] env_steps=321600 | episode_return_mean=104.443 | episode_len_mean=200.0
# [Iter 0269] env_steps=322800 | episode_return_mean=104.433 | episode_len_mean=200.0
# [Iter 0270] env_steps=324000 | episode_return_mean=104.351 | episode_len_mean=200.0
# [Iter 0271] env_steps=325200 | episode_return_mean=104.567 | episode_len_mean=200.0
# [Iter 0272] env_steps=326400 | episode_return_mean=104.602 | episode_len_mean=200.0
# [Iter 0273] env_steps=327600 | episode_return_mean=104.771 | episode_len_mean=200.0
# [Iter 0274] env_steps=328800 | episode_return_mean=104.549 | episode_len_mean=200.0
# [Iter 0275] env_steps=330000 | episode_return_mean=104.364 | episode_len_mean=200.0
# [Iter 0276] env_steps=331200 | episode_return_mean=104.263 | episode_len_mean=200.0
# [Iter 0277] env_steps=332400 | episode_return_mean=104.613 | episode_len_mean=200.0
# [Iter 0278] env_steps=333600 | episode_return_mean=104.406 | episode_len_mean=200.0
# [Iter 0279] env_steps=334800 | episode_return_mean=104.674 | episode_len_mean=200.0
# [Iter 0280] env_steps=336000 | episode_return_mean=104.644 | episode_len_mean=200.0
# [Iter 0281] env_steps=337200 | episode_return_mean=104.437 | episode_len_mean=200.0
# [Iter 0282] env_steps=338400 | episode_return_mean=104.518 | episode_len_mean=200.0
# [Iter 0283] env_steps=339600 | episode_return_mean=104.581 | episode_len_mean=200.0
# [Iter 0284] env_steps=340800 | episode_return_mean=104.228 | episode_len_mean=200.0
# [Iter 0285] env_steps=342000 | episode_return_mean=104.262 | episode_len_mean=200.0
# [Iter 0286] env_steps=343200 | episode_return_mean=104.378 | episode_len_mean=200.0
# [Iter 0287] env_steps=344400 | episode_return_mean=104.450 | episode_len_mean=200.0
# [Iter 0288] env_steps=345600 | episode_return_mean=104.264 | episode_len_mean=200.0
# [Iter 0289] env_steps=346800 | episode_return_mean=104.239 | episode_len_mean=200.0
# [Iter 0290] env_steps=348000 | episode_return_mean=104.299 | episode_len_mean=200.0
# [Iter 0291] env_steps=349200 | episode_return_mean=104.311 | episode_len_mean=200.0
# [Iter 0292] env_steps=350400 | episode_return_mean=104.423 | episode_len_mean=200.0
# [Iter 0293] env_steps=351600 | episode_return_mean=104.812 | episode_len_mean=200.0
# [Iter 0294] env_steps=352800 | episode_return_mean=104.802 | episode_len_mean=200.0
# [Iter 0295] env_steps=354000 | episode_return_mean=104.643 | episode_len_mean=200.0
# [Iter 0296] env_steps=355200 | episode_return_mean=104.519 | episode_len_mean=200.0
# [Iter 0297] env_steps=356400 | episode_return_mean=104.754 | episode_len_mean=200.0
# [Iter 0298] env_steps=357600 | episode_return_mean=104.565 | episode_len_mean=200.0
# [Iter 0299] env_steps=358800 | episode_return_mean=104.809 | episode_len_mean=200.0
# [Iter 0300] env_steps=360000 | episode_return_mean=104.783 | episode_len_mean=200.0
# [Iter 0301] env_steps=361200 | episode_return_mean=105.092 | episode_len_mean=200.0
# [Iter 0302] env_steps=362400 | episode_return_mean=105.100 | episode_len_mean=200.0
# [Iter 0303] env_steps=363600 | episode_return_mean=104.915 | episode_len_mean=200.0
# [Iter 0304] env_steps=364800 | episode_return_mean=104.984 | episode_len_mean=200.0
# [Iter 0305] env_steps=366000 | episode_return_mean=104.802 | episode_len_mean=200.0
# [Iter 0306] env_steps=367200 | episode_return_mean=105.092 | episode_len_mean=200.0
# [Iter 0307] env_steps=368400 | episode_return_mean=105.168 | episode_len_mean=200.0
# [Iter 0308] env_steps=369600 | episode_return_mean=105.116 | episode_len_mean=200.0
# [Iter 0309] env_steps=370800 | episode_return_mean=105.409 | episode_len_mean=200.0
# [Iter 0310] env_steps=372000 | episode_return_mean=105.280 | episode_len_mean=200.0
# [Iter 0311] env_steps=373200 | episode_return_mean=105.111 | episode_len_mean=200.0
# [Iter 0312] env_steps=374400 | episode_return_mean=104.906 | episode_len_mean=200.0
# [Iter 0313] env_steps=375600 | episode_return_mean=104.890 | episode_len_mean=200.0
# [Iter 0314] env_steps=376800 | episode_return_mean=104.696 | episode_len_mean=200.0
# [Iter 0315] env_steps=378000 | episode_return_mean=104.890 | episode_len_mean=200.0
# [Iter 0316] env_steps=379200 | episode_return_mean=104.693 | episode_len_mean=200.0
# [Iter 0317] env_steps=380400 | episode_return_mean=104.468 | episode_len_mean=200.0
# [Iter 0318] env_steps=381600 | episode_return_mean=104.454 | episode_len_mean=200.0
# [Iter 0319] env_steps=382800 | episode_return_mean=104.426 | episode_len_mean=200.0
# [Iter 0320] env_steps=384000 | episode_return_mean=104.392 | episode_len_mean=200.0
# [Iter 0321] env_steps=385200 | episode_return_mean=104.604 | episode_len_mean=200.0
# [Iter 0322] env_steps=386400 | episode_return_mean=104.557 | episode_len_mean=200.0
# [Iter 0323] env_steps=387600 | episode_return_mean=104.412 | episode_len_mean=200.0
# [Iter 0324] env_steps=388800 | episode_return_mean=104.460 | episode_len_mean=200.0
# [Iter 0325] env_steps=390000 | episode_return_mean=104.317 | episode_len_mean=200.0
# [Iter 0326] env_steps=391200 | episode_return_mean=104.173 | episode_len_mean=200.0
# [Iter 0327] env_steps=392400 | episode_return_mean=104.274 | episode_len_mean=200.0
# [Iter 0328] env_steps=393600 | episode_return_mean=104.505 | episode_len_mean=200.0
# [Iter 0329] env_steps=394800 | episode_return_mean=104.581 | episode_len_mean=200.0
# [Iter 0330] env_steps=396000 | episode_return_mean=104.701 | episode_len_mean=200.0
# [Iter 0331] env_steps=397200 | episode_return_mean=104.815 | episode_len_mean=200.0
# [Iter 0332] env_steps=398400 | episode_return_mean=104.708 | episode_len_mean=200.0
# [Iter 0333] env_steps=399600 | episode_return_mean=104.688 | episode_len_mean=200.0
# [Iter 0334] env_steps=400800 | episode_return_mean=104.631 | episode_len_mean=200.0
# [Iter 0335] env_steps=402000 | episode_return_mean=104.281 | episode_len_mean=200.0
# [Iter 0336] env_steps=403200 | episode_return_mean=104.286 | episode_len_mean=200.0
# [Iter 0337] env_steps=404400 | episode_return_mean=104.343 | episode_len_mean=200.0
# [Iter 0338] env_steps=405600 | episode_return_mean=104.447 | episode_len_mean=200.0
# [Iter 0339] env_steps=406800 | episode_return_mean=104.580 | episode_len_mean=200.0
# [Iter 0340] env_steps=408000 | episode_return_mean=104.839 | episode_len_mean=200.0
# [Iter 0341] env_steps=409200 | episode_return_mean=104.593 | episode_len_mean=200.0
# [Iter 0342] env_steps=410400 | episode_return_mean=104.594 | episode_len_mean=200.0
# [Iter 0343] env_steps=411600 | episode_return_mean=104.602 | episode_len_mean=200.0
# [Iter 0344] env_steps=412800 | episode_return_mean=104.499 | episode_len_mean=200.0
# [Iter 0345] env_steps=414000 | episode_return_mean=104.549 | episode_len_mean=200.0
# [Iter 0346] env_steps=415200 | episode_return_mean=104.488 | episode_len_mean=200.0
# [Iter 0347] env_steps=416400 | episode_return_mean=104.466 | episode_len_mean=200.0
# [Iter 0348] env_steps=417600 | episode_return_mean=104.520 | episode_len_mean=200.0
# [Iter 0349] env_steps=418800 | episode_return_mean=104.719 | episode_len_mean=200.0
# [Iter 0350] env_steps=420000 | episode_return_mean=104.904 | episode_len_mean=200.0
# [Iter 0351] env_steps=421200 | episode_return_mean=105.104 | episode_len_mean=200.0
# [Iter 0352] env_steps=422400 | episode_return_mean=105.036 | episode_len_mean=200.0
# [Iter 0353] env_steps=423600 | episode_return_mean=104.873 | episode_len_mean=200.0
# [Iter 0354] env_steps=424800 | episode_return_mean=104.651 | episode_len_mean=200.0
# [Iter 0355] env_steps=426000 | episode_return_mean=104.445 | episode_len_mean=200.0
# [Iter 0356] env_steps=427200 | episode_return_mean=104.316 | episode_len_mean=200.0
# [Iter 0357] env_steps=428400 | episode_return_mean=104.271 | episode_len_mean=200.0
# [Iter 0358] env_steps=429600 | episode_return_mean=104.544 | episode_len_mean=200.0
# [Iter 0359] env_steps=430800 | episode_return_mean=104.527 | episode_len_mean=200.0
# [Iter 0360] env_steps=432000 | episode_return_mean=104.205 | episode_len_mean=200.0
# [Iter 0361] env_steps=433200 | episode_return_mean=104.268 | episode_len_mean=200.0
# [Iter 0362] env_steps=434400 | episode_return_mean=104.020 | episode_len_mean=200.0
# [Iter 0363] env_steps=435600 | episode_return_mean=104.258 | episode_len_mean=200.0
# [Iter 0364] env_steps=436800 | episode_return_mean=104.102 | episode_len_mean=200.0
# [Iter 0365] env_steps=438000 | episode_return_mean=104.099 | episode_len_mean=200.0
# [Iter 0366] env_steps=439200 | episode_return_mean=103.998 | episode_len_mean=200.0
# [Iter 0367] env_steps=440400 | episode_return_mean=103.871 | episode_len_mean=200.0
# [Iter 0368] env_steps=441600 | episode_return_mean=104.002 | episode_len_mean=200.0
# [Iter 0369] env_steps=442800 | episode_return_mean=104.183 | episode_len_mean=200.0
# [Iter 0370] env_steps=444000 | episode_return_mean=104.514 | episode_len_mean=200.0
# [Iter 0371] env_steps=445200 | episode_return_mean=104.669 | episode_len_mean=200.0
# [Iter 0372] env_steps=446400 | episode_return_mean=104.929 | episode_len_mean=200.0
# [Iter 0373] env_steps=447600 | episode_return_mean=104.747 | episode_len_mean=200.0
# [Iter 0374] env_steps=448800 | episode_return_mean=104.770 | episode_len_mean=200.0
# [Iter 0375] env_steps=450000 | episode_return_mean=104.418 | episode_len_mean=200.0
# [Iter 0376] env_steps=451200 | episode_return_mean=104.634 | episode_len_mean=200.0
# [Iter 0377] env_steps=452400 | episode_return_mean=105.023 | episode_len_mean=200.0
# [Iter 0378] env_steps=453600 | episode_return_mean=104.917 | episode_len_mean=200.0
# [Iter 0379] env_steps=454800 | episode_return_mean=104.678 | episode_len_mean=200.0
# [Iter 0380] env_steps=456000 | episode_return_mean=104.449 | episode_len_mean=200.0
# [Iter 0381] env_steps=457200 | episode_return_mean=104.492 | episode_len_mean=200.0
# [Iter 0382] env_steps=458400 | episode_return_mean=104.427 | episode_len_mean=200.0
# [Iter 0383] env_steps=459600 | episode_return_mean=104.426 | episode_len_mean=200.0
# [Iter 0384] env_steps=460800 | episode_return_mean=104.411 | episode_len_mean=200.0
# [Iter 0385] env_steps=462000 | episode_return_mean=104.657 | episode_len_mean=200.0
# [Iter 0386] env_steps=463200 | episode_return_mean=104.509 | episode_len_mean=200.0
# [Iter 0387] env_steps=464400 | episode_return_mean=104.609 | episode_len_mean=200.0
# [Iter 0388] env_steps=465600 | episode_return_mean=104.626 | episode_len_mean=200.0
# [Iter 0389] env_steps=466800 | episode_return_mean=104.735 | episode_len_mean=200.0
# [Iter 0390] env_steps=468000 | episode_return_mean=104.511 | episode_len_mean=200.0
# [Iter 0391] env_steps=469200 | episode_return_mean=104.652 | episode_len_mean=200.0
# [Iter 0392] env_steps=470400 | episode_return_mean=104.605 | episode_len_mean=200.0
# [Iter 0393] env_steps=471600 | episode_return_mean=104.318 | episode_len_mean=200.0
# [Iter 0394] env_steps=472800 | episode_return_mean=104.257 | episode_len_mean=200.0
# [Iter 0395] env_steps=474000 | episode_return_mean=104.364 | episode_len_mean=200.0
# [Iter 0396] env_steps=475200 | episode_return_mean=104.639 | episode_len_mean=200.0
# [Iter 0397] env_steps=476400 | episode_return_mean=104.523 | episode_len_mean=200.0
# [Iter 0398] env_steps=477600 | episode_return_mean=104.432 | episode_len_mean=200.0
# [Iter 0399] env_steps=478800 | episode_return_mean=104.351 | episode_len_mean=200.0
# [Iter 0400] env_steps=480000 | episode_return_mean=104.520 | episode_len_mean=200.0
# [Iter 0401] env_steps=481200 | episode_return_mean=104.170 | episode_len_mean=200.0
# [Iter 0402] env_steps=482400 | episode_return_mean=104.103 | episode_len_mean=200.0
# [Iter 0403] env_steps=483600 | episode_return_mean=103.982 | episode_len_mean=200.0
# [Iter 0404] env_steps=484800 | episode_return_mean=103.786 | episode_len_mean=200.0
# [Iter 0405] env_steps=486000 | episode_return_mean=103.856 | episode_len_mean=200.0
# [Iter 0406] env_steps=487200 | episode_return_mean=103.894 | episode_len_mean=200.0
# [Iter 0407] env_steps=488400 | episode_return_mean=103.928 | episode_len_mean=200.0
# [Iter 0408] env_steps=489600 | episode_return_mean=103.838 | episode_len_mean=200.0
# [Iter 0409] env_steps=490800 | episode_return_mean=103.807 | episode_len_mean=200.0
# [Iter 0410] env_steps=492000 | episode_return_mean=103.862 | episode_len_mean=200.0
# [Iter 0411] env_steps=493200 | episode_return_mean=104.115 | episode_len_mean=200.0
# [Iter 0412] env_steps=494400 | episode_return_mean=104.096 | episode_len_mean=200.0
# [Iter 0413] env_steps=495600 | episode_return_mean=104.155 | episode_len_mean=200.0
# [Iter 0414] env_steps=496800 | episode_return_mean=104.110 | episode_len_mean=200.0
# [Iter 0415] env_steps=498000 | episode_return_mean=104.199 | episode_len_mean=200.0
# [Iter 0416] env_steps=499200 | episode_return_mean=103.872 | episode_len_mean=200.0
# [Iter 0417] env_steps=500400 | episode_return_mean=104.032 | episode_len_mean=200.0
# [Iter 0418] env_steps=501600 | episode_return_mean=104.364 | episode_len_mean=200.0
# [Iter 0419] env_steps=502800 | episode_return_mean=104.482 | episode_len_mean=200.0
# [Iter 0420] env_steps=504000 | episode_return_mean=104.564 | episode_len_mean=200.0
# [Iter 0421] env_steps=505200 | episode_return_mean=104.399 | episode_len_mean=200.0
# [Iter 0422] env_steps=506400 | episode_return_mean=104.278 | episode_len_mean=200.0
# [Iter 0423] env_steps=507600 | episode_return_mean=104.275 | episode_len_mean=200.0
# [Iter 0424] env_steps=508800 | episode_return_mean=104.537 | episode_len_mean=200.0
# [Iter 0425] env_steps=510000 | episode_return_mean=104.679 | episode_len_mean=200.0
# [Iter 0426] env_steps=511200 | episode_return_mean=104.421 | episode_len_mean=200.0
# [Iter 0427] env_steps=512400 | episode_return_mean=104.582 | episode_len_mean=200.0
# [Iter 0428] env_steps=513600 | episode_return_mean=104.553 | episode_len_mean=200.0
# [Iter 0429] env_steps=514800 | episode_return_mean=104.692 | episode_len_mean=200.0
# [Iter 0430] env_steps=516000 | episode_return_mean=104.501 | episode_len_mean=200.0
# [Iter 0431] env_steps=517200 | episode_return_mean=104.862 | episode_len_mean=200.0
# [Iter 0432] env_steps=518400 | episode_return_mean=104.972 | episode_len_mean=200.0
# [Iter 0433] env_steps=519600 | episode_return_mean=105.094 | episode_len_mean=200.0
# [Iter 0434] env_steps=520800 | episode_return_mean=105.110 | episode_len_mean=200.0
# [Iter 0435] env_steps=522000 | episode_return_mean=105.047 | episode_len_mean=200.0
# [Iter 0436] env_steps=523200 | episode_return_mean=105.071 | episode_len_mean=200.0
# [Iter 0437] env_steps=524400 | episode_return_mean=105.123 | episode_len_mean=200.0
# [Iter 0438] env_steps=525600 | episode_return_mean=104.953 | episode_len_mean=200.0
# [Iter 0439] env_steps=526800 | episode_return_mean=105.059 | episode_len_mean=200.0
# [Iter 0440] env_steps=528000 | episode_return_mean=105.096 | episode_len_mean=200.0
# [Iter 0441] env_steps=529200 | episode_return_mean=105.229 | episode_len_mean=200.0
# [Iter 0442] env_steps=530400 | episode_return_mean=105.204 | episode_len_mean=200.0
# [Iter 0443] env_steps=531600 | episode_return_mean=105.211 | episode_len_mean=200.0
# [Iter 0444] env_steps=532800 | episode_return_mean=105.248 | episode_len_mean=200.0
# [Iter 0445] env_steps=534000 | episode_return_mean=105.005 | episode_len_mean=200.0
# [Iter 0446] env_steps=535200 | episode_return_mean=105.036 | episode_len_mean=200.0
# [Iter 0447] env_steps=536400 | episode_return_mean=105.046 | episode_len_mean=200.0
# [Iter 0448] env_steps=537600 | episode_return_mean=104.828 | episode_len_mean=200.0
# [Iter 0449] env_steps=538800 | episode_return_mean=104.836 | episode_len_mean=200.0
# [Iter 0450] env_steps=540000 | episode_return_mean=104.933 | episode_len_mean=200.0
# [Iter 0451] env_steps=541200 | episode_return_mean=104.970 | episode_len_mean=200.0
# [Iter 0452] env_steps=542400 | episode_return_mean=104.840 | episode_len_mean=200.0
# [Iter 0453] env_steps=543600 | episode_return_mean=104.989 | episode_len_mean=200.0
# [Iter 0454] env_steps=544800 | episode_return_mean=104.894 | episode_len_mean=200.0
# [Iter 0455] env_steps=546000 | episode_return_mean=105.136 | episode_len_mean=200.0
# [Iter 0456] env_steps=547200 | episode_return_mean=104.704 | episode_len_mean=200.0
# [Iter 0457] env_steps=548400 | episode_return_mean=104.331 | episode_len_mean=200.0
# [Iter 0458] env_steps=549600 | episode_return_mean=104.019 | episode_len_mean=200.0
# [Iter 0459] env_steps=550800 | episode_return_mean=104.113 | episode_len_mean=200.0
# [Iter 0460] env_steps=552000 | episode_return_mean=104.089 | episode_len_mean=200.0
# [Iter 0461] env_steps=553200 | episode_return_mean=104.129 | episode_len_mean=200.0
# [Iter 0462] env_steps=554400 | episode_return_mean=104.124 | episode_len_mean=200.0
# [Iter 0463] env_steps=555600 | episode_return_mean=104.127 | episode_len_mean=200.0
# [Iter 0464] env_steps=556800 | episode_return_mean=104.189 | episode_len_mean=200.0
# [Iter 0465] env_steps=558000 | episode_return_mean=104.131 | episode_len_mean=200.0
# [Iter 0466] env_steps=559200 | episode_return_mean=104.083 | episode_len_mean=200.0
# [Iter 0467] env_steps=560400 | episode_return_mean=104.079 | episode_len_mean=200.0
# [Iter 0468] env_steps=561600 | episode_return_mean=104.098 | episode_len_mean=200.0
# [Iter 0469] env_steps=562800 | episode_return_mean=103.975 | episode_len_mean=200.0
# [Iter 0470] env_steps=564000 | episode_return_mean=104.151 | episode_len_mean=200.0
# [Iter 0471] env_steps=565200 | episode_return_mean=104.007 | episode_len_mean=200.0
# [Iter 0472] env_steps=566400 | episode_return_mean=103.985 | episode_len_mean=200.0
# [Iter 0473] env_steps=567600 | episode_return_mean=104.407 | episode_len_mean=200.0
# [Iter 0474] env_steps=568800 | episode_return_mean=105.132 | episode_len_mean=200.0
# [Iter 0475] env_steps=570000 | episode_return_mean=105.139 | episode_len_mean=200.0
# [Iter 0476] env_steps=571200 | episode_return_mean=105.346 | episode_len_mean=200.0
# [Iter 0477] env_steps=572400 | episode_return_mean=105.306 | episode_len_mean=200.0
# [Iter 0478] env_steps=573600 | episode_return_mean=105.346 | episode_len_mean=200.0
# [Iter 0479] env_steps=574800 | episode_return_mean=104.897 | episode_len_mean=200.0
# [Iter 0480] env_steps=576000 | episode_return_mean=105.064 | episode_len_mean=200.0
# [Iter 0481] env_steps=577200 | episode_return_mean=105.051 | episode_len_mean=200.0
# [Iter 0482] env_steps=578400 | episode_return_mean=105.063 | episode_len_mean=200.0
# [Iter 0483] env_steps=579600 | episode_return_mean=105.054 | episode_len_mean=200.0
# [Iter 0484] env_steps=580800 | episode_return_mean=104.957 | episode_len_mean=200.0
# [Iter 0485] env_steps=582000 | episode_return_mean=104.875 | episode_len_mean=200.0
# [Iter 0486] env_steps=583200 | episode_return_mean=105.176 | episode_len_mean=200.0
# [Iter 0487] env_steps=584400 | episode_return_mean=104.840 | episode_len_mean=200.0
# [Iter 0488] env_steps=585600 | episode_return_mean=105.148 | episode_len_mean=200.0
# [Iter 0489] env_steps=586800 | episode_return_mean=105.139 | episode_len_mean=200.0
# [Iter 0490] env_steps=588000 | episode_return_mean=104.729 | episode_len_mean=200.0
# [Iter 0491] env_steps=589200 | episode_return_mean=104.125 | episode_len_mean=200.0
# [Iter 0492] env_steps=590400 | episode_return_mean=104.152 | episode_len_mean=200.0
# [Iter 0493] env_steps=591600 | episode_return_mean=104.109 | episode_len_mean=200.0
# [Iter 0494] env_steps=592800 | episode_return_mean=104.341 | episode_len_mean=200.0
# [Iter 0495] env_steps=594000 | episode_return_mean=104.430 | episode_len_mean=200.0
# [Iter 0496] env_steps=595200 | episode_return_mean=104.359 | episode_len_mean=200.0
# [Iter 0497] env_steps=596400 | episode_return_mean=104.256 | episode_len_mean=200.0
# [Iter 0498] env_steps=597600 | episode_return_mean=104.136 | episode_len_mean=200.0
# [Iter 0499] env_steps=598800 | episode_return_mean=103.998 | episode_len_mean=200.0
# [Iter 0500] env_steps=600000 | episode_return_mean=104.399 | episode_len_mean=200.0
# [Iter 0501] env_steps=601200 | episode_return_mean=104.480 | episode_len_mean=200.0
# [Iter 0502] env_steps=602400 | episode_return_mean=104.414 | episode_len_mean=200.0
# [Iter 0503] env_steps=603600 | episode_return_mean=104.350 | episode_len_mean=200.0
# [Iter 0504] env_steps=604800 | episode_return_mean=104.600 | episode_len_mean=200.0
# [Iter 0505] env_steps=606000 | episode_return_mean=104.421 | episode_len_mean=200.0
# [Iter 0506] env_steps=607200 | episode_return_mean=104.305 | episode_len_mean=200.0
# [Iter 0507] env_steps=608400 | episode_return_mean=104.510 | episode_len_mean=200.0
# [Iter 0508] env_steps=609600 | episode_return_mean=104.738 | episode_len_mean=200.0
# [Iter 0509] env_steps=610800 | episode_return_mean=104.613 | episode_len_mean=200.0
# [Iter 0510] env_steps=612000 | episode_return_mean=104.712 | episode_len_mean=200.0
# [Iter 0511] env_steps=613200 | episode_return_mean=104.543 | episode_len_mean=200.0
# [Iter 0512] env_steps=614400 | episode_return_mean=104.539 | episode_len_mean=200.0
# [Iter 0513] env_steps=615600 | episode_return_mean=104.827 | episode_len_mean=200.0
# [Iter 0514] env_steps=616800 | episode_return_mean=104.660 | episode_len_mean=200.0
# [Iter 0515] env_steps=618000 | episode_return_mean=104.558 | episode_len_mean=200.0
# [Iter 0516] env_steps=619200 | episode_return_mean=104.578 | episode_len_mean=200.0
# [Iter 0517] env_steps=620400 | episode_return_mean=104.493 | episode_len_mean=200.0
# [Iter 0518] env_steps=621600 | episode_return_mean=104.450 | episode_len_mean=200.0
# [Iter 0519] env_steps=622800 | episode_return_mean=104.495 | episode_len_mean=200.0
# [Iter 0520] env_steps=624000 | episode_return_mean=104.491 | episode_len_mean=200.0
# [Iter 0521] env_steps=625200 | episode_return_mean=104.478 | episode_len_mean=200.0
# [Iter 0522] env_steps=626400 | episode_return_mean=104.735 | episode_len_mean=200.0
# [Iter 0523] env_steps=627600 | episode_return_mean=104.567 | episode_len_mean=200.0
# [Iter 0524] env_steps=628800 | episode_return_mean=104.571 | episode_len_mean=200.0
# [Iter 0525] env_steps=630000 | episode_return_mean=104.187 | episode_len_mean=200.0
# [Iter 0526] env_steps=631200 | episode_return_mean=104.293 | episode_len_mean=200.0
# [Iter 0527] env_steps=632400 | episode_return_mean=104.355 | episode_len_mean=200.0
# [Iter 0528] env_steps=633600 | episode_return_mean=104.468 | episode_len_mean=200.0
# [Iter 0529] env_steps=634800 | episode_return_mean=104.659 | episode_len_mean=200.0
# [Iter 0530] env_steps=636000 | episode_return_mean=104.383 | episode_len_mean=200.0
# [Iter 0531] env_steps=637200 | episode_return_mean=104.649 | episode_len_mean=200.0
# [Iter 0532] env_steps=638400 | episode_return_mean=104.609 | episode_len_mean=200.0
# [Iter 0533] env_steps=639600 | episode_return_mean=104.225 | episode_len_mean=200.0
# [Iter 0534] env_steps=640800 | episode_return_mean=104.012 | episode_len_mean=200.0
# [Iter 0535] env_steps=642000 | episode_return_mean=103.996 | episode_len_mean=200.0
# [Iter 0536] env_steps=643200 | episode_return_mean=103.875 | episode_len_mean=200.0
# [Iter 0537] env_steps=644400 | episode_return_mean=103.792 | episode_len_mean=200.0
# [Iter 0538] env_steps=645600 | episode_return_mean=103.871 | episode_len_mean=200.0
# [Iter 0539] env_steps=646800 | episode_return_mean=103.783 | episode_len_mean=200.0
# [Iter 0540] env_steps=648000 | episode_return_mean=104.154 | episode_len_mean=200.0
# [Iter 0541] env_steps=649200 | episode_return_mean=104.316 | episode_len_mean=200.0
# [Iter 0542] env_steps=650400 | episode_return_mean=104.555 | episode_len_mean=200.0
# [Iter 0543] env_steps=651600 | episode_return_mean=104.660 | episode_len_mean=200.0
# [Iter 0544] env_steps=652800 | episode_return_mean=104.484 | episode_len_mean=200.0
# [Iter 0545] env_steps=654000 | episode_return_mean=104.545 | episode_len_mean=200.0
# [Iter 0546] env_steps=655200 | episode_return_mean=104.628 | episode_len_mean=200.0
# [Iter 0547] env_steps=656400 | episode_return_mean=104.650 | episode_len_mean=200.0
# [Iter 0548] env_steps=657600 | episode_return_mean=104.850 | episode_len_mean=200.0
# [Iter 0549] env_steps=658800 | episode_return_mean=104.998 | episode_len_mean=200.0
# [Iter 0550] env_steps=660000 | episode_return_mean=105.405 | episode_len_mean=200.0
# [Iter 0551] env_steps=661200 | episode_return_mean=105.302 | episode_len_mean=200.0
# [Iter 0552] env_steps=662400 | episode_return_mean=105.542 | episode_len_mean=200.0
# ...
# [Iter 0569] env_steps=682800 | episode_return_mean=104.613 | episode_len_mean=200.0
# [Iter 0570] env_steps=684000 | episode_return_mean=104.593 | episode_len_mean=200.0
# [Iter 0571] env_steps=685200 | episode_return_mean=104.642 | episode_len_mean=200.0
# [Iter 0572] env_steps=686400 | episode_return_mean=104.390 | episode_len_mean=200.0
# [Iter 0573] env_steps=687600 | episode_return_mean=104.850 | episode_len_mean=200.0
# [Iter 0574] env_steps=688800 | episode_return_mean=104.915 | episode_len_mean=200.0
# [Iter 0575] env_steps=690000 | episode_return_mean=104.668 | episode_len_mean=200.0
# [Iter 0576] env_steps=691200 | episode_return_mean=104.717 | episode_len_mean=200.0
# [Iter 0577] env_steps=692400 | episode_return_mean=104.680 | episode_len_mean=200.0
# [Iter 0578] env_steps=693600 | episode_return_mean=104.612 | episode_len_mean=200.0
# [Iter 0579] env_steps=694800 | episode_return_mean=104.475 | episode_len_mean=200.0
# [Iter 0580] env_steps=696000 | episode_return_mean=104.423 | episode_len_mean=200.0
# [Iter 0581] env_steps=697200 | episode_return_mean=104.569 | episode_len_mean=200.0
# [Iter 0582] env_steps=698400 | episode_return_mean=104.498 | episode_len_mean=200.0
# [Iter 0583] env_steps=699600 | episode_return_mean=104.387 | episode_len_mean=200.0
# [Iter 0584] env_steps=700800 | episode_return_mean=104.495 | episode_len_mean=200.0
# [Iter 0585] env_steps=702000 | episode_return_mean=104.231 | episode_len_mean=200.0
# [Iter 0586] env_steps=703200 | episode_return_mean=103.940 | episode_len_mean=200.0
# [Iter 0587] env_steps=704400 | episode_return_mean=103.747 | episode_len_mean=200.0
# [Iter 0588] env_steps=705600 | episode_return_mean=103.514 | episode_len_mean=200.0
# [Iter 0589] env_steps=706800 | episode_return_mean=103.477 | episode_len_mean=200.0
# [Iter 0590] env_steps=708000 | episode_return_mean=103.416 | episode_len_mean=200.0
# [Iter 0591] env_steps=709200 | episode_return_mean=103.698 | episode_len_mean=200.0
# [Iter 0592] env_steps=710400 | episode_return_mean=103.742 | episode_len_mean=200.0
# [Iter 0593] env_steps=711600 | episode_return_mean=103.797 | episode_len_mean=200.0
# [Iter 0594] env_steps=712800 | episode_return_mean=103.655 | episode_len_mean=200.0
# [Iter 0595] env_steps=714000 | episode_return_mean=103.323 | episode_len_mean=200.0
# [Iter 0596] env_steps=715200 | episode_return_mean=103.570 | episode_len_mean=200.0
# [Iter 0597] env_steps=716400 | episode_return_mean=103.851 | episode_len_mean=200.0
# [Iter 0598] env_steps=717600 | episode_return_mean=104.069 | episode_len_mean=200.0
# [Iter 0599] env_steps=718800 | episode_return_mean=104.347 | episode_len_mean=200.0
# [Iter 0600] env_steps=720000 | episode_return_mean=104.097 | episode_len_mean=200.0
# [Iter 0601] env_steps=721200 | episode_return_mean=104.048 | episode_len_mean=200.0
# [Iter 0602] env_steps=722400 | episode_return_mean=104.145 | episode_len_mean=200.0
# [Iter 0603] env_steps=723600 | episode_return_mean=104.292 | episode_len_mean=200.0
# [Iter 0604] env_steps=724800 | episode_return_mean=104.401 | episode_len_mean=200.0
# [Iter 0605] env_steps=726000 | episode_return_mean=104.793 | episode_len_mean=200.0
# [Iter 0606] env_steps=727200 | episode_return_mean=104.764 | episode_len_mean=200.0
# [Iter 0607] env_steps=728400 | episode_return_mean=104.628 | episode_len_mean=200.0
# [Iter 0608] env_steps=729600 | episode_return_mean=104.459 | episode_len_mean=200.0
# [Iter 0609] env_steps=730800 | episode_return_mean=104.481 | episode_len_mean=200.0
# [Iter 0610] env_steps=732000 | episode_return_mean=104.642 | episode_len_mean=200.0
# [Iter 0611] env_steps=733200 | episode_return_mean=104.734 | episode_len_mean=200.0
# [Iter 0612] env_steps=734400 | episode_return_mean=104.701 | episode_len_mean=200.0
# [Iter 0613] env_steps=735600 | episode_return_mean=104.413 | episode_len_mean=200.0
# [Iter 0614] env_steps=736800 | episode_return_mean=104.440 | episode_len_mean=200.0
# [Iter 0615] env_steps=738000 | episode_return_mean=104.194 | episode_len_mean=200.0
# [Iter 0616] env_steps=739200 | episode_return_mean=104.180 | episode_len_mean=200.0
# [Iter 0617] env_steps=740400 | episode_return_mean=104.084 | episode_len_mean=200.0
# [Iter 0618] env_steps=741600 | episode_return_mean=104.152 | episode_len_mean=200.0
# [Iter 0619] env_steps=742800 | episode_return_mean=104.392 | episode_len_mean=200.0
# [Iter 0620] env_steps=744000 | episode_return_mean=104.541 | episode_len_mean=200.0
# [Iter 0621] env_steps=745200 | episode_return_mean=104.333 | episode_len_mean=200.0
# [Iter 0622] env_steps=746400 | episode_return_mean=104.573 | episode_len_mean=200.0
# [Iter 0623] env_steps=747600 | episode_return_mean=104.454 | episode_len_mean=200.0
# [Iter 0624] env_steps=748800 | episode_return_mean=104.447 | episode_len_mean=200.0
# [Iter 0625] env_steps=750000 | episode_return_mean=104.611 | episode_len_mean=200.0
# [Iter 0626] env_steps=751200 | episode_return_mean=104.845 | episode_len_mean=200.0
# [Iter 0627] env_steps=752400 | episode_return_mean=104.830 | episode_len_mean=200.0
# [Iter 0628] env_steps=753600 | episode_return_mean=104.694 | episode_len_mean=200.0
# [Iter 0629] env_steps=754800 | episode_return_mean=104.766 | episode_len_mean=200.0
# [Iter 0630] env_steps=756000 | episode_return_mean=104.849 | episode_len_mean=200.0
# [Iter 0631] env_steps=757200 | episode_return_mean=104.625 | episode_len_mean=200.0
# [Iter 0632] env_steps=758400 | episode_return_mean=105.119 | episode_len_mean=200.0
# [Iter 0633] env_steps=759600 | episode_return_mean=105.071 | episode_len_mean=200.0
# [Iter 0634] env_steps=760800 | episode_return_mean=105.079 | episode_len_mean=200.0
# [Iter 0635] env_steps=762000 | episode_return_mean=104.824 | episode_len_mean=200.0
# [Iter 0636] env_steps=763200 | episode_return_mean=104.749 | episode_len_mean=200.0
# [Iter 0637] env_steps=764400 | episode_return_mean=104.667 | episode_len_mean=200.0
# [Iter 0638] env_steps=765600 | episode_return_mean=104.902 | episode_len_mean=200.0
# [Iter 0639] env_steps=766800 | episode_return_mean=104.632 | episode_len_mean=200.0
# [Iter 0640] env_steps=768000 | episode_return_mean=104.690 | episode_len_mean=200.0
# [Iter 0641] env_steps=769200 | episode_return_mean=104.785 | episode_len_mean=200.0
# [Iter 0642] env_steps=770400 | episode_return_mean=104.408 | episode_len_mean=200.0
# [Iter 0643] env_steps=771600 | episode_return_mean=104.462 | episode_len_mean=200.0
# [Iter 0644] env_steps=772800 | episode_return_mean=104.715 | episode_len_mean=200.0
# [Iter 0645] env_steps=774000 | episode_return_mean=104.663 | episode_len_mean=200.0
# [Iter 0646] env_steps=775200 | episode_return_mean=104.837 | episode_len_mean=200.0
# [Iter 0647] env_steps=776400 | episode_return_mean=105.074 | episode_len_mean=200.0
# [Iter 0648] env_steps=777600 | episode_return_mean=105.102 | episode_len_mean=200.0
# [Iter 0649] env_steps=778800 | episode_return_mean=104.926 | episode_len_mean=200.0
# [Iter 0650] env_steps=780000 | episode_return_mean=105.180 | episode_len_mean=200.0
# [Iter 0651] env_steps=781200 | episode_return_mean=105.204 | episode_len_mean=200.0
# [Iter 0652] env_steps=782400 | episode_return_mean=105.259 | episode_len_mean=200.0
# [Iter 0653] env_steps=783600 | episode_return_mean=105.434 | episode_len_mean=200.0
# [Iter 0654] env_steps=784800 | episode_return_mean=105.516 | episode_len_mean=200.0
# [Iter 0655] env_steps=786000 | episode_return_mean=105.399 | episode_len_mean=200.0
# [Iter 0656] env_steps=787200 | episode_return_mean=105.366 | episode_len_mean=200.0
# [Iter 0657] env_steps=788400 | episode_return_mean=105.461 | episode_len_mean=200.0
# [Iter 0658] env_steps=789600 | episode_return_mean=105.628 | episode_len_mean=200.0
# [Iter 0659] env_steps=790800 | episode_return_mean=105.536 | episode_len_mean=200.0
# [Iter 0660] env_steps=792000 | episode_return_mean=105.417 | episode_len_mean=200.0
# [Iter 0661] env_steps=793200 | episode_return_mean=105.305 | episode_len_mean=200.0
# [Iter 0662] env_steps=794400 | episode_return_mean=105.286 | episode_len_mean=200.0
# [Iter 0663] env_steps=795600 | episode_return_mean=105.236 | episode_len_mean=200.0
# [Iter 0664] env_steps=796800 | episode_return_mean=105.008 | episode_len_mean=200.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 2529
#    2526 iter_idx = 0
#    2528 while total_env_steps < total_target_env_steps:
# -> 2529     result = algo.train()
#    2530     iter_idx += 1
#    2532     total_env_steps = get_total_env_steps(result)
#
# File ~/miniconda3/envs/wr/lib/python3.11/site-packages/ray/tune/trainable/trainable.py:328, in Trainable.train(self)
#     326 start = time.time()
#     327 try:
# --> 328     result = self.step()
#     329 except Exception as e:
#     330     skipped = skip_exceptions(e)
#
# File ~/miniconda3/envs/wr/lib/python3.11/site-packages/ray/rllib/algorithms/algorithm.py:1245, in Algorithm.step(self)
#    1240         train_results, train_iter_ctx = self._run_one_training_iteration()
#    1241     else:
#    1242         (
#    1243             train_results,
#    1244             train_iter_ctx,
# -> 1245         ) = self._run_one_training_iteration_old_api_stack()
#    1247 # Sequential: Train (already done above), then evaluate.
#    1248 if evaluate_this_iter and not self.config.evaluation_parallel_to_training:
#
# File ~/miniconda3/envs/wr/lib/python3.11/site-packages/ray/rllib/algorithms/algorithm.py:4330, in Algorithm._run_one_training_iteration_old_api_stack(self)
#    4323         self._make_on_env_runners_recreated_callbacks(
#    4324             config=self.config,
#    4325             env_runner_group=self.env_runner_group,
#    4326             restored_env_runner_indices=restored,
#    4327         )
#    4329 with self._timers[TRAINING_STEP_TIMER]:
# -> 4330     training_step_results = self.training_step()
#    4332 if training_step_results:
#    4333     results = training_step_results
#
# File ~/miniconda3/envs/wr/lib/python3.11/site-packages/ray/rllib/algorithms/ppo/ppo.py:393, in PPO.training_step(self)
#     389 @override(Algorithm)
#     390 def training_step(self) -> None:
#     391     # Old API stack (Policy, RolloutWorker, Connector).
#     392     if not self.config.enable_env_runner_and_connector_v2:
# --> 393         return self._training_step_old_api_stack()
#     395     # Collect batches from sample workers until we have a full batch.
#     396     with self.metrics.log_time((TIMERS, ENV_RUNNER_SAMPLING_TIMER)):
#     397         # Sample in parallel from the workers.
#
# File ~/miniconda3/envs/wr/lib/python3.11/site-packages/ray/rllib/algorithms/ppo/ppo.py:472, in PPO._training_step_old_api_stack(self)
#     466     train_batch = synchronous_parallel_sample(
#     467         worker_set=self.env_runner_group,
#     468         max_agent_steps=self.config.total_train_batch_size,
#     469         sample_timeout_s=self.config.sample_timeout_s,
#     470     )
#     471 else:
# --> 472     train_batch = synchronous_parallel_sample(
#     473         worker_set=self.env_runner_group,
#     474         max_env_steps=self.config.total_train_batch_size,
#     475         sample_timeout_s=self.config.sample_timeout_s,
#     476     )
#     477 # Return early if all our workers failed.
#     478 if not train_batch:
#
# File ~/miniconda3/envs/wr/lib/python3.11/site-packages/ray/rllib/execution/rollout_ops.py:107, in synchronous_parallel_sample(worker_set, max_agent_steps, max_env_steps, concat, sample_timeout_s, random_actions, _uses_new_env_runners, _return_metrics)
#     104         stats_dicts = [worker_set.local_env_runner.get_metrics()]
#     105 # Loop over remote workers' `sample()` method in parallel.
#     106 else:
# --> 107     sampled_data = worker_set.foreach_env_runner(
#     108         (
#     109             (lambda w: w.sample(**random_action_kwargs))
#     110             if not _return_metrics
#     111             else (lambda w: (w.sample(**random_action_kwargs), w.get_metrics()))
#     112         ),
#     113         local_env_runner=False,
#     114         timeout_seconds=sample_timeout_s,
#     115     )
#     116     # Nothing was returned (maybe all workers are stalling) or no healthy
#     117     # remote workers left: Break.
#     118     # There is no point staying in this loop, since we will not be able to
#     119     # get any new samples if we don't have any healthy remote workers left.
#     120     if not sampled_data or worker_set.num_healthy_remote_workers() <= 0:
#
# File ~/miniconda3/envs/wr/lib/python3.11/site-packages/ray/rllib/env/env_runner_group.py:879, in EnvRunnerGroup.foreach_env_runner(self, func, kwargs, local_env_runner, healthy_only, remote_worker_ids, timeout_seconds, return_obj_refs, mark_healthy)
#     876 if not self._worker_manager.actor_ids():
#     877     return local_result
# --> 879 remote_results = self._worker_manager.foreach_actor(
#     880     func,
#     881     kwargs=kwargs,
#     882     healthy_only=healthy_only,
#     883     remote_actor_ids=remote_worker_ids,
#     884     timeout_seconds=timeout_seconds,
#     885     return_obj_refs=return_obj_refs,
#     886     mark_healthy=mark_healthy,
#     887 )
#     889 FaultTolerantActorManager.handle_remote_call_result_errors(
#     890     remote_results, ignore_ray_errors=self._ignore_ray_errors_on_env_runners
#     891 )
#     893 # With application errors handled, return good results.
#
# File ~/miniconda3/envs/wr/lib/python3.11/site-packages/ray/rllib/utils/actor_manager.py:484, in FaultTolerantActorManager.foreach_actor(self, func, kwargs, healthy_only, remote_actor_ids, timeout_seconds, return_obj_refs, mark_healthy)
#     477 remote_calls = self._call_actors(
#     478     func=func,
#     479     kwargs=kwargs,
#     480     remote_actor_ids=remote_actor_ids,
#     481 )
#     483 # Collect remote request results (if available given timeout and/or errors).
# --> 484 _, remote_results = self._fetch_result(
#     485     remote_actor_ids=remote_actor_ids,
#     486     remote_calls=remote_calls,
#     487     tags=[None] * len(remote_calls),
#     488     timeout_seconds=timeout_seconds,
#     489     return_obj_refs=return_obj_refs,
#     490     mark_healthy=mark_healthy,
#     491 )
#     493 return remote_results
#
# File ~/miniconda3/envs/wr/lib/python3.11/site-packages/ray/rllib/utils/actor_manager.py:939, in FaultTolerantActorManager._fetch_result(self, remote_actor_ids, remote_calls, tags, timeout_seconds, return_obj_refs, mark_healthy)
#     936 if not remote_calls:
#     937     return [], RemoteCallResults()
# --> 939 readies, _ = ray.wait(
#     940     remote_calls,
#     941     num_returns=len(remote_calls),
#     942     timeout=timeout,
#     943     # Make sure remote results are fetched locally in parallel.
#     944     fetch_local=not return_obj_refs,
#     945 )
#     947 # Remote data should already be fetched to local object store at this point.
#     948 remote_results = RemoteCallResults()
#
# File ~/miniconda3/envs/wr/lib/python3.11/site-packages/ray/_private/auto_init_hook.py:22, in wrap_auto_init.<locals>.auto_init_wrapper(*args, **kwargs)
#      19 @wraps(fn)
#      20 def auto_init_wrapper(*args, **kwargs):
#      21     auto_init_ray()
# ---> 22     return fn(*args, **kwargs)
#
# File ~/miniconda3/envs/wr/lib/python3.11/site-packages/ray/_private/client_mode_hook.py:104, in client_mode_hook.<locals>.wrapper(*args, **kwargs)
#     102     if func.__name__ != "init" or is_client_mode_enabled_by_default:
#     103         return getattr(ray, func.__name__)(*args, **kwargs)
# --> 104 return func(*args, **kwargs)
#
# File ~/miniconda3/envs/wr/lib/python3.11/site-packages/ray/_private/worker.py:3213, in wait(ray_waitables, num_returns, timeout, fetch_local)
#    3211 timeout = timeout if timeout is not None else 10**6
#    3212 timeout_milliseconds = int(timeout * 1000)
# -> 3213 ready_ids, remaining_ids = worker.core_worker.wait(
#    3214     ray_waitables,
#    3215     num_returns,
#    3216     timeout_milliseconds,
#    3217     fetch_local,
#    3218 )
#    3219 return ready_ids, remaining_ids
#
# File python/ray/_raylet.pyx:3172, in ray._raylet.CoreWorker.wait()
#
# File python/ray/includes/common.pxi:98, in ray._raylet.check_status()
#
# KeyboardInterrupt:

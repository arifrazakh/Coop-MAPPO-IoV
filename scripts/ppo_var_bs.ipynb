# %%
import argparse
import math
import random
from collections import defaultdict
from types import SimpleNamespace
import time
import csv  # used for episode-wise CSV logging

import gymnasium as gym
from gymnasium.utils import seeding
import matplotlib.pyplot as plt
import numpy as np

# RLlib / Ray
import os
import ray
from ray.rllib.algorithms.ppo import PPOConfig   # <<< PPO
from ray.rllib.policy.policy import PolicySpec
from ray.tune.registry import register_env
from ray.rllib.env.multi_agent_env import MultiAgentEnv
from ray.rllib.algorithms.callbacks import DefaultCallbacks
import torch


# ----------------------
# Basic PHY & helper functions
# ----------------------
def rx_sensitivity_dBm(bw_hz, nf_db=7.0, snr_req_db=-5.0):
    """Thermal-noise-based RX sensitivity in dBm."""
    return -174.0 + 10.0 * np.log10(max(bw_hz, 1.0)) + nf_db + snr_req_db


MOD_ORDER = 256
BITS_PER_CODEWORD = int(np.log2(MOD_ORDER))
NR_OVERHEAD = 0.85
SNR_GAP_DB = 1.5
MAX_SE = 7.5  # peak spectral efficiency (bit/s/Hz)

# Antenna / beamforming gains per BS type
BEAM_GAIN_DB = {
    "Ma": {
        "tx_main": 8.0,   # main-lobe TX gain (dB)
        "tx_side": -3.0,  # side-lobe TX gain (dB)
        "rx": 0.0,        # UE RX gain (dB)
    }
}

UE_INTERF_RX_DB = 0.0  # interference-side RX gain at UE
MACRO_REUSE_ONE = False
MIMO_MAX_RANK = {"Ma": 4}


def spectral_efficiency_from_sinr(SINR_dB, gap_db=SNR_GAP_DB, max_se=MAX_SE):
    """Shannon-like SE with SNR gap."""
    gamma_lin = 10.0 ** (SINR_dB / 10.0) / (10.0 ** (gap_db / 10.0))
    se = np.log2(1.0 + gamma_lin)
    return float(np.clip(se, 0.0, max_se))


def mimo_rank_and_total_se(
    SINR_dB: float,
    max_layers: int,
    gap_db: float = SNR_GAP_DB,
    max_se: float = MAX_SE,
):
    """Simple MIMO rank-selection and SE aggregation."""
    sinr_lin = 10.0 ** (SINR_dB / 10.0)
    best_L = 1
    best_sum_se = spectral_efficiency_from_sinr(SINR_dB, gap_db, max_se)

    for L in range(2, max_layers + 1):
        per_layer_snr_dB = 10.0 * np.log10(max(sinr_lin / max(L, 1), 1e-12))
        se_layer = spectral_efficiency_from_sinr(
            per_layer_snr_dB, gap_db, max_se
        )
        corr_eff = max(0.5, 1.0 - 0.07 * (L - 1))  # crude correlation penalty
        sum_se = L * se_layer * corr_eff
        if sum_se > best_sum_se:
            best_sum_se = sum_se
            best_L = L

    return best_L, float(best_sum_se)


# 19-D BS observation layout (0-1 normalized)
OBS_IDX = SimpleNamespace(
    BS_TYPE=0,
    TX_NORM=1,
    CH_UTIL=2,
    COV_UTIL=3,
    LOAD_RATIO_NORM=4,
    NEARBY_POT=5,
    AVG_SPEED=6,
    REQ_P_NORM=7,
    AVG_RADIAL_V=8,
    SP_VAR=9,
    NEIGHBOR_TX_NORM=10,
    AVG_DEMAND_NORM=11,
    INTER_NORM=12,
    MEC_QUEUE_NORM=13,
    CPU_UTIL_NORM=14,
    OFFLOAD_FRAC=15,
    SERVED_RATIO_NORM=16,  # local served throughput / max possible
    BLOCK_FRAC_NORM=17,    # fraction of in-coverage users not associated
    CH_MATCH_NORM=18,      # how well channels match covered users
    OFFLOAD_MAND_FRAC=19,  # fraction of covered users with mandatory-offload tasks
)


# ----------------
# Building blocks
# ----------------
class Channel:
    def __init__(self, id, frequency, bandwidth, noise_figure_db=7.0):
        self.id = int(id)
        self.frequency = float(frequency)
        self.bandwidth = float(bandwidth)
        self.noise_figure_db = float(noise_figure_db)
        self.users = []
        self.base_station = None

    def calculate_noise_power(self):
        """Noise power in Watts for this channel."""
        k = 1.380649e-23
        T = 293.15
        N = k * T * self.bandwidth
        NF = 10.0 ** (self.noise_figure_db / 10.0)
        return N * NF


class BaseStation:
    def __init__(
        self,
        id,
        transmit_power_mW,
        height_m,
        location_xy,
        type_bs="Ma",
        mec_cpu_capacity_cycles=5e9,
    ):
        self.id = int(id)
        self.transmit_power = float(transmit_power_mW)  # total TX power in mW
        self.height = float(height_m)
        self.location = np.array(location_xy, dtype=float)
        self.type_bs = type_bs
        self.assigned_channels = []
        self.per_channel_power = {}
        self.coverage_area = float(0.0)  # coverage radius (m)

        # MEC-related attributes (compute plane)
        self.mec_cpu_capacity = float(mec_cpu_capacity_cycles)  # F_i^{max}
        self.mec_queue_cycles = 0.0     # q_t^{bs,i} [cycles]
        self.offload_frac = 1.0         # x_t^i in [0,1]
        self.cpu_util_frac = 1.0        # aggregate CPU utilization fraction
        self.last_cpu_used = 0.0        # F_used this step [cycles/s]

        # simple type-dependent caps
        self.MAX_COVERAGE = {"Ma": 2000.0}
        self.COV_MARGIN_DB = {"Ma": 3.0}
        self.SNR_REQ_DB = {"Ma": -5.0}

    # ---- 3GPP-like UMa pathloss ----
    def _pl_uma_los(self, d3d, f_ghz, h_ut=1.5):
        c = 3e8
        f_hz = f_ghz * 1e9
        h_bs = float(self.height)

        d2d = max(np.sqrt(max(d3d**2 - (h_bs - h_ut) ** 2, 1e-9)), 1.0)
        h_bs_eff = h_bs - 1.0
        h_ut_eff = h_ut - 1.0
        d_bp = 4.0 * h_bs_eff * h_ut_eff * f_hz / c

        pl1 = 28.0 + 22.0 * np.log10(d3d) + 20.0 * np.log10(f_ghz)
        if d2d <= d_bp:
            return pl1
        pl2 = (
            28.0
            + 40.0 * np.log10(d3d)
            + 20.0 * np.log10(f_ghz)
            - 9.0 * np.log10(d_bp**2 + (h_bs - h_ut) ** 2)
        )
        return pl2

    def _pl_uma_nlos(self, d3d, f_ghz, h_ut=1.5):
        pl_los = self._pl_uma_los(d3d, f_ghz, h_ut)
        pl_nlos = (
            13.54
            + 39.08 * np.log10(d3d)
            + 20.0 * np.log10(f_ghz)
            - 0.6 * (h_ut - 1.5)
        )
        return max(pl_nlos, pl_los)

    def calculate_path_loss(self, distance_m, frequency_hz, user_height=1.5):
        """Average path loss (LOS-probability weighted)."""
        d2d = float(max(distance_m, 0.1))
        f_ghz = frequency_hz / 1e9
        d3d = np.sqrt(d2d**2 + (self.height - user_height) ** 2)

        p_los = min(18.0 / d2d, 1.0) * (1.0 - np.exp(-d2d / 63.0)) + np.exp(
            -d2d / 63.0
        )
        pl_los = self._pl_uma_los(d3d, f_ghz, h_ut=user_height)
        pl_nlos = self._pl_uma_nlos(d3d, f_ghz, h_ut=user_height)

        return float(p_los * pl_los + (1.0 - p_los) * pl_nlos)

    def _eirp_dbm(self, transmit_power_mW: float) -> float:
        g = BEAM_GAIN_DB[self.type_bs]
        tx_dbm = 10.0 * np.log10(max(transmit_power_mW, 1e-15))
        return tx_dbm + g["tx_main"] + g["rx"]

    def update_coverage_area_from_power(
        self, total_transmit_power_mW, frequency_hz
    ):
        """Update coverage radius from link budget."""
        if self.per_channel_power:
            values = list(self.per_channel_power.values())
            p_ch = float(np.percentile(values, 80))
        else:
            n = max(1, len(self.assigned_channels))
            p_ch = float(total_transmit_power_mW / n)

        if self.assigned_channels:
            bw_hz = self.assigned_channels[0].bandwidth
            nf_db = self.assigned_channels[0].noise_figure_db
        else:
            bw_hz = 20e6
            nf_db = 7.0

        sens_dBm = rx_sensitivity_dBm(
            bw_hz, nf_db=nf_db, snr_req_db=self.SNR_REQ_DB[self.type_bs]
        )
        eirp_plus_grx_dbm = self._eirp_dbm(p_ch)
        path_loss_budget_dB = (
            eirp_plus_grx_dbm - sens_dBm - self.COV_MARGIN_DB[self.type_bs]
        )

        radius_m = self.find_distance_for_path_loss(
            path_loss_budget_dB, frequency_hz
        )
        cap = self.MAX_COVERAGE.get(self.type_bs, None)
        if cap is not None:
            radius_m = min(radius_m, float(cap))

        self.coverage_area = float(max(radius_m, 1.0))
        return self.coverage_area

    def find_distance_for_path_loss(self, path_loss_dB, frequency_hz):
        """Invert pathloss model via binary search."""
        d_min, d_max = 1.0, 10000.0
        tol = 0.1
        d_mid = 0.0
        for _ in range(40):
            d_mid = 0.5 * (d_min + d_max)
            PL_mid = self.calculate_path_loss(d_mid, frequency_hz)
            if abs(PL_mid - path_loss_dB) < tol:
                return d_mid
            if PL_mid < path_loss_dB:
                d_min = d_mid
            else:
                d_max = d_mid
        return d_mid

    def assign_channels(self, channels):
        self.assigned_channels = list(channels)
        for ch in self.assigned_channels:
            ch.base_station = self

    def clear_assigned_channels(self):
        for ch in self.assigned_channels:
            ch.base_station = None
            ch.users = []
        self.assigned_channels = []
        self.per_channel_power = {}

    def find_available_channel(self):
        """Find a free (unoccupied) channel, if any."""
        for ch in self.assigned_channels:
            if len(ch.users) == 0:
                return ch
        return None


class User:
    def __init__(self, id, location_xy, velocity_xy, demand_bits=1e6):
        self.id = int(id)
        self.location = np.array(location_xy, dtype=float)
        self.velocity = np.array(velocity_xy, dtype=float)
        self.height = 1.5

        # radio link properties
        self.channel = []
        self.channel_SINR = []
        self.SINR = -100.0
        self.data_rate = 0.0  # instantaneous achievable rate (Mbps)
        self.demand = float(demand_bits)  # "required" rate (Mbps-like scale)
        self.mimo_layers = []

        # service class
        self.service_class = "infotainment"

        # task model (set properly by generate_task())
        self.task_type = "light"
        self.task_cycles = 0.0
        self.task_input_Mbit = 0.0
        self.task_offload_mandatory = False

        # mobility
        self.speed = float(np.linalg.norm(self.velocity))
        self.waypoint = None
        self.pause_time = 0
        self.dir_axis = None
        self.dir_sign = 1
        self.next_intersection = None

    def clear_channel(self):
        self.channel = []
        self.channel_SINR = []
        self.SINR = -100.0
        self.mimo_layers = []
        self.data_rate = 0.0

    def calculate_data_rate(self):
        """Aggregate rate across all assigned channels with MIMO."""
        self.data_rate = 0.0
        self.mimo_layers = []

        for i, ch in enumerate(self.channel):
            bw_eff = ch.bandwidth * NR_OVERHEAD
            SINR_dB = self.channel_SINR[i]
            max_rank = MIMO_MAX_RANK[ch.base_station.type_bs]

            L, total_se = mimo_rank_and_total_se(
                SINR_dB, max_rank, gap_db=SNR_GAP_DB, max_se=MAX_SE
            )
            dr_Mbps = (bw_eff * total_se) / 1e6
            self.mimo_layers.append(L)
            self.data_rate += dr_Mbps

    def calculate_demand_from_rng(self, rng):
        """Random traffic demand model."""
        if getattr(self, "service_class", "infotainment") == "safety":
            base_mbps = rng.uniform(0.5, 2.0)
        else:
            app_types = {"video": 5.0, "gaming": 10.0, "browsing": 2.0}
            app = rng.choice(list(app_types.keys()))
            base_mbps = app_types[app] * (1.0 + rng.uniform(0.0, 0.5))
        self.demand = float(base_mbps)

    def generate_task(self, rng, heavy_ratio, ue_cpu,
                      heavy_cyc_range, heavy_data_range,
                      light_cyc_range, light_data_range):
        """
        Assign a compute task to this user.

        heavy_ratio : fraction of users that get heavy (offload-mandatory) tasks
        ue_cpu      : UE local compute budget (cycles/step)
        *_range     : (lo, hi) for task cycles / input-data Mbit
        """
        if rng.random() < heavy_ratio:
            self.task_type = "heavy"    # MUST offload
            self.task_cycles = float(rng.uniform(*heavy_cyc_range))
            self.task_input_Mbit = float(rng.uniform(*heavy_data_range))
        else:
            self.task_type = "light"    # can run locally
            self.task_cycles = float(rng.uniform(*light_cyc_range))
            self.task_input_Mbit = float(rng.uniform(*light_data_range))
        self.task_offload_mandatory = (self.task_cycles > ue_cpu)

    def calculate_latency_ms(self, num_users_on_channel: float = None):
        """Very simplified base latency model (communication-centric)."""
        if not self.channel or self.data_rate <= 0:
            return 1000.0

        avg_d = np.mean(
            [
                np.linalg.norm(self.location - ch.base_station.location)
                for ch in self.channel
            ]
        )
        prop_delay_ms = (avg_d / 3e8) * 1e3
        proc_delay = 1.0
        sched_delay = 1.0

        if num_users_on_channel is None:
            num_users_on_channel = (
                np.mean([len(ch.users) for ch in self.channel])
                if self.channel
                else 1.0
            )

        queue_delay = 1.0 + num_users_on_channel / (self.data_rate + 1e-6)

        return float(
            np.clip(
                prop_delay_ms + proc_delay + sched_delay + queue_delay,
                0.0,
                1000.0,
            )
        )


# -----------------------
# Main environment class
# -----------------------
class MultiAgentMobileNetwork(MultiAgentEnv):
    """Multi-agent cellular + MEC environment (Gymnasium-style MA API)."""

    metadata = {"render_modes": ["human"], "render_fps": 30}

    def __init__(
        self,
        num_base_stations=4,
        num_users=80,
        num_channels_per_carrier=50,
        area_size=2000.0,
        bs_loc=None,
        max_steps=200,
        mobility_model="manhattan",
        seed=42,
        step_duration_s=1.0,
        deadline_ms=100.0,
        safety_traffic_ratio=0.3,
    ):
        super().__init__()

        # RNGs
        self.seed(seed)

        # topology / sim parameters
        self.num_base_stations = int(num_base_stations)
        self.num_users = int(num_users)
        self.num_channels_per_carrier = int(num_channels_per_carrier)
        self.area_size = float(area_size)
        self.max_steps = int(max_steps)
        self.mobility_model = mobility_model

        # time / QoS
        self.step_duration_s = float(step_duration_s)
        self.deadline_ms = float(deadline_ms)
        self.safety_traffic_ratio = float(
            np.clip(safety_traffic_ratio, 0.0, 1.0)
        )

        # radio parameters
        self.ma_transmission_power = 40000.0  # mW (40 W)
        self.max_ma_channels = int(num_channels_per_carrier)
        self.macro_carrier_frequencies = (
            [3.5e9] if MACRO_REUSE_ONE else [3.4e9, 3.5e9, 3.6e9, 3.7e9]
        )
        self.macro_channel_bw = 180e3  # Hz

        # MEC / compute parameters
        self.mec_cpu_capacity_cycles = 50e9
        self.cycles_per_Mbit = 5e7
        self.cpu_kappa = 1e-27
        self.max_user_demand_Mbps = 10.0

        # ---- Task-model parameters (heterogeneous compute requirements) ----
        # Each user generates a task per step with compute_cycles & input_data.
        # "heavy" tasks EXCEED local UE capacity -> MUST offload to MEC.
        # "light" tasks fit on UE -> can run locally or be offloaded.
        self.heavy_task_ratio = 0.70          # 70% users get heavy tasks
        self.ue_local_cpu_cycles = 0.5e9      # UE compute budget per step (0.5 GHz)
        # Heavy tasks: 1-5 Gcycles  (well above UE capacity)
        self.heavy_task_cycles_range = (0.5e9, 2.5e9)
        self.heavy_task_data_range = (2.0, 8.0)     # input data in Mbit
        # Light tasks: 0.05-0.4 Gcycles (fit on UE)
        self.light_task_cycles_range = (0.05e9, 0.4e9)
        self.light_task_data_range = (0.2, 1.5)      # input data in Mbit
        # Penalty: attempting to run a heavy task locally -> huge delay
        self.local_heavy_penalty_ms = 4000.0

        # reward weights
        self.reward_weights = SimpleNamespace(
            w_lat=0.2,
            w_thr=0.3,
            w_dead=0.2,
            w_qoe=0.3,
            w_eng=0.05,
            w_block=0.2,
            w_fair=0.1,
        )

        # objects
        self.users = []
        self.base_stations = []

        # BS placement
        if bs_loc is None:
            bs_loc = self._default_bs_locations(
                self.num_base_stations, self.area_size
            )
        assert len(bs_loc) >= self.num_base_stations

        for i in range(self.num_base_stations):
            bs = BaseStation(
                i,
                self.ma_transmission_power,
                30.0,
                bs_loc[i],
                type_bs="Ma",
                mec_cpu_capacity_cycles=self.mec_cpu_capacity_cycles,
            )
            self.base_stations.append(bs)

        # build macro channels
        self.macro_channels = []
        ch_id = 0
        for f in self.macro_carrier_frequencies:
            for _ in range(self.num_channels_per_carrier):
                self.macro_channels.append(
                    Channel(
                        ch_id,
                        f,
                        self.macro_channel_bw,
                        noise_figure_db=7.0,
                    )
                )
                ch_id += 1

        # spawn users
        rng = self.np_random
        for u_id in range(self.num_users):
            if self.mobility_model == "manhattan":
                loc, vel = self._spawn_on_grid()
            else:
                loc = rng.uniform(0, self.area_size, 2)
                vel = rng.uniform(-5.0, 5.0, 2)

            u = User(u_id, loc, vel)
            svc = (
                "safety"
                if rng.random() < self.safety_traffic_ratio
                else "infotainment"
            )
            u.service_class = svc
            u.calculate_demand_from_rng(rng)
            u.generate_task(
                rng, self.heavy_task_ratio, self.ue_local_cpu_cycles,
                self.heavy_task_cycles_range, self.heavy_task_data_range,
                self.light_task_cycles_range, self.light_task_data_range,
            )
            self.users.append(u)

            if self.mobility_model == "manhattan":
                self._init_user_manhattan(u)

        # multi-agent API ids
        self.agents = [f"agent_{i}" for i in range(self.num_base_stations)]
        self.possible_agents = list(self.agents)
        self._agent_ids = set(self.agents)

        # action: (power_frac, channel_frac, offload_frac, cpu_frac)
        self.action_spaces = {
            a: gym.spaces.Box(
                low=np.array([0.0, 0.0, 0.0, 0.0], dtype=np.float32),
                high=np.array([1.0, 1.0, 1.0, 1.0], dtype=np.float32),
                dtype=np.float32,
            )
            for a in self.agents
        }

        # 19-D observation
        obs_dim = len(vars(OBS_IDX))
        self.observation_spaces = {
            a: gym.spaces.Box(
                low=0.0, high=1.0, shape=(obs_dim,), dtype=np.float32
            )
            for a in self.agents
        }

        # simulation state
        self.num_steps = 0
        self.current_episode_reward = 0.0
        self.assigned_channels = {}
        self.bs_carrier_frequency = {}

        self._assign_frequency_subsets()
        self.reset_user_info()

        # normalization constants
        self.energy_normalization_J = (
            self.num_base_stations
            * self.ma_transmission_power
            * 1e-3
            * self.step_duration_s
        )
        self.throughput_normalization_Mbps = (
            self.num_users * self.max_user_demand_Mbps
        )

        self.fig = None
        self._panel_axes = None

        # shared spaces for RLlib
        first_agent = self.agents[0]
        self.observation_space = self.observation_spaces[first_agent]
        self.action_space = self.action_spaces[first_agent]

    # -------------
    # RNG helpers
    # -------------
    def seed(self, seed=None):
        if seed is None:
            seed = random.randrange(2**31 - 1)
        seed_int = int(seed) & 0xFFFFFFFF
        self.np_random, _ = seeding.np_random(seed_int)
        random.seed(seed_int)
        np.random.seed(seed_int)
        return [seed_int]

    # -------------
    # Topology helpers
    # -------------
    def _default_bs_locations(self, n, L):
        """Simple grid-based macro deployment."""
        coords = []
        grid = int(math.ceil(math.sqrt(n)))
        xs = np.linspace(0.2 * L, 0.8 * L, grid)
        ys = np.linspace(0.2 * L, 0.8 * L, grid)
        for x in xs:
            for y in ys:
                coords.append((float(x), float(y)))
                if len(coords) >= n:
                    return coords[:n]
        return coords[:n]

    def _assign_frequency_subsets(self):
        """Assign each BS to a carrier (reuse pattern)."""
        idx = 0
        for bs in self.base_stations:
            if MACRO_REUSE_ONE:
                self.bs_carrier_frequency[bs.id] = (
                    self.macro_carrier_frequencies[0]
                )
            else:
                self.bs_carrier_frequency[bs.id] = (
                    self.macro_carrier_frequencies[
                        idx % len(self.macro_carrier_frequencies)
                    ]
                )
                idx += 1

    # -------------
    # Manhattan mobility
    # -------------
    def _build_road_grid(self):
        L = self.area_size
        spacing = max(50.0, float(250.0))
        self.grid_xs = np.arange(0.0, L + 1e-9, spacing)
        self.grid_ys = np.arange(0.0, L + 1e-9, spacing)

    def _spawn_on_grid(self):
        if not hasattr(self, "grid_xs"):
            self._build_road_grid()

        L = self.area_size
        if self.np_random.random() < 0.5:
            # horizontal road
            y = float(self.np_random.choice(self.grid_ys))
            x = float(self.np_random.uniform(0, L))
            dir_axis, dir_sign = "x", (1 if self.np_random.random() < 0.5 else -1)
        else:
            # vertical road
            x = float(self.np_random.choice(self.grid_xs))
            y = float(self.np_random.uniform(0, L))
            dir_axis, dir_sign = "y", (1 if self.np_random.random() < 0.5 else -1)

        speed = float(max(1.0, self.np_random.normal(12.0, 3.0)))
        if dir_axis == "x":
            vel = np.array([dir_sign * speed, 0.0], dtype=float)
        else:
            vel = np.array([0.0, dir_sign * speed], dtype=float)

        return np.array([x, y], dtype=float), vel

    def _init_user_manhattan(self, u: User):
        if not hasattr(self, "grid_xs"):
            self._build_road_grid()

        u.location = self._snap_to_grid(u.location)
        if abs(u.velocity[0]) >= abs(u.velocity[1]):
            u.dir_axis = "x"
            u.dir_sign = 1 if u.velocity[0] >= 0 else -1
        else:
            u.dir_axis = "y"
            u.dir_sign = 1 if u.velocity[1] >= 0 else -1

        u.speed = float(max(1.0, np.linalg.norm(u.velocity)))

        if u.dir_axis == "x":
            candidates = (
                self.grid_xs[self.grid_xs > u.location[0]]
                if u.dir_sign > 0
                else self.grid_xs[self.grid_xs < u.location[0]]
            )
            if u.dir_sign > 0:
                coord = candidates.min() if candidates.size else self.area_size
            else:
                coord = candidates.max() if candidates.size else 0.0
            u.next_intersection = np.array(
                [coord, self._snap_to_grid(u.location)[1]], dtype=float
            )
        else:
            candidates = (
                self.grid_ys[self.grid_ys > u.location[1]]
                if u.dir_sign > 0
                else self.grid_ys[self.grid_ys < u.location[1]]
            )
            if u.dir_sign > 0:
                coord = candidates.min() if candidates.size else self.area_size
            else:
                coord = candidates.max() if candidates.size else 0.0
            u.next_intersection = np.array(
                [self._snap_to_grid(u.location)[0], coord], dtype=float
            )
        u.pause_time = 0

    def _snap_to_grid(self, p):
        if not hasattr(self, "grid_xs"):
            self._build_road_grid()
        x = self.grid_xs[np.argmin(np.abs(self.grid_xs - p[0]))]
        y = self.grid_ys[np.argmin(np.abs(self.grid_ys - p[1]))]
        return np.array([x, y], dtype=float)

    def _advance_user_manhattan(self, u: User):
        if u.pause_time > 0:
            u.pause_time -= 1
            return

        delta = u.next_intersection - u.location
        dist = float(np.linalg.norm(delta))
        step = min(dist, u.speed)
        if dist > 1e-9:
            u.location += (delta / dist) * step

        # reached intersection or step exhausted
        if (
            np.linalg.norm(u.location - u.next_intersection) <= 1e-6
            or step == dist
        ):
            # occasional pause
            if self.np_random.random() < 0.15:
                u.pause_time = int(self.np_random.integers(0, 4))

            # turn decisions
            r = self.np_random.random()
            if r < 0.25:
                u.dir_axis = "y" if u.dir_axis == "x" else "x"
                u.dir_sign = -u.dir_sign
            elif r < 0.5:
                u.dir_axis = "y" if u.dir_axis == "x" else "x"

            u.speed = float(max(1.0, self.np_random.normal(12.0, 3.0)))

            if u.dir_axis == "x":
                if u.dir_sign > 0:
                    candidates = self.grid_xs[self.grid_xs > u.location[0]]
                    x_next = candidates.min() if candidates.size > 0 else self.area_size
                else:
                    candidates = self.grid_xs[self.grid_xs < u.location[0]]
                    x_next = candidates.max() if candidates.size > 0 else 0.0
                u.next_intersection = np.array(
                    [x_next, self._snap_to_grid(u.location)[1]], dtype=float
                )
                u.velocity = np.array([u.dir_sign * u.speed, 0.0], dtype=float)
            else:
                if u.dir_sign > 0:
                    candidates = self.grid_ys[self.grid_ys > u.location[1]]
                    y_next = candidates.min() if candidates.size > 0 else self.area_size
                else:
                    candidates = self.grid_ys[self.grid_ys < u.location[1]]
                    y_next = candidates.max() if candidates.size > 0 else 0.0
                u.next_intersection = np.array(
                    [self._snap_to_grid(u.location)[0], y_next], dtype=float
                )
                u.velocity = np.array([0.0, u.dir_sign * u.speed], dtype=float)

    # -------------
    # User / BS state helpers
    # -------------
    def reset_user_info(self):
        """Per-user association / channel bookkeeping."""
        self.user_info = {
            u.id: {
                "user": u.id,
                "ma_assigned_channel": [],
                "ma_base_station": [],
                "ma_base_station_location": [],
            }
            for u in self.users
        }

    def assign_channels_on_demand(self):
        """UE association and 1-channel assignment per UE to its best BS."""
        for u in self.users:
            u.clear_channel()

        for bs in self.base_stations:
            for ch in bs.assigned_channels:
                ch.users = []

        for u in self.users:
            best_bs, _ = self._best_bs_in_cov(u, type_filter="Ma")
            if best_bs:
                ch = best_bs.find_available_channel()
                if ch:
                    u.channel.append(ch)
                    ch.users.append(u)
                    info = self.user_info[u.id]
                    info["ma_assigned_channel"].append(ch.id)
                    info["ma_base_station"].append(best_bs.id)
                    info["ma_base_station_location"].append(
                        best_bs.location.copy()
                    )

    def _per_channel_tx_power_mW(self, bs: BaseStation):
        if bs.per_channel_power:
            vals = list(bs.per_channel_power.values())
            return float(np.mean(vals))
        n = max(1, len(bs.assigned_channels))
        return bs.transmit_power / n

    def _noise_mW_for(self, bs: BaseStation):
        """Noise (mW) for BS based on reference channel bandwidth."""
        if bs.assigned_channels:
            return bs.assigned_channels[0].calculate_noise_power() * 1e3
        # fallback
        bw_hz = self.macro_channel_bw
        k = 1.380649e-23
        T = 293.15
        NF = 10 ** (7 / 10)
        return k * T * bw_hz * NF * 1e3

    def _est_rate_one_channel_Mbps(self, u: User, bs: BaseStation):
        """Estimated per-channel rate for association decisions."""
        if not bs.assigned_channels:
            return 0.0

        f = self.bs_carrier_frequency[bs.id]
        d = float(np.linalg.norm(u.location - bs.location))
        PL_dB = bs.calculate_path_loss(d, f)

        n_ch = max(1, len(bs.assigned_channels))
        p_ch = bs.transmit_power / n_ch

        g = BEAM_GAIN_DB[bs.type_bs]
        g_tx = 10 ** (g["tx_main"] / 10.0)
        g_rx = 10 ** (g["rx"] / 10.0)

        sig_mW = p_ch * g_tx * g_rx / (10.0 ** (PL_dB / 10.0))
        noise_mW = self._noise_mW_for(bs)

        # ignore inter-cell interference in this quick estimate
        SINR = sig_mW / max(noise_mW, 1e-12)
        SINR_dB = 10.0 * np.log10(max(SINR, 1e-12))

        bw = bs.assigned_channels[0].bandwidth * NR_OVERHEAD
        _, total_se = mimo_rank_and_total_se(
            SINR_dB, MIMO_MAX_RANK[bs.type_bs], gap_db=SNR_GAP_DB, max_se=MAX_SE
        )
        return (bw * total_se) / 1e6

    def _best_bs_in_cov(self, u: User, type_filter=None):
        """Select BS with best rate*fairness score among those covering user."""
        best = None
        best_score = 0.0

        for bs in self.base_stations:
            if type_filter is not None and bs.type_bs != type_filter:
                continue
            if not bs.assigned_channels:
                continue

            d = np.linalg.norm(u.location - bs.location)
            if d > bs.coverage_area:
                continue

            r = self._est_rate_one_channel_Mbps(u, bs)
            load = (
                sum(1 for c in bs.assigned_channels if len(c.users) > 0)
                / max(1, len(bs.assigned_channels))
            )
            fairness = 1.0 - 0.5 * load
            score = r * fairness
            if score > best_score:
                best_score = score
                best = bs

        return best, best_score

    def _estimate_interference_mW(self, u: User, f, exclude_bs: BaseStation):
        """Downlink inter-cell interference (mW) from co-channel BSs."""
        co_bs = [
            b
            for b in self.base_stations
            if b is not exclude_bs and self.bs_carrier_frequency[b.id] == f
        ]
        I = 0.0
        g_rx_int = 10 ** (UE_INTERF_RX_DB / 10.0)

        for bi in co_bs:
            if not bi.assigned_channels:
                continue

            p_i = self._per_channel_tx_power_mW(bi)
            d_i = np.linalg.norm(u.location - bi.location)
            PL_i = bi.calculate_path_loss(d_i, f)

            gi = BEAM_GAIN_DB[bi.type_bs]
            g_tx_i = 10 ** (gi["tx_side"] / 10.0)

            users_in_cov_bi = [
                uu
                for uu in self.users
                if np.linalg.norm(uu.location - bi.location)
                <= bi.coverage_area
            ]
            util = min(
                1.0, len(users_in_cov_bi) / max(1, len(bi.assigned_channels))
            )

            I += (
                util
                * p_i
                * g_tx_i
                * g_rx_int
                / (10.0 ** (PL_i / 10.0))
            )

        return I

    # -------------
    # Water-filling power allocation
    # -------------
    @staticmethod
    def _waterfill(P_total, h_list, n_list, p_floor_list=None, tol=1e-6, max_it=200):
        """Classical water-filling with optional minimum powers (p_floor_list)."""
        K = len(h_list)
        if K == 0:
            return []

        h = np.asarray(h_list, dtype=float)
        n = np.asarray(n_list, dtype=float)
        p_floor = (
            np.zeros(K, dtype=float)
            if p_floor_list is None
            else np.asarray(p_floor_list, dtype=float)
        )

        mask = h > 0
        if not np.any(mask):
            return [0.0] * K

        p_floor_sum = float(np.sum(np.maximum(p_floor, 0.0)))
        if p_floor_sum > P_total and p_floor_sum > 0:
            scaled = P_total * (p_floor / p_floor_sum)
            return list(np.maximum(scaled, 0.0))

        def alloc(lmbd):
            base = 1.0 / max(lmbd, 1e-18)
            out = np.maximum(p_floor, base - n / np.maximum(h, 1e-18))
            return np.maximum(out, 0.0)

        lo, hi = 0.0, 1e12
        for _ in range(max_it):
            mid = 0.5 * (lo + hi)
            p = alloc(mid)
            s = float(np.sum(p))
            if abs(s - P_total) <= tol:
                return list(np.maximum(p, 0.0))
            if s > P_total:
                lo = mid
            else:
                hi = mid

        return list(np.maximum(alloc(hi), 0.0))

    # -------------
    # Core RL API (Gymnasium-style MA)
    # -------------
    def step(self, action_dict):
        """
        Gymnasium-style multi-agent step.

        Returns:
            obs (dict): agent_id -> observation
            rewards (dict): agent_id -> reward (float)
            terminateds (dict): agent_id -> bool, plus "__all__"
            truncateds (dict): agent_id -> bool, plus "__all__"
            infos (dict): agent_id -> info dict
        """
        start_wall = time.time()
        self.num_steps += 1

        # --------- parse / clip actions ----------
        for agent in self.agents:
            if agent not in action_dict:
                action_dict[agent] = np.array(
                    [0.5, 0.5, 0.5, 0.5], dtype=float
                )
            action_dict[agent] = np.clip(
                np.array(action_dict[agent], dtype=float),
                0.0,
                1.0,
            )

        # --------- traffic demand & task update ----------
        for u in self.users:
            if self.np_random.random() < 0.05:
                u.calculate_demand_from_rng(self.np_random)
            # Re-generate task every step (new task arrival each TTI)
            u.generate_task(
                self.np_random, self.heavy_task_ratio, self.ue_local_cpu_cycles,
                self.heavy_task_cycles_range, self.heavy_task_data_range,
                self.light_task_cycles_range, self.light_task_data_range,
            )

        # --------- clear previous associations & channel assignments ----------
        for u in self.users:
            u.clear_channel()

        for bs in self.base_stations:
            bs.clear_assigned_channels()
            # keep MEC queues across steps (do not reset)

        for ch in self.macro_channels:
            ch.users = []
            ch.base_station = None

        self.assigned_channels.clear()
        self.reset_user_info()

        # --------- resource allocation per BS: power, channels, offload, CPU ----------
        for i, bs in enumerate(self.base_stations):
            agent = f"agent_{i}"
            power_frac, channel_frac, offload_frac, cpu_frac = action_dict[
                agent
            ]

            # power allocation
            bs.transmit_power = float(
                np.clip(power_frac, 0.0, 1.0)
            ) * self.ma_transmission_power

            # channel allocation
            max_cap = int(self.max_ma_channels)
            req_ch = int(
                np.rint(
                    float(np.clip(channel_frac, 0.0, 1.0)) * max_cap
                )
            )

            if req_ch == 0 and bs.transmit_power > 1e-9:
                req_ch = 1

            freq = self.bs_carrier_frequency[bs.id]
            avail = [
                c
                for c in self.macro_channels
                if c.frequency == freq and c.base_station is None
            ]
            req_ch = min(len(avail), req_ch)

            if req_ch > 0:
                chosen = avail[:req_ch]
                bs.assign_channels(chosen)
                for ch in chosen:
                    self.assigned_channels[ch] = bs.id

            # MEC-related controls
            bs.offload_frac = float(np.clip(offload_frac, 0.0, 1.0))
            bs.cpu_util_frac = float(np.clip(cpu_frac, 0.0, 1.0))
            bs.last_cpu_used = bs.cpu_util_frac * bs.mec_cpu_capacity

            bs.update_coverage_area_from_power(bs.transmit_power, freq)

        # --------- user association and 1ch-per-user assignment ----------
        self.assign_channels_on_demand()

        # --------- per-BS water-filling ----------
        for bs in self.base_stations:
            bs.per_channel_power = {}
            ch_act = []
            H = []
            N = []
            floors = []

            for ch in bs.assigned_channels:
                if not ch.users:
                    continue

                # simple single-UE-per-channel view (first user)
                u = ch.users[0]
                f = ch.frequency
                d = float(np.linalg.norm(u.location - bs.location))
                PL_dB = bs.calculate_path_loss(d, f)

                g = BEAM_GAIN_DB[bs.type_bs]
                h_linear = (
                    10 ** (g["tx_main"] / 10.0)
                    * 10 ** (g["rx"] / 10.0)
                ) / (10.0 ** (PL_dB / 10.0))

                noise_mW = ch.calculate_noise_power() * 1e3
                I_mW = self._estimate_interference_mW(u, f, bs)

                prio = float(
                    np.clip(
                        0.5 + (u.demand / self.max_user_demand_Mbps),
                        0.5,
                        2.0,
                    )
                )
                N_eff = (noise_mW + I_mW) / prio

                ch_act.append(ch)
                H.append(h_linear)
                N.append(N_eff)
                floors.append(0.0)

            if ch_act:
                P_total = float(bs.transmit_power)
                p_list = self._waterfill(
                    P_total,
                    H,
                    N,
                    p_floor_list=floors,
                    tol=1e-6,
                    max_it=120,
                )
                for ch, p in zip(ch_act, p_list):
                    bs.per_channel_power[ch.id] = float(max(p, 0.0))
            else:
                bs.per_channel_power = {}

            f = self.bs_carrier_frequency[bs.id]
            bs.update_coverage_area_from_power(bs.transmit_power, f)

        # --------- SINR & rates ----------
        for u in self.users:
            self.calculate_SINR(u)
            u.calculate_data_rate()

        # --------- MEC queue dynamics & compute delays (task-aware) ----------
        bs_to_users = defaultdict(list)
        for u in self.users:
            if u.channel:
                bs = u.channel[0].base_station
                if bs is not None:
                    bs_to_users[bs.id].append(u)

        user_comp_delay_ms = {u.id: 0.0 for u in self.users}

        for bs in self.base_stations:
            assoc_users = bs_to_users.get(bs.id, [])

            off_frac = float(np.clip(bs.offload_frac, 0.0, 1.0))
            cpu_frac = float(np.clip(bs.cpu_util_frac, 0.0, 1.0))
            F_max = bs.mec_cpu_capacity
            F_used = cpu_frac * F_max
            bs.last_cpu_used = F_used

            # ---- Partition users into offloaded vs local ----
            offloaded = []       # (user, cycles) pairs sent to MEC
            total_new_cycles = 0.0

            for u in assoc_users:
                C = u.task_cycles  # per-user task compute requirement

                if u.task_offload_mandatory:
                    # Heavy task: MUST offload regardless of off_frac
                    offloaded.append((u, C))
                    total_new_cycles += C
                else:
                    # Light task: agent's off_frac decides
                    if self.np_random.random() < off_frac:
                        offloaded.append((u, C))
                        total_new_cycles += C
                    else:
                        # Run locally on UE — fast for light tasks
                        local_delay_s = C / max(self.ue_local_cpu_cycles, 1e-9)
                        user_comp_delay_ms[u.id] += local_delay_s * 1000.0

            # ---- MEC queue update ----
            q_prev = bs.mec_queue_cycles
            mu_cycles = F_used * self.step_duration_s
            q_after_serv = max(q_prev - mu_cycles, 0.0)
            q_next = q_after_serv + total_new_cycles

            if F_used > 0.0:
                queue_delay_s = q_after_serv / F_used
            else:
                queue_delay_s = (
                    self.deadline_ms / 1000.0 * 10.0
                )

            n_off = len(offloaded)
            for (u, C_cycles) in offloaded:
                if F_used > 0.0 and n_off > 0:
                    f_share = F_used / n_off
                    T_proc_s = C_cycles / max(f_share, 1e-9)
                    T_queue_s = queue_delay_s
                else:
                    T_proc_s = self.deadline_ms / 1000.0 * 10.0
                    T_queue_s = self.deadline_ms / 1000.0 * 10.0

                comp_ms = (T_proc_s + T_queue_s) * 1000.0
                comp_ms = float(np.clip(comp_ms, 0.0, 5000.0))
                user_comp_delay_ms[u.id] += comp_ms

            bs.mec_queue_cycles = float(q_next)

        # ---------------- BS-level throughput for fairness across BSs ----------------
        bs_served = []
        for bs in self.base_stations:
            assoc_users = bs_to_users.get(bs.id, [])
            local_served = sum(
                min(u.data_rate, u.demand) for u in assoc_users
            )
            bs_served.append(local_served)
        bs_served_arr = np.asarray(bs_served, dtype=float)
        if np.any(bs_served_arr > 0):
            jain_num_bs = float(np.sum(bs_served_arr) ** 2)
            jain_den_bs = float(
                len(bs_served_arr) * np.sum(bs_served_arr**2) + 1e-9
            )
            jain_fairness_bs = float(jain_num_bs / jain_den_bs)
        else:
            jain_fairness_bs = 0.0

        # --------- QoE metrics: throughput, latency, energy, fairness ----------
        served_rates = []
        latencies = []
        qoe_list = []
        deadline_hits = 0
        deadline_candidates = 0

        svc_stats = {
            "safety": {
                "served_rates": [],
                "latencies": [],
                "qoes": [],
                "deadline_hits": 0,
                "deadline_candidates": 0,
            },
            "infotainment": {
                "served_rates": [],
                "latencies": [],
                "qoes": [],
                "deadline_hits": 0,
                "deadline_candidates": 0,
            },
        }

        for u in self.users:
            svc = getattr(u, "service_class", "infotainment")

            served = min(u.data_rate, u.demand)
            served_rates.append(served)

            bucket = svc_stats.get(svc, None)
            if bucket is not None:
                bucket["served_rates"].append(served)

            base_lat = u.calculate_latency_ms()
            lat = base_lat + user_comp_delay_ms.get(u.id, 0.0)
            latencies.append(lat)
            if bucket is not None:
                bucket["latencies"].append(lat)

            if u.demand > 0:
                deadline_candidates += 1
                if lat <= self.deadline_ms:
                    deadline_hits += 1

                if bucket is not None:
                    bucket["deadline_candidates"] += 1
                    if lat <= self.deadline_ms:
                        bucket["deadline_hits"] += 1

            if u.demand > 0:
                thr_norm = np.clip(served / u.demand, 0.0, 1.0)
            else:
                thr_norm = 0.0
            if lat <= self.deadline_ms:
                lat_factor = 1.0
            else:
                lat_factor = max(
                    0.0,
                    1.0 - (lat - self.deadline_ms) / (5 * self.deadline_ms),
                )
            qoe = 0.5 * thr_norm + 0.5 * lat_factor
            qoe_clipped = float(np.clip(qoe, 0.0, 1.0))
            qoe_list.append(qoe_clipped)
            if bucket is not None:
                bucket["qoes"].append(qoe_clipped)

        # throughput metrics (Mbps)
        total_throughput_Mbps = float(np.sum(served_rates))
        avg_throughput_Mbps = float(
            total_throughput_Mbps / max(1, self.num_users)
        )

        # latency metrics
        if latencies:
            avg_latency_ms = float(np.mean(latencies))
            p95_latency_ms = float(np.percentile(latencies, 95))
        else:
            avg_latency_ms = 0.0
            p95_latency_ms = 0.0

        # deadline satisfaction
        if deadline_candidates > 0:
            deadline_satisfaction = float(
                deadline_hits / max(1, deadline_candidates)
            )
        else:
            deadline_satisfaction = 0.0

        # fairness (Jain's index) over users (for logging only)
        served_arr = np.asarray(served_rates, dtype=float)
        if np.any(served_arr > 0):
            jain_num_users = float(np.sum(served_arr) ** 2)
            jain_den_users = float(
                len(served_arr) * np.sum(served_arr**2) + 1e-9
            )
            jain_fairness_users = float(jain_num_users / jain_den_users)
        else:
            jain_fairness_users = 0.0

        # Use BS-level fairness in the reward
        jain_fairness = jain_fairness_bs

        # energy metrics
        total_radio_power_mW = float(
            np.sum([bs.transmit_power for bs in self.base_stations])
        )
        total_cpu_power_W = float(
            np.sum(
                [self.cpu_kappa * (bs.last_cpu_used**3) for bs in self.base_stations]
            )
        )
        step_energy_J = (
            total_radio_power_mW * 1e-3 * self.step_duration_s
            + total_cpu_power_W * self.step_duration_s
        )

        satisfied_tasks = deadline_hits
        if satisfied_tasks > 0:
            energy_per_task_J = float(step_energy_J / satisfied_tasks)
        else:
            energy_per_task_J = 0.0

        # blocking rate: users without any channel
        blocked_users = [u for u in self.users if not u.channel]
        blocking_rate = float(len(blocked_users) / max(1, self.num_users))

        # QoE statistics
        if qoe_list:
            avg_qoe = float(np.mean(qoe_list))
        else:
            avg_qoe = 0.0

        # ---------------- service-class metrics (for ITS-oriented analysis) ----------------
        def _svc_metrics(bucket):
            if not bucket["served_rates"]:
                return {
                    "avg_throughput_Mbps": 0.0,
                    "avg_latency_ms": 0.0,
                    "p95_latency_ms": 0.0,
                    "deadline_satisfaction": 0.0,
                    "avg_qoe": 0.0,
                }
            s_rates = np.asarray(bucket["served_rates"], dtype=float)
            lats = np.asarray(bucket["latencies"], dtype=float)
            qoes = np.asarray(bucket["qoes"], dtype=float)

            if lats.size > 0:
                avg_lat = float(np.mean(lats))
                p95_lat = float(np.percentile(lats, 95))
            else:
                avg_lat = 0.0
                p95_lat = 0.0

            if s_rates.size > 0:
                avg_tput = float(np.mean(s_rates))
            else:
                avg_tput = 0.0

            if bucket["deadline_candidates"] > 0:
                ds = float(
                    bucket["deadline_hits"]
                    / max(1, bucket["deadline_candidates"])
                )
            else:
                ds = 0.0

            if qoes.size > 0:
                avg_qoe_svc = float(np.mean(qoes))
            else:
                avg_qoe_svc = 0.0

            return {
                "avg_throughput_Mbps": avg_tput,
                "avg_latency_ms": avg_lat,
                "p95_latency_ms": p95_lat,
                "deadline_satisfaction": ds,
                "avg_qoe": avg_qoe_svc,
            }

        svc_safety = _svc_metrics(svc_stats["safety"])
        svc_infot = _svc_metrics(svc_stats["infotainment"])

        # ---------------- Normalized components (for logging) ----------------
        U_norm = float(
            np.clip(
                total_throughput_Mbps
                / max(1e-9, self.throughput_normalization_Mbps),
                0.0,
                1.0,
            )
        )

        if latencies:
            violations = [
                max(lat - self.deadline_ms, 0.0)
                / (5.0 * max(1.0, self.deadline_ms))
                for lat in latencies
            ]
            D_norm = float(np.clip(np.mean(violations), 0.0, 1.0))
        else:
            D_norm = 0.0

        E_norm = float(
            np.clip(
                step_energy_J / max(1e-9, 2.0 * self.energy_normalization_J),
                0.0,
                1.0,
            )
        )

        # ------------- Joint latency + throughput reward ----------------
        latency_ref_ms = self.deadline_ms if self.deadline_ms > 0 else 100.0

        if latency_ref_ms > 0:
            L_mean = avg_latency_ms / latency_ref_ms
            L_p95 = p95_latency_ms / (1.5 * latency_ref_ms)
        else:
            L_mean = 0.0
            L_p95 = 0.0

        L_norm = float(np.clip(0.7 * L_mean + 0.3 * L_p95, 0.0, 1.0))

        T_norm = U_norm
        V_fair = 1.0 - jain_fairness

        w = self.reward_weights
        positive = (
            w.w_thr * T_norm
            + w.w_lat * (1.0 - D_norm)
            + w.w_dead * deadline_satisfaction
            + w.w_qoe * avg_qoe
        )
        negative = (
            w.w_eng * E_norm
            + w.w_block * blocking_rate
            + w.w_fair * V_fair
        )
        global_reward = float(np.clip(positive - negative, -1.0, 1.0))

        rewards = {agent: global_reward for agent in self.agents}

        scenario_type = "urban" if self.mobility_model == "manhattan" else "highway_like"

        # --------- per-BS infos ----------
        infos = {}
        association_fractions = []
        channel_rewards = []

        for i, bs in enumerate(self.base_stations):
            agent = f"agent_{i}"
            users_in_cov = [
                u
                for u in self.users
                if np.linalg.norm(u.location - bs.location)
                <= bs.coverage_area
            ]
            assoc_users = [
                u
                for u in users_in_cov
                if any(ch.base_station == bs for ch in u.channel)
            ]

            assoc_frac = (
                len(assoc_users) / max(1, len(users_in_cov))
                if users_in_cov
                else 0.0
            )
            association_fractions.append(assoc_frac)

            ch_num = max(1, len(bs.assigned_channels))
            usr_num = max(1, len(users_in_cov))
            channel_rewards.append(
                1.0 - abs(ch_num - usr_num) / (ch_num + usr_num)
            )

            local_served = sum(
                min(u.data_rate, u.demand) for u in assoc_users
            )
            local_demand = sum(u.demand for u in assoc_users) + 1e-9
            local_util = (
                local_served / local_demand if local_demand > 0 else 0.0
            )

            if assoc_users:
                loc_latencies = [
                    latencies[self.users.index(u)] for u in assoc_users
                ]
                loc_avg_lat_ms = float(np.mean(loc_latencies))
            else:
                loc_avg_lat_ms = 0.0

            infos[agent] = {
                "local_data_rate_Mbps": float(
                    sum(u.data_rate for u in assoc_users)
                ),
                "local_served_throughput_Mbps": float(local_served),
                "local_demand_Mbps": float(local_demand),
                "local_power_mW": float(bs.transmit_power),
                "local_channels": int(len(bs.assigned_channels)),
                "users_in_cov": int(len(users_in_cov)),
                "assoc_users": int(len(assoc_users)),
                "local_avg_latency_ms": loc_avg_lat_ms,
                "local_util": float(local_util),
                "local_mec_queue_cycles": float(bs.mec_queue_cycles),
                "local_cpu_used_cycles_per_s": float(bs.last_cpu_used),
                "local_offload_frac": float(bs.offload_frac),
                "local_cpu_util_frac": float(bs.cpu_util_frac),
            }

        if association_fractions:
            mean_assoc_frac = float(np.mean(association_fractions))
        else:
            mean_assoc_frac = 0.0

        if channel_rewards:
            mean_channel_reward = float(np.mean(channel_rewards))
        else:
            mean_channel_reward = 0.0

        global_info = {
            "total_throughput_Mbps": total_throughput_Mbps,
            "avg_throughput_Mbps": avg_throughput_Mbps,
            "avg_latency_ms": avg_latency_ms,
            "p95_latency_ms": p95_latency_ms,
            "deadline_satisfaction": deadline_satisfaction,
            "blocking_rate": blocking_rate,
            "avg_qoe": avg_qoe,
            "qoe_per_user": qoe_list,
            "total_radio_power_mW": total_radio_power_mW,
            "total_cpu_power_W": total_cpu_power_W,
            "step_energy_J": step_energy_J,
            "energy_per_task_J": energy_per_task_J,
            "jain_fairness": jain_fairness,
            "jain_fairness_bs": jain_fairness_bs,
            "jain_fairness_users": jain_fairness_users,
            "num_users": int(self.num_users),
            "num_base_stations": int(self.num_base_stations),
            "mean_assoc_frac": mean_assoc_frac,
            "mean_channel_reward": mean_channel_reward,
            "env_step_walltime_ms": float(
                (time.time() - start_wall) * 1e3
            ),
            "U_norm": U_norm,
            "D_norm": D_norm,
            "E_norm": E_norm,
            "L_norm": L_norm,
            "V_fair": V_fair,
            "global_reward": global_reward,
            "reward_w_lat": self.reward_weights.w_lat,
            "reward_w_thr": self.reward_weights.w_thr,
            "reward_w_dead": self.reward_weights.w_dead,
            "reward_w_qoe": self.reward_weights.w_qoe,
            "reward_w_eng": self.reward_weights.w_eng,
            "reward_w_block": self.reward_weights.w_block,
            "reward_w_fair": self.reward_weights.w_fair,
            "scenario_type": scenario_type,
            "svc_safety_avg_throughput_Mbps": svc_safety["avg_throughput_Mbps"],
            "svc_safety_avg_latency_ms": svc_safety["avg_latency_ms"],
            "svc_safety_p95_latency_ms": svc_safety["p95_latency_ms"],
            "svc_safety_deadline_satisfaction": svc_safety["deadline_satisfaction"],
            "svc_safety_avg_qoe": svc_safety["avg_qoe"],
            "svc_infotainment_avg_throughput_Mbps": svc_infot["avg_throughput_Mbps"],
            "svc_infotainment_avg_latency_ms": svc_infot["avg_latency_ms"],
            "svc_infotainment_p95_latency_ms": svc_infot["p95_latency_ms"],
            "svc_infotainment_deadline_satisfaction": svc_infot["deadline_satisfaction"],
            "svc_infotainment_avg_qoe": svc_infot["avg_qoe"],
            "qoe_safety": svc_stats["safety"]["qoes"],
            "qoe_infotainment": svc_stats["infotainment"]["qoes"],
        }

        for agent in self.agents:
            infos[agent].update(global_info)

        self.current_episode_reward += global_reward

        # Gymnasium-style: terminateds / truncateds
        done_all = self.num_steps >= self.max_steps

        terminateds = {agent: False for agent in self.agents}
        truncateds = {agent: done_all for agent in self.agents}
        terminateds["__all__"] = False
        truncateds["__all__"] = done_all

        obs = self.get_observation()
        self.update_user_location()

        # step() -> obs, rewards, terminateds, truncateds, infos
        return obs, rewards, terminateds, truncateds, infos

    def reset(self, *, seed=None, options=None):
        """
        Gymnasium-style reset.

        Returns:
            obs (dict): agent_id -> observation
            infos (dict): agent_id -> info dict (empty at reset)
        """
        if seed is not None:
            self.seed(seed)

        self.num_steps = 0
        self.current_episode_reward = 0.0

        # reset users
        for u in self.users:
            if self.mobility_model == "manhattan":
                loc, vel = self._spawn_on_grid()
                u.location = loc
                u.velocity = vel
                self._init_user_manhattan(u)
            else:
                u.location = self.np_random.uniform(0, self.area_size, 2)
                u.waypoint = self.np_random.uniform(0, self.area_size, 2)

            svc = (
                "safety"
                if self.np_random.random() < self.safety_traffic_ratio
                else "infotainment"
            )
            u.service_class = svc
            u.calculate_demand_from_rng(self.np_random)
            u.generate_task(
                self.np_random, self.heavy_task_ratio, self.ue_local_cpu_cycles,
                self.heavy_task_cycles_range, self.heavy_task_data_range,
                self.light_task_cycles_range, self.light_task_data_range,
            )

            u.data_rate = 0.0
            u.SINR = -100.0
            u.clear_channel()

        # reset channels & BSs
        for ch in self.macro_channels:
            ch.users = []
            ch.base_station = None

        self.assigned_channels.clear()

        for bs in self.base_stations:
            bs.clear_assigned_channels()
            bs.transmit_power = self.ma_transmission_power
            bs.mec_queue_cycles = 0.0
            bs.offload_frac = 1.0
            bs.cpu_util_frac = 1.0
            bs.last_cpu_used = bs.mec_cpu_capacity

        # simple initial allocation: 1 channel per BS if available
        for bs in self.base_stations:
            freq = self.bs_carrier_frequency[bs.id]
            avail = [
                c
                for c in self.macro_channels
                if c.frequency == freq and c.base_station is None
            ]
            if avail:
                chosen = [avail[0]]
                bs.assign_channels(chosen)
                self.assigned_channels[avail[0]] = bs.id
            bs.update_coverage_area_from_power(
                bs.transmit_power, self.bs_carrier_frequency[bs.id]
            )

        self.reset_user_info()
        self.prev_assoc_by_user = {u.id: {"Ma": None} for u in self.users}

        obs = self.get_observation()
        infos = {agent: {} for agent in self.agents}
        return obs, infos

    # -------------
    # Observation & global state
    # -------------
    def get_observation(self):
        obs = {}
        max_speed = 25.0

        for i, bs in enumerate(self.base_stations):
            agent = f"agent_{i}"
            users_in_cov = [
                u
                for u in self.users
                if np.linalg.norm(u.location - bs.location)
                <= bs.coverage_area
            ]

            max_power = self.ma_transmission_power
            max_ch_for_bs = float(max(1, self.max_ma_channels))

            bs_type = 0.5
            tx_norm = np.clip(bs.transmit_power / max_power, 0.0, 1.0)

            used = sum(1 for c in bs.assigned_channels if len(c.users) > 0)
            ch_util = np.clip(used / max_ch_for_bs, 0.0, 1.0)

            cov_util = len(users_in_cov) / max(1, self.num_users)

            load_ratio = (
                len(users_in_cov)
                / max(1, len(bs.assigned_channels))
                if bs.assigned_channels
                else 0.0
            )
            load_ratio_norm = float(np.clip(load_ratio / 2.0, 0.0, 1.0))

            nearby_pot = len(
                [
                    u
                    for u in self.users
                    if np.linalg.norm(u.location - bs.location)
                    <= bs.coverage_area * 1.5
                ]
            ) / max(1, self.num_users)

            avg_speed = np.clip(
                (
                    sum(u.speed for u in users_in_cov) / len(users_in_cov)
                    if users_in_cov
                    else 0.0
                )
                / max_speed,
                0.0,
                1.0,
            )

            # approximate required power so that edge user meets SNR target
            if users_in_cov:
                max_dist = max(
                    np.linalg.norm(u.location - bs.location)
                    for u in users_in_cov
                )
                req_p_per_ch = self.calculate_required_power_for_distance(
                    max_dist, bs
                )
                req_total = req_p_per_ch * max(
                    1, len(bs.assigned_channels)
                )
            else:
                req_total = 0.0

            req_p_norm = np.clip(
                req_total / max_power if max_power > 0 else 0.0, 0.0, 1.0
            )

            # radial velocity statistics
            avg_radial_v = 0.5
            if users_in_cov:
                comps = []
                for u in users_in_cov:
                    vec = bs.location - u.location
                    dist = np.linalg.norm(vec)
                    if dist > 1e-6:
                        comp = np.dot(u.velocity, vec / dist)
                        comps.append(comp)
                if comps:
                    avg_radial = float(np.mean(comps))
                    avg_radial_v = float(
                        np.clip((avg_radial / max_speed + 1) / 2.0, 0.0, 1.0)
                    )

            sp_var = np.clip(
                np.var([u.speed for u in users_in_cov])
                / ((max_speed**2) / 4.0)
                if len(users_in_cov) > 1
                else 0.0,
                0.0,
                1.0,
            )

            # coarse interference estimate
            f = self.bs_carrier_frequency[bs.id]
            co_bs = [
                o
                for o in self.base_stations
                if o is not bs and self.bs_carrier_frequency[o.id] == f
            ]

            sampled_users = users_in_cov[: min(len(users_in_cov), 8)]
            I_b = 0.0
            g_rx = 10.0 ** (UE_INTERF_RX_DB / 10.0)

            for b2 in co_bs:
                if not b2.assigned_channels:
                    continue
                p_i = self._per_channel_tx_power_mW(b2)
                gi = BEAM_GAIN_DB[b2.type_bs]
                g_tx_i = 10.0 ** (gi["tx_side"] / 10.0)

                users_in_cov_b2 = [
                    uu
                    for uu in self.users
                    if np.linalg.norm(uu.location - b2.location)
                    <= b2.coverage_area
                ]
                util = min(
                    1.0,
                    len(users_in_cov_b2) / max(1, len(b2.assigned_channels)),
                )

                if sampled_users:
                    acc = 0.0
                    for uu in sampled_users:
                        d_i = np.linalg.norm(uu.location - b2.location)
                        PL_i = b2.calculate_path_loss(d_i, f)
                        acc += (
                            p_i
                            * g_tx_i
                            * g_rx
                            / (10.0 ** (PL_i / 10.0))
                        )
                    I_b += util * (acc / len(sampled_users))

            I_dBm = 10.0 * np.log10(max(I_b, 1e-12))
            inter_norm = np.clip((I_dBm + 120.0) / 120.0, 0.0, 1.0)

            avg_demand_norm = (
                float(
                    np.clip(
                        np.mean(
                            [u.demand for u in users_in_cov]
                        )
                        / self.max_user_demand_Mbps,
                        0.0,
                        1.0,
                    )
                )
                if users_in_cov
                else 0.0
            )

            neigh = [
                o.transmit_power / max(1.0, self.ma_transmission_power)
                for o in self.base_stations
                if o is not bs
                and np.linalg.norm(bs.location - o.location) < 1000.0
            ]
            neighbor_tx_norm = float(np.mean(neigh)) if neigh else 0.0

            mec_queue_norm = float(
                np.clip(
                    bs.mec_queue_cycles
                    / max(
                        1.0,
                        bs.mec_cpu_capacity
                        * self.step_duration_s
                        * 10.0,
                    ),
                    0.0,
                    1.0,
                )
            )
            cpu_util_norm = float(
                np.clip(
                    bs.last_cpu_used / max(1.0, bs.mec_cpu_capacity),
                    0.0,
                    1.0,
                )
            )
            offload_norm = float(np.clip(bs.offload_frac, 0.0, 1.0))

            assoc_users = [
                u
                for u in users_in_cov
                if any(ch.base_station == bs for ch in u.channel)
            ]

            if assoc_users:
                local_served = sum(
                    min(u.data_rate, u.demand) for u in assoc_users
                )
                max_served = len(assoc_users) * self.max_user_demand_Mbps
                served_ratio_norm = float(
                    np.clip(
                        local_served / max(1e-9, max_served),
                        0.0,
                        1.0,
                    )
                )
            else:
                served_ratio_norm = 0.0

            if users_in_cov:
                blocked_local = len(
                    [
                        u
                        for u in users_in_cov
                        if not any(ch.base_station == bs for ch in u.channel)
                    ]
                )
                block_frac_norm = float(
                    np.clip(
                        blocked_local / max(1, len(users_in_cov)), 0.0, 1.0
                    )
                )
            else:
                block_frac_norm = 0.0

            ch_num = len(bs.assigned_channels)
            usr_num = len(users_in_cov)
            if ch_num + usr_num > 0:
                ch_match_norm = float(
                    1.0
                    - min(1.0, abs(ch_num - usr_num) / (ch_num + usr_num))
                )
            else:
                ch_match_norm = 1.0

            # fraction of covered users whose tasks MUST be offloaded
            if users_in_cov:
                offload_mand_frac = float(
                    np.mean([1.0 if u.task_offload_mandatory else 0.0
                             for u in users_in_cov])
                )
            else:
                offload_mand_frac = 0.0

            vec_obs = np.array(
                [
                    bs_type,
                    tx_norm,
                    ch_util,
                    cov_util,
                    load_ratio_norm,
                    nearby_pot,
                    avg_speed,
                    req_p_norm,
                    avg_radial_v,
                    sp_var,
                    neighbor_tx_norm,
                    avg_demand_norm,
                    inter_norm,
                    mec_queue_norm,
                    cpu_util_norm,
                    offload_norm,
                    served_ratio_norm,
                    block_frac_norm,
                    ch_match_norm,
                    offload_mand_frac,
                ],
                dtype=np.float32,
            )
            obs[agent] = vec_obs

        return obs

    def get_global_state(self):
        """Optional centralized critic state."""
        per_bs = []
        for bs in self.base_stations:
            users_in_cov = [
                u
                for u in self.users
                if np.linalg.norm(u.location - bs.location)
                <= bs.coverage_area
            ]
            assoc_users = [
                u
                for u in users_in_cov
                if any(ch.base_station == bs for ch in u.channel)
            ]
            mean_rate = (
                float(np.mean([u.data_rate for u in assoc_users]))
                if assoc_users
                else 0.0
            )
            served_frac = (
                float(
                    sum(
                        min(u.data_rate, u.demand) for u in assoc_users
                    )
                    / max(
                        1e-9,
                        sum(u.demand for u in assoc_users),
                    )
                )
                if assoc_users
                else 0.0
            )
            per_bs.extend(
                [
                    bs.transmit_power,
                    len(bs.assigned_channels),
                    mean_rate,
                    served_frac,
                    bs.mec_queue_cycles,
                    bs.last_cpu_used,
                ]
            )
        return np.array(per_bs, dtype=np.float32)

    # -------------
    # PHY helpers
    # -------------
    def calculate_SINR(self, user: User):
        """Populate user.channel_SINR and aggregate SINR."""
        user.channel_SINR = []
        user.SINR = -100.0

        for ch in user.channel:
            bs = ch.base_station
            if bs is None:
                user.channel_SINR.append(-100.0)
                continue

            d = np.linalg.norm(user.location - bs.location)
            PL_dB = bs.calculate_path_loss(d, ch.frequency)

            p_tx_ch = bs.per_channel_power.get(ch.id, None)
            if p_tx_ch is None:
                n = max(1, len(bs.assigned_channels))
                p_tx_ch = bs.transmit_power / n

            g = BEAM_GAIN_DB[bs.type_bs]
            g_tx_main = 10.0 ** (g["tx_main"] / 10.0)
            g_rx_sig = 10.0 ** (g["rx"] / 10.0)

            signal_mW = (
                p_tx_ch * g_tx_main * g_rx_sig / (10.0 ** (PL_dB / 10.0))
            )

            interference_mW = self._estimate_interference_mW(
                user, ch.frequency, bs
            )
            noise_mW = ch.calculate_noise_power() * 1e3

            denom = max(interference_mW + noise_mW, 1e-15)
            SINR_lin = signal_mW / denom if signal_mW > 0 else 0.0
            if SINR_lin > 0:
                SINR_dB = 10.0 * np.log10(SINR_lin)
            else:
                SINR_dB = -100.0

            SINR_dB = float(np.clip(SINR_dB, -100.0, 60.0))
            user.channel_SINR.append(SINR_dB)

        if user.channel_SINR:
            s_ma = np.mean([10.0 ** (x / 10.0) for x in user.channel_SINR])
            user.SINR = 10.0 * np.log10(s_ma) if s_ma > 0 else -100.0
        else:
            user.SINR = -100.0

    def calculate_required_power_for_distance(
        self, distance_m, base_station: BaseStation
    ):
        """Required TX power (mW) so that UE at distance_m hits target SNR."""
        f = self.bs_carrier_frequency[base_station.id]
        pl_dB = base_station.calculate_path_loss(distance_m, f)

        if base_station.assigned_channels:
            bw_hz = base_station.assigned_channels[0].bandwidth
            nf_db = base_station.assigned_channels[0].noise_figure_db
        else:
            bw_hz = self.macro_channel_bw
            nf_db = 7.0

        sens_dBm = rx_sensitivity_dBm(
            bw_hz, nf_db=nf_db, snr_req_db=-5.0
        )
        g = BEAM_GAIN_DB[base_station.type_bs]
        req_tx_dBm = sens_dBm + pl_dB - (g["tx_main"] + g["rx"])

        return 10.0 ** (req_tx_dBm / 10.0)

    # -------------
    # Mobility update
    # -------------
    def update_user_location(self):
        if self.mobility_model == "manhattan":
            if not hasattr(self, "grid_xs"):
                self._build_road_grid()
            for u in self.users:
                self._advance_user_manhattan(u)
                u.location = np.clip(u.location, 0.0, self.area_size)
        else:
            L = self.area_size
            for u in self.users:
                if u.pause_time > 0:
                    u.pause_time -= 1
                    continue

                if u.waypoint is None:
                    u.waypoint = self.np_random.uniform(0, L, 2)

                delta = u.waypoint - u.location
                dist = np.linalg.norm(delta)

                if dist <= u.speed:
                    u.location = u.waypoint
                    u.pause_time = int(self.np_random.integers(0, 10))
                    u.waypoint = self.np_random.uniform(0, L, 2)
                else:
                    direction = delta / dist if dist > 0 else np.zeros(2)
                    u.velocity = direction * u.speed
                    u.location = np.clip(u.location + u.velocity, 0.0, L)

    # -------------
    # Rendering
    # -------------
    def render(self, mode="human"):
        if mode != "human":
            return

        if self.fig is None:
            self.fig, self._panel_axes = plt.subplots(1, 1, figsize=(8, 8))

        ax = self._panel_axes
        ax.clear()

        L = self.area_size
        ax.set_xlim(0, L)
        ax.set_ylim(0, L)
        ax.set_aspect("equal")

        # BSs and coverage
        for bs in self.base_stations:
            circle = plt.Circle(
                (bs.location[0], bs.location[1]),
                bs.coverage_area,
                color="C0",
                alpha=0.12,
            )
            ax.add_patch(circle)
            ax.scatter(
                bs.location[0], bs.location[1], marker="^", c="C0", s=80
            )
            ax.text(
                bs.location[0] + 5,
                bs.location[1] + 5,
                f"BS{bs.id}",
                fontsize=8,
            )

        # users and serving links
        for u in self.users:
            ax.plot(u.location[0], u.location[1], "ro", ms=4)
            for ch in u.channel:
                bs = ch.base_station
                if bs is None:
                    continue
                ax.plot(
                    [u.location[0], bs.location[0]],
                    [u.location[1], bs.location[1]],
                    "k-",
                    lw=0.6,
                    alpha=0.6,
                )

        plt.pause(0.001)

    def close(self):
        try:
            if self.fig is not None:
                plt.close(self.fig)
        except Exception:
            pass
        self.fig = None


# ==========================
# RLlib Callbacks: Episode-wise CSV logging
# ==========================
class EpisodeCSVLogger(DefaultCallbacks):
    """
    Collect scalar 'info' fields over an episode and write episode-wise means to CSV.
    Compatible with EpisodeV2.

    Important notebook fix:
    - The CSV directory is bound to the callback CLASS via CSV_BASE_DIR.
    - This avoids stale Ray workers writing into an old run directory.
    """

    CSV_BASE_DIR = None

    def __init__(self):
        super().__init__()

        base_dir = self.CSV_BASE_DIR or os.getcwd()
        os.makedirs(base_dir, exist_ok=True)

        self.csv_path = os.path.join(base_dir, "ppo_episode_metrics.csv")
        self.header_written = False
        self.fieldnames = None

        if os.path.exists(self.csv_path):
            try:
                with open(self.csv_path, "r", newline="") as f:
                    reader = csv.reader(f)
                    header = next(reader, None)
                    if header:
                        self.fieldnames = header
                        self.header_written = True
            except Exception:
                self.fieldnames = None
                self.header_written = os.path.getsize(self.csv_path) > 0

    def on_episode_step(
        self, *, worker, base_env, policies, episode, env_index, **kwargs
    ):
        info = None

        if hasattr(episode, "get_agents") and hasattr(episode, "last_info_for"):
            agent_ids = list(episode.get_agents())
            if not agent_ids:
                return
            agent_id = agent_ids[0]
            info = episode.last_info_for(agent_id)
        elif hasattr(episode, "last_info_for"):
            if hasattr(episode, "agent_ids"):
                agent_ids = list(episode.agent_ids)
                if not agent_ids:
                    return
                agent_id = agent_ids[0]
                info = episode.last_info_for(agent_id)

        if not info:
            return

        for k, v in info.items():
            if isinstance(v, (int, float)):
                episode.user_data.setdefault(k, []).append(float(v))

    def on_episode_end(
        self, *, worker, base_env, policies, episode, env_index, **kwargs
    ):
        row = {
            "episode_id": episode.episode_id,
            "episode_len": episode.length,
        }

        for k, values in episode.user_data.items():
            if not values:
                continue
            mean_val = float(np.mean(values))
            row[k] = mean_val
            episode.custom_metrics[k] = mean_val

        ep_return = None
        if "global_reward" in episode.user_data and episode.user_data["global_reward"]:
            ep_return = float(np.sum(episode.user_data["global_reward"]))

        if ep_return is None and hasattr(episode, "total_reward"):
            try:
                ep_return = float(episode.total_reward)
            except Exception:
                ep_return = None

        if ep_return is not None:
            row["episode_return"] = ep_return
            episode.custom_metrics["episode_return"] = ep_return
            print(f"[Episode {episode.episode_id}] total_reward={ep_return:.3f}")

        if self.fieldnames is None:
            self.fieldnames = list(row.keys())

        for h in self.fieldnames:
            row.setdefault(h, "")

        os.makedirs(os.path.dirname(self.csv_path), exist_ok=True)

        with open(self.csv_path, "a", newline="") as f:
            writer = csv.DictWriter(
                f,
                fieldnames=self.fieldnames,
                extrasaction="ignore",
            )
            if not self.header_written or os.path.getsize(self.csv_path) == 0:
                writer.writeheader()
                self.header_written = True
            writer.writerow(row)


def make_episode_csv_logger(run_dir):
    """Bind one callback class to one specific run directory."""
    class RunEpisodeCSVLogger(EpisodeCSVLogger):
        CSV_BASE_DIR = run_dir

    RunEpisodeCSVLogger.__name__ = f"EpisodeCSVLogger_{os.path.basename(run_dir)}"
    return RunEpisodeCSVLogger


# ==========================
# RLlib PPO SECTION (Multi-agent, shared policy)
# ==========================
def rllib_env_creator(env_config: dict):
    """RLlib env creator."""
    num_base_stations = int(env_config.get("num_base_stations", 4))
    area_size = float(env_config.get("area_size", 5000.0))
    bs_loc = env_config.get("bs_loc", None)
    if bs_loc is None:
        bs_loc = make_bs_locations(num_base_stations, area_size)

    return MultiAgentMobileNetwork(
        num_base_stations=num_base_stations,
        num_users=env_config.get("num_users", 100),
        num_channels_per_carrier=env_config.get(
            "num_channels_per_carrier", 100
        ),
        area_size=area_size,
        bs_loc=bs_loc,
        max_steps=env_config.get("max_steps", 200),
        mobility_model=env_config.get("mobility_model", "manhattan"),
        seed=env_config.get("seed", 42),
        step_duration_s=env_config.get("step_duration_s", 1.0),
        deadline_ms=env_config.get("deadline_ms", 100.0),
        safety_traffic_ratio=env_config.get("safety_traffic_ratio", 0.3),
    )



# ==========================
# Experiment helpers
# ==========================
def make_bs_locations(num_base_stations, area_size):
    """Generate a grid-like BS deployment for any BS count."""
    coords = []
    grid = int(math.ceil(math.sqrt(num_base_stations)))
    xs = np.linspace(0.2 * area_size, 0.8 * area_size, grid)
    ys = np.linspace(0.2 * area_size, 0.8 * area_size, grid)
    for x in xs:
        for y in ys:
            coords.append((float(x), float(y)))
            if len(coords) >= num_base_stations:
                return coords[:num_base_stations]
    return coords[:num_base_stations]


def get_total_env_steps(result_dict):
    """Try several keys used in different RLlib versions for total env steps."""
    for k in [
        "num_env_steps_sampled",
        "num_env_steps_sampled_lifetime",
        "timesteps_total",
    ]:
        v = result_dict.get(k, None)
        if v is not None:
            return int(v)
    return 0


def get_mean_return_and_len(result_dict):
    """Extract mean episode return/length, checking both top-level and env_runners."""
    mean_ret = result_dict.get("episode_return_mean", None)
    if mean_ret is None:
        mean_ret = result_dict.get("episode_reward_mean", None)

    mean_len = result_dict.get("episode_len_mean", None)

    env_runners = result_dict.get("env_runners", {})
    if isinstance(env_runners, dict):
        if mean_ret is None or (isinstance(mean_ret, float) and math.isnan(mean_ret)):
            mean_ret = env_runners.get(
                "episode_return_mean",
                env_runners.get("episode_reward_mean", mean_ret),
            )
        if mean_len is None or (isinstance(mean_len, float) and math.isnan(mean_len)):
            mean_len = env_runners.get("episode_len_mean", mean_len)

    if mean_ret is None:
        mean_ret = float("nan")
    if mean_len is None:
        mean_len = float("nan")

    return float(mean_ret), float(mean_len)


def safe_float(value, default=float("nan")):
    try:
        if value is None or value == "":
            return default
        return float(value)
    except Exception:
        return default


def summarize_episode_csv(csv_path, tail_fraction=0.20):
    """Summarize a run using the last tail_fraction of logged episodes."""
    if not os.path.exists(csv_path):
        return None

    with open(csv_path, "r", newline="") as f:
        rows = list(csv.DictReader(f))

    if not rows:
        return None

    start_idx = max(0, int(len(rows) * (1.0 - tail_fraction)))
    tail_rows = rows[start_idx:] if start_idx < len(rows) else rows[-1:]

    metrics = [
        "episode_return",
        "total_throughput_Mbps",
        "avg_throughput_Mbps",
        "avg_latency_ms",
        "p95_latency_ms",
        "blocking_rate",
        "jain_fairness_bs",
        "jain_fairness_users",
        "deadline_satisfaction",
        "avg_qoe",
        "step_energy_J",
        "energy_per_task_J",
        "env_step_walltime_ms",
    ]

    summary = {
        "num_episodes": len(rows),
        "tail_episodes": len(tail_rows),
    }

    for metric in metrics:
        vals = [safe_float(r.get(metric, "")) for r in tail_rows]
        vals = [v for v in vals if not math.isnan(v)]
        summary[metric] = float(np.mean(vals)) if vals else float("nan")

    return summary


def write_scalability_summary(summary_rows, out_csv_path):
    """Write one summary row per BS count."""
    if not summary_rows:
        return

    fieldnames = [
        "num_base_stations",
        "num_users",
        "area_size",
        "episodes_logged",
        "tail_episodes_used",
        "episode_return",
        "total_throughput_Mbps",
        "avg_throughput_Mbps",
        "avg_latency_ms",
        "p95_latency_ms",
        "blocking_rate",
        "jain_fairness_bs",
        "jain_fairness_users",
        "deadline_satisfaction",
        "avg_qoe",
        "step_energy_J",
        "energy_per_task_J",
        "env_step_walltime_ms",
        "run_dir",
    ]

    with open(out_csv_path, "w", newline="") as f:
        writer = csv.DictWriter(f, fieldnames=fieldnames)
        writer.writeheader()
        for row in summary_rows:
            writer.writerow(row)


def build_ppo_config(env_id, env_config, num_env_runners, train_batch_size, lr, csv_dir):
    """Build PPO config for one run."""
    config = PPOConfig()

    # Use the old API stack for compatibility with this code.
    config.enable_rl_module_and_learner = False
    config.enable_env_runner_and_connector_v2 = False

    exploration_conf = {"type": "StochasticSampling"}
    config.exploration_config = exploration_conf

    config.environment(
        env=env_id,
        env_config=env_config,
    )

    config.framework("torch")

    config.env_runners(
        num_env_runners=num_env_runners,
        rollout_fragment_length="auto",
        batch_mode="complete_episodes",
    )

    config.training(
        gamma=0.99,
        lr=lr,
        lambda_=0.95,
        clip_param=0.2,
        vf_clip_param=10.0,
        train_batch_size=train_batch_size,
        use_gae=True,
    )
    config.sgd_minibatch_size = 256
    config.num_sgd_iter = 10

    config.resources(num_gpus=0)
    config.normalize_actions = True

    config.multi_agent(
        policies={
            "shared_policy": PolicySpec(
                config={
                    "exploration_config": exploration_conf,
                }
            )
        },
        policy_mapping_fn=lambda agent_id, *args, **kwargs: "shared_policy",
        policies_to_train=["shared_policy"],
    )

    config.callbacks(make_episode_csv_logger(csv_dir))
    return config


def save_checkpoint_compat(algo, run_dir):
    """Save checkpoint across RLlib versions."""
    try:
        chkpt = algo.save(checkpoint_dir=run_dir)
    except TypeError:
        chkpt = algo.save()

    if hasattr(chkpt, "path"):
        return chkpt.path
    if isinstance(chkpt, dict) and "checkpoint" in chkpt:
        return chkpt["checkpoint"]
    return str(chkpt)


def run_single_experiment(args, env_id, base_output_dir, num_base_stations):
    """Train PPO for one BS count and return summary metrics."""
    run_dir = os.path.join(base_output_dir, f"bs_{num_base_stations}")
    os.makedirs(run_dir, exist_ok=True)


    env_config = dict(
        num_base_stations=num_base_stations,
        num_users=args.num_users,
        num_channels_per_carrier=args.num_channels_per_carrier,
        area_size=args.area_size,
        bs_loc=make_bs_locations(num_base_stations, args.area_size),
        max_steps=args.max_steps,
        mobility_model=args.mobility_model,
        seed=args.seed,
        step_duration_s=args.step_duration_s,
        deadline_ms=args.deadline_ms,
        safety_traffic_ratio=args.safety_traffic_ratio,
    )

    print("\n" + "=" * 90)
    print(
        f"Running PPO scalability experiment | BS={num_base_stations} | "
        f"Users={args.num_users} | Area={args.area_size:.1f} m"
    )
    print(f"Output directory: {run_dir}")
    print("=" * 90)

    config = build_ppo_config(
        env_id=env_id,
        env_config=env_config,
        num_env_runners=args.num_env_runners,
        train_batch_size=args.train_batch_size,
        lr=args.lr,
        csv_dir=run_dir,
    )

    if hasattr(config, "build_algo"):
        algo = config.build_algo()
    else:
        algo = config.build()

    total_env_steps = 0
    iter_idx = 0
    last_checkpoint_path = None

    while total_env_steps < args.total_target_env_steps:
        result = algo.train()
        iter_idx += 1

        total_env_steps = get_total_env_steps(result)
        mean_reward, mean_len = get_mean_return_and_len(result)

        if iter_idx % args.log_every_iter == 0:
            print(
                f"[BS={num_base_stations} | Iter {iter_idx:04d}] "
                f"env_steps={total_env_steps} | "
                f"episode_return_mean={mean_reward:.3f} | "
                f"episode_len_mean={mean_len:.1f}"
            )

        if args.save_every_iter > 0 and iter_idx % args.save_every_iter == 0:
            last_checkpoint_path = save_checkpoint_compat(algo, run_dir)

    if last_checkpoint_path is None:
        last_checkpoint_path = save_checkpoint_compat(algo, run_dir)

    algo.stop()

    csv_path = os.path.join(run_dir, "ppo_episode_metrics.csv")
    summary = summarize_episode_csv(csv_path, tail_fraction=args.tail_fraction)

    if summary is None:
        summary = {
            "num_episodes": 0,
            "tail_episodes": 0,
            "episode_return": float("nan"),
            "total_throughput_Mbps": float("nan"),
            "avg_throughput_Mbps": float("nan"),
            "avg_latency_ms": float("nan"),
            "p95_latency_ms": float("nan"),
            "blocking_rate": float("nan"),
            "jain_fairness_bs": float("nan"),
            "jain_fairness_users": float("nan"),
            "deadline_satisfaction": float("nan"),
            "avg_qoe": float("nan"),
            "step_energy_J": float("nan"),
            "energy_per_task_J": float("nan"),
            "env_step_walltime_ms": float("nan"),
        }

    print(
        f"Completed BS={num_base_stations} | "
        f"throughput={summary['total_throughput_Mbps']:.3f} Mbps | "
        f"avg_latency={summary['avg_latency_ms']:.3f} ms | "
        f"p95_latency={summary['p95_latency_ms']:.3f} ms | "
        f"blocking={summary['blocking_rate']:.4f}"
    )
    print(f"Episode CSV: {csv_path}")
    print(f"Last checkpoint: {last_checkpoint_path}")

    return {
        "num_base_stations": num_base_stations,
        "num_users": args.num_users,
        "area_size": args.area_size,
        "episodes_logged": summary["num_episodes"],
        "tail_episodes_used": summary["tail_episodes"],
        "episode_return": summary["episode_return"],
        "total_throughput_Mbps": summary["total_throughput_Mbps"],
        "avg_throughput_Mbps": summary["avg_throughput_Mbps"],
        "avg_latency_ms": summary["avg_latency_ms"],
        "p95_latency_ms": summary["p95_latency_ms"],
        "blocking_rate": summary["blocking_rate"],
        "jain_fairness_bs": summary["jain_fairness_bs"],
        "jain_fairness_users": summary["jain_fairness_users"],
        "deadline_satisfaction": summary["deadline_satisfaction"],
        "avg_qoe": summary["avg_qoe"],
        "step_energy_J": summary["step_energy_J"],
        "energy_per_task_J": summary["energy_per_task_J"],
        "env_step_walltime_ms": summary["env_step_walltime_ms"],
        "run_dir": run_dir,
    }


# ==========================
# Notebook / script entry helpers
# ==========================

def build_arg_parser():
    parser = argparse.ArgumentParser(
        description="Run PPO while varying the number of base stations for scalability analysis."
    )
    parser.add_argument(
        "--bs-values",
        type=int,
        nargs="+",
        default=[6, 8],
        help="List of BS counts to evaluate. Default: 6 8",
    )
    parser.add_argument("--num-users", type=int, default=100)
    parser.add_argument("--num-channels-per-carrier", type=int, default=100)
    parser.add_argument("--area-size", type=float, default=5000.0)
    parser.add_argument("--max-steps", type=int, default=200)
    parser.add_argument("--mobility-model", type=str, default="manhattan")
    parser.add_argument("--seed", type=int, default=42)
    parser.add_argument("--step-duration-s", type=float, default=1.0)
    parser.add_argument("--deadline-ms", type=float, default=100.0)
    parser.add_argument("--safety-traffic-ratio", type=float, default=0.3)
    parser.add_argument(
        "--total-target-env-steps",
        type=int,
        default=500_000,
        help="Training budget per BS setting.",
    )
    parser.add_argument("--num-env-runners", type=int, default=1)
    parser.add_argument("--train-batch-size", type=int, default=1024)
    parser.add_argument("--lr", type=float, default=5e-5)
    parser.add_argument("--log-every-iter", type=int, default=1)
    parser.add_argument("--save-every-iter", type=int, default=10)
    parser.add_argument(
        "--tail-fraction",
        type=float,
        default=0.20,
        help="Fraction of last logged episodes used for summary.",
    )
    parser.add_argument(
        "--output-dir",
        type=str,
        default="ppo_scalability_varying_bs",
        help="Root directory where all BS-specific folders and summary CSV are saved.",
    )
    parser.add_argument(
        "--restart-ray",
        action="store_true",
        help="Shutdown any existing Ray runtime before starting. Helpful in notebooks.",
    )
    return parser


def parse_args_notebook_safe(cli_args=None):
    """
    Safe argument parsing for both terminal and Jupyter notebook.

    - In terminal use: parse_args_notebook_safe()
    - In notebook use: parse_args_notebook_safe([]) or call
      run_scalability_experiments(...) directly.
    """
    parser = build_arg_parser()
    if cli_args is None:
        args, unknown = parser.parse_known_args()
        if unknown:
            print("Ignoring unknown Jupyter/launcher args:", unknown)
        return args
    return parser.parse_args(cli_args)


def run_scalability_experiments(
    bs_values=(6, 8),
    num_users=100,
    num_channels_per_carrier=100,
    area_size=5000.0,
    max_steps=200,
    mobility_model="manhattan",
    seed=42,
    step_duration_s=1.0,
    deadline_ms=100.0,
    safety_traffic_ratio=0.3,
    total_target_env_steps=500_000,
    num_env_runners=1,
    train_batch_size=1024,
    lr=5e-5,
    log_every_iter=1,
    save_every_iter=10,
    tail_fraction=0.20,
    output_dir="ppo_scalability_varying_bs",
    shutdown_ray_at_end=True,
    restart_ray=True,
):
    """
    Notebook-friendly entry point.

    Example in Jupyter:
        import ppo_variable_bs_fixed as pvb
        summaries, summary_csv_path = pvb.run_scalability_experiments(
            bs_values=[6, 8],
            total_target_env_steps=200000,
            output_dir="ppo_scalability_notebook"
        )
    """
    args = argparse.Namespace(
        bs_values=list(bs_values),
        num_users=num_users,
        num_channels_per_carrier=num_channels_per_carrier,
        area_size=area_size,
        max_steps=max_steps,
        mobility_model=mobility_model,
        seed=seed,
        step_duration_s=step_duration_s,
        deadline_ms=deadline_ms,
        safety_traffic_ratio=safety_traffic_ratio,
        total_target_env_steps=total_target_env_steps,
        num_env_runners=num_env_runners,
        train_batch_size=train_batch_size,
        lr=lr,
        log_every_iter=log_every_iter,
        save_every_iter=save_every_iter,
        tail_fraction=tail_fraction,
        output_dir=output_dir,
    )

    base_output_dir = os.path.abspath(args.output_dir)
    os.makedirs(base_output_dir, exist_ok=True)

    os.environ.setdefault("RAY_DEDUP_LOGS", "1")
    if restart_ray and ray.is_initialized():
        ray.shutdown()
    if not ray.is_initialized():
        ray.init(ignore_reinit_error=True)

    env_id = "multi_agent_mobile_network_varying_bs"
    try:
        register_env(env_id, rllib_env_creator)
    except Exception:
        pass

    all_summaries = []
    summary_csv_path = os.path.join(base_output_dir, "scalability_summary.csv")

    try:
        for num_bs in args.bs_values:
            summary_row = run_single_experiment(
                args=args,
                env_id=env_id,
                base_output_dir=base_output_dir,
                num_base_stations=num_bs,
            )
            all_summaries.append(summary_row)

        write_scalability_summary(all_summaries, summary_csv_path)

        print("\n" + "=" * 90)
        print("All scalability experiments completed.")
        print(f"Summary CSV saved at: {summary_csv_path}")
        print("BS values processed:", args.bs_values)
        print("=" * 90)
        return all_summaries, summary_csv_path
    finally:
        if shutdown_ray_at_end and ray.is_initialized():
            ray.shutdown()


# ==========================
# Main: config + training
# ==========================
if __name__ == "__main__":
    args = parse_args_notebook_safe()
    run_scalability_experiments(
        bs_values=args.bs_values,
        num_users=args.num_users,
        num_channels_per_carrier=args.num_channels_per_carrier,
        area_size=args.area_size,
        max_steps=args.max_steps,
        mobility_model=args.mobility_model,
        seed=args.seed,
        step_duration_s=args.step_duration_s,
        deadline_ms=args.deadline_ms,
        safety_traffic_ratio=args.safety_traffic_ratio,
        total_target_env_steps=args.total_target_env_steps,
        num_env_runners=args.num_env_runners,
        train_batch_size=args.train_batch_size,
        lr=args.lr,
        log_every_iter=args.log_every_iter,
        save_every_iter=args.save_every_iter,
        tail_fraction=args.tail_fraction,
        output_dir=args.output_dir,
        shutdown_ray_at_end=True,
        restart_ray=args.restart_ray,
    )
# Out:
# Ignoring unknown Jupyter/launcher args: ['-f', '/home/umb/.local/share/jupyter/runtime/kernel-450fbbf1-b01b-4d8f-b9ad-8085b00f2ee0.json']
# 2026-04-12 21:27:38,785	INFO worker.py:2023 -- Started a local Ray instance.
# ==========================================================================================
# Running PPO scalability experiment | BS=6 | Users=100 | Area=5000.0 m
# Output directory: /home/umb/Desktop/wr/multi/ppo_scalability_varying_bs/bs_6
# ==========================================================================================
# /home/umb/miniconda3/envs/wr/lib/python3.11/site-packages/ray/rllib/algorithms/algorithm.py:525: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# `UnifiedLogger` will be removed in Ray 2.7.
#   return UnifiedLogger(config, logdir, loggers=None)
# /home/umb/miniconda3/envs/wr/lib/python3.11/site-packages/ray/tune/logger/unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `JsonLogger interface is deprecated in favor of the `ray.tune.json.JsonLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# /home/umb/miniconda3/envs/wr/lib/python3.11/site-packages/ray/tune/logger/unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `CSVLogger interface is deprecated in favor of the `ray.tune.csv.CSVLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# /home/umb/miniconda3/envs/wr/lib/python3.11/site-packages/ray/tune/logger/unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `TBXLogger interface is deprecated in favor of the `ray.tune.tensorboardx.TBXLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# (RolloutWorker pid=240238) [Episode 128355989445507485] total_reward=-21.437
# (RolloutWorker pid=240238) [Episode 854949519964969681] total_reward=-17.877
# (RolloutWorker pid=240238) [Episode 282341088111907415] total_reward=-15.774
# (RolloutWorker pid=240238) [Episode 160876273137374942] total_reward=-18.350
# (RolloutWorker pid=240238) [Episode 118168890076913833] total_reward=-18.988
# (RolloutWorker pid=240238) [Episode 853931770133622125] total_reward=-21.819
# (pid=gcs_server) [2026-04-12 21:28:08,162 E 239974 239974] (gcs_server) gcs_server.cc:303: Failed to establish connection to the event+metrics exporter agent. Events and metrics will not be exported. Exporter agent status: RpcError: Running out of retries to initialize the metrics agent. rpc_code: 14
# (raylet) [2026-04-12 21:28:08,703 E 240115 240115] (raylet) main.cc:979: Failed to establish connection to the metrics exporter agent. Metrics will not be exported. Exporter agent status: RpcError: Running out of retries to initialize the metrics agent. rpc_code: 14
# (RolloutWorker pid=240238) [2026-04-12 21:28:09,140 E 240238 240882] core_worker_process.cc:837: Failed to establish connection to the metrics exporter agent. Metrics will not be exported. Exporter agent status: RpcError: Running out of retries to initialize the metrics agent. rpc_code: 14
# [2026-04-12 21:28:09,244 E 3367632 240191] core_worker_process.cc:837: Failed to establish connection to the metrics exporter agent. Metrics will not be exported. Exporter agent status: RpcError: Running out of retries to initialize the metrics agent. rpc_code: 14
# [BS=6 | Iter 0001] env_steps=1200 | episode_return_mean=-114.245 | episode_len_mean=200.0
# (RolloutWorker pid=240238) [Episode 628764812031418704] total_reward=-16.762
# (RolloutWorker pid=240238) [Episode 680791512660942722] total_reward=-18.428
# (RolloutWorker pid=240238) [Episode 36642940499726745] total_reward=-16.866
# (RolloutWorker pid=240238) [Episode 108023259460586094] total_reward=-15.523
# (RolloutWorker pid=240238) [Episode 268239748164266123] total_reward=-17.803
# (RolloutWorker pid=240238) [Episode 694080340840347345] total_reward=-18.624
# [BS=6 | Iter 0002] env_steps=2400 | episode_return_mean=-109.126 | episode_len_mean=200.0
# (RolloutWorker pid=240238) [Episode 647071500822319027] total_reward=-17.434
# (RolloutWorker pid=240238) [Episode 825514409025013289] total_reward=-15.998
# (RolloutWorker pid=240238) [Episode 808572641880232841] total_reward=-16.488
# (RolloutWorker pid=240238) [Episode 483673423642446070] total_reward=-13.648
# (RolloutWorker pid=240238) [Episode 517902765409618912] total_reward=-12.383
# (RolloutWorker pid=240238) [Episode 320732049773829548] total_reward=-15.708
# [BS=6 | Iter 0003] env_steps=3600 | episode_return_mean=-103.304 | episode_len_mean=200.0
# (RolloutWorker pid=240238) [Episode 874845324523988767] total_reward=-9.829
# (RolloutWorker pid=240238) [Episode 184074656725740477] total_reward=-11.309
# (RolloutWorker pid=240238) [Episode 487241232158376826] total_reward=-16.791
# (RolloutWorker pid=240238) [Episode 320363845452998774] total_reward=-15.545
# (RolloutWorker pid=240238) [Episode 248239863311991088] total_reward=-12.444
# (RolloutWorker pid=240238) [Episode 880248801192569443] total_reward=-15.217
# [BS=6 | Iter 0004] env_steps=4800 | episode_return_mean=-97.761 | episode_len_mean=200.0
# (RolloutWorker pid=240238) [Episode 117840426440527737] total_reward=-9.927
# (RolloutWorker pid=240238) [Episode 438026358954537233] total_reward=-10.559
# (RolloutWorker pid=240238) [Episode 413875040606644119] total_reward=-9.735
# (RolloutWorker pid=240238) [Episode 396553951827551251] total_reward=-11.734
# (RolloutWorker pid=240238) [Episode 304971791897315843] total_reward=-13.351
# (RolloutWorker pid=240238) [Episode 50094947228972415] total_reward=-10.132
# [BS=6 | Iter 0005] env_steps=6000 | episode_return_mean=-91.297 | episode_len_mean=200.0
# (RolloutWorker pid=240238) [Episode 529680822053090256] total_reward=-11.663
# (RolloutWorker pid=240238) [Episode 143914765730070149] total_reward=-9.164
# (RolloutWorker pid=240238) [Episode 90850439815733523] total_reward=-10.918
# (RolloutWorker pid=240238) [Episode 338011540564379889] total_reward=-8.028
# (RolloutWorker pid=240238) [Episode 724772341738102066] total_reward=-4.263
# (RolloutWorker pid=240238) [Episode 416936801523520193] total_reward=-13.076
# [BS=6 | Iter 0006] env_steps=7200 | episode_return_mean=-85.599 | episode_len_mean=200.0
# (RolloutWorker pid=240238) [Episode 221693647224920511] total_reward=-10.069
# (RolloutWorker pid=240238) [Episode 80191633762472432] total_reward=-6.446
# (RolloutWorker pid=240238) [Episode 762384702718551449] total_reward=-9.732
# (RolloutWorker pid=240238) [Episode 891287113119009422] total_reward=-8.761
# (RolloutWorker pid=240238) [Episode 986114192172728113] total_reward=-8.099
# (RolloutWorker pid=240238) [Episode 998987657219944184] total_reward=-6.918
# [BS=6 | Iter 0007] env_steps=8400 | episode_return_mean=-80.517 | episode_len_mean=200.0
# (RolloutWorker pid=240238) [Episode 438255701653666512] total_reward=-5.311
# (RolloutWorker pid=240238) [Episode 522746488039229241] total_reward=-6.260
# (RolloutWorker pid=240238) [Episode 961663851982239535] total_reward=-8.694
# (RolloutWorker pid=240238) [Episode 187527404810773569] total_reward=-4.892
# (RolloutWorker pid=240238) [Episode 409599234334273032] total_reward=-1.454
# (RolloutWorker pid=240238) [Episode 772659369000190126] total_reward=-6.417
# [BS=6 | Iter 0008] env_steps=9600 | episode_return_mean=-74.581 | episode_len_mean=200.0
# (RolloutWorker pid=240238) [Episode 809143729152108677] total_reward=-6.019
# (RolloutWorker pid=240238) [Episode 788076805772318793] total_reward=-1.739
# (RolloutWorker pid=240238) [Episode 82321490621867435] total_reward=-4.357
# (RolloutWorker pid=240238) [Episode 732080124566962803] total_reward=-5.792
# (RolloutWorker pid=240238) [Episode 615821345167490561] total_reward=-3.760
# (RolloutWorker pid=240238) [Episode 282247781897735636] total_reward=-5.495
# [BS=6 | Iter 0009] env_steps=10800 | episode_return_mean=-69.312 | episode_len_mean=200.0
# (RolloutWorker pid=240238) [Episode 532949740704546543] total_reward=-3.471
# (RolloutWorker pid=240238) [Episode 311228652046253559] total_reward=-4.035
# (RolloutWorker pid=240238) [Episode 793396718494746152] total_reward=-2.093
# (RolloutWorker pid=240238) [Episode 253199053319586361] total_reward=-3.325
# (RolloutWorker pid=240238) [Episode 373872538075455791] total_reward=-1.623
# (RolloutWorker pid=240238) [Episode 885805242841900197] total_reward=-0.515
# [BS=6 | Iter 0010] env_steps=12000 | episode_return_mean=-63.887 | episode_len_mean=200.0
# (RolloutWorker pid=240238) [Episode 64492064018525753] total_reward=-0.852
# (RolloutWorker pid=240238) [Episode 947473883880154361] total_reward=-1.609
# (RolloutWorker pid=240238) [Episode 928154613330720931] total_reward=3.389
# (RolloutWorker pid=240238) [Episode 462511513199020028] total_reward=0.974
# (RolloutWorker pid=240238) [Episode 76310265645935262] total_reward=-1.625
# (RolloutWorker pid=240238) [Episode 653914079150376932] total_reward=3.015
# [BS=6 | Iter 0011] env_steps=13200 | episode_return_mean=-57.780 | episode_len_mean=200.0
# (RolloutWorker pid=240238) [Episode 827698802236956910] total_reward=3.015
# (RolloutWorker pid=240238) [Episode 245141710811609815] total_reward=-0.713
# (RolloutWorker pid=240238) [Episode 575574458552210453] total_reward=0.798
# (RolloutWorker pid=240238) [Episode 741157749712210533] total_reward=1.365
# (RolloutWorker pid=240238) [Episode 164719728713486505] total_reward=0.655
# (RolloutWorker pid=240238) [Episode 160982801390186462] total_reward=3.837
# [BS=6 | Iter 0012] env_steps=14400 | episode_return_mean=-52.219 | episode_len_mean=200.0
# (RolloutWorker pid=240238) [Episode 858913818680687352] total_reward=0.585
# (RolloutWorker pid=240238) [Episode 621398507906257531] total_reward=-0.424
# (RolloutWorker pid=240238) [Episode 861248283799128252] total_reward=5.629
# (RolloutWorker pid=240238) [Episode 493950567587474809] total_reward=5.242
# (RolloutWorker pid=240238) [Episode 672767662536243317] total_reward=0.692
# (RolloutWorker pid=240238) [Episode 417353488675052695] total_reward=0.457
# [BS=6 | Iter 0013] env_steps=15600 | episode_return_mean=-47.265 | episode_len_mean=200.0
# (RolloutWorker pid=240238) [Episode 159485643362050032] total_reward=4.789
# (RolloutWorker pid=240238) [Episode 568985024610717864] total_reward=1.414
# (RolloutWorker pid=240238) [Episode 871357502204532440] total_reward=3.565
# (RolloutWorker pid=240238) [Episode 992784065789677973] total_reward=2.443
# (RolloutWorker pid=240238) [Episode 176214043245279029] total_reward=-1.162
# (RolloutWorker pid=240238) [Episode 184446686026812868] total_reward=3.161
# [BS=6 | Iter 0014] env_steps=16800 | episode_return_mean=-42.874 | episode_len_mean=200.0
# (RolloutWorker pid=240238) [Episode 784541428591474316] total_reward=2.827
# (RolloutWorker pid=240238) [Episode 687612802635050216] total_reward=6.563
# (RolloutWorker pid=240238) [Episode 443606504894061072] total_reward=3.162
# (RolloutWorker pid=240238) [Episode 687012576486346018] total_reward=5.494
# (RolloutWorker pid=240238) [Episode 539624780589027225] total_reward=2.997
# (RolloutWorker pid=240238) [Episode 289860739419867561] total_reward=5.263
# [BS=6 | Iter 0015] env_steps=18000 | episode_return_mean=-38.262 | episode_len_mean=200.0
# (RolloutWorker pid=240238) [Episode 637826033723676601] total_reward=5.853
# (RolloutWorker pid=240238) [Episode 784313366770379664] total_reward=4.159
# (RolloutWorker pid=240238) [Episode 132069165115718073] total_reward=11.268
# (RolloutWorker pid=240238) [Episode 865703166790263604] total_reward=5.425
# (RolloutWorker pid=240238) [Episode 886134002934523848] total_reward=0.295
# (RolloutWorker pid=240238) [Episode 392195619991982739] total_reward=5.329
# [BS=6 | Iter 0016] env_steps=19200 | episode_return_mean=-33.850 | episode_len_mean=200.0
# (RolloutWorker pid=240238) [Episode 338382606667001577] total_reward=4.177
# (RolloutWorker pid=240238) [Episode 182343474074142362] total_reward=6.859
# (RolloutWorker pid=240238) [Episode 3741592773409955] total_reward=7.955
# (RolloutWorker pid=240238) [Episode 832515466658138060] total_reward=9.067
# (RolloutWorker pid=240238) [Episode 829735321107686893] total_reward=5.439
# (RolloutWorker pid=240238) [Episode 878482605600041311] total_reward=7.540
# [BS=6 | Iter 0017] env_steps=20400 | episode_return_mean=-27.675 | episode_len_mean=200.0
# (RolloutWorker pid=240238) [Episode 585317117369000244] total_reward=7.707
# (RolloutWorker pid=240238) [Episode 122683326663359087] total_reward=3.527
# (RolloutWorker pid=240238) [Episode 720922041172774422] total_reward=7.510
# (RolloutWorker pid=240238) [Episode 970378691364708520] total_reward=6.502
# (RolloutWorker pid=240238) [Episode 585295455530922407] total_reward=6.837
# (RolloutWorker pid=240238) [Episode 229328888032229575] total_reward=5.418
# [BS=6 | Iter 0018] env_steps=21600 | episode_return_mean=-18.817 | episode_len_mean=200.0
# (RolloutWorker pid=240238) [Episode 431093315629250941] total_reward=5.123
# (RolloutWorker pid=240238) [Episode 186253360305006689] total_reward=5.990
# (RolloutWorker pid=240238) [Episode 690536093004954321] total_reward=7.111
# (RolloutWorker pid=240238) [Episode 563324029285164091] total_reward=5.970
# (RolloutWorker pid=240238) [Episode 128974702591634818] total_reward=9.612
# (RolloutWorker pid=240238) [Episode 418488332978841649] total_reward=8.618
# [BS=6 | Iter 0019] env_steps=22800 | episode_return_mean=-10.137 | episode_len_mean=200.0
# (RolloutWorker pid=240238) [Episode 930148022756051001] total_reward=1.380
# (RolloutWorker pid=240238) [Episode 276069723034697471] total_reward=14.928
# (RolloutWorker pid=240238) [Episode 277706031488053018] total_reward=6.071
# (RolloutWorker pid=240238) [Episode 654118016803749048] total_reward=7.962
# (RolloutWorker pid=240238) [Episode 90800697945835382] total_reward=9.250
# (RolloutWorker pid=240238) [Episode 843832001674699369] total_reward=5.076
# [BS=6 | Iter 0020] env_steps=24000 | episode_return_mean=-2.695 | episode_len_mean=200.0
# (RolloutWorker pid=240238) [Episode 940810758620045025] total_reward=10.807
# (RolloutWorker pid=240238) [Episode 614168395175613125] total_reward=7.364
# (RolloutWorker pid=240238) [Episode 144992004643600820] total_reward=8.515
# (RolloutWorker pid=240238) [Episode 760640907696292701] total_reward=7.551
# (RolloutWorker pid=240238) [Episode 190378422076173744] total_reward=7.967
# (RolloutWorker pid=240238) [Episode 608366450576113731] total_reward=7.947
# [BS=6 | Iter 0021] env_steps=25200 | episode_return_mean=5.143 | episode_len_mean=200.0
# (RolloutWorker pid=240238) [Episode 699355172141778330] total_reward=9.429
# (RolloutWorker pid=240238) [Episode 870761487223705339] total_reward=10.622
# (RolloutWorker pid=240238) [Episode 795363234081981226] total_reward=5.938
# (RolloutWorker pid=240238) [Episode 821974200636842719] total_reward=13.503
# (RolloutWorker pid=240238) [Episode 460006799925093274] total_reward=11.679
# (RolloutWorker pid=240238) [Episode 774402343117659070] total_reward=13.955
# [BS=6 | Iter 0022] env_steps=26400 | episode_return_mean=12.997 | episode_len_mean=200.0
# (RolloutWorker pid=240238) [Episode 430524530950039694] total_reward=17.205
# (RolloutWorker pid=240238) [Episode 520528082625354164] total_reward=12.053
# (RolloutWorker pid=240238) [Episode 285815715992838551] total_reward=13.569
# (RolloutWorker pid=240238) [Episode 73816835082273743] total_reward=11.329
# (RolloutWorker pid=240238) [Episode 24250851389130395] total_reward=12.768
# (RolloutWorker pid=240238) [Episode 638628035617842786] total_reward=11.798
# [BS=6 | Iter 0023] env_steps=27600 | episode_return_mean=20.889 | episode_len_mean=200.0
# (RolloutWorker pid=240238) [Episode 678425265468656787] total_reward=7.474
# (RolloutWorker pid=240238) [Episode 8290477533047478] total_reward=16.451
# (RolloutWorker pid=240238) [Episode 816085044000758358] total_reward=12.994
# (RolloutWorker pid=240238) [Episode 67876832632895158] total_reward=11.011
# (RolloutWorker pid=240238) [Episode 77707280901729748] total_reward=10.368
# (RolloutWorker pid=240238) [Episode 36216675662142246] total_reward=12.596
# [BS=6 | Iter 0024] env_steps=28800 | episode_return_mean=27.847 | episode_len_mean=200.0
# (RolloutWorker pid=240238) [Episode 380958118174068929] total_reward=11.774
# (RolloutWorker pid=240238) [Episode 592781649807389971] total_reward=12.170
# (RolloutWorker pid=240238) [Episode 321062425739517741] total_reward=12.548
# (RolloutWorker pid=240238) [Episode 559644815751520423] total_reward=19.945
# (RolloutWorker pid=240238) [Episode 621694399597263162] total_reward=13.706
# (RolloutWorker pid=240238) [Episode 833968721148981359] total_reward=13.049
# [BS=6 | Iter 0025] env_steps=30000 | episode_return_mean=34.592 | episode_len_mean=200.0
# (RolloutWorker pid=240238) [Episode 664326800560611674] total_reward=11.573
# (RolloutWorker pid=240238) [Episode 280156741608470521] total_reward=15.669
# (RolloutWorker pid=240238) [Episode 545300673451577759] total_reward=10.379
# (RolloutWorker pid=240238) [Episode 469308189389103005] total_reward=12.951
# (RolloutWorker pid=240238) [Episode 108750243494802527] total_reward=14.049
# (RolloutWorker pid=240238) [Episode 759755384088982827] total_reward=16.326
# [BS=6 | Iter 0026] env_steps=31200 | episode_return_mean=41.063 | episode_len_mean=200.0
# (RolloutWorker pid=240238) [Episode 408477286058778323] total_reward=17.741
# (RolloutWorker pid=240238) [Episode 473968656753075729] total_reward=8.990
# (RolloutWorker pid=240238) [Episode 995935959408111027] total_reward=14.853
# (RolloutWorker pid=240238) [Episode 62455124037252890] total_reward=11.864
# (RolloutWorker pid=240238) [Episode 753382879163162211] total_reward=17.817
# (RolloutWorker pid=240238) [Episode 744994534491045968] total_reward=14.279
# [BS=6 | Iter 0027] env_steps=32400 | episode_return_mean=46.797 | episode_len_mean=200.0
# (RolloutWorker pid=240238) [Episode 69881652359326190] total_reward=10.568
# (RolloutWorker pid=240238) [Episode 839573104875417658] total_reward=14.609
# (RolloutWorker pid=240238) [Episode 923020320550193415] total_reward=9.686
# (RolloutWorker pid=240238) [Episode 125978618627527262] total_reward=17.909
# (RolloutWorker pid=240238) [Episode 220888313675378948] total_reward=13.507
# (RolloutWorker pid=240238) [Episode 618295375260911599] total_reward=19.486
# [BS=6 | Iter 0028] env_steps=33600 | episode_return_mean=51.459 | episode_len_mean=200.0
# (RolloutWorker pid=240238) [Episode 161619187483563645] total_reward=14.255
# (RolloutWorker pid=240238) [Episode 211547306011422561] total_reward=19.269
# (RolloutWorker pid=240238) [Episode 533373852039691289] total_reward=17.984
# (RolloutWorker pid=240238) [Episode 86912863383003772] total_reward=12.930
# (RolloutWorker pid=240238) [Episode 931586220951143476] total_reward=19.302
# (RolloutWorker pid=240238) [Episode 986862636530491367] total_reward=19.810
# [BS=6 | Iter 0029] env_steps=34800 | episode_return_mean=57.263 | episode_len_mean=200.0
# (RolloutWorker pid=240238) [Episode 112881080161410723] total_reward=17.890
# (RolloutWorker pid=240238) [Episode 751871868338920280] total_reward=13.253
# (RolloutWorker pid=240238) [Episode 623255456077380053] total_reward=22.589
# (RolloutWorker pid=240238) [Episode 17014645382834032] total_reward=20.220
# (RolloutWorker pid=240238) [Episode 107524660741022595] total_reward=19.801
# (RolloutWorker pid=240238) [Episode 868801875697623785] total_reward=17.706
# [BS=6 | Iter 0030] env_steps=36000 | episode_return_mean=62.857 | episode_len_mean=200.0
# (RolloutWorker pid=240238) [Episode 272527000110112677] total_reward=16.190
# (RolloutWorker pid=240238) [Episode 468563508025580898] total_reward=20.141
# (RolloutWorker pid=240238) [Episode 554968476047047191] total_reward=14.963
# (RolloutWorker pid=240238) [Episode 996874035012314241] total_reward=16.731
# (RolloutWorker pid=240238) [Episode 189813674716871376] total_reward=18.906
# (RolloutWorker pid=240238) [Episode 2484975215862243] total_reward=20.629
# [BS=6 | Iter 0031] env_steps=37200 | episode_return_mean=68.267 | episode_len_mean=200.0
# (RolloutWorker pid=240238) [Episode 450125642143183688] total_reward=14.832
# (RolloutWorker pid=240238) [Episode 905192518805150150] total_reward=18.068
# (RolloutWorker pid=240238) [Episode 328869972841033146] total_reward=15.280
# (RolloutWorker pid=240238) [Episode 803115322315519978] total_reward=15.669
# (RolloutWorker pid=240238) [Episode 842215289533940931] total_reward=12.990
# (RolloutWorker pid=240238) [Episode 903154351572518269] total_reward=19.924
# [BS=6 | Iter 0032] env_steps=38400 | episode_return_mean=72.457 | episode_len_mean=200.0
# (RolloutWorker pid=240238) [Episode 763085665046287668] total_reward=11.018
# (RolloutWorker pid=240238) [Episode 561093942224460490] total_reward=17.861
# (RolloutWorker pid=240238) [Episode 218937332967982039] total_reward=17.527
# (RolloutWorker pid=240238) [Episode 250992040307133266] total_reward=14.617
# (RolloutWorker pid=240238) [Episode 67426648495838790] total_reward=19.358
# (RolloutWorker pid=240238) [Episode 848247212994799808] total_reward=14.809
# [BS=6 | Iter 0033] env_steps=39600 | episode_return_mean=76.168 | episode_len_mean=200.0
# (RolloutWorker pid=240238) [Episode 70279290927533584] total_reward=21.136
# (RolloutWorker pid=240238) [Episode 361561736148112283] total_reward=18.772
# (RolloutWorker pid=240238) [Episode 57810174150337067] total_reward=16.159
# (RolloutWorker pid=240238) [Episode 549699732714072506] total_reward=17.035
# (RolloutWorker pid=240238) [Episode 612346749617166794] total_reward=14.939
# (RolloutWorker pid=240238) [Episode 65577683065340645] total_reward=20.652
# [BS=6 | Iter 0034] env_steps=40800 | episode_return_mean=80.215 | episode_len_mean=200.0
# (RolloutWorker pid=240238) [Episode 585486398274247458] total_reward=19.265
# (RolloutWorker pid=240238) [Episode 981531131356786515] total_reward=19.771
# (RolloutWorker pid=240238) [Episode 78999713685322134] total_reward=15.270
# (RolloutWorker pid=240238) [Episode 78353541908150401] total_reward=22.767
# (RolloutWorker pid=240238) [Episode 993609891914103500] total_reward=21.566
# (RolloutWorker pid=240238) [Episode 465521516129702550] total_reward=13.507
# [BS=6 | Iter 0035] env_steps=42000 | episode_return_mean=84.701 | episode_len_mean=200.0
# (RolloutWorker pid=240238) [Episode 656791036997787289] total_reward=20.244
# (RolloutWorker pid=240238) [Episode 667448226777397268] total_reward=23.326
# (RolloutWorker pid=240238) [Episode 45819018609846358] total_reward=18.422
# (RolloutWorker pid=240238) [Episode 94520434570021221] total_reward=17.595
# (RolloutWorker pid=240238) [Episode 757899658953642723] total_reward=23.442
# (RolloutWorker pid=240238) [Episode 651662277793778700] total_reward=11.201
# [BS=6 | Iter 0036] env_steps=43200 | episode_return_mean=88.698 | episode_len_mean=200.0
# (RolloutWorker pid=240238) [Episode 364749597346961045] total_reward=19.694
# (RolloutWorker pid=240238) [Episode 300642380385151189] total_reward=22.772
# (RolloutWorker pid=240238) [Episode 772141477526131896] total_reward=28.940
# (RolloutWorker pid=240238) [Episode 362229337138157709] total_reward=11.951
# (RolloutWorker pid=240238) [Episode 306232685353403869] total_reward=22.271
# (RolloutWorker pid=240238) [Episode 150892381880858790] total_reward=27.264
# [BS=6 | Iter 0037] env_steps=44400 | episode_return_mean=93.879 | episode_len_mean=200.0
# (RolloutWorker pid=240238) [Episode 744211740999541756] total_reward=21.310
# (RolloutWorker pid=240238) [Episode 527144045018651586] total_reward=19.426
# (RolloutWorker pid=240238) [Episode 10739991236980611] total_reward=25.399
# (RolloutWorker pid=240238) [Episode 716147856835228455] total_reward=26.010
# (RolloutWorker pid=240238) [Episode 649087476746073538] total_reward=26.495
# (RolloutWorker pid=240238) [Episode 115270539886472525] total_reward=21.459
# [BS=6 | Iter 0038] env_steps=45600 | episode_return_mean=99.163 | episode_len_mean=200.0
# (RolloutWorker pid=240238) [Episode 619850264588924640] total_reward=24.738
# (RolloutWorker pid=240238) [Episode 583245341257713643] total_reward=22.854
# (RolloutWorker pid=240238) [Episode 152712021524360367] total_reward=20.782
# (RolloutWorker pid=240238) [Episode 402379791865091646] total_reward=25.740
# (RolloutWorker pid=240238) [Episode 79310981540368513] total_reward=17.552
# (RolloutWorker pid=240238) [Episode 281640757634783939] total_reward=20.836
# [BS=6 | Iter 0039] env_steps=46800 | episode_return_mean=102.653 | episode_len_mean=200.0
# (RolloutWorker pid=240238) [Episode 328568096402527186] total_reward=24.535
# (RolloutWorker pid=240238) [Episode 505192410723260600] total_reward=21.655
# (RolloutWorker pid=240238) [Episode 626287667917639474] total_reward=23.693
# (RolloutWorker pid=240238) [Episode 348778517419995459] total_reward=18.337
# (RolloutWorker pid=240238) [Episode 930522883874836057] total_reward=26.939
# (RolloutWorker pid=240238) [Episode 609827101904403942] total_reward=25.784
# [BS=6 | Iter 0040] env_steps=48000 | episode_return_mean=106.707 | episode_len_mean=200.0
# (RolloutWorker pid=240238) [Episode 769993847005557232] total_reward=18.533
# (RolloutWorker pid=240238) [Episode 639412903219149978] total_reward=22.198
# (RolloutWorker pid=240238) [Episode 119427104727357383] total_reward=26.889
# (RolloutWorker pid=240238) [Episode 304908447703426831] total_reward=24.772
# (RolloutWorker pid=240238) [Episode 855948160343127465] total_reward=22.460
# (RolloutWorker pid=240238) [Episode 179219238062395543] total_reward=26.069
# [BS=6 | Iter 0041] env_steps=49200 | episode_return_mean=110.907 | episode_len_mean=200.0
# (RolloutWorker pid=240238) [Episode 324842864690896089] total_reward=21.091
# (RolloutWorker pid=240238) [Episode 242839454968324267] total_reward=24.186
# (RolloutWorker pid=240238) [Episode 395314058635865767] total_reward=27.306
# (RolloutWorker pid=240238) [Episode 792630223871865867] total_reward=30.332
# (RolloutWorker pid=240238) [Episode 983341526876515113] total_reward=23.211
# (RolloutWorker pid=240238) [Episode 582696972936573670] total_reward=30.124
# [BS=6 | Iter 0042] env_steps=50400 | episode_return_mean=115.093 | episode_len_mean=200.0
# (RolloutWorker pid=240238) [Episode 289523090391592032] total_reward=27.503
# (RolloutWorker pid=240238) [Episode 58567139754918080] total_reward=27.119
# (RolloutWorker pid=240238) [Episode 731280176098369353] total_reward=28.234
# (RolloutWorker pid=240238) [Episode 956173250779379251] total_reward=25.150
# (RolloutWorker pid=240238) [Episode 50828576904479731] total_reward=22.027
# (RolloutWorker pid=240238) [Episode 384564504046362318] total_reward=26.813
# [BS=6 | Iter 0043] env_steps=51600 | episode_return_mean=119.677 | episode_len_mean=200.0
# (RolloutWorker pid=240238) [Episode 150824797887533517] total_reward=26.557
# (RolloutWorker pid=240238) [Episode 186291334255968285] total_reward=25.587
# (RolloutWorker pid=240238) [Episode 509401661568012063] total_reward=20.804
# (RolloutWorker pid=240238) [Episode 813579177461214617] total_reward=23.963
# (RolloutWorker pid=240238) [Episode 646681592529216457] total_reward=25.499
# (RolloutWorker pid=240238) [Episode 128981802130454182] total_reward=24.789
# [BS=6 | Iter 0044] env_steps=52800 | episode_return_mean=123.470 | episode_len_mean=200.0
# (RolloutWorker pid=240238) [Episode 796691380361708208] total_reward=31.795
# (RolloutWorker pid=240238) [Episode 171847894572719338] total_reward=28.407
# (RolloutWorker pid=240238) [Episode 41537614610419259] total_reward=25.392
# (RolloutWorker pid=240238) [Episode 425677051264500971] total_reward=30.595
# (RolloutWorker pid=240238) [Episode 637018067102030032] total_reward=26.025
# (RolloutWorker pid=240238) [Episode 495510347510806903] total_reward=25.856
# [BS=6 | Iter 0045] env_steps=54000 | episode_return_mean=127.907 | episode_len_mean=200.0
# (RolloutWorker pid=240238) [Episode 48225392290448642] total_reward=28.617
# (RolloutWorker pid=240238) [Episode 420414567310034151] total_reward=27.610
# (RolloutWorker pid=240238) [Episode 45995658873078065] total_reward=25.549
# (RolloutWorker pid=240238) [Episode 412525960464690368] total_reward=26.041
# (RolloutWorker pid=240238) [Episode 786369355583034220] total_reward=27.771
# (RolloutWorker pid=240238) [Episode 768921875746205255] total_reward=20.542
# [BS=6 | Iter 0046] env_steps=55200 | episode_return_mean=131.205 | episode_len_mean=200.0
# (RolloutWorker pid=240238) [Episode 407763697307528899] total_reward=20.114
# (RolloutWorker pid=240238) [Episode 645501749346808508] total_reward=31.342
# (RolloutWorker pid=240238) [Episode 864088860741839914] total_reward=26.184
# (RolloutWorker pid=240238) [Episode 272939557837385397] total_reward=26.728
# (RolloutWorker pid=240238) [Episode 187351781449583764] total_reward=26.221
# (RolloutWorker pid=240238) [Episode 922206955264058217] total_reward=29.274
# [BS=6 | Iter 0047] env_steps=56400 | episode_return_mean=133.798 | episode_len_mean=200.0
# (RolloutWorker pid=240238) [Episode 204127485389880410] total_reward=29.497
# (RolloutWorker pid=240238) [Episode 475343095498833424] total_reward=27.768
# (RolloutWorker pid=240238) [Episode 206788764009784890] total_reward=30.890
# (RolloutWorker pid=240238) [Episode 902030209753684806] total_reward=36.197
# (RolloutWorker pid=240238) [Episode 474672960553743145] total_reward=27.039
# (RolloutWorker pid=240238) [Episode 772350335764088866] total_reward=28.649
# [BS=6 | Iter 0048] env_steps=57600 | episode_return_mean=138.353 | episode_len_mean=200.0
# (RolloutWorker pid=240238) [Episode 847463640384883911] total_reward=30.202
# (RolloutWorker pid=240238) [Episode 286117350213502058] total_reward=23.984
# (RolloutWorker pid=240238) [Episode 183542615336902923] total_reward=18.361
# (RolloutWorker pid=240238) [Episode 808518706271445055] total_reward=31.829
# (RolloutWorker pid=240238) [Episode 441040575658731431] total_reward=30.281
# (RolloutWorker pid=240238) [Episode 44646429306016400] total_reward=24.539
# [BS=6 | Iter 0049] env_steps=58800 | episode_return_mean=142.340 | episode_len_mean=200.0
# (RolloutWorker pid=240238) [Episode 542668649090827383] total_reward=27.443
# (RolloutWorker pid=240238) [Episode 230091805707823745] total_reward=36.630
# (RolloutWorker pid=240238) [Episode 403128716166065876] total_reward=25.591
# (RolloutWorker pid=240238) [Episode 946014037708176666] total_reward=28.967
# (RolloutWorker pid=240238) [Episode 257013356526023354] total_reward=26.811
# (RolloutWorker pid=240238) [Episode 760966452882628443] total_reward=33.831
# [BS=6 | Iter 0050] env_steps=60000 | episode_return_mean=146.723 | episode_len_mean=200.0
# (RolloutWorker pid=240238) [Episode 459399997846254647] total_reward=27.542
# (RolloutWorker pid=240238) [Episode 321207454287853996] total_reward=29.941
# (RolloutWorker pid=240238) [Episode 80036680618621961] total_reward=28.500
# (RolloutWorker pid=240238) [Episode 891584916440353616] total_reward=26.677
# (RolloutWorker pid=240238) [Episode 404843923462470744] total_reward=25.906
# (RolloutWorker pid=240238) [Episode 587304757206984117] total_reward=26.627
# [BS=6 | Iter 0051] env_steps=61200 | episode_return_mean=150.165 | episode_len_mean=200.0
# (RolloutWorker pid=240238) [Episode 783431044716122782] total_reward=27.913
# (RolloutWorker pid=240238) [Episode 972675097345957925] total_reward=24.349
# (RolloutWorker pid=240238) [Episode 381789802842124071] total_reward=34.644
# (RolloutWorker pid=240238) [Episode 31821257816266873] total_reward=35.253
# (RolloutWorker pid=240238) [Episode 301160619882327202] total_reward=23.979
# (RolloutWorker pid=240238) [Episode 669374386175123163] total_reward=21.013
# [BS=6 | Iter 0052] env_steps=62400 | episode_return_mean=153.193 | episode_len_mean=200.0
# (RolloutWorker pid=240238) [Episode 44107545743563397] total_reward=29.960
# (RolloutWorker pid=240238) [Episode 687799825638376700] total_reward=28.262
# (RolloutWorker pid=240238) [Episode 398550100529353228] total_reward=29.763
# (RolloutWorker pid=240238) [Episode 906689958914420185] total_reward=33.482
# (RolloutWorker pid=240238) [Episode 503127893628233759] total_reward=30.478
# (RolloutWorker pid=240238) [Episode 133330514507243309] total_reward=31.670
# [BS=6 | Iter 0053] env_steps=63600 | episode_return_mean=157.423 | episode_len_mean=200.0
# (RolloutWorker pid=240238) [Episode 219145906981389869] total_reward=31.207
# (RolloutWorker pid=240238) [Episode 51174184238546572] total_reward=29.850
# (RolloutWorker pid=240238) [Episode 502740094138119120] total_reward=28.191
# (RolloutWorker pid=240238) [Episode 599427346896705251] total_reward=24.930
# (RolloutWorker pid=240238) [Episode 929843724726468214] total_reward=30.858
# (RolloutWorker pid=240238) [Episode 791892371403439468] total_reward=30.389
# [BS=6 | Iter 0054] env_steps=64800 | episode_return_mean=160.079 | episode_len_mean=200.0
# (RolloutWorker pid=240238) [Episode 849746603956793514] total_reward=23.704
# (RolloutWorker pid=240238) [Episode 227166041551032131] total_reward=28.407
# (RolloutWorker pid=240238) [Episode 497252047871909462] total_reward=26.338
# (RolloutWorker pid=240238) [Episode 718449271560994127] total_reward=23.239
# (RolloutWorker pid=240238) [Episode 764833681337271942] total_reward=26.905
# (RolloutWorker pid=240238) [Episode 143683208202389395] total_reward=30.729
# [BS=6 | Iter 0055] env_steps=66000 | episode_return_mean=160.821 | episode_len_mean=200.0
# (RolloutWorker pid=240238) [Episode 584672443300440976] total_reward=31.708
# (RolloutWorker pid=240238) [Episode 768875168233506710] total_reward=31.529
# (RolloutWorker pid=240238) [Episode 376063283742666773] total_reward=22.261
# (RolloutWorker pid=240238) [Episode 803826573106198070] total_reward=34.079
# (RolloutWorker pid=240238) [Episode 639194072395812640] total_reward=28.037
# (RolloutWorker pid=240238) [Episode 221176569884176118] total_reward=31.357
# [BS=6 | Iter 0056] env_steps=67200 | episode_return_mean=163.693 | episode_len_mean=200.0
# (RolloutWorker pid=240238) [Episode 766611437478108926] total_reward=31.335
# (RolloutWorker pid=240238) [Episode 437124745880382567] total_reward=26.363
# (RolloutWorker pid=240238) [Episode 862540417900787052] total_reward=35.220
# (RolloutWorker pid=240238) [Episode 200639864966628262] total_reward=28.485
# (RolloutWorker pid=240238) [Episode 656133691072996015] total_reward=27.801
# (RolloutWorker pid=240238) [Episode 468172795428932890] total_reward=29.444
# [BS=6 | Iter 0057] env_steps=68400 | episode_return_mean=166.283 | episode_len_mean=200.0
# (RolloutWorker pid=240238) [Episode 961219683267484898] total_reward=34.201
# (RolloutWorker pid=240238) [Episode 350343965554940555] total_reward=32.310
# (RolloutWorker pid=240238) [Episode 242324134836776300] total_reward=27.568
# (RolloutWorker pid=240238) [Episode 905918250792855112] total_reward=32.519
# (RolloutWorker pid=240238) [Episode 699433167491817958] total_reward=22.409
# (RolloutWorker pid=240238) [Episode 371528069918935466] total_reward=31.810
# [BS=6 | Iter 0058] env_steps=69600 | episode_return_mean=168.404 | episode_len_mean=200.0
# (RolloutWorker pid=240238) [Episode 509344597446063945] total_reward=34.835
# (RolloutWorker pid=240238) [Episode 778945170601239145] total_reward=22.378
# (RolloutWorker pid=240238) [Episode 589343490445746842] total_reward=32.318
# (RolloutWorker pid=240238) [Episode 915114609183210178] total_reward=32.797
# (RolloutWorker pid=240238) [Episode 848505783842260825] total_reward=26.285
# (RolloutWorker pid=240238) [Episode 759603196530320677] total_reward=32.593
# [BS=6 | Iter 0059] env_steps=70800 | episode_return_mean=169.340 | episode_len_mean=200.0
# (RolloutWorker pid=240238) [Episode 327183449262991624] total_reward=32.036
# (RolloutWorker pid=240238) [Episode 765371364863682985] total_reward=24.432
# (RolloutWorker pid=240238) [Episode 713959099301652855] total_reward=27.840
# (RolloutWorker pid=240238) [Episode 107668105631557083] total_reward=33.471
# (RolloutWorker pid=240238) [Episode 270785055445128900] total_reward=27.566
# (RolloutWorker pid=240238) [Episode 357889276794132032] total_reward=23.564
# [BS=6 | Iter 0060] env_steps=72000 | episode_return_mean=170.213 | episode_len_mean=200.0
# (RolloutWorker pid=240238) [Episode 929903709524200703] total_reward=29.390
# (RolloutWorker pid=240238) [Episode 169887552507620840] total_reward=31.768
# (RolloutWorker pid=240238) [Episode 53280791693671951] total_reward=26.061
# (RolloutWorker pid=240238) [Episode 704750907784595715] total_reward=30.624
# (RolloutWorker pid=240238) [Episode 886007888018434269] total_reward=30.610
# (RolloutWorker pid=240238) [Episode 525059090823831280] total_reward=27.031
# [BS=6 | Iter 0061] env_steps=73200 | episode_return_mean=171.427 | episode_len_mean=200.0
# (RolloutWorker pid=240238) [Episode 663703360540003804] total_reward=34.807
# (RolloutWorker pid=240238) [Episode 828196448578732524] total_reward=37.121
# (RolloutWorker pid=240238) [Episode 442697035402200487] total_reward=28.619
# (RolloutWorker pid=240238) [Episode 460768380015575189] total_reward=26.760
# (RolloutWorker pid=240238) [Episode 170138172631925684] total_reward=29.261
# (RolloutWorker pid=240238) [Episode 792774669860301545] total_reward=27.916
# [BS=6 | Iter 0062] env_steps=74400 | episode_return_mean=172.650 | episode_len_mean=200.0
# (RolloutWorker pid=240238) [Episode 992020432217388344] total_reward=26.794
# (RolloutWorker pid=240238) [Episode 897457627687636501] total_reward=27.734
# (RolloutWorker pid=240238) [Episode 252306653038666131] total_reward=27.764
# (RolloutWorker pid=240238) [Episode 927075542069864655] total_reward=29.854
# (RolloutWorker pid=240238) [Episode 802331651995419440] total_reward=32.473
# (RolloutWorker pid=240238) [Episode 535589557976490259] total_reward=28.489
# [BS=6 | Iter 0063] env_steps=75600 | episode_return_mean=173.955 | episode_len_mean=200.0
# (RolloutWorker pid=240238) [Episode 642645129103613092] total_reward=31.978
# (RolloutWorker pid=240238) [Episode 139916942791971367] total_reward=34.113
# (RolloutWorker pid=240238) [Episode 153729517278113471] total_reward=31.534
# (RolloutWorker pid=240238) [Episode 535697182484439919] total_reward=28.715
# (RolloutWorker pid=240238) [Episode 612353367366590401] total_reward=33.826
# (RolloutWorker pid=240238) [Episode 644396990161388804] total_reward=30.055
# [BS=6 | Iter 0064] env_steps=76800 | episode_return_mean=175.428 | episode_len_mean=200.0
# (RolloutWorker pid=240238) [Episode 365819637221265445] total_reward=33.670
# (RolloutWorker pid=240238) [Episode 870743982701136803] total_reward=29.963
# (RolloutWorker pid=240238) [Episode 510252422219988305] total_reward=33.859
# (RolloutWorker pid=240238) [Episode 939638529444989010] total_reward=30.926
# (RolloutWorker pid=240238) [Episode 491998594802984003] total_reward=27.800
# (RolloutWorker pid=240238) [Episode 514103387206276635] total_reward=28.793
# [BS=6 | Iter 0065] env_steps=78000 | episode_return_mean=175.911 | episode_len_mean=200.0
# (RolloutWorker pid=240238) [Episode 183496571700080185] total_reward=24.354
# (RolloutWorker pid=240238) [Episode 993236011009979383] total_reward=28.357
# (RolloutWorker pid=240238) [Episode 518895105810383752] total_reward=30.924
# (RolloutWorker pid=240238) [Episode 866739622810116255] total_reward=26.753
# (RolloutWorker pid=240238) [Episode 968295979898575472] total_reward=36.057
# (RolloutWorker pid=240238) [Episode 319718218656499631] total_reward=30.887
# [BS=6 | Iter 0066] env_steps=79200 | episode_return_mean=176.406 | episode_len_mean=200.0
# (RolloutWorker pid=240238) [Episode 896598044354305425] total_reward=30.677
# (RolloutWorker pid=240238) [Episode 558702323198846867] total_reward=35.202
# (RolloutWorker pid=240238) [Episode 275831705908188649] total_reward=27.420
# (RolloutWorker pid=240238) [Episode 507138576871064751] total_reward=31.641
# (RolloutWorker pid=240238) [Episode 822661218779394807] total_reward=28.560
# (RolloutWorker pid=240238) [Episode 270352691973421809] total_reward=30.609
# [BS=6 | Iter 0067] env_steps=80400 | episode_return_mean=177.091 | episode_len_mean=200.0
# (RolloutWorker pid=240238) [Episode 387205849955639065] total_reward=24.172
# (RolloutWorker pid=240238) [Episode 92899715435686535] total_reward=29.037
# (RolloutWorker pid=240238) [Episode 173895912080046983] total_reward=28.358
# (RolloutWorker pid=240238) [Episode 441609624994706392] total_reward=34.948
# (RolloutWorker pid=240238) [Episode 176172474766373361] total_reward=27.334
# (RolloutWorker pid=240238) [Episode 246670875470324366] total_reward=34.403
# [BS=6 | Iter 0068] env_steps=81600 | episode_return_mean=178.188 | episode_len_mean=200.0
# (RolloutWorker pid=240238) [Episode 478310119821626705] total_reward=30.902
# (RolloutWorker pid=240238) [Episode 381480268291665594] total_reward=37.713
# (RolloutWorker pid=240238) [Episode 537174151906496603] total_reward=34.497
# (RolloutWorker pid=240238) [Episode 71787481035451951] total_reward=29.362
# (RolloutWorker pid=240238) [Episode 960258137409132860] total_reward=33.741
# (RolloutWorker pid=240238) [Episode 449036186901448351] total_reward=27.637
# [BS=6 | Iter 0069] env_steps=82800 | episode_return_mean=179.433 | episode_len_mean=200.0
# (RolloutWorker pid=240238) [Episode 887514103221026433] total_reward=32.243
# (RolloutWorker pid=240238) [Episode 22518808577952622] total_reward=34.186
# (RolloutWorker pid=240238) [Episode 663725785147638147] total_reward=31.357
# (RolloutWorker pid=240238) [Episode 549920192510076596] total_reward=34.133
# (RolloutWorker pid=240238) [Episode 344276947801267580] total_reward=33.543
# (RolloutWorker pid=240238) [Episode 449623993262259965] total_reward=38.214
# [BS=6 | Iter 0070] env_steps=84000 | episode_return_mean=180.466 | episode_len_mean=200.0
# (RolloutWorker pid=240238) [Episode 963529561370526385] total_reward=31.158
# (RolloutWorker pid=240238) [Episode 620526061998111373] total_reward=27.408
# (RolloutWorker pid=240238) [Episode 846975409476939743] total_reward=34.698
# (RolloutWorker pid=240238) [Episode 922185212292453281] total_reward=37.481
# (RolloutWorker pid=240238) [Episode 562890267208005964] total_reward=37.564
# (RolloutWorker pid=240238) [Episode 314672991792006207] total_reward=37.134
# [BS=6 | Iter 0071] env_steps=85200 | episode_return_mean=182.804 | episode_len_mean=200.0
# (RolloutWorker pid=240238) [Episode 559907104107983454] total_reward=27.889
# (RolloutWorker pid=240238) [Episode 448321829081066426] total_reward=37.555
# (RolloutWorker pid=240238) [Episode 771158780985251310] total_reward=32.945
# (RolloutWorker pid=240238) [Episode 920195453299736083] total_reward=31.526
# (RolloutWorker pid=240238) [Episode 834924288116083743] total_reward=23.395
# (RolloutWorker pid=240238) [Episode 969037050382671634] total_reward=35.497
# [BS=6 | Iter 0072] env_steps=86400 | episode_return_mean=183.905 | episode_len_mean=200.0
# (RolloutWorker pid=240238) [Episode 615802625342585721] total_reward=33.212
# (RolloutWorker pid=240238) [Episode 682405910582035174] total_reward=32.913
# (RolloutWorker pid=240238) [Episode 764386679396761142] total_reward=32.567
# (RolloutWorker pid=240238) [Episode 96784828978964735] total_reward=30.603
# (RolloutWorker pid=240238) [Episode 494156880886316478] total_reward=36.380
# (RolloutWorker pid=240238) [Episode 999411565780087688] total_reward=25.028
# [BS=6 | Iter 0073] env_steps=87600 | episode_return_mean=184.942 | episode_len_mean=200.0
# (RolloutWorker pid=240238) [Episode 209519304229641885] total_reward=33.210
# (RolloutWorker pid=240238) [Episode 299939805836309547] total_reward=33.761
# (RolloutWorker pid=240238) [Episode 377411929117619059] total_reward=27.858
# (RolloutWorker pid=240238) [Episode 524232632338177628] total_reward=35.570
# (RolloutWorker pid=240238) [Episode 389111638850808505] total_reward=32.198
# (RolloutWorker pid=240238) [Episode 320808035432688228] total_reward=29.168
# [BS=6 | Iter 0074] env_steps=88800 | episode_return_mean=185.200 | episode_len_mean=200.0
# (RolloutWorker pid=240238) [Episode 486031160057068914] total_reward=31.789
# (RolloutWorker pid=240238) [Episode 962586752908058093] total_reward=30.566
# (RolloutWorker pid=240238) [Episode 542226865418915469] total_reward=33.408
# (RolloutWorker pid=240238) [Episode 863566173524348294] total_reward=36.974
# (RolloutWorker pid=240238) [Episode 60050611551821310] total_reward=38.809
# (RolloutWorker pid=240238) [Episode 258510552586190915] total_reward=32.088
# [BS=6 | Iter 0075] env_steps=90000 | episode_return_mean=187.127 | episode_len_mean=200.0
# (RolloutWorker pid=240238) [Episode 79111595282651127] total_reward=30.525
# (RolloutWorker pid=240238) [Episode 46414473121588387] total_reward=26.904
# (RolloutWorker pid=240238) [Episode 35775152374771053] total_reward=21.699
# (RolloutWorker pid=240238) [Episode 285098240969916709] total_reward=27.572
# (RolloutWorker pid=240238) [Episode 967564989144059189] total_reward=31.492
# (RolloutWorker pid=240238) [Episode 716351238835773430] total_reward=36.297
# [BS=6 | Iter 0076] env_steps=91200 | episode_return_mean=186.769 | episode_len_mean=200.0
# (RolloutWorker pid=240238) [Episode 275023592889157515] total_reward=28.241
# (RolloutWorker pid=240238) [Episode 545978729995699348] total_reward=34.248
# (RolloutWorker pid=240238) [Episode 131882054645295025] total_reward=33.900
# (RolloutWorker pid=240238) [Episode 536147679098209851] total_reward=35.221
# (RolloutWorker pid=240238) [Episode 295428868898038512] total_reward=30.258
# (RolloutWorker pid=240238) [Episode 425307181275115293] total_reward=32.683
# [BS=6 | Iter 0077] env_steps=92400 | episode_return_mean=188.026 | episode_len_mean=200.0
# (RolloutWorker pid=240238) [Episode 698546714536327863] total_reward=27.839
# (RolloutWorker pid=240238) [Episode 828209503361568319] total_reward=33.952
# (RolloutWorker pid=240238) [Episode 896732985134548651] total_reward=38.303
# (RolloutWorker pid=240238) [Episode 188809119493109952] total_reward=29.569
# (RolloutWorker pid=240238) [Episode 358603462389788876] total_reward=30.377
# (RolloutWorker pid=240238) [Episode 667178077036239893] total_reward=29.904
# [BS=6 | Iter 0078] env_steps=93600 | episode_return_mean=188.247 | episode_len_mean=200.0
# (RolloutWorker pid=240238) [Episode 663848425990417947] total_reward=40.920
# (RolloutWorker pid=240238) [Episode 432699465058144418] total_reward=37.268
# (RolloutWorker pid=240238) [Episode 228658667431080992] total_reward=37.857
# (RolloutWorker pid=240238) [Episode 682642355755712838] total_reward=23.901
# (RolloutWorker pid=240238) [Episode 957583895279967035] total_reward=32.907
# (RolloutWorker pid=240238) [Episode 279986279315338538] total_reward=31.434
# [BS=6 | Iter 0079] env_steps=94800 | episode_return_mean=190.479 | episode_len_mean=200.0
# (RolloutWorker pid=240238) [Episode 803808803535860780] total_reward=36.621
# (RolloutWorker pid=240238) [Episode 347701159529631412] total_reward=35.510
# (RolloutWorker pid=240238) [Episode 788896963766309208] total_reward=34.133
# (RolloutWorker pid=240238) [Episode 928710513388720976] total_reward=38.390
# (RolloutWorker pid=240238) [Episode 917987476935374569] total_reward=37.572
# (RolloutWorker pid=240238) [Episode 652475810742876467] total_reward=31.493
# [BS=6 | Iter 0080] env_steps=96000 | episode_return_mean=192.222 | episode_len_mean=200.0
# (RolloutWorker pid=240238) [Episode 47349488064055878] total_reward=29.992
# (RolloutWorker pid=240238) [Episode 614213451901982856] total_reward=42.294
# (RolloutWorker pid=240238) [Episode 762682178091495016] total_reward=35.193
# (RolloutWorker pid=240238) [Episode 79501701666421695] total_reward=32.345
# (RolloutWorker pid=240238) [Episode 746566542007117174] total_reward=35.082
# (RolloutWorker pid=240238) [Episode 14586930173504812] total_reward=35.912
# [BS=6 | Iter 0081] env_steps=97200 | episode_return_mean=193.605 | episode_len_mean=200.0
# (RolloutWorker pid=240238) [Episode 484294756394715597] total_reward=37.257
# (RolloutWorker pid=240238) [Episode 565164089903695724] total_reward=34.605
# (RolloutWorker pid=240238) [Episode 499818448634026083] total_reward=36.197
# (RolloutWorker pid=240238) [Episode 417574376959257751] total_reward=33.143
# (RolloutWorker pid=240238) [Episode 530043382142478722] total_reward=29.783
# ...
# (RolloutWorker pid=240204) [Episode 852673055351963657] total_reward=65.964
# [BS=8 | Iter 0397] env_steps=476400 | episode_return_mean=516.899 | episode_len_mean=200.0
# (RolloutWorker pid=240204) [Episode 279680305825737317] total_reward=61.095
# (RolloutWorker pid=240204) [Episode 424590581860394562] total_reward=68.853
# (RolloutWorker pid=240204) [Episode 894535609677904785] total_reward=70.383
# (RolloutWorker pid=240204) [Episode 844472729662338110] total_reward=69.228
# (RolloutWorker pid=240204) [Episode 630139905976267683] total_reward=68.463
# (RolloutWorker pid=240204) [Episode 917695013883672180] total_reward=64.036
# [BS=8 | Iter 0398] env_steps=477600 | episode_return_mean=517.388 | episode_len_mean=200.0
# (RolloutWorker pid=240204) [Episode 173591218968633989] total_reward=61.488
# (RolloutWorker pid=240204) [Episode 27566652350013539] total_reward=66.107
# (RolloutWorker pid=240204) [Episode 624359104762461558] total_reward=65.338
# (RolloutWorker pid=240204) [Episode 733191021024721212] total_reward=61.522
# (RolloutWorker pid=240204) [Episode 799505872243806827] total_reward=62.674
# (RolloutWorker pid=240204) [Episode 11062069995509430] total_reward=65.185
# [BS=8 | Iter 0399] env_steps=478800 | episode_return_mean=517.014 | episode_len_mean=200.0
# (RolloutWorker pid=240204) [Episode 386248736591059213] total_reward=60.408
# (RolloutWorker pid=240204) [Episode 874985739868164326] total_reward=63.636
# (RolloutWorker pid=240204) [Episode 433815343514063009] total_reward=65.824
# (RolloutWorker pid=240204) [Episode 850951372807894210] total_reward=63.878
# (RolloutWorker pid=240204) [Episode 354535633419158489] total_reward=65.768
# (RolloutWorker pid=240204) [Episode 236573001042913066] total_reward=62.168
# [BS=8 | Iter 0400] env_steps=480000 | episode_return_mean=516.215 | episode_len_mean=200.0
# (RolloutWorker pid=240204) [Episode 484014709016136992] total_reward=58.672
# (RolloutWorker pid=240204) [Episode 164145450947492120] total_reward=69.972
# (RolloutWorker pid=240204) [Episode 322616574574779209] total_reward=66.155
# (RolloutWorker pid=240204) [Episode 50613557167953936] total_reward=66.550
# (RolloutWorker pid=240204) [Episode 266869703859282865] total_reward=66.486
# (RolloutWorker pid=240204) [Episode 974800014875599278] total_reward=65.777
# [BS=8 | Iter 0401] env_steps=481200 | episode_return_mean=517.459 | episode_len_mean=200.0
# (RolloutWorker pid=240204) [Episode 476222071887556781] total_reward=65.442
# (RolloutWorker pid=240204) [Episode 528566113296687701] total_reward=64.409
# (RolloutWorker pid=240204) [Episode 862269307956784188] total_reward=66.131
# (RolloutWorker pid=240204) [Episode 669582949384727102] total_reward=62.793
# (RolloutWorker pid=240204) [Episode 582718537244064774] total_reward=67.212
# (RolloutWorker pid=240204) [Episode 734659658407343780] total_reward=64.922
# [BS=8 | Iter 0402] env_steps=482400 | episode_return_mean=517.460 | episode_len_mean=200.0
# (RolloutWorker pid=240204) [Episode 454656088900966033] total_reward=66.174
# (RolloutWorker pid=240204) [Episode 682409353774896934] total_reward=70.835
# (RolloutWorker pid=240204) [Episode 71807255717917467] total_reward=67.120
# (RolloutWorker pid=240204) [Episode 763745843950586278] total_reward=59.651
# (RolloutWorker pid=240204) [Episode 150696400669573704] total_reward=65.825
# (RolloutWorker pid=240204) [Episode 336279563583427210] total_reward=61.714
# [BS=8 | Iter 0403] env_steps=483600 | episode_return_mean=517.842 | episode_len_mean=200.0
# (RolloutWorker pid=240204) [Episode 981036708383444309] total_reward=64.819
# (RolloutWorker pid=240204) [Episode 453043586297124059] total_reward=62.413
# (RolloutWorker pid=240204) [Episode 959115205783240914] total_reward=66.402
# (RolloutWorker pid=240204) [Episode 376142454279116282] total_reward=69.955
# (RolloutWorker pid=240204) [Episode 521994263344200458] total_reward=59.339
# (RolloutWorker pid=240204) [Episode 269335407435376244] total_reward=60.700
# [BS=8 | Iter 0404] env_steps=484800 | episode_return_mean=517.755 | episode_len_mean=200.0
# (RolloutWorker pid=240204) [Episode 156926273231583622] total_reward=58.475
# (RolloutWorker pid=240204) [Episode 887918598409548604] total_reward=65.113
# (RolloutWorker pid=240204) [Episode 125637124588268812] total_reward=65.371
# (RolloutWorker pid=240204) [Episode 121815091477281900] total_reward=62.863
# (RolloutWorker pid=240204) [Episode 518315167928580758] total_reward=61.078
# (RolloutWorker pid=240204) [Episode 362055733485724500] total_reward=67.136
# [BS=8 | Iter 0405] env_steps=486000 | episode_return_mean=516.428 | episode_len_mean=200.0
# (RolloutWorker pid=240204) [Episode 139199977708664034] total_reward=61.484
# (RolloutWorker pid=240204) [Episode 413077295267469811] total_reward=63.251
# (RolloutWorker pid=240204) [Episode 888137805743672604] total_reward=63.513
# (RolloutWorker pid=240204) [Episode 521024918816007624] total_reward=64.676
# (RolloutWorker pid=240204) [Episode 534202252574671140] total_reward=63.889
# (RolloutWorker pid=240204) [Episode 982845044251135787] total_reward=60.377
# [BS=8 | Iter 0406] env_steps=487200 | episode_return_mean=515.691 | episode_len_mean=200.0
# (RolloutWorker pid=240204) [Episode 104248185457911736] total_reward=59.402
# (RolloutWorker pid=240204) [Episode 931095833243908916] total_reward=66.576
# (RolloutWorker pid=240204) [Episode 350735995934689877] total_reward=65.328
# (RolloutWorker pid=240204) [Episode 812469324732044260] total_reward=62.984
# (RolloutWorker pid=240204) [Episode 695560417457903724] total_reward=63.098
# (RolloutWorker pid=240204) [Episode 247902085114433017] total_reward=65.854
# [BS=8 | Iter 0407] env_steps=488400 | episode_return_mean=515.780 | episode_len_mean=200.0
# (RolloutWorker pid=240204) [Episode 987561745427933727] total_reward=66.924
# (RolloutWorker pid=240204) [Episode 171005700551100697] total_reward=66.828
# (RolloutWorker pid=240204) [Episode 819908660197702294] total_reward=65.569
# (RolloutWorker pid=240204) [Episode 456838759222211871] total_reward=64.866
# (RolloutWorker pid=240204) [Episode 56436220367083488] total_reward=66.524
# (RolloutWorker pid=240204) [Episode 344539887096816584] total_reward=64.392
# [BS=8 | Iter 0408] env_steps=489600 | episode_return_mean=516.329 | episode_len_mean=200.0
# (RolloutWorker pid=240204) [Episode 945498946381957756] total_reward=66.778
# (RolloutWorker pid=240204) [Episode 200455856060169136] total_reward=64.238
# (RolloutWorker pid=240204) [Episode 985288224111214515] total_reward=65.175
# (RolloutWorker pid=240204) [Episode 640971042772448422] total_reward=62.721
# (RolloutWorker pid=240204) [Episode 634246207589454268] total_reward=64.255
# (RolloutWorker pid=240204) [Episode 109210810273126302] total_reward=64.090
# [BS=8 | Iter 0409] env_steps=490800 | episode_return_mean=516.968 | episode_len_mean=200.0
# (RolloutWorker pid=240204) [Episode 117491168828749678] total_reward=66.084
# (RolloutWorker pid=240204) [Episode 915200329560894826] total_reward=68.960
# (RolloutWorker pid=240204) [Episode 140026074867792414] total_reward=67.068
# (RolloutWorker pid=240204) [Episode 71099721892994025] total_reward=61.493
# (RolloutWorker pid=240204) [Episode 900385570131494908] total_reward=66.364
# (RolloutWorker pid=240204) [Episode 256280775786858184] total_reward=64.340
# [BS=8 | Iter 0410] env_steps=492000 | episode_return_mean=517.690 | episode_len_mean=200.0
# (RolloutWorker pid=240204) [Episode 228431830518762967] total_reward=65.764
# (RolloutWorker pid=240204) [Episode 461839387359724232] total_reward=62.090
# (RolloutWorker pid=240204) [Episode 791233033080085143] total_reward=63.665
# (RolloutWorker pid=240204) [Episode 96890861489099740] total_reward=59.565
# (RolloutWorker pid=240204) [Episode 675748918240422946] total_reward=64.065
# (RolloutWorker pid=240204) [Episode 86454340789744010] total_reward=64.713
# [BS=8 | Iter 0411] env_steps=493200 | episode_return_mean=516.534 | episode_len_mean=200.0
# (RolloutWorker pid=240204) [Episode 227990612538899781] total_reward=61.697
# (RolloutWorker pid=240204) [Episode 744772187978333094] total_reward=67.170
# (RolloutWorker pid=240204) [Episode 933057839956801299] total_reward=64.852
# (RolloutWorker pid=240204) [Episode 106044143250733986] total_reward=66.615
# (RolloutWorker pid=240204) [Episode 976842065699876997] total_reward=66.223
# (RolloutWorker pid=240204) [Episode 932583458181525410] total_reward=61.896
# [BS=8 | Iter 0412] env_steps=494400 | episode_return_mean=516.222 | episode_len_mean=200.0
# (RolloutWorker pid=240204) [Episode 141264778619286577] total_reward=66.311
# (RolloutWorker pid=240204) [Episode 58381294865990508] total_reward=65.394
# (RolloutWorker pid=240204) [Episode 499395297582650148] total_reward=65.667
# (RolloutWorker pid=240204) [Episode 835211906688612704] total_reward=64.599
# (RolloutWorker pid=240204) [Episode 571994791170974290] total_reward=67.422
# (RolloutWorker pid=240204) [Episode 441256998723135182] total_reward=66.993
# [BS=8 | Iter 0413] env_steps=495600 | episode_return_mean=516.696 | episode_len_mean=200.0
# (RolloutWorker pid=240204) [Episode 491910127832992434] total_reward=70.351
# (RolloutWorker pid=240204) [Episode 408068790610106338] total_reward=66.382
# (RolloutWorker pid=240204) [Episode 317032397577724586] total_reward=61.381
# (RolloutWorker pid=240204) [Episode 514216167601376322] total_reward=68.541
# (RolloutWorker pid=240204) [Episode 171360351272046563] total_reward=63.122
# (RolloutWorker pid=240204) [Episode 708016674470545697] total_reward=67.819
# [BS=8 | Iter 0414] env_steps=496800 | episode_return_mean=518.001 | episode_len_mean=200.0
# (RolloutWorker pid=240204) [Episode 711326241340414638] total_reward=66.544
# (RolloutWorker pid=240204) [Episode 746261185894793290] total_reward=64.061
# (RolloutWorker pid=240204) [Episode 575182867656344351] total_reward=67.008
# (RolloutWorker pid=240204) [Episode 552285062364262057] total_reward=67.297
# (RolloutWorker pid=240204) [Episode 101136060492043008] total_reward=62.568
# (RolloutWorker pid=240204) [Episode 441586552638760488] total_reward=65.896
# [BS=8 | Iter 0415] env_steps=498000 | episode_return_mean=517.495 | episode_len_mean=200.0
# (RolloutWorker pid=240204) [Episode 483344844008318542] total_reward=63.404
# (RolloutWorker pid=240204) [Episode 740927914350979747] total_reward=63.954
# (RolloutWorker pid=240204) [Episode 919106654203057730] total_reward=63.525
# (RolloutWorker pid=240204) [Episode 287247801561890831] total_reward=67.230
# (RolloutWorker pid=240204) [Episode 626793477490533156] total_reward=60.328
# (RolloutWorker pid=240204) [Episode 22516536966843194] total_reward=62.826
# [BS=8 | Iter 0416] env_steps=499200 | episode_return_mean=517.695 | episode_len_mean=200.0
# (RolloutWorker pid=240204) [Episode 440990263902047776] total_reward=64.412
# (RolloutWorker pid=240204) [Episode 822460384839180734] total_reward=62.953
# (RolloutWorker pid=240204) [Episode 553038506179347824] total_reward=67.012
# (RolloutWorker pid=240204) [Episode 900933340442756302] total_reward=66.585
# (RolloutWorker pid=240204) [Episode 396644333561050234] total_reward=68.576
# (RolloutWorker pid=240204) [Episode 652151334247936872] total_reward=68.914
# [BS=8 | Iter 0417] env_steps=500400 | episode_return_mean=518.669 | episode_len_mean=200.0
# Completed BS=8 | throughput=177.586 Mbps | avg_latency=318.120 ms | p95_latency=764.849 ms | blocking=0.0233
# Episode CSV: /home/umb/Desktop/wr/multi/ppo_scalability_varying_bs/bs_8/ppo_episode_metrics.csv
# Last checkpoint: TrainingResult(checkpoint=Checkpoint(filesystem=local, path=/home/umb/Desktop/wr/multi/ppo_scalability_varying_bs/bs_8), metrics={'custom_metrics': {}, 'episode_media': {}, 'info': {'learner': {'shared_policy': {'learner_stats': {'allreduce_latency': np.float64(0.0), 'grad_gnorm': np.float32(10.490439), 'cur_kl_coeff': np.float64(0.09999999999999999), 'cur_lr': np.float64(5.000000000000001e-05), 'total_loss': np.float64(0.032647161193502444), 'policy_loss': np.float64(-0.005510677293149961), 'vf_loss': np.float64(0.03716085635456774), 'vf_explained_var': np.float64(0.6105225020514594), 'kl': np.float64(0.009969823212595682), 'entropy': np.float64(-3.2316524576610988), 'entropy_coeff': np.float64(0.0)}, 'model': {}, 'custom_metrics': {}, 'num_agent_steps_trained': np.float64(128.0), 'num_grad_updates_lifetime': np.float64(921375.5), 'diff_num_grad_updates_vs_sampler_policy': np.float64(1124.5)}}, 'num_env_steps_sampled': 492000, 'num_env_steps_trained': 492000, 'num_agent_steps_sampled': 3936000, 'num_agent_steps_trained': 3936000}, 'env_runners': {'episode_reward_max': 566.6806625136364, 'episode_reward_min': 467.80338334878263, 'episode_reward_mean': np.float64(517.6899156021548), 'episode_len_mean': np.float64(200.0), 'episode_media': {}, 'episodes_timesteps_total': 20000, 'policy_reward_min': {'shared_policy': np.float64(58.47542291859797)}, 'policy_reward_max': {'shared_policy': np.float64(70.83508281420464)}, 'policy_reward_mean': {'shared_policy': np.float64(64.71123945026935)}, 'custom_metrics': {'local_data_rate_Mbps_mean': np.float64(27.853038683093246), 'local_data_rate_Mbps_min': np.float64(13.576730013304328), 'local_data_rate_Mbps_max': np.float64(40.45666743318165), 'local_served_throughput_Mbps_mean': np.float64(23.29228921509848), 'local_served_throughput_Mbps_min': np.float64(11.876785013745245), 'local_served_throughput_Mbps_max': np.float64(36.35670177486521), 'local_demand_Mbps_mean': np.float64(69.29947576760239), 'local_demand_Mbps_min': np.float64(26.686668206341828), 'local_demand_Mbps_max': np.float64(110.84114785788162), 'local_power_mW_mean': np.float64(34271.20944702625), 'local_power_mW_min': np.float64(30935.08404493332), 'local_power_mW_max': np.float64(37811.993741989136), 'local_channels_mean': np.float64(47.4561), 'local_channels_min': np.float64(37.72), 'local_channels_max': np.float64(56.125), 'users_in_cov_mean': np.float64(31.33865), 'users_in_cov_min': np.float64(20.385), 'users_in_cov_max': np.float64(43.085), 'assoc_users_mean': np.float64(12.8751), 'assoc_users_min': np.float64(5.84), 'assoc_users_max': np.float64(20.825), 'local_avg_latency_ms_mean': np.float64(295.31093716070615), 'local_avg_latency_ms_min': np.float64(156.76366904472772), 'local_avg_latency_ms_max': np.float64(470.759886458684), 'local_util_mean': np.float64(0.3556471261471444), 'local_util_min': np.float64(0.2548048932915086), 'local_util_max': np.float64(0.4904254356375246), 'local_mec_queue_cycles_mean': np.float64(14341106656.147966), 'local_mec_queue_cycles_min': np.float64(6483221651.448159), 'local_mec_queue_cycles_max': np.float64(23324169563.411392), 'local_cpu_used_cycles_per_s_mean': np.float64(49916921317.42835), 'local_cpu_used_cycles_per_s_min': np.float64(48328352808.95233), 'local_cpu_used_cycles_per_s_max': np.float64(50000000000.0), 'local_offload_frac_mean': np.float64(0.9338191150382161), 'local_offload_frac_min': np.float64(0.7782634598016739), 'local_offload_frac_max': np.float64(0.9747191068530082), 'local_cpu_util_frac_mean': np.float64(0.998338426348567), 'local_cpu_util_frac_min': np.float64(0.9665670561790466), 'local_cpu_util_frac_max': np.float64(1.0), 'total_throughput_Mbps_mean': np.float64(176.57304658524959), 'total_throughput_Mbps_min': np.float64(159.94271114464928), 'total_throughput_Mbps_max': np.float64(197.92034642245852), 'avg_throughput_Mbps_mean': np.float64(1.7657304658524953), 'avg_throughput_Mbps_min': np.float64(1.5994271114464929), 'avg_throughput_Mbps_ ...
#
# ==========================================================================================
# All scalability experiments completed.
# Summary CSV saved at: /home/umb/Desktop/wr/multi/ppo_scalability_varying_bs/scalability_summary.csv
# BS values processed: [6, 8]
# ==========================================================================================
# (pid=240241) [2026-04-12 21:28:09,240 E 240241 241493] core_worker_process.cc:837: Failed to establish connection to the metrics exporter agent. Metrics will not be exported. Exporter agent status: RpcError: Running out of retries to initialize the metrics agent. rpc_code: 14 [repeated 23x across cluster]

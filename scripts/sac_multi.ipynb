# %%
import math
import random
from collections import defaultdict
from types import SimpleNamespace
import time
import csv  # used for episode-wise CSV logging

import gymnasium as gym
from gymnasium.utils import seeding
import matplotlib.pyplot as plt
import numpy as np

# RLlib / Ray
import os
import ray
from ray.rllib.algorithms.sac import SACConfig   # <<< SAC (was PPOConfig)
from ray.rllib.policy.policy import PolicySpec
from ray.tune.registry import register_env
from ray.rllib.env.multi_agent_env import MultiAgentEnv
from ray.rllib.algorithms.callbacks import DefaultCallbacks
import torch


# ----------------------
# Basic PHY & helper functions
# ----------------------
def rx_sensitivity_dBm(bw_hz, nf_db=7.0, snr_req_db=-5.0):
    """Thermal-noise-based RX sensitivity in dBm."""
    return -174.0 + 10.0 * np.log10(max(bw_hz, 1.0)) + nf_db + snr_req_db


MOD_ORDER = 256
BITS_PER_CODEWORD = int(np.log2(MOD_ORDER))
NR_OVERHEAD = 0.85
SNR_GAP_DB = 1.5
MAX_SE = 7.5  # peak spectral efficiency (bit/s/Hz)

# Antenna / beamforming gains per BS type
BEAM_GAIN_DB = {
    "Ma": {
        "tx_main": 8.0,   # main-lobe TX gain (dB)
        "tx_side": -3.0,  # side-lobe TX gain (dB)
        "rx": 0.0,        # UE RX gain (dB)
    }
}

UE_INTERF_RX_DB = 0.0  # interference-side RX gain at UE
MACRO_REUSE_ONE = False
MIMO_MAX_RANK = {"Ma": 4}


def spectral_efficiency_from_sinr(SINR_dB, gap_db=SNR_GAP_DB, max_se=MAX_SE):
    """Shannon-like SE with SNR gap."""
    gamma_lin = 10.0 ** (SINR_dB / 10.0) / (10.0 ** (gap_db / 10.0))
    se = np.log2(1.0 + gamma_lin)
    return float(np.clip(se, 0.0, max_se))


def mimo_rank_and_total_se(
    SINR_dB: float,
    max_layers: int,
    gap_db: float = SNR_GAP_DB,
    max_se: float = MAX_SE,
):
    """Simple MIMO rank-selection and SE aggregation."""
    sinr_lin = 10.0 ** (SINR_dB / 10.0)
    best_L = 1
    best_sum_se = spectral_efficiency_from_sinr(SINR_dB, gap_db, max_se)

    for L in range(2, max_layers + 1):
        per_layer_snr_dB = 10.0 * np.log10(max(sinr_lin / max(L, 1), 1e-12))
        se_layer = spectral_efficiency_from_sinr(
            per_layer_snr_dB, gap_db, max_se
        )
        corr_eff = max(0.5, 1.0 - 0.07 * (L - 1))  # crude correlation penalty
        sum_se = L * se_layer * corr_eff
        if sum_se > best_sum_se:
            best_sum_se = sum_se
            best_L = L

    return best_L, float(best_sum_se)


# 20-D BS observation layout (0-1 normalized)
OBS_IDX = SimpleNamespace(
    BS_TYPE=0,
    TX_NORM=1,
    CH_UTIL=2,
    COV_UTIL=3,
    LOAD_RATIO_NORM=4,
    NEARBY_POT=5,
    AVG_SPEED=6,
    REQ_P_NORM=7,
    AVG_RADIAL_V=8,
    SP_VAR=9,
    NEIGHBOR_TX_NORM=10,
    AVG_DEMAND_NORM=11,
    INTER_NORM=12,
    MEC_QUEUE_NORM=13,
    CPU_UTIL_NORM=14,
    OFFLOAD_FRAC=15,
    SERVED_RATIO_NORM=16,  # local served throughput / max possible
    BLOCK_FRAC_NORM=17,    # fraction of in-coverage users not associated
    CH_MATCH_NORM=18,      # how well channels match covered users
    OFFLOAD_MAND_FRAC=19,  # fraction of covered users with mandatory-offload tasks
)


# ----------------
# Building blocks
# ----------------
class Channel:
    def __init__(self, id, frequency, bandwidth, noise_figure_db=7.0):
        self.id = int(id)
        self.frequency = float(frequency)
        self.bandwidth = float(bandwidth)
        self.noise_figure_db = float(noise_figure_db)
        self.users = []
        self.base_station = None

    def calculate_noise_power(self):
        """Noise power in Watts for this channel."""
        k = 1.380649e-23
        T = 293.15
        N = k * T * self.bandwidth
        NF = 10.0 ** (self.noise_figure_db / 10.0)
        return N * NF


class BaseStation:
    def __init__(
        self,
        id,
        transmit_power_mW,
        height_m,
        location_xy,
        type_bs="Ma",
        mec_cpu_capacity_cycles=5e9,
    ):
        self.id = int(id)
        self.transmit_power = float(transmit_power_mW)  # total TX power in mW
        self.height = float(height_m)
        self.location = np.array(location_xy, dtype=float)
        self.type_bs = type_bs
        self.assigned_channels = []
        self.per_channel_power = {}
        self.coverage_area = float(0.0)  # coverage radius (m)

        # MEC-related attributes (compute plane)
        self.mec_cpu_capacity = float(mec_cpu_capacity_cycles)  # F_i^{max}
        self.mec_queue_cycles = 0.0     # q_t^{bs,i} [cycles]
        self.offload_frac = 1.0         # x_t^i in [0,1]
        self.cpu_util_frac = 1.0        # aggregate CPU utilization fraction
        self.last_cpu_used = 0.0        # F_used this step [cycles/s]

        # simple type-dependent caps
        self.MAX_COVERAGE = {"Ma": 2000.0}
        self.COV_MARGIN_DB = {"Ma": 3.0}
        self.SNR_REQ_DB = {"Ma": -5.0}

    # ---- 3GPP-like UMa pathloss ----
    def _pl_uma_los(self, d3d, f_ghz, h_ut=1.5):
        c = 3e8
        f_hz = f_ghz * 1e9
        h_bs = float(self.height)

        d2d = max(np.sqrt(max(d3d**2 - (h_bs - h_ut) ** 2, 1e-9)), 1.0)
        h_bs_eff = h_bs - 1.0
        h_ut_eff = h_ut - 1.0
        d_bp = 4.0 * h_bs_eff * h_ut_eff * f_hz / c

        pl1 = 28.0 + 22.0 * np.log10(d3d) + 20.0 * np.log10(f_ghz)
        if d2d <= d_bp:
            return pl1
        pl2 = (
            28.0
            + 40.0 * np.log10(d3d)
            + 20.0 * np.log10(f_ghz)
            - 9.0 * np.log10(d_bp**2 + (h_bs - h_ut) ** 2)
        )
        return pl2

    def _pl_uma_nlos(self, d3d, f_ghz, h_ut=1.5):
        pl_los = self._pl_uma_los(d3d, f_ghz, h_ut)
        pl_nlos = (
            13.54
            + 39.08 * np.log10(d3d)
            + 20.0 * np.log10(f_ghz)
            - 0.6 * (h_ut - 1.5)
        )
        return max(pl_nlos, pl_los)

    def calculate_path_loss(self, distance_m, frequency_hz, user_height=1.5):
        """Average path loss (LOS-probability weighted)."""
        d2d = float(max(distance_m, 0.1))
        f_ghz = frequency_hz / 1e9
        d3d = np.sqrt(d2d**2 + (self.height - user_height) ** 2)

        p_los = min(18.0 / d2d, 1.0) * (1.0 - np.exp(-d2d / 63.0)) + np.exp(
            -d2d / 63.0
        )
        pl_los = self._pl_uma_los(d3d, f_ghz, h_ut=user_height)
        pl_nlos = self._pl_uma_nlos(d3d, f_ghz, h_ut=user_height)

        return float(p_los * pl_los + (1.0 - p_los) * pl_nlos)

    def _eirp_dbm(self, transmit_power_mW: float) -> float:
        g = BEAM_GAIN_DB[self.type_bs]
        tx_dbm = 10.0 * np.log10(max(transmit_power_mW, 1e-15))
        return tx_dbm + g["tx_main"] + g["rx"]

    def update_coverage_area_from_power(
        self, total_transmit_power_mW, frequency_hz
    ):
        """Update coverage radius from link budget."""
        if self.per_channel_power:
            values = list(self.per_channel_power.values())
            p_ch = float(np.percentile(values, 80))
        else:
            n = max(1, len(self.assigned_channels))
            p_ch = float(total_transmit_power_mW / n)

        if self.assigned_channels:
            bw_hz = self.assigned_channels[0].bandwidth
            nf_db = self.assigned_channels[0].noise_figure_db
        else:
            bw_hz = 20e6
            nf_db = 7.0

        sens_dBm = rx_sensitivity_dBm(
            bw_hz, nf_db=nf_db, snr_req_db=self.SNR_REQ_DB[self.type_bs]
        )
        eirp_plus_grx_dbm = self._eirp_dbm(p_ch)
        path_loss_budget_dB = (
            eirp_plus_grx_dbm - sens_dBm - self.COV_MARGIN_DB[self.type_bs]
        )

        radius_m = self.find_distance_for_path_loss(
            path_loss_budget_dB, frequency_hz
        )
        cap = self.MAX_COVERAGE.get(self.type_bs, None)
        if cap is not None:
            radius_m = min(radius_m, float(cap))

        self.coverage_area = float(max(radius_m, 1.0))
        return self.coverage_area

    def find_distance_for_path_loss(self, path_loss_dB, frequency_hz):
        """Invert pathloss model via binary search."""
        d_min, d_max = 1.0, 10000.0
        tol = 0.1
        d_mid = 0.0
        for _ in range(40):
            d_mid = 0.5 * (d_min + d_max)
            PL_mid = self.calculate_path_loss(d_mid, frequency_hz)
            if abs(PL_mid - path_loss_dB) < tol:
                return d_mid
            if PL_mid < path_loss_dB:
                d_min = d_mid
            else:
                d_max = d_mid
        return d_mid

    def assign_channels(self, channels):
        self.assigned_channels = list(channels)
        for ch in self.assigned_channels:
            ch.base_station = self

    def clear_assigned_channels(self):
        for ch in self.assigned_channels:
            ch.base_station = None
            ch.users = []
        self.assigned_channels = []
        self.per_channel_power = {}

    def find_available_channel(self):
        """Find a free (unoccupied) channel, if any."""
        for ch in self.assigned_channels:
            if len(ch.users) == 0:
                return ch
        return None


class User:
    def __init__(self, id, location_xy, velocity_xy, demand_bits=1e6):
        self.id = int(id)
        self.location = np.array(location_xy, dtype=float)
        self.velocity = np.array(velocity_xy, dtype=float)
        self.height = 1.5

        # radio link properties
        self.channel = []
        self.channel_SINR = []
        self.SINR = -100.0
        self.data_rate = 0.0  # instantaneous achievable rate (Mbps)
        self.demand = float(demand_bits)  # "required" rate (Mbps-like scale)
        self.mimo_layers = []

        # service class
        self.service_class = "infotainment"

        # task model (set properly by generate_task())
        self.task_type = "light"
        self.task_cycles = 0.0
        self.task_input_Mbit = 0.0
        self.task_offload_mandatory = False

        # mobility
        self.speed = float(np.linalg.norm(self.velocity))
        self.waypoint = None
        self.pause_time = 0
        self.dir_axis = None
        self.dir_sign = 1
        self.next_intersection = None

    def clear_channel(self):
        self.channel = []
        self.channel_SINR = []
        self.SINR = -100.0
        self.mimo_layers = []
        self.data_rate = 0.0

    def calculate_data_rate(self):
        """Aggregate rate across all assigned channels with MIMO."""
        self.data_rate = 0.0
        self.mimo_layers = []

        for i, ch in enumerate(self.channel):
            bw_eff = ch.bandwidth * NR_OVERHEAD
            SINR_dB = self.channel_SINR[i]
            max_rank = MIMO_MAX_RANK[ch.base_station.type_bs]

            L, total_se = mimo_rank_and_total_se(
                SINR_dB, max_rank, gap_db=SNR_GAP_DB, max_se=MAX_SE
            )
            dr_Mbps = (bw_eff * total_se) / 1e6
            self.mimo_layers.append(L)
            self.data_rate += dr_Mbps

    def calculate_demand_from_rng(self, rng):
        """Random traffic demand model."""
        if getattr(self, "service_class", "infotainment") == "safety":
            base_mbps = rng.uniform(0.5, 2.0)
        else:
            app_types = {"video": 5.0, "gaming": 10.0, "browsing": 2.0}
            app = rng.choice(list(app_types.keys()))
            base_mbps = app_types[app] * (1.0 + rng.uniform(0.0, 0.5))
        self.demand = float(base_mbps)

    def generate_task(self, rng, heavy_ratio, ue_cpu,
                      heavy_cyc_range, heavy_data_range,
                      light_cyc_range, light_data_range):
        """
        Assign a compute task to this user.

        heavy_ratio : fraction of users that get heavy (offload-mandatory) tasks
        ue_cpu      : UE local compute budget (cycles/step)
        *_range     : (lo, hi) for task cycles / input-data Mbit
        """
        if rng.random() < heavy_ratio:
            self.task_type = "heavy"    # MUST offload
            self.task_cycles = float(rng.uniform(*heavy_cyc_range))
            self.task_input_Mbit = float(rng.uniform(*heavy_data_range))
        else:
            self.task_type = "light"    # can run locally
            self.task_cycles = float(rng.uniform(*light_cyc_range))
            self.task_input_Mbit = float(rng.uniform(*light_data_range))
        self.task_offload_mandatory = (self.task_cycles > ue_cpu)

    def calculate_latency_ms(self, num_users_on_channel: float = None):
        """Very simplified base latency model (communication-centric)."""
        if not self.channel or self.data_rate <= 0:
            return 1000.0

        avg_d = np.mean(
            [
                np.linalg.norm(self.location - ch.base_station.location)
                for ch in self.channel
            ]
        )
        prop_delay_ms = (avg_d / 3e8) * 1e3
        proc_delay = 1.0
        sched_delay = 1.0

        if num_users_on_channel is None:
            num_users_on_channel = (
                np.mean([len(ch.users) for ch in self.channel])
                if self.channel
                else 1.0
            )

        queue_delay = 1.0 + num_users_on_channel / (self.data_rate + 1e-6)

        return float(
            np.clip(
                prop_delay_ms + proc_delay + sched_delay + queue_delay,
                0.0,
                1000.0,
            )
        )


# -----------------------
# Main environment class
# -----------------------
class MultiAgentMobileNetwork(MultiAgentEnv):
    """Multi-agent cellular + MEC environment (Gymnasium-style MA API)."""

    metadata = {"render_modes": ["human"], "render_fps": 30}

    def __init__(
        self,
        num_base_stations=4,
        num_users=80,
        num_channels_per_carrier=50,
        area_size=2000.0,
        bs_loc=None,
        max_steps=200,
        mobility_model="manhattan",
        seed=42,
        step_duration_s=1.0,
        deadline_ms=100.0,
        safety_traffic_ratio=0.3,
    ):
        super().__init__()

        # RNGs
        self.seed(seed)

        # topology / sim parameters
        self.num_base_stations = int(num_base_stations)
        self.num_users = int(num_users)
        self.num_channels_per_carrier = int(num_channels_per_carrier)
        self.area_size = float(area_size)
        self.max_steps = int(max_steps)
        self.mobility_model = mobility_model

        # time / QoS
        self.step_duration_s = float(step_duration_s)
        self.deadline_ms = float(deadline_ms)
        self.safety_traffic_ratio = float(
            np.clip(safety_traffic_ratio, 0.0, 1.0)
        )

        # radio parameters
        self.ma_transmission_power = 40000.0  # mW (40 W)
        self.max_ma_channels = int(num_channels_per_carrier)
        self.macro_carrier_frequencies = (
            [3.5e9] if MACRO_REUSE_ONE else [3.4e9, 3.5e9, 3.6e9, 3.7e9]
        )
        self.macro_channel_bw = 180e3  # Hz

        # MEC / compute parameters
        self.mec_cpu_capacity_cycles = 50e9       # 50 GHz multi-core edge server
        self.cycles_per_Mbit = 5e7
        self.cpu_kappa = 1e-27
        self.max_user_demand_Mbps = 10.0

        # ---- Task-model parameters (heterogeneous compute requirements) ----
        self.heavy_task_ratio = 0.70
        self.ue_local_cpu_cycles = 0.5e9
        self.heavy_task_cycles_range = (0.5e9, 2.5e9)   # balanced for 50 GHz MEC
        self.heavy_task_data_range = (2.0, 8.0)
        self.light_task_cycles_range = (0.05e9, 0.4e9)
        self.light_task_data_range = (0.2, 1.5)
        self.local_heavy_penalty_ms = 4000.0

        # reward weights
        self.reward_weights = SimpleNamespace(
            w_lat=0.2,
            w_thr=0.3,
            w_dead=0.2,
            w_qoe=0.3,
            w_eng=0.05,
            w_block=0.2,
            w_fair=0.1,
        )

        # objects
        self.users = []
        self.base_stations = []

        # BS placement
        if bs_loc is None:
            bs_loc = self._default_bs_locations(
                self.num_base_stations, self.area_size
            )
        assert len(bs_loc) >= self.num_base_stations

        for i in range(self.num_base_stations):
            bs = BaseStation(
                i,
                self.ma_transmission_power,
                30.0,
                bs_loc[i],
                type_bs="Ma",
                mec_cpu_capacity_cycles=self.mec_cpu_capacity_cycles,
            )
            self.base_stations.append(bs)

        # build macro channels
        self.macro_channels = []
        ch_id = 0
        for f in self.macro_carrier_frequencies:
            for _ in range(self.num_channels_per_carrier):
                self.macro_channels.append(
                    Channel(
                        ch_id,
                        f,
                        self.macro_channel_bw,
                        noise_figure_db=7.0,
                    )
                )
                ch_id += 1

        # spawn users
        rng = self.np_random
        for u_id in range(self.num_users):
            if self.mobility_model == "manhattan":
                loc, vel = self._spawn_on_grid()
            else:
                loc = rng.uniform(0, self.area_size, 2)
                vel = rng.uniform(-5.0, 5.0, 2)

            u = User(u_id, loc, vel)
            svc = (
                "safety"
                if rng.random() < self.safety_traffic_ratio
                else "infotainment"
            )
            u.service_class = svc
            u.calculate_demand_from_rng(rng)
            u.generate_task(
                rng, self.heavy_task_ratio, self.ue_local_cpu_cycles,
                self.heavy_task_cycles_range, self.heavy_task_data_range,
                self.light_task_cycles_range, self.light_task_data_range,
            )
            self.users.append(u)

            if self.mobility_model == "manhattan":
                self._init_user_manhattan(u)

        # multi-agent API ids
        self.agents = [f"agent_{i}" for i in range(self.num_base_stations)]
        self.possible_agents = list(self.agents)
        self._agent_ids = set(self.agents)

        # action: (power_frac, channel_frac, offload_frac, cpu_frac)
        self.action_spaces = {
            a: gym.spaces.Box(
                low=np.array([0.0, 0.0, 0.0, 0.0], dtype=np.float32),
                high=np.array([1.0, 1.0, 1.0, 1.0], dtype=np.float32),
                dtype=np.float32,
            )
            for a in self.agents
        }

        # 20-D observation
        obs_dim = len(vars(OBS_IDX))
        self.observation_spaces = {
            a: gym.spaces.Box(
                low=0.0, high=1.0, shape=(obs_dim,), dtype=np.float32
            )
            for a in self.agents
        }

        # simulation state
        self.num_steps = 0
        self.current_episode_reward = 0.0
        self.assigned_channels = {}
        self.bs_carrier_frequency = {}

        self._assign_frequency_subsets()
        self.reset_user_info()

        # normalization constants
        self.energy_normalization_J = (
            self.num_base_stations
            * self.ma_transmission_power
            * 1e-3
            * self.step_duration_s
        )
        self.throughput_normalization_Mbps = (
            self.num_users * self.max_user_demand_Mbps
        )

        self.fig = None
        self._panel_axes = None

        # shared spaces for RLlib
        first_agent = self.agents[0]
        self.observation_space = self.observation_spaces[first_agent]
        self.action_space = self.action_spaces[first_agent]

    # -------------
    # RNG helpers
    # -------------
    def seed(self, seed=None):
        if seed is None:
            seed = random.randrange(2**31 - 1)
        seed_int = int(seed) & 0xFFFFFFFF
        self.np_random, _ = seeding.np_random(seed_int)
        random.seed(seed_int)
        np.random.seed(seed_int)
        return [seed_int]

    # -------------
    # Topology helpers
    # -------------
    def _default_bs_locations(self, n, L):
        coords = []
        grid = int(math.ceil(math.sqrt(n)))
        xs = np.linspace(0.2 * L, 0.8 * L, grid)
        ys = np.linspace(0.2 * L, 0.8 * L, grid)
        for x in xs:
            for y in ys:
                coords.append((float(x), float(y)))
                if len(coords) >= n:
                    return coords[:n]
        return coords[:n]

    def _assign_frequency_subsets(self):
        idx = 0
        for bs in self.base_stations:
            if MACRO_REUSE_ONE:
                self.bs_carrier_frequency[bs.id] = (
                    self.macro_carrier_frequencies[0]
                )
            else:
                self.bs_carrier_frequency[bs.id] = (
                    self.macro_carrier_frequencies[
                        idx % len(self.macro_carrier_frequencies)
                    ]
                )
                idx += 1

    # -------------
    # Manhattan mobility
    # -------------
    def _build_road_grid(self):
        L = self.area_size
        spacing = max(50.0, float(250.0))
        self.grid_xs = np.arange(0.0, L + 1e-9, spacing)
        self.grid_ys = np.arange(0.0, L + 1e-9, spacing)

    def _spawn_on_grid(self):
        if not hasattr(self, "grid_xs"):
            self._build_road_grid()
        L = self.area_size
        if self.np_random.random() < 0.5:
            y = float(self.np_random.choice(self.grid_ys))
            x = float(self.np_random.uniform(0, L))
            dir_axis, dir_sign = "x", (1 if self.np_random.random() < 0.5 else -1)
        else:
            x = float(self.np_random.choice(self.grid_xs))
            y = float(self.np_random.uniform(0, L))
            dir_axis, dir_sign = "y", (1 if self.np_random.random() < 0.5 else -1)
        speed = float(max(1.0, self.np_random.normal(12.0, 3.0)))
        if dir_axis == "x":
            vel = np.array([dir_sign * speed, 0.0], dtype=float)
        else:
            vel = np.array([0.0, dir_sign * speed], dtype=float)
        return np.array([x, y], dtype=float), vel

    def _init_user_manhattan(self, u: User):
        if not hasattr(self, "grid_xs"):
            self._build_road_grid()
        u.location = self._snap_to_grid(u.location)
        if abs(u.velocity[0]) >= abs(u.velocity[1]):
            u.dir_axis = "x"
            u.dir_sign = 1 if u.velocity[0] >= 0 else -1
        else:
            u.dir_axis = "y"
            u.dir_sign = 1 if u.velocity[1] >= 0 else -1
        u.speed = float(max(1.0, np.linalg.norm(u.velocity)))
        if u.dir_axis == "x":
            candidates = (
                self.grid_xs[self.grid_xs > u.location[0]]
                if u.dir_sign > 0
                else self.grid_xs[self.grid_xs < u.location[0]]
            )
            if u.dir_sign > 0:
                coord = candidates.min() if candidates.size else self.area_size
            else:
                coord = candidates.max() if candidates.size else 0.0
            u.next_intersection = np.array(
                [coord, self._snap_to_grid(u.location)[1]], dtype=float
            )
        else:
            candidates = (
                self.grid_ys[self.grid_ys > u.location[1]]
                if u.dir_sign > 0
                else self.grid_ys[self.grid_ys < u.location[1]]
            )
            if u.dir_sign > 0:
                coord = candidates.min() if candidates.size else self.area_size
            else:
                coord = candidates.max() if candidates.size else 0.0
            u.next_intersection = np.array(
                [self._snap_to_grid(u.location)[0], coord], dtype=float
            )
        u.pause_time = 0

    def _snap_to_grid(self, p):
        if not hasattr(self, "grid_xs"):
            self._build_road_grid()
        x = self.grid_xs[np.argmin(np.abs(self.grid_xs - p[0]))]
        y = self.grid_ys[np.argmin(np.abs(self.grid_ys - p[1]))]
        return np.array([x, y], dtype=float)

    def _advance_user_manhattan(self, u: User):
        if u.pause_time > 0:
            u.pause_time -= 1
            return
        delta = u.next_intersection - u.location
        dist = float(np.linalg.norm(delta))
        step = min(dist, u.speed)
        if dist > 1e-9:
            u.location += (delta / dist) * step
        if (
            np.linalg.norm(u.location - u.next_intersection) <= 1e-6
            or step == dist
        ):
            if self.np_random.random() < 0.15:
                u.pause_time = int(self.np_random.integers(0, 4))
            r = self.np_random.random()
            if r < 0.25:
                u.dir_axis = "y" if u.dir_axis == "x" else "x"
                u.dir_sign = -u.dir_sign
            elif r < 0.5:
                u.dir_axis = "y" if u.dir_axis == "x" else "x"
            u.speed = float(max(1.0, self.np_random.normal(12.0, 3.0)))
            if u.dir_axis == "x":
                if u.dir_sign > 0:
                    candidates = self.grid_xs[self.grid_xs > u.location[0]]
                    x_next = candidates.min() if candidates.size > 0 else self.area_size
                else:
                    candidates = self.grid_xs[self.grid_xs < u.location[0]]
                    x_next = candidates.max() if candidates.size > 0 else 0.0
                u.next_intersection = np.array(
                    [x_next, self._snap_to_grid(u.location)[1]], dtype=float
                )
                u.velocity = np.array([u.dir_sign * u.speed, 0.0], dtype=float)
            else:
                if u.dir_sign > 0:
                    candidates = self.grid_ys[self.grid_ys > u.location[1]]
                    y_next = candidates.min() if candidates.size > 0 else self.area_size
                else:
                    candidates = self.grid_ys[self.grid_ys < u.location[1]]
                    y_next = candidates.max() if candidates.size > 0 else 0.0
                u.next_intersection = np.array(
                    [self._snap_to_grid(u.location)[0], y_next], dtype=float
                )
                u.velocity = np.array([0.0, u.dir_sign * u.speed], dtype=float)

    # -------------
    # User / BS state helpers
    # -------------
    def reset_user_info(self):
        self.user_info = {
            u.id: {
                "user": u.id,
                "ma_assigned_channel": [],
                "ma_base_station": [],
                "ma_base_station_location": [],
            }
            for u in self.users
        }

    def assign_channels_on_demand(self):
        for u in self.users:
            u.clear_channel()
        for bs in self.base_stations:
            for ch in bs.assigned_channels:
                ch.users = []
        for u in self.users:
            best_bs, _ = self._best_bs_in_cov(u, type_filter="Ma")
            if best_bs:
                ch = best_bs.find_available_channel()
                if ch:
                    u.channel.append(ch)
                    ch.users.append(u)
                    info = self.user_info[u.id]
                    info["ma_assigned_channel"].append(ch.id)
                    info["ma_base_station"].append(best_bs.id)
                    info["ma_base_station_location"].append(
                        best_bs.location.copy()
                    )

    def _per_channel_tx_power_mW(self, bs: BaseStation):
        if bs.per_channel_power:
            vals = list(bs.per_channel_power.values())
            return float(np.mean(vals))
        n = max(1, len(bs.assigned_channels))
        return bs.transmit_power / n

    def _noise_mW_for(self, bs: BaseStation):
        if bs.assigned_channels:
            return bs.assigned_channels[0].calculate_noise_power() * 1e3
        bw_hz = self.macro_channel_bw
        k = 1.380649e-23
        T = 293.15
        NF = 10 ** (7 / 10)
        return k * T * bw_hz * NF * 1e3

    def _est_rate_one_channel_Mbps(self, u: User, bs: BaseStation):
        if not bs.assigned_channels:
            return 0.0
        f = self.bs_carrier_frequency[bs.id]
        d = float(np.linalg.norm(u.location - bs.location))
        PL_dB = bs.calculate_path_loss(d, f)
        n_ch = max(1, len(bs.assigned_channels))
        p_ch = bs.transmit_power / n_ch
        g = BEAM_GAIN_DB[bs.type_bs]
        g_tx = 10 ** (g["tx_main"] / 10.0)
        g_rx = 10 ** (g["rx"] / 10.0)
        sig_mW = p_ch * g_tx * g_rx / (10.0 ** (PL_dB / 10.0))
        noise_mW = self._noise_mW_for(bs)
        SINR = sig_mW / max(noise_mW, 1e-12)
        SINR_dB = 10.0 * np.log10(max(SINR, 1e-12))
        bw = bs.assigned_channels[0].bandwidth * NR_OVERHEAD
        _, total_se = mimo_rank_and_total_se(
            SINR_dB, MIMO_MAX_RANK[bs.type_bs], gap_db=SNR_GAP_DB, max_se=MAX_SE
        )
        return (bw * total_se) / 1e6

    def _best_bs_in_cov(self, u: User, type_filter=None):
        best = None
        best_score = 0.0
        for bs in self.base_stations:
            if type_filter is not None and bs.type_bs != type_filter:
                continue
            if not bs.assigned_channels:
                continue
            d = np.linalg.norm(u.location - bs.location)
            if d > bs.coverage_area:
                continue
            r = self._est_rate_one_channel_Mbps(u, bs)
            load = (
                sum(1 for c in bs.assigned_channels if len(c.users) > 0)
                / max(1, len(bs.assigned_channels))
            )
            fairness = 1.0 - 0.5 * load
            score = r * fairness
            if score > best_score:
                best_score = score
                best = bs
        return best, best_score

    def _estimate_interference_mW(self, u: User, f, exclude_bs: BaseStation):
        co_bs = [
            b
            for b in self.base_stations
            if b is not exclude_bs and self.bs_carrier_frequency[b.id] == f
        ]
        I = 0.0
        g_rx_int = 10 ** (UE_INTERF_RX_DB / 10.0)
        for bi in co_bs:
            if not bi.assigned_channels:
                continue
            p_i = self._per_channel_tx_power_mW(bi)
            d_i = np.linalg.norm(u.location - bi.location)
            PL_i = bi.calculate_path_loss(d_i, f)
            gi = BEAM_GAIN_DB[bi.type_bs]
            g_tx_i = 10 ** (gi["tx_side"] / 10.0)
            users_in_cov_bi = [
                uu
                for uu in self.users
                if np.linalg.norm(uu.location - bi.location)
                <= bi.coverage_area
            ]
            util = min(
                1.0, len(users_in_cov_bi) / max(1, len(bi.assigned_channels))
            )
            I += (
                util * p_i * g_tx_i * g_rx_int / (10.0 ** (PL_i / 10.0))
            )
        return I

    # -------------
    # Water-filling power allocation
    # -------------
    @staticmethod
    def _waterfill(P_total, h_list, n_list, p_floor_list=None, tol=1e-6, max_it=200):
        K = len(h_list)
        if K == 0:
            return []
        h = np.asarray(h_list, dtype=float)
        n = np.asarray(n_list, dtype=float)
        p_floor = (
            np.zeros(K, dtype=float)
            if p_floor_list is None
            else np.asarray(p_floor_list, dtype=float)
        )
        mask = h > 0
        if not np.any(mask):
            return [0.0] * K
        p_floor_sum = float(np.sum(np.maximum(p_floor, 0.0)))
        if p_floor_sum > P_total and p_floor_sum > 0:
            scaled = P_total * (p_floor / p_floor_sum)
            return list(np.maximum(scaled, 0.0))

        def alloc(lmbd):
            base = 1.0 / max(lmbd, 1e-18)
            out = np.maximum(p_floor, base - n / np.maximum(h, 1e-18))
            return np.maximum(out, 0.0)

        lo, hi = 0.0, 1e12
        for _ in range(max_it):
            mid = 0.5 * (lo + hi)
            p = alloc(mid)
            s = float(np.sum(p))
            if abs(s - P_total) <= tol:
                return list(np.maximum(p, 0.0))
            if s > P_total:
                lo = mid
            else:
                hi = mid
        return list(np.maximum(alloc(hi), 0.0))

    # -------------
    # Core RL API (Gymnasium-style MA)
    # -------------
    def step(self, action_dict):
        start_wall = time.time()
        self.num_steps += 1

        for agent in self.agents:
            if agent not in action_dict:
                action_dict[agent] = np.array(
                    [0.5, 0.5, 0.5, 0.5], dtype=float
                )
            action_dict[agent] = np.clip(
                np.array(action_dict[agent], dtype=float), 0.0, 1.0,
            )

        # --------- traffic demand & task update ----------
        for u in self.users:
            if self.np_random.random() < 0.05:
                u.calculate_demand_from_rng(self.np_random)
            u.generate_task(
                self.np_random, self.heavy_task_ratio, self.ue_local_cpu_cycles,
                self.heavy_task_cycles_range, self.heavy_task_data_range,
                self.light_task_cycles_range, self.light_task_data_range,
            )

        for u in self.users:
            u.clear_channel()
        for bs in self.base_stations:
            bs.clear_assigned_channels()
        for ch in self.macro_channels:
            ch.users = []
            ch.base_station = None
        self.assigned_channels.clear()
        self.reset_user_info()

        # --------- resource allocation per BS ----------
        for i, bs in enumerate(self.base_stations):
            agent = f"agent_{i}"
            power_frac, channel_frac, offload_frac, cpu_frac = action_dict[agent]
            bs.transmit_power = float(np.clip(power_frac, 0.0, 1.0)) * self.ma_transmission_power
            max_cap = int(self.max_ma_channels)
            req_ch = int(np.rint(float(np.clip(channel_frac, 0.0, 1.0)) * max_cap))
            if req_ch == 0 and bs.transmit_power > 1e-9:
                req_ch = 1
            freq = self.bs_carrier_frequency[bs.id]
            avail = [
                c for c in self.macro_channels
                if c.frequency == freq and c.base_station is None
            ]
            req_ch = min(len(avail), req_ch)
            if req_ch > 0:
                chosen = avail[:req_ch]
                bs.assign_channels(chosen)
                for ch in chosen:
                    self.assigned_channels[ch] = bs.id
            bs.offload_frac = float(np.clip(offload_frac, 0.0, 1.0))
            bs.cpu_util_frac = float(np.clip(cpu_frac, 0.0, 1.0))
            bs.last_cpu_used = bs.cpu_util_frac * bs.mec_cpu_capacity
            bs.update_coverage_area_from_power(bs.transmit_power, freq)

        self.assign_channels_on_demand()

        # --------- per-BS water-filling ----------
        for bs in self.base_stations:
            bs.per_channel_power = {}
            ch_act, H, N, floors = [], [], [], []
            for ch in bs.assigned_channels:
                if not ch.users:
                    continue
                u = ch.users[0]
                f = ch.frequency
                d = float(np.linalg.norm(u.location - bs.location))
                PL_dB = bs.calculate_path_loss(d, f)
                g = BEAM_GAIN_DB[bs.type_bs]
                h_linear = (
                    10 ** (g["tx_main"] / 10.0) * 10 ** (g["rx"] / 10.0)
                ) / (10.0 ** (PL_dB / 10.0))
                noise_mW = ch.calculate_noise_power() * 1e3
                I_mW = self._estimate_interference_mW(u, f, bs)
                prio = float(np.clip(0.5 + (u.demand / self.max_user_demand_Mbps), 0.5, 2.0))
                N_eff = (noise_mW + I_mW) / prio
                ch_act.append(ch)
                H.append(h_linear)
                N.append(N_eff)
                floors.append(0.0)
            if ch_act:
                P_total = float(bs.transmit_power)
                p_list = self._waterfill(P_total, H, N, p_floor_list=floors, tol=1e-6, max_it=120)
                for ch, p in zip(ch_act, p_list):
                    bs.per_channel_power[ch.id] = float(max(p, 0.0))
            else:
                bs.per_channel_power = {}
            f = self.bs_carrier_frequency[bs.id]
            bs.update_coverage_area_from_power(bs.transmit_power, f)

        for u in self.users:
            self.calculate_SINR(u)
            u.calculate_data_rate()

        # --------- MEC queue dynamics (task-aware) ----------
        bs_to_users = defaultdict(list)
        for u in self.users:
            if u.channel:
                bs = u.channel[0].base_station
                if bs is not None:
                    bs_to_users[bs.id].append(u)

        user_comp_delay_ms = {u.id: 0.0 for u in self.users}

        for bs in self.base_stations:
            assoc_users = bs_to_users.get(bs.id, [])
            off_frac = float(np.clip(bs.offload_frac, 0.0, 1.0))
            cpu_frac = float(np.clip(bs.cpu_util_frac, 0.0, 1.0))
            F_max = bs.mec_cpu_capacity
            F_used = cpu_frac * F_max
            bs.last_cpu_used = F_used

            offloaded = []
            total_new_cycles = 0.0
            for u in assoc_users:
                C = u.task_cycles
                if u.task_offload_mandatory:
                    offloaded.append((u, C))
                    total_new_cycles += C
                else:
                    if self.np_random.random() < off_frac:
                        offloaded.append((u, C))
                        total_new_cycles += C
                    else:
                        local_delay_s = C / max(self.ue_local_cpu_cycles, 1e-9)
                        user_comp_delay_ms[u.id] += local_delay_s * 1000.0

            q_prev = bs.mec_queue_cycles
            mu_cycles = F_used * self.step_duration_s
            q_after_serv = max(q_prev - mu_cycles, 0.0)
            q_next = q_after_serv + total_new_cycles

            if F_used > 0.0:
                queue_delay_s = q_after_serv / F_used
            else:
                queue_delay_s = self.deadline_ms / 1000.0 * 10.0

            n_off = len(offloaded)
            for (u, C_cycles) in offloaded:
                if F_used > 0.0 and n_off > 0:
                    f_share = F_used / n_off
                    T_proc_s = C_cycles / max(f_share, 1e-9)
                    T_queue_s = queue_delay_s
                else:
                    T_proc_s = self.deadline_ms / 1000.0 * 10.0
                    T_queue_s = self.deadline_ms / 1000.0 * 10.0
                comp_ms = (T_proc_s + T_queue_s) * 1000.0
                comp_ms = float(np.clip(comp_ms, 0.0, 5000.0))
                user_comp_delay_ms[u.id] += comp_ms
            bs.mec_queue_cycles = float(q_next)

        # --------- Metrics ----------
        bs_served = []
        for bs in self.base_stations:
            assoc_users = bs_to_users.get(bs.id, [])
            local_served = sum(min(u.data_rate, u.demand) for u in assoc_users)
            bs_served.append(local_served)
        bs_served_arr = np.asarray(bs_served, dtype=float)
        if np.any(bs_served_arr > 0):
            jain_num_bs = float(np.sum(bs_served_arr) ** 2)
            jain_den_bs = float(len(bs_served_arr) * np.sum(bs_served_arr**2) + 1e-9)
            jain_fairness_bs = float(jain_num_bs / jain_den_bs)
        else:
            jain_fairness_bs = 0.0

        served_rates, latencies, qoe_list = [], [], []
        deadline_hits, deadline_candidates = 0, 0
        svc_stats = {
            "safety": {"served_rates": [], "latencies": [], "qoes": [], "deadline_hits": 0, "deadline_candidates": 0},
            "infotainment": {"served_rates": [], "latencies": [], "qoes": [], "deadline_hits": 0, "deadline_candidates": 0},
        }

        for u in self.users:
            svc = getattr(u, "service_class", "infotainment")
            served = min(u.data_rate, u.demand)
            served_rates.append(served)
            bucket = svc_stats.get(svc, None)
            if bucket is not None:
                bucket["served_rates"].append(served)
            base_lat = u.calculate_latency_ms()
            lat = base_lat + user_comp_delay_ms.get(u.id, 0.0)
            latencies.append(lat)
            if bucket is not None:
                bucket["latencies"].append(lat)
            if u.demand > 0:
                deadline_candidates += 1
                if lat <= self.deadline_ms:
                    deadline_hits += 1
                if bucket is not None:
                    bucket["deadline_candidates"] += 1
                    if lat <= self.deadline_ms:
                        bucket["deadline_hits"] += 1
            thr_norm = np.clip(served / u.demand, 0.0, 1.0) if u.demand > 0 else 0.0
            if lat <= self.deadline_ms:
                lat_factor = 1.0
            else:
                lat_factor = max(0.0, 1.0 - (lat - self.deadline_ms) / (5 * self.deadline_ms))
            qoe = 0.5 * thr_norm + 0.5 * lat_factor
            qoe_clipped = float(np.clip(qoe, 0.0, 1.0))
            qoe_list.append(qoe_clipped)
            if bucket is not None:
                bucket["qoes"].append(qoe_clipped)

        total_throughput_Mbps = float(np.sum(served_rates))
        avg_throughput_Mbps = float(total_throughput_Mbps / max(1, self.num_users))
        avg_latency_ms = float(np.mean(latencies)) if latencies else 0.0
        p95_latency_ms = float(np.percentile(latencies, 95)) if latencies else 0.0
        deadline_satisfaction = float(deadline_hits / max(1, deadline_candidates)) if deadline_candidates > 0 else 0.0

        served_arr = np.asarray(served_rates, dtype=float)
        if np.any(served_arr > 0):
            jain_num_users = float(np.sum(served_arr) ** 2)
            jain_den_users = float(len(served_arr) * np.sum(served_arr**2) + 1e-9)
            jain_fairness_users = float(jain_num_users / jain_den_users)
        else:
            jain_fairness_users = 0.0
        jain_fairness = jain_fairness_bs

        total_radio_power_mW = float(np.sum([bs.transmit_power for bs in self.base_stations]))
        total_cpu_power_W = float(np.sum([self.cpu_kappa * (bs.last_cpu_used**3) for bs in self.base_stations]))
        step_energy_J = total_radio_power_mW * 1e-3 * self.step_duration_s + total_cpu_power_W * self.step_duration_s
        energy_per_task_J = float(step_energy_J / deadline_hits) if deadline_hits > 0 else 0.0
        blocked_users = [u for u in self.users if not u.channel]
        blocking_rate = float(len(blocked_users) / max(1, self.num_users))
        avg_qoe = float(np.mean(qoe_list)) if qoe_list else 0.0

        def _svc_metrics(bucket):
            if not bucket["served_rates"]:
                return {"avg_throughput_Mbps": 0.0, "avg_latency_ms": 0.0, "p95_latency_ms": 0.0, "deadline_satisfaction": 0.0, "avg_qoe": 0.0}
            s_rates = np.asarray(bucket["served_rates"], dtype=float)
            lats = np.asarray(bucket["latencies"], dtype=float)
            qoes = np.asarray(bucket["qoes"], dtype=float)
            avg_lat = float(np.mean(lats)) if lats.size > 0 else 0.0
            p95_lat = float(np.percentile(lats, 95)) if lats.size > 0 else 0.0
            avg_tput = float(np.mean(s_rates)) if s_rates.size > 0 else 0.0
            ds = float(bucket["deadline_hits"] / max(1, bucket["deadline_candidates"])) if bucket["deadline_candidates"] > 0 else 0.0
            avg_qoe_svc = float(np.mean(qoes)) if qoes.size > 0 else 0.0
            return {"avg_throughput_Mbps": avg_tput, "avg_latency_ms": avg_lat, "p95_latency_ms": p95_lat, "deadline_satisfaction": ds, "avg_qoe": avg_qoe_svc}

        svc_safety = _svc_metrics(svc_stats["safety"])
        svc_infot = _svc_metrics(svc_stats["infotainment"])

        U_norm = float(np.clip(total_throughput_Mbps / max(1e-9, self.throughput_normalization_Mbps), 0.0, 1.0))
        D_norm = float(np.clip(np.mean([max(lat - self.deadline_ms, 0.0) / (5.0 * max(1.0, self.deadline_ms)) for lat in latencies]), 0.0, 1.0)) if latencies else 0.0
        E_norm = float(np.clip(step_energy_J / max(1e-9, 2.0 * self.energy_normalization_J), 0.0, 1.0))

        latency_ref_ms = self.deadline_ms if self.deadline_ms > 0 else 100.0
        L_mean = avg_latency_ms / latency_ref_ms if latency_ref_ms > 0 else 0.0
        L_p95 = p95_latency_ms / (1.5 * latency_ref_ms) if latency_ref_ms > 0 else 0.0
        L_norm = float(np.clip(0.7 * L_mean + 0.3 * L_p95, 0.0, 1.0))
        T_norm = U_norm
        V_fair = 1.0 - jain_fairness

        w = self.reward_weights
        positive = w.w_thr * T_norm + w.w_lat * (1.0 - D_norm) + w.w_dead * deadline_satisfaction + w.w_qoe * avg_qoe
        negative = w.w_eng * E_norm + w.w_block * blocking_rate + w.w_fair * V_fair
        global_reward = float(np.clip(positive - negative, -1.0, 1.0))
        rewards = {agent: global_reward for agent in self.agents}
        scenario_type = "urban" if self.mobility_model == "manhattan" else "highway_like"

        # --------- per-BS infos ----------
        infos = {}
        association_fractions, channel_rewards = [], []
        for i, bs in enumerate(self.base_stations):
            agent = f"agent_{i}"
            users_in_cov = [u for u in self.users if np.linalg.norm(u.location - bs.location) <= bs.coverage_area]
            assoc_users = [u for u in users_in_cov if any(ch.base_station == bs for ch in u.channel)]
            assoc_frac = len(assoc_users) / max(1, len(users_in_cov)) if users_in_cov else 0.0
            association_fractions.append(assoc_frac)
            ch_num = max(1, len(bs.assigned_channels))
            usr_num = max(1, len(users_in_cov))
            channel_rewards.append(1.0 - abs(ch_num - usr_num) / (ch_num + usr_num))
            local_served = sum(min(u.data_rate, u.demand) for u in assoc_users)
            local_demand = sum(u.demand for u in assoc_users) + 1e-9
            local_util = local_served / local_demand if local_demand > 0 else 0.0
            loc_avg_lat_ms = float(np.mean([latencies[self.users.index(u)] for u in assoc_users])) if assoc_users else 0.0
            infos[agent] = {
                "local_data_rate_Mbps": float(sum(u.data_rate for u in assoc_users)),
                "local_served_throughput_Mbps": float(local_served),
                "local_demand_Mbps": float(local_demand),
                "local_power_mW": float(bs.transmit_power),
                "local_channels": int(len(bs.assigned_channels)),
                "users_in_cov": int(len(users_in_cov)),
                "assoc_users": int(len(assoc_users)),
                "local_avg_latency_ms": loc_avg_lat_ms,
                "local_util": float(local_util),
                "local_mec_queue_cycles": float(bs.mec_queue_cycles),
                "local_cpu_used_cycles_per_s": float(bs.last_cpu_used),
                "local_offload_frac": float(bs.offload_frac),
                "local_cpu_util_frac": float(bs.cpu_util_frac),
            }

        mean_assoc_frac = float(np.mean(association_fractions)) if association_fractions else 0.0
        mean_channel_reward = float(np.mean(channel_rewards)) if channel_rewards else 0.0

        global_info = {
            "total_throughput_Mbps": total_throughput_Mbps, "avg_throughput_Mbps": avg_throughput_Mbps,
            "avg_latency_ms": avg_latency_ms, "p95_latency_ms": p95_latency_ms,
            "deadline_satisfaction": deadline_satisfaction, "blocking_rate": blocking_rate,
            "avg_qoe": avg_qoe, "total_radio_power_mW": total_radio_power_mW,
            "total_cpu_power_W": total_cpu_power_W, "step_energy_J": step_energy_J,
            "energy_per_task_J": energy_per_task_J, "jain_fairness": jain_fairness,
            "jain_fairness_bs": jain_fairness_bs, "jain_fairness_users": jain_fairness_users,
            "num_users": int(self.num_users), "num_base_stations": int(self.num_base_stations),
            "mean_assoc_frac": mean_assoc_frac, "mean_channel_reward": mean_channel_reward,
            "env_step_walltime_ms": float((time.time() - start_wall) * 1e3),
            "U_norm": U_norm, "D_norm": D_norm, "E_norm": E_norm, "L_norm": L_norm,
            "V_fair": V_fair, "global_reward": global_reward,
            "reward_w_lat": w.w_lat, "reward_w_thr": w.w_thr, "reward_w_dead": w.w_dead,
            "reward_w_qoe": w.w_qoe, "reward_w_eng": w.w_eng, "reward_w_block": w.w_block,
            "reward_w_fair": w.w_fair, "scenario_type": scenario_type,
            "svc_safety_avg_throughput_Mbps": svc_safety["avg_throughput_Mbps"],
            "svc_safety_avg_latency_ms": svc_safety["avg_latency_ms"],
            "svc_safety_p95_latency_ms": svc_safety["p95_latency_ms"],
            "svc_safety_deadline_satisfaction": svc_safety["deadline_satisfaction"],
            "svc_safety_avg_qoe": svc_safety["avg_qoe"],
            "svc_infotainment_avg_throughput_Mbps": svc_infot["avg_throughput_Mbps"],
            "svc_infotainment_avg_latency_ms": svc_infot["avg_latency_ms"],
            "svc_infotainment_p95_latency_ms": svc_infot["p95_latency_ms"],
            "svc_infotainment_deadline_satisfaction": svc_infot["deadline_satisfaction"],
            "svc_infotainment_avg_qoe": svc_infot["avg_qoe"],
        }

        for agent in self.agents:
            infos[agent].update(global_info)
        self.current_episode_reward += global_reward

        done_all = self.num_steps >= self.max_steps
        terminateds = {agent: False for agent in self.agents}
        truncateds = {agent: done_all for agent in self.agents}
        terminateds["__all__"] = False
        truncateds["__all__"] = done_all

        obs = self.get_observation()
        self.update_user_location()
        return obs, rewards, terminateds, truncateds, infos

    def reset(self, *, seed=None, options=None):
        if seed is not None:
            self.seed(seed)
        self.num_steps = 0
        self.current_episode_reward = 0.0
        for u in self.users:
            if self.mobility_model == "manhattan":
                loc, vel = self._spawn_on_grid()
                u.location = loc
                u.velocity = vel
                self._init_user_manhattan(u)
            else:
                u.location = self.np_random.uniform(0, self.area_size, 2)
                u.waypoint = self.np_random.uniform(0, self.area_size, 2)
            svc = "safety" if self.np_random.random() < self.safety_traffic_ratio else "infotainment"
            u.service_class = svc
            u.calculate_demand_from_rng(self.np_random)
            u.generate_task(
                self.np_random, self.heavy_task_ratio, self.ue_local_cpu_cycles,
                self.heavy_task_cycles_range, self.heavy_task_data_range,
                self.light_task_cycles_range, self.light_task_data_range,
            )
            u.data_rate = 0.0
            u.SINR = -100.0
            u.clear_channel()
        for ch in self.macro_channels:
            ch.users = []
            ch.base_station = None
        self.assigned_channels.clear()
        for bs in self.base_stations:
            bs.clear_assigned_channels()
            bs.transmit_power = self.ma_transmission_power
            bs.mec_queue_cycles = 0.0
            bs.offload_frac = 1.0
            bs.cpu_util_frac = 1.0
            bs.last_cpu_used = bs.mec_cpu_capacity
        for bs in self.base_stations:
            freq = self.bs_carrier_frequency[bs.id]
            avail = [c for c in self.macro_channels if c.frequency == freq and c.base_station is None]
            if avail:
                chosen = [avail[0]]
                bs.assign_channels(chosen)
                self.assigned_channels[avail[0]] = bs.id
            bs.update_coverage_area_from_power(bs.transmit_power, self.bs_carrier_frequency[bs.id])
        self.reset_user_info()
        self.prev_assoc_by_user = {u.id: {"Ma": None} for u in self.users}
        obs = self.get_observation()
        infos = {agent: {} for agent in self.agents}
        return obs, infos

    # -------------
    # Observation & global state
    # -------------
    def get_observation(self):
        obs = {}
        max_speed = 25.0
        for i, bs in enumerate(self.base_stations):
            agent = f"agent_{i}"
            users_in_cov = [u for u in self.users if np.linalg.norm(u.location - bs.location) <= bs.coverage_area]
            max_power = self.ma_transmission_power
            max_ch_for_bs = float(max(1, self.max_ma_channels))
            bs_type = 0.5
            tx_norm = np.clip(bs.transmit_power / max_power, 0.0, 1.0)
            used = sum(1 for c in bs.assigned_channels if len(c.users) > 0)
            ch_util = np.clip(used / max_ch_for_bs, 0.0, 1.0)
            cov_util = len(users_in_cov) / max(1, self.num_users)
            load_ratio = len(users_in_cov) / max(1, len(bs.assigned_channels)) if bs.assigned_channels else 0.0
            load_ratio_norm = float(np.clip(load_ratio / 2.0, 0.0, 1.0))
            nearby_pot = len([u for u in self.users if np.linalg.norm(u.location - bs.location) <= bs.coverage_area * 1.5]) / max(1, self.num_users)
            avg_speed = np.clip((sum(u.speed for u in users_in_cov) / len(users_in_cov) if users_in_cov else 0.0) / max_speed, 0.0, 1.0)
            if users_in_cov:
                max_dist = max(np.linalg.norm(u.location - bs.location) for u in users_in_cov)
                req_p_per_ch = self.calculate_required_power_for_distance(max_dist, bs)
                req_total = req_p_per_ch * max(1, len(bs.assigned_channels))
            else:
                req_total = 0.0
            req_p_norm = np.clip(req_total / max_power if max_power > 0 else 0.0, 0.0, 1.0)
            avg_radial_v = 0.5
            if users_in_cov:
                comps = []
                for u in users_in_cov:
                    vec = bs.location - u.location
                    dist = np.linalg.norm(vec)
                    if dist > 1e-6:
                        comps.append(np.dot(u.velocity, vec / dist))
                if comps:
                    avg_radial_v = float(np.clip((float(np.mean(comps)) / max_speed + 1) / 2.0, 0.0, 1.0))
            sp_var = np.clip(np.var([u.speed for u in users_in_cov]) / ((max_speed**2) / 4.0) if len(users_in_cov) > 1 else 0.0, 0.0, 1.0)

            f = self.bs_carrier_frequency[bs.id]
            co_bs = [o for o in self.base_stations if o is not bs and self.bs_carrier_frequency[o.id] == f]
            sampled_users = users_in_cov[:min(len(users_in_cov), 8)]
            I_b = 0.0
            g_rx = 10.0 ** (UE_INTERF_RX_DB / 10.0)
            for b2 in co_bs:
                if not b2.assigned_channels:
                    continue
                p_i = self._per_channel_tx_power_mW(b2)
                gi = BEAM_GAIN_DB[b2.type_bs]
                g_tx_i = 10.0 ** (gi["tx_side"] / 10.0)
                users_in_cov_b2 = [uu for uu in self.users if np.linalg.norm(uu.location - b2.location) <= b2.coverage_area]
                util = min(1.0, len(users_in_cov_b2) / max(1, len(b2.assigned_channels)))
                if sampled_users:
                    acc = sum(p_i * g_tx_i * g_rx / (10.0 ** (b2.calculate_path_loss(np.linalg.norm(uu.location - b2.location), f) / 10.0)) for uu in sampled_users)
                    I_b += util * (acc / len(sampled_users))
            I_dBm = 10.0 * np.log10(max(I_b, 1e-12))
            inter_norm = np.clip((I_dBm + 120.0) / 120.0, 0.0, 1.0)
            avg_demand_norm = float(np.clip(np.mean([u.demand for u in users_in_cov]) / self.max_user_demand_Mbps, 0.0, 1.0)) if users_in_cov else 0.0
            neigh = [o.transmit_power / max(1.0, self.ma_transmission_power) for o in self.base_stations if o is not bs and np.linalg.norm(bs.location - o.location) < 1000.0]
            neighbor_tx_norm = float(np.mean(neigh)) if neigh else 0.0
            mec_queue_norm = float(np.clip(bs.mec_queue_cycles / max(1.0, bs.mec_cpu_capacity * self.step_duration_s * 10.0), 0.0, 1.0))
            cpu_util_norm = float(np.clip(bs.last_cpu_used / max(1.0, bs.mec_cpu_capacity), 0.0, 1.0))
            offload_norm = float(np.clip(bs.offload_frac, 0.0, 1.0))
            assoc_users = [u for u in users_in_cov if any(ch.base_station == bs for ch in u.channel)]
            if assoc_users:
                local_served = sum(min(u.data_rate, u.demand) for u in assoc_users)
                max_served = len(assoc_users) * self.max_user_demand_Mbps
                served_ratio_norm = float(np.clip(local_served / max(1e-9, max_served), 0.0, 1.0))
            else:
                served_ratio_norm = 0.0
            if users_in_cov:
                blocked_local = len([u for u in users_in_cov if not any(ch.base_station == bs for ch in u.channel)])
                block_frac_norm = float(np.clip(blocked_local / max(1, len(users_in_cov)), 0.0, 1.0))
            else:
                block_frac_norm = 0.0
            ch_num = len(bs.assigned_channels)
            usr_num = len(users_in_cov)
            ch_match_norm = float(1.0 - min(1.0, abs(ch_num - usr_num) / (ch_num + usr_num))) if ch_num + usr_num > 0 else 1.0
            offload_mand_frac = float(np.mean([1.0 if u.task_offload_mandatory else 0.0 for u in users_in_cov])) if users_in_cov else 0.0

            vec_obs = np.array([
                bs_type, tx_norm, ch_util, cov_util, load_ratio_norm, nearby_pot,
                avg_speed, req_p_norm, avg_radial_v, sp_var, neighbor_tx_norm,
                avg_demand_norm, inter_norm, mec_queue_norm, cpu_util_norm, offload_norm,
                served_ratio_norm, block_frac_norm, ch_match_norm, offload_mand_frac,
            ], dtype=np.float32)
            obs[agent] = vec_obs
        return obs

    def get_global_state(self):
        per_bs = []
        for bs in self.base_stations:
            users_in_cov = [u for u in self.users if np.linalg.norm(u.location - bs.location) <= bs.coverage_area]
            assoc_users = [u for u in users_in_cov if any(ch.base_station == bs for ch in u.channel)]
            mean_rate = float(np.mean([u.data_rate for u in assoc_users])) if assoc_users else 0.0
            served_frac = float(sum(min(u.data_rate, u.demand) for u in assoc_users) / max(1e-9, sum(u.demand for u in assoc_users))) if assoc_users else 0.0
            per_bs.extend([bs.transmit_power, len(bs.assigned_channels), mean_rate, served_frac, bs.mec_queue_cycles, bs.last_cpu_used])
        return np.array(per_bs, dtype=np.float32)

    def calculate_SINR(self, user: User):
        user.channel_SINR = []
        user.SINR = -100.0
        for ch in user.channel:
            bs = ch.base_station
            if bs is None:
                user.channel_SINR.append(-100.0)
                continue
            d = np.linalg.norm(user.location - bs.location)
            PL_dB = bs.calculate_path_loss(d, ch.frequency)
            p_tx_ch = bs.per_channel_power.get(ch.id, None)
            if p_tx_ch is None:
                p_tx_ch = bs.transmit_power / max(1, len(bs.assigned_channels))
            g = BEAM_GAIN_DB[bs.type_bs]
            g_tx_main = 10.0 ** (g["tx_main"] / 10.0)
            g_rx_sig = 10.0 ** (g["rx"] / 10.0)
            signal_mW = p_tx_ch * g_tx_main * g_rx_sig / (10.0 ** (PL_dB / 10.0))
            interference_mW = self._estimate_interference_mW(user, ch.frequency, bs)
            noise_mW = ch.calculate_noise_power() * 1e3
            denom = max(interference_mW + noise_mW, 1e-15)
            SINR_lin = signal_mW / denom if signal_mW > 0 else 0.0
            SINR_dB = 10.0 * np.log10(SINR_lin) if SINR_lin > 0 else -100.0
            SINR_dB = float(np.clip(SINR_dB, -100.0, 60.0))
            user.channel_SINR.append(SINR_dB)
        if user.channel_SINR:
            s_ma = np.mean([10.0 ** (x / 10.0) for x in user.channel_SINR])
            user.SINR = 10.0 * np.log10(s_ma) if s_ma > 0 else -100.0
        else:
            user.SINR = -100.0

    def calculate_required_power_for_distance(self, distance_m, base_station: BaseStation):
        f = self.bs_carrier_frequency[base_station.id]
        pl_dB = base_station.calculate_path_loss(distance_m, f)
        if base_station.assigned_channels:
            bw_hz = base_station.assigned_channels[0].bandwidth
            nf_db = base_station.assigned_channels[0].noise_figure_db
        else:
            bw_hz = self.macro_channel_bw
            nf_db = 7.0
        sens_dBm = rx_sensitivity_dBm(bw_hz, nf_db=nf_db, snr_req_db=-5.0)
        g = BEAM_GAIN_DB[base_station.type_bs]
        req_tx_dBm = sens_dBm + pl_dB - (g["tx_main"] + g["rx"])
        return 10.0 ** (req_tx_dBm / 10.0)

    def update_user_location(self):
        if self.mobility_model == "manhattan":
            if not hasattr(self, "grid_xs"):
                self._build_road_grid()
            for u in self.users:
                self._advance_user_manhattan(u)
                u.location = np.clip(u.location, 0.0, self.area_size)
        else:
            L = self.area_size
            for u in self.users:
                if u.pause_time > 0:
                    u.pause_time -= 1
                    continue
                if u.waypoint is None:
                    u.waypoint = self.np_random.uniform(0, L, 2)
                delta = u.waypoint - u.location
                dist = np.linalg.norm(delta)
                if dist <= u.speed:
                    u.location = u.waypoint
                    u.pause_time = int(self.np_random.integers(0, 10))
                    u.waypoint = self.np_random.uniform(0, L, 2)
                else:
                    direction = delta / dist if dist > 0 else np.zeros(2)
                    u.velocity = direction * u.speed
                    u.location = np.clip(u.location + u.velocity, 0.0, L)

    def render(self, mode="human"):
        if mode != "human":
            return
        if self.fig is None:
            self.fig, self._panel_axes = plt.subplots(1, 1, figsize=(8, 8))
        ax = self._panel_axes
        ax.clear()
        L = self.area_size
        ax.set_xlim(0, L)
        ax.set_ylim(0, L)
        ax.set_aspect("equal")
        for bs in self.base_stations:
            circle = plt.Circle((bs.location[0], bs.location[1]), bs.coverage_area, color="C0", alpha=0.12)
            ax.add_patch(circle)
            ax.scatter(bs.location[0], bs.location[1], marker="^", c="C0", s=80)
            ax.text(bs.location[0] + 5, bs.location[1] + 5, f"BS{bs.id}", fontsize=8)
        for u in self.users:
            ax.plot(u.location[0], u.location[1], "ro", ms=4)
            for ch in u.channel:
                bs = ch.base_station
                if bs is None:
                    continue
                ax.plot([u.location[0], bs.location[0]], [u.location[1], bs.location[1]], "k-", lw=0.6, alpha=0.6)
        plt.pause(0.001)

    def close(self):
        try:
            if self.fig is not None:
                plt.close(self.fig)
        except Exception:
            pass
        self.fig = None


# ==========================
# RLlib Callbacks: Episode-wise CSV logging (SAC version)
# ==========================
class EpisodeCSVLogger(DefaultCallbacks):
    """Episode-wise CSV logger — writes to 'sac_episode_metrics.csv'."""

    def __init__(self):
        super().__init__()
        base_dir = os.environ.get("SAC_CSV_BASE_DIR", os.getcwd())
        self.csv_path = os.path.join(base_dir, "sac_episode_metrics.csv")
        self.header_written = False
        self.fieldnames = None
        if os.path.exists(self.csv_path):
            try:
                with open(self.csv_path, "r", newline="") as f:
                    reader = csv.reader(f)
                    header = next(reader, None)
                    if header:
                        self.fieldnames = header
                        self.header_written = True
            except Exception:
                self.fieldnames = None
                self.header_written = os.path.getsize(self.csv_path) > 0

    def on_episode_step(self, *, worker, base_env, policies, episode, env_index, **kwargs):
        info = None
        if hasattr(episode, "get_agents") and hasattr(episode, "last_info_for"):
            agent_ids = list(episode.get_agents())
            if not agent_ids:
                return
            info = episode.last_info_for(agent_ids[0])
        elif hasattr(episode, "last_info_for") and hasattr(episode, "agent_ids"):
            agent_ids = list(episode.agent_ids)
            if not agent_ids:
                return
            info = episode.last_info_for(agent_ids[0])
        if not info:
            return
        for k, v in info.items():
            if isinstance(v, (int, float)):
                episode.user_data.setdefault(k, []).append(float(v))

    def on_episode_end(self, *, worker, base_env, policies, episode, env_index, **kwargs):
        row = {"episode_id": episode.episode_id, "episode_len": episode.length}
        for k, values in episode.user_data.items():
            if not values:
                continue
            mean_val = float(np.mean(values))
            row[k] = mean_val
            episode.custom_metrics[k] = mean_val
        ep_return = None
        if "global_reward" in episode.user_data and episode.user_data["global_reward"]:
            ep_return = float(np.sum(episode.user_data["global_reward"]))
        if ep_return is None and hasattr(episode, "total_reward"):
            try:
                ep_return = float(episode.total_reward)
            except Exception:
                ep_return = None
        if ep_return is not None:
            row["episode_return"] = ep_return
            episode.custom_metrics["episode_return"] = ep_return
            print(f"[Episode {episode.episode_id}] total_reward={ep_return:.3f}")
        if self.fieldnames is None:
            self.fieldnames = list(row.keys())
        for h in self.fieldnames:
            row.setdefault(h, "")
        with open(self.csv_path, "a", newline="") as f:
            writer = csv.DictWriter(f, fieldnames=self.fieldnames, extrasaction="ignore")
            if not self.header_written or os.path.getsize(self.csv_path) == 0:
                writer.writeheader()
                self.header_written = True
            writer.writerow(row)


# ==========================
# RLlib SAC SECTION (Multi-agent, shared policy)
# ==========================
def rllib_env_creator(env_config: dict):
    """RLlib env creator."""
    return MultiAgentMobileNetwork(
        num_base_stations=env_config.get("num_base_stations", 4),
        num_users=env_config.get("num_users", 100),
        num_channels_per_carrier=env_config.get("num_channels_per_carrier", 100),
        area_size=env_config.get("area_size", 5000.0),
        bs_loc=env_config.get("bs_loc", [(1250, 1400), (3750, 1400), (1250, 3550), (3750, 3550)]),
        max_steps=env_config.get("max_steps", 200),
        mobility_model=env_config.get("mobility_model", "manhattan"),
        seed=env_config.get("seed", 42),
        step_duration_s=env_config.get("step_duration_s", 1.0),
        deadline_ms=env_config.get("deadline_ms", 100.0),
        safety_traffic_ratio=env_config.get("safety_traffic_ratio", 0.3),
    )


# ==========================
# Main: config + training
# ==========================
if __name__ == "__main__":
    # --------------------------
    # Ensure CSV base dir is the current working directory
    # --------------------------
    base_dir = os.getcwd()
    os.environ["SAC_CSV_BASE_DIR"] = base_dir

    # --------------------------
    # Ray / RLlib initialization
    # --------------------------
    os.environ.setdefault("RAY_DEDUP_LOGS", "1")
    os.environ["CUDA_VISIBLE_DEVICES"] = ""   # force CPU (RTX 5090 sm_120 not supported)

    if not ray.is_initialized():
        ray.init(ignore_reinit_error=True)

    ENV_ID = "multi_agent_mobile_network"
    register_env(ENV_ID, rllib_env_creator)

    bs_locs = [(1250, 1400), (3750, 1400), (1250, 3550), (3750, 3550)]

    base_env_config = dict(
        num_base_stations=4,
        num_users=100,
        num_channels_per_carrier=100,
        area_size=5000.0,
        bs_loc=bs_locs,
        max_steps=200,
        mobility_model="manhattan",
        seed=42,
        step_duration_s=1.0,
        deadline_ms=100.0,
        safety_traffic_ratio=0.3,
    )

    # --------------------------
    # SACConfig for multi-agent
    # --------------------------
    config = SACConfig()

    # IMPORTANT FIX:
    # Use the old API stack explicitly via api_stack() instead of mutating
    # internal flags directly. This keeps the legacy multi-agent/callback path
    # and avoids the exploration-init crash seen during policy dummy-batch setup.
    config.api_stack(
        enable_rl_module_and_learner=False,
        enable_env_runner_and_connector_v2=False,
    )

    # Environment
    config.environment(
        env=ENV_ID,
        env_config=base_env_config,
    )

    # Framework
    config.framework("torch")

    # Env runners (local only)
    config.env_runners(
        num_env_runners=0,
        rollout_fragment_length="auto",
        batch_mode="complete_episodes",
    )

    # Make SAC exploration explicit on the old stack.
    config.exploration_config = {"type": "StochasticSampling"}

    # Training: SAC-specific hyperparameters
    # IMPORTANT FIXES:
    # - Do NOT set generic `lr` for SAC.
    # - Use actor_lr / critic_lr / alpha_lr.
    # - Use num_steps_sampled_before_learning_starts instead of putting
    #   learning_starts inside replay_buffer_config.
    config.training(
        gamma=0.99,
        tau=0.005,
        train_batch_size=256,
        target_network_update_freq=1,
        n_step=1,
        actor_lr=3e-4,
        critic_lr=3e-4,
        alpha_lr=3e-4,
        num_steps_sampled_before_learning_starts=1000,
    )

    # Replay buffer (SAC is off-policy).
    # For old-stack multi-agent SAC, use the prioritized multi-agent replay buffer.
    config.replay_buffer_config = {
        "type": "MultiAgentPrioritizedReplayBuffer",
        "capacity": 100_000,
        "prioritized_replay_alpha": 0.6,
        "prioritized_replay_beta": 0.4,
        "prioritized_replay_eps": 1e-6,
    }

    # Resources
    config.resources(num_gpus=0)

    # IMPORTANT FIX:
    # Leave action normalization off here. The environment already clips actions
    # into [0, 1], and keeping this off avoids extra action-transform surprises.
    config.normalize_actions = False

    # Multi-agent shared policy (identical to PPO version)
    config.multi_agent(
        policies={
            "shared_policy": PolicySpec()
        },
        policy_mapping_fn=lambda agent_id, *args, **kwargs: "shared_policy",
        policies_to_train=["shared_policy"],
    )

    # Callbacks: episode-wise CSV logging
    config.callbacks(EpisodeCSVLogger)

    # --------------------------
    # Build SAC algorithm
    # --------------------------
    if hasattr(config, "build_algo"):
        algo = config.build_algo()
    else:
        algo = config.build()

    # --------------------------
    # Helpers for robust metric extraction
    # --------------------------
    def get_total_env_steps(result_dict):
        for k in ["num_env_steps_sampled", "num_env_steps_sampled_lifetime", "timesteps_total"]:
            v = result_dict.get(k, None)
            if v is not None:
                return int(v)
        return 0

    def get_mean_return_and_len(result_dict):
        mean_ret = result_dict.get("episode_return_mean", None)
        if mean_ret is None:
            mean_ret = result_dict.get("episode_reward_mean", None)
        mean_len = result_dict.get("episode_len_mean", None)
        env_runners = result_dict.get("env_runners", {})
        if isinstance(env_runners, dict):
            if mean_ret is None or (isinstance(mean_ret, float) and math.isnan(mean_ret)):
                mean_ret = env_runners.get("episode_return_mean", env_runners.get("episode_reward_mean", mean_ret))
            if mean_len is None or (isinstance(mean_len, float) and math.isnan(mean_len)):
                mean_len = env_runners.get("episode_len_mean", mean_len)
        if mean_ret is None:
            mean_ret = float("nan")
        if mean_len is None:
            mean_len = float("nan")
        return float(mean_ret), float(mean_len)

    # --------------------------
    # Simple training loop
    # --------------------------
    total_target_env_steps = 500_000
    log_every_iter = 1
    save_every_iter = 10

    total_env_steps = 0
    iter_idx = 0

    while total_env_steps < total_target_env_steps:
        result = algo.train()
        iter_idx += 1

        total_env_steps = get_total_env_steps(result)
        mean_reward, mean_len = get_mean_return_and_len(result)

        if iter_idx % log_every_iter == 0:
            print(
                f"[Iter {iter_idx:04d}] "
                f"env_steps={total_env_steps} | "
                f"episode_return_mean={mean_reward:.3f} | "
                f"episode_len_mean={mean_len:.1f}"
            )

        if iter_idx % save_every_iter == 0:
            chkpt = algo.save()
            if hasattr(chkpt, "path"):
                chkpt_path = chkpt.path
            elif isinstance(chkpt, dict) and "checkpoint" in chkpt:
                chkpt_path = chkpt["checkpoint"]
            else:
                chkpt_path = str(chkpt)

    print("\n✅ SAC Training finished.")
    ray.shutdown()
# Out:
# /home/umb/miniconda3/envs/wr/lib/python3.11/site-packages/ray/rllib/algorithms/algorithm.py:525: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# `UnifiedLogger` will be removed in Ray 2.7.
#   return UnifiedLogger(config, logdir, loggers=None)
# /home/umb/miniconda3/envs/wr/lib/python3.11/site-packages/ray/tune/logger/unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `JsonLogger interface is deprecated in favor of the `ray.tune.json.JsonLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# /home/umb/miniconda3/envs/wr/lib/python3.11/site-packages/ray/tune/logger/unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `CSVLogger interface is deprecated in favor of the `ray.tune.csv.CSVLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# /home/umb/miniconda3/envs/wr/lib/python3.11/site-packages/ray/tune/logger/unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `TBXLogger interface is deprecated in favor of the `ray.tune.tensorboardx.TBXLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# 2026-04-11 15:20:06,332	WARNING multi_agent_prioritized_replay_buffer.py:216 -- Adding batches with column `weights` to this buffer while providing weights as a call argument to the add method results in the column being overwritten.
# [Episode 128355989445507485] total_reward=-48.713
# [Iter 0001] env_steps=200 | episode_return_mean=-194.853 | episode_len_mean=200.0
# [Episode 854949519964969681] total_reward=-50.288
# [Iter 0002] env_steps=400 | episode_return_mean=-198.002 | episode_len_mean=200.0
# [Episode 282341088111907415] total_reward=-47.570
# [Iter 0003] env_steps=600 | episode_return_mean=-195.428 | episode_len_mean=200.0
# [Episode 160876273137374942] total_reward=-47.559
# [Iter 0004] env_steps=800 | episode_return_mean=-194.130 | episode_len_mean=200.0
# [Episode 118168890076913833] total_reward=-48.706
# [Iter 0005] env_steps=1000 | episode_return_mean=-194.269 | episode_len_mean=200.0
# 2026-04-11 15:20:15,570	WARNING train_ops.py:114 -- DeprecationWarning: `ray.rllib.execution.train_ops.multi_gpu_train_one_step` has been deprecated. This will raise an error in the future!
# [Episode 853931770133622125] total_reward=-49.117
# [Iter 0006] env_steps=1200 | episode_return_mean=-194.636 | episode_len_mean=200.0
# [Episode 628764812031418704] total_reward=-48.397
# [Iter 0007] env_steps=1400 | episode_return_mean=-194.486 | episode_len_mean=200.0
# [Episode 505192410723260600] total_reward=-48.904
# [Iter 0008] env_steps=1600 | episode_return_mean=-194.627 | episode_len_mean=200.0
# [Episode 258510552586190915] total_reward=-48.510
# [Iter 0009] env_steps=1800 | episode_return_mean=-194.562 | episode_len_mean=200.0
# [Episode 746758426592428771] total_reward=-50.024
# [Iter 0010] env_steps=2000 | episode_return_mean=-195.115 | episode_len_mean=200.0
# [Episode 678901195123267047] total_reward=-46.516
# [Iter 0011] env_steps=2200 | episode_return_mean=-194.292 | episode_len_mean=200.0
# [Episode 763389865307903277] total_reward=-47.596
# [Iter 0012] env_steps=2400 | episode_return_mean=-193.967 | episode_len_mean=200.0
# [Episode 416772110710452131] total_reward=-47.830
# [Iter 0013] env_steps=2600 | episode_return_mean=-193.763 | episode_len_mean=200.0
# [Episode 182093668014455322] total_reward=-47.188
# [Iter 0014] env_steps=2800 | episode_return_mean=-193.405 | episode_len_mean=200.0
# [Episode 537266115551531148] total_reward=-48.976
# [Iter 0015] env_steps=3000 | episode_return_mean=-193.572 | episode_len_mean=200.0
# [Episode 743670348826656606] total_reward=-48.129
# [Iter 0016] env_steps=3200 | episode_return_mean=-193.506 | episode_len_mean=200.0
# [Episode 937749371590640011] total_reward=-48.845
# [Iter 0017] env_steps=3400 | episode_return_mean=-193.616 | episode_len_mean=200.0
# [Episode 744772187978333094] total_reward=-48.568
# [Iter 0018] env_steps=3600 | episode_return_mean=-193.653 | episode_len_mean=200.0
# [Episode 787590044465490403] total_reward=-47.734
# [Iter 0019] env_steps=3800 | episode_return_mean=-193.510 | episode_len_mean=200.0
# [Episode 864824389948399009] total_reward=-47.136
# [Iter 0020] env_steps=4000 | episode_return_mean=-193.261 | episode_len_mean=200.0
# [Episode 625450087748675849] total_reward=-47.218
# [Iter 0021] env_steps=4200 | episode_return_mean=-193.052 | episode_len_mean=200.0
# [Episode 979507436992132202] total_reward=-47.187
# [Iter 0022] env_steps=4400 | episode_return_mean=-192.857 | episode_len_mean=200.0
# [Episode 644057361836755353] total_reward=-48.871
# [Iter 0023] env_steps=4600 | episode_return_mean=-192.971 | episode_len_mean=200.0
# [Episode 309930693298623847] total_reward=-47.586
# [Iter 0024] env_steps=4800 | episode_return_mean=-192.862 | episode_len_mean=200.0
# [Episode 888199270613275710] total_reward=-47.526
# [Iter 0025] env_steps=5000 | episode_return_mean=-192.751 | episode_len_mean=200.0
# [Episode 523058272174537858] total_reward=-47.485
# [Iter 0026] env_steps=5200 | episode_return_mean=-192.643 | episode_len_mean=200.0
# [Episode 933059168078538570] total_reward=-47.591
# [Iter 0027] env_steps=5400 | episode_return_mean=-192.559 | episode_len_mean=200.0
# [Episode 925007790586453473] total_reward=-47.440
# [Iter 0028] env_steps=5600 | episode_return_mean=-192.459 | episode_len_mean=200.0
# [Episode 273378856404695869] total_reward=-46.286
# [Iter 0029] env_steps=5800 | episode_return_mean=-192.207 | episode_len_mean=200.0
# [Episode 445157543453397453] total_reward=-46.099
# [Iter 0030] env_steps=6000 | episode_return_mean=-191.946 | episode_len_mean=200.0
# [Episode 30839362746348289] total_reward=-47.833
# [Iter 0031] env_steps=6200 | episode_return_mean=-191.926 | episode_len_mean=200.0
# [Episode 898652366113150700] total_reward=-46.334
# [Iter 0032] env_steps=6400 | episode_return_mean=-191.721 | episode_len_mean=200.0
# [Episode 346329848220007685] total_reward=-48.432
# [Iter 0033] env_steps=6600 | episode_return_mean=-191.781 | episode_len_mean=200.0
# [Episode 893975720455155607] total_reward=-46.788
# [Iter 0034] env_steps=6800 | episode_return_mean=-191.645 | episode_len_mean=200.0
# [Episode 370823662332760965] total_reward=-47.436
# [Iter 0035] env_steps=7000 | episode_return_mean=-191.591 | episode_len_mean=200.0
# [Episode 136613499693208787] total_reward=-47.716
# [Iter 0036] env_steps=7200 | episode_return_mean=-191.571 | episode_len_mean=200.0
# [Episode 542781294407830816] total_reward=-48.047
# [Iter 0037] env_steps=7400 | episode_return_mean=-191.587 | episode_len_mean=200.0
# [Episode 7402106874997266] total_reward=-49.346
# [Iter 0038] env_steps=7600 | episode_return_mean=-191.740 | episode_len_mean=200.0
# [Episode 171287616371558130] total_reward=-48.670
# [Iter 0039] env_steps=7800 | episode_return_mean=-191.815 | episode_len_mean=200.0
# [Episode 343974878356699292] total_reward=-48.007
# [Iter 0040] env_steps=8000 | episode_return_mean=-191.821 | episode_len_mean=200.0
# [Episode 325174884454286766] total_reward=-47.364
# [Iter 0041] env_steps=8200 | episode_return_mean=-191.763 | episode_len_mean=200.0
# [Episode 266982119462218771] total_reward=-48.913
# [Iter 0042] env_steps=8400 | episode_return_mean=-191.856 | episode_len_mean=200.0
# [Episode 494721441173747438] total_reward=-49.145
# [Iter 0043] env_steps=8600 | episode_return_mean=-191.965 | episode_len_mean=200.0
# [Episode 86635589548959625] total_reward=-49.071
# [Iter 0044] env_steps=8800 | episode_return_mean=-192.064 | episode_len_mean=200.0
# [Episode 879673936356774794] total_reward=-48.889
# [Iter 0045] env_steps=9000 | episode_return_mean=-192.141 | episode_len_mean=200.0
# [Episode 133258357451844692] total_reward=-48.231
# [Iter 0046] env_steps=9200 | episode_return_mean=-192.158 | episode_len_mean=200.0
# [Episode 470971648579572500] total_reward=-49.126
# [Iter 0047] env_steps=9400 | episode_return_mean=-192.251 | episode_len_mean=200.0
# [Episode 462034373856733785] total_reward=-48.372
# [Iter 0048] env_steps=9600 | episode_return_mean=-192.276 | episode_len_mean=200.0
# [Episode 362290082347257832] total_reward=-49.265
# [Iter 0049] env_steps=9800 | episode_return_mean=-192.374 | episode_len_mean=200.0
# [Episode 535835455722969713] total_reward=-47.539
# [Iter 0050] env_steps=10000 | episode_return_mean=-192.330 | episode_len_mean=200.0
# [Episode 867576283437464665] total_reward=-48.000
# [Iter 0051] env_steps=10200 | episode_return_mean=-192.323 | episode_len_mean=200.0
# [Episode 370395785669627148] total_reward=-47.058
# [Iter 0052] env_steps=10400 | episode_return_mean=-192.245 | episode_len_mean=200.0
# [Episode 890064384288837272] total_reward=-49.309
# [Iter 0053] env_steps=10600 | episode_return_mean=-192.339 | episode_len_mean=200.0
# [Episode 283507540093834952] total_reward=-47.050
# [Iter 0054] env_steps=10800 | episode_return_mean=-192.262 | episode_len_mean=200.0
# [Episode 134120535850996973] total_reward=-47.169
# [Iter 0055] env_steps=11000 | episode_return_mean=-192.197 | episode_len_mean=200.0
# [Episode 417800570798426217] total_reward=-48.004
# [Iter 0056] env_steps=11200 | episode_return_mean=-192.194 | episode_len_mean=200.0
# [Episode 901117825511563669] total_reward=-49.442
# [Iter 0057] env_steps=11400 | episode_return_mean=-192.292 | episode_len_mean=200.0
# [Episode 323766784703998602] total_reward=-46.374
# [Iter 0058] env_steps=11600 | episode_return_mean=-192.174 | episode_len_mean=200.0
# [Episode 637603113826165156] total_reward=-46.900
# [Iter 0059] env_steps=11800 | episode_return_mean=-192.097 | episode_len_mean=200.0
# [Episode 171819133535414931] total_reward=-46.971
# [Iter 0060] env_steps=12000 | episode_return_mean=-192.027 | episode_len_mean=200.0
# [Episode 94897259808041793] total_reward=-47.032
# [Iter 0061] env_steps=12200 | episode_return_mean=-191.963 | episode_len_mean=200.0
# [Episode 930724747837408761] total_reward=-49.701
# [Iter 0062] env_steps=12400 | episode_return_mean=-192.073 | episode_len_mean=200.0
# [Episode 489817177732424329] total_reward=-48.567
# [Iter 0063] env_steps=12600 | episode_return_mean=-192.108 | episode_len_mean=200.0
# [Episode 708134540490866338] total_reward=-47.623
# [Iter 0064] env_steps=12800 | episode_return_mean=-192.083 | episode_len_mean=200.0
# [Episode 769121761863314182] total_reward=-48.205
# [Iter 0065] env_steps=13000 | episode_return_mean=-192.094 | episode_len_mean=200.0
# [Episode 542331998987543713] total_reward=-46.803
# [Iter 0066] env_steps=13200 | episode_return_mean=-192.020 | episode_len_mean=200.0
# [Episode 249718031934220908] total_reward=-47.102
# [Iter 0067] env_steps=13400 | episode_return_mean=-191.966 | episode_len_mean=200.0
# [Episode 837147042724959184] total_reward=-48.423
# [Iter 0068] env_steps=13600 | episode_return_mean=-191.991 | episode_len_mean=200.0
# [Episode 810973935658620167] total_reward=-48.592
# [Iter 0069] env_steps=13800 | episode_return_mean=-192.026 | episode_len_mean=200.0
# [Episode 130218103398660422] total_reward=-45.893
# [Iter 0070] env_steps=14000 | episode_return_mean=-191.905 | episode_len_mean=200.0
# [Episode 223146911115799095] total_reward=-48.339
# [Iter 0071] env_steps=14200 | episode_return_mean=-191.925 | episode_len_mean=200.0
# [Episode 497615852082344485] total_reward=-49.019
# [Iter 0072] env_steps=14400 | episode_return_mean=-191.983 | episode_len_mean=200.0
# [Episode 768838853311815263] total_reward=-48.010
# [Iter 0073] env_steps=14600 | episode_return_mean=-191.984 | episode_len_mean=200.0
# [Episode 754971839274214303] total_reward=-47.429
# [Iter 0074] env_steps=14800 | episode_return_mean=-191.953 | episode_len_mean=200.0
# [Episode 410748878760668193] total_reward=-47.577
# [Iter 0075] env_steps=15000 | episode_return_mean=-191.931 | episode_len_mean=200.0
# [Episode 84499467074999079] total_reward=-46.147
# [Iter 0076] env_steps=15200 | episode_return_mean=-191.835 | episode_len_mean=200.0
# [Episode 671653676247800855] total_reward=-47.375
# [Iter 0077] env_steps=15400 | episode_return_mean=-191.804 | episode_len_mean=200.0
# [Episode 880769259775535801] total_reward=-46.331
# [Iter 0078] env_steps=15600 | episode_return_mean=-191.721 | episode_len_mean=200.0
# [Episode 527212933267381274] total_reward=-48.619
# [Iter 0079] env_steps=15800 | episode_return_mean=-191.756 | episode_len_mean=200.0
# [Episode 140918290078325669] total_reward=-46.955
# [Iter 0080] env_steps=16000 | episode_return_mean=-191.707 | episode_len_mean=200.0
# [Episode 1409357212235187] total_reward=-46.341
# [Iter 0081] env_steps=16200 | episode_return_mean=-191.629 | episode_len_mean=200.0
# [Episode 122556286655244383] total_reward=-45.422
# [Iter 0082] env_steps=16400 | episode_return_mean=-191.507 | episode_len_mean=200.0
# [Episode 252216594285052855] total_reward=-47.726
# [Iter 0083] env_steps=16600 | episode_return_mean=-191.500 | episode_len_mean=200.0
# [Episode 803564910651603675] total_reward=-47.159
# [Iter 0084] env_steps=16800 | episode_return_mean=-191.466 | episode_len_mean=200.0
# [Episode 535593277128770255] total_reward=-48.582
# [Iter 0085] env_steps=17000 | episode_return_mean=-191.500 | episode_len_mean=200.0
# [Episode 334158293962260841] total_reward=-47.232
# [Iter 0086] env_steps=17200 | episode_return_mean=-191.470 | episode_len_mean=200.0
# [Episode 523912929944249452] total_reward=-48.338
# [Iter 0087] env_steps=17400 | episode_return_mean=-191.491 | episode_len_mean=200.0
# [Episode 635628334226700351] total_reward=-47.636
# [Iter 0088] env_steps=17600 | episode_return_mean=-191.481 | episode_len_mean=200.0
# [Episode 757942069787688175] total_reward=-47.316
# [Iter 0089] env_steps=17800 | episode_return_mean=-191.456 | episode_len_mean=200.0
# [Episode 738269804894025662] total_reward=-47.441
# [Iter 0090] env_steps=18000 | episode_return_mean=-191.437 | episode_len_mean=200.0
# [Episode 710104931786097655] total_reward=-46.211
# [Iter 0091] env_steps=18200 | episode_return_mean=-191.365 | episode_len_mean=200.0
# [Episode 920295406699406453] total_reward=-47.974
# [Iter 0092] env_steps=18400 | episode_return_mean=-191.370 | episode_len_mean=200.0
# [Episode 94921271115656391] total_reward=-46.783
# [Iter 0093] env_steps=18600 | episode_return_mean=-191.325 | episode_len_mean=200.0
# [Episode 852193687005500013] total_reward=-47.330
# [Iter 0094] env_steps=18800 | episode_return_mean=-191.303 | episode_len_mean=200.0
# [Episode 862373435394844385] total_reward=-46.920
# [Iter 0095] env_steps=19000 | episode_return_mean=-191.265 | episode_len_mean=200.0
# [Episode 769730046281346200] total_reward=-45.617
# [Iter 0096] env_steps=19200 | episode_return_mean=-191.174 | episode_len_mean=200.0
# [Episode 282282700056287567] total_reward=-45.261
# [Iter 0097] env_steps=19400 | episode_return_mean=-191.069 | episode_len_mean=200.0
# [Episode 607722537659864783] total_reward=-48.774
# [Iter 0098] env_steps=19600 | episode_return_mean=-191.110 | episode_len_mean=200.0
# [Episode 369244146239952809] total_reward=-47.149
# [Iter 0099] env_steps=19800 | episode_return_mean=-191.085 | episode_len_mean=200.0
# [Episode 763994982554362761] total_reward=-48.657
# [Iter 0100] env_steps=20000 | episode_return_mean=-191.120 | episode_len_mean=200.0
# [Episode 391684357045022234] total_reward=-48.332
# [Iter 0101] env_steps=20200 | episode_return_mean=-191.105 | episode_len_mean=200.0
# [Episode 751709000386855719] total_reward=-46.457
# [Iter 0102] env_steps=20400 | episode_return_mean=-190.952 | episode_len_mean=200.0
# [Episode 308023503654953566] total_reward=-47.371
# [Iter 0103] env_steps=20600 | episode_return_mean=-190.944 | episode_len_mean=200.0
# [Episode 476705874851269276] total_reward=-47.574
# [Iter 0104] env_steps=20800 | episode_return_mean=-190.944 | episode_len_mean=200.0
# [Episode 199903768555472531] total_reward=-48.760
# [Iter 0105] env_steps=21000 | episode_return_mean=-190.947 | episode_len_mean=200.0
# [Episode 559119041975992592] total_reward=-46.893
# [Iter 0106] env_steps=21200 | episode_return_mean=-190.858 | episode_len_mean=200.0
# [Episode 362102463585188523] total_reward=-44.624
# [Iter 0107] env_steps=21400 | episode_return_mean=-190.707 | episode_len_mean=200.0
# [Episode 603615054015525788] total_reward=-48.425
# [Iter 0108] env_steps=21600 | episode_return_mean=-190.688 | episode_len_mean=200.0
# [Episode 688379377553788177] total_reward=-49.177
# [Iter 0109] env_steps=21800 | episode_return_mean=-190.714 | episode_len_mean=200.0
# [Episode 732516036183000867] total_reward=-46.535
# [Iter 0110] env_steps=22000 | episode_return_mean=-190.575 | episode_len_mean=200.0
# [Episode 360473418601755654] total_reward=-48.406
# [Iter 0111] env_steps=22200 | episode_return_mean=-190.650 | episode_len_mean=200.0
# [Episode 88555231126171086] total_reward=-47.271
# [Iter 0112] env_steps=22400 | episode_return_mean=-190.637 | episode_len_mean=200.0
# [Episode 826758410576756023] total_reward=-48.573
# [Iter 0113] env_steps=22600 | episode_return_mean=-190.667 | episode_len_mean=200.0
# [Episode 996694525242762783] total_reward=-47.125
# [Iter 0114] env_steps=22800 | episode_return_mean=-190.665 | episode_len_mean=200.0
# [Episode 254019393327324314] total_reward=-49.244
# [Iter 0115] env_steps=23000 | episode_return_mean=-190.675 | episode_len_mean=200.0
# [Episode 666378749475112992] total_reward=-48.830
# [Iter 0116] env_steps=23200 | episode_return_mean=-190.703 | episode_len_mean=200.0
# [Episode 776885147962036750] total_reward=-49.170
# [Iter 0117] env_steps=23400 | episode_return_mean=-190.716 | episode_len_mean=200.0
# [Episode 832841936035413518] total_reward=-47.806
# [Iter 0118] env_steps=23600 | episode_return_mean=-190.686 | episode_len_mean=200.0
# [Episode 131263906254379965] total_reward=-48.625
# [Iter 0119] env_steps=23800 | episode_return_mean=-190.721 | episode_len_mean=200.0
# [Episode 868218595860921147] total_reward=-48.351
# [Iter 0120] env_steps=24000 | episode_return_mean=-190.770 | episode_len_mean=200.0
# [Episode 610594767241986705] total_reward=-45.609
# [Iter 0121] env_steps=24200 | episode_return_mean=-190.706 | episode_len_mean=200.0
# [Episode 509321757720587415] total_reward=-48.155
# [Iter 0122] env_steps=24400 | episode_return_mean=-190.744 | episode_len_mean=200.0
# [Episode 691940328700524266] total_reward=-50.065
# [Iter 0123] env_steps=24600 | episode_return_mean=-190.792 | episode_len_mean=200.0
# [Episode 620558220498420125] total_reward=-47.484
# [Iter 0124] env_steps=24800 | episode_return_mean=-190.788 | episode_len_mean=200.0
# [Episode 136450235599336189] total_reward=-45.890
# [Iter 0125] env_steps=25000 | episode_return_mean=-190.723 | episode_len_mean=200.0
# [Episode 237473532539290919] total_reward=-47.938
# [Iter 0126] env_steps=25200 | episode_return_mean=-190.741 | episode_len_mean=200.0
# [Episode 762523118691717197] total_reward=-48.452
# [Iter 0127] env_steps=25400 | episode_return_mean=-190.775 | episode_len_mean=200.0
# [Episode 931659986529767143] total_reward=-49.577
# [Iter 0128] env_steps=25600 | episode_return_mean=-190.861 | episode_len_mean=200.0
# [Episode 475309007991171528] total_reward=-48.983
# [Iter 0129] env_steps=25800 | episode_return_mean=-190.969 | episode_len_mean=200.0
# [Episode 972031184459866684] total_reward=-48.223
# [Iter 0130] env_steps=26000 | episode_return_mean=-191.054 | episode_len_mean=200.0
# [Episode 215155632768953796] total_reward=-49.497
# [Iter 0131] env_steps=26200 | episode_return_mean=-191.120 | episode_len_mean=200.0
# [Episode 275093442171910542] total_reward=-48.216
# [Iter 0132] env_steps=26400 | episode_return_mean=-191.195 | episode_len_mean=200.0
# [Episode 894435059625048164] total_reward=-47.886
# [Iter 0133] env_steps=26600 | episode_return_mean=-191.174 | episode_len_mean=200.0
# [Episode 994391338531569447] total_reward=-48.957
# [Iter 0134] env_steps=26800 | episode_return_mean=-191.260 | episode_len_mean=200.0
# [Episode 311758284371274465] total_reward=-47.750
# [Iter 0135] env_steps=27000 | episode_return_mean=-191.273 | episode_len_mean=200.0
# [Episode 815705031237911411] total_reward=-47.150
# [Iter 0136] env_steps=27200 | episode_return_mean=-191.250 | episode_len_mean=200.0
# [Episode 514246063323522788] total_reward=-47.894
# [Iter 0137] env_steps=27400 | episode_return_mean=-191.244 | episode_len_mean=200.0
# [Episode 723092726815582833] total_reward=-47.499
# [Iter 0138] env_steps=27600 | episode_return_mean=-191.170 | episode_len_mean=200.0
# [Episode 874355360926382939] total_reward=-47.962
# [Iter 0139] env_steps=27800 | episode_return_mean=-191.142 | episode_len_mean=200.0
# [Episode 487844925113097442] total_reward=-49.917
# [Iter 0140] env_steps=28000 | episode_return_mean=-191.218 | episode_len_mean=200.0
# [Episode 387798027346991556] total_reward=-48.829
# [Iter 0141] env_steps=28200 | episode_return_mean=-191.277 | episode_len_mean=200.0
# [Episode 251338715987325715] total_reward=-49.640
# [Iter 0142] env_steps=28400 | episode_return_mean=-191.306 | episode_len_mean=200.0
# [Episode 649729634633302322] total_reward=-49.669
# [Iter 0143] env_steps=28600 | episode_return_mean=-191.327 | episode_len_mean=200.0
# [Episode 533448759091040283] total_reward=-46.775
# [Iter 0144] env_steps=28800 | episode_return_mean=-191.235 | episode_len_mean=200.0
# [Episode 262835027968418922] total_reward=-49.037
# [Iter 0145] env_steps=29000 | episode_return_mean=-191.241 | episode_len_mean=200.0
# [Episode 802074197744627395] total_reward=-47.950
# [Iter 0146] env_steps=29200 | episode_return_mean=-191.230 | episode_len_mean=200.0
# [Episode 87110446653161275] total_reward=-47.725
# [Iter 0147] env_steps=29400 | episode_return_mean=-191.174 | episode_len_mean=200.0
# [Episode 967231401958429496] total_reward=-49.853
# [Iter 0148] env_steps=29600 | episode_return_mean=-191.233 | episode_len_mean=200.0
# [Episode 103881032884729081] total_reward=-50.535
# [Iter 0149] env_steps=29800 | episode_return_mean=-191.284 | episode_len_mean=200.0
# [Episode 57967448362539818] total_reward=-48.848
# [Iter 0150] env_steps=30000 | episode_return_mean=-191.336 | episode_len_mean=200.0
# [Episode 991919273826820351] total_reward=-46.944
# [Iter 0151] env_steps=30200 | episode_return_mean=-191.294 | episode_len_mean=200.0
# [Episode 196408205033098647] total_reward=-48.082
# [Iter 0152] env_steps=30400 | episode_return_mean=-191.335 | episode_len_mean=200.0
# [Episode 907823837467218423] total_reward=-47.989
# [Iter 0153] env_steps=30600 | episode_return_mean=-191.282 | episode_len_mean=200.0
# [Episode 932654568959649003] total_reward=-49.502
# [Iter 0154] env_steps=30800 | episode_return_mean=-191.380 | episode_len_mean=200.0
# [Episode 13762954178840920] total_reward=-46.305
# [Iter 0155] env_steps=31000 | episode_return_mean=-191.345 | episode_len_mean=200.0
# [Episode 769676041599775671] total_reward=-47.748
# [Iter 0156] env_steps=31200 | episode_return_mean=-191.335 | episode_len_mean=200.0
# [Episode 128777042041736671] total_reward=-47.423
# [Iter 0157] env_steps=31400 | episode_return_mean=-191.254 | episode_len_mean=200.0
# [Episode 723040859960711320] total_reward=-48.919
# [Iter 0158] env_steps=31600 | episode_return_mean=-191.356 | episode_len_mean=200.0
# [Episode 981885642942719813] total_reward=-47.969
# [Iter 0159] env_steps=31800 | episode_return_mean=-191.399 | episode_len_mean=200.0
# [Episode 359224892971083143] total_reward=-48.798
# [Iter 0160] env_steps=32000 | episode_return_mean=-191.472 | episode_len_mean=200.0
# [Episode 909722086337734058] total_reward=-46.954
# [Iter 0161] env_steps=32200 | episode_return_mean=-191.469 | episode_len_mean=200.0
# [Episode 415945538180237394] total_reward=-47.608
# [Iter 0162] env_steps=32400 | episode_return_mean=-191.385 | episode_len_mean=200.0
# [Episode 76248214962005085] total_reward=-45.966
# [Iter 0163] env_steps=32600 | episode_return_mean=-191.281 | episode_len_mean=200.0
# [Episode 103474246815076533] total_reward=-48.633
# [Iter 0164] env_steps=32800 | episode_return_mean=-191.322 | episode_len_mean=200.0
# [Episode 767318144035963740] total_reward=-48.670
# [Iter 0165] env_steps=33000 | episode_return_mean=-191.340 | episode_len_mean=200.0
# [Episode 650730975335525787] total_reward=-48.672
# [Iter 0166] env_steps=33200 | episode_return_mean=-191.415 | episode_len_mean=200.0
# [Episode 586620396642467494] total_reward=-47.330
# [Iter 0167] env_steps=33400 | episode_return_mean=-191.424 | episode_len_mean=200.0
# [Episode 700976962263288013] total_reward=-49.159
# [Iter 0168] env_steps=33600 | episode_return_mean=-191.454 | episode_len_mean=200.0
# [Episode 141614511884957940] total_reward=-48.993
# [Iter 0169] env_steps=33800 | episode_return_mean=-191.470 | episode_len_mean=200.0
# [Episode 553414414139357193] total_reward=-50.799
# [Iter 0170] env_steps=34000 | episode_return_mean=-191.666 | episode_len_mean=200.0
# [Episode 444735217304330739] total_reward=-48.609
# [Iter 0171] env_steps=34200 | episode_return_mean=-191.677 | episode_len_mean=200.0
# [Episode 634264055282778021] total_reward=-47.341
# [Iter 0172] env_steps=34400 | episode_return_mean=-191.610 | episode_len_mean=200.0
# [Episode 577572105017486756] total_reward=-50.302
# [Iter 0173] env_steps=34600 | episode_return_mean=-191.701 | episode_len_mean=200.0
# [Episode 606224416375102231] total_reward=-48.668
# [Iter 0174] env_steps=34800 | episode_return_mean=-191.751 | episode_len_mean=200.0
# [Episode 856798860483123226] total_reward=-46.384
# [Iter 0175] env_steps=35000 | episode_return_mean=-191.703 | episode_len_mean=200.0
# [Episode 733169039031050194] total_reward=-49.013
# [Iter 0176] env_steps=35200 | episode_return_mean=-191.818 | episode_len_mean=200.0
# [Episode 677631810205147212] total_reward=-47.800
# [Iter 0177] env_steps=35400 | episode_return_mean=-191.835 | episode_len_mean=200.0
# [Episode 297981639083906139] total_reward=-48.872
# [Iter 0178] env_steps=35600 | episode_return_mean=-191.936 | episode_len_mean=200.0
# [Episode 669345226841921383] total_reward=-49.153
# [Iter 0179] env_steps=35800 | episode_return_mean=-191.958 | episode_len_mean=200.0
# [Episode 168450899631120329] total_reward=-48.783
# [Iter 0180] env_steps=36000 | episode_return_mean=-192.031 | episode_len_mean=200.0
# [Episode 12063065911656709] total_reward=-48.973
# [Iter 0181] env_steps=36200 | episode_return_mean=-192.136 | episode_len_mean=200.0
# [Episode 472423159272223798] total_reward=-47.377
# [Iter 0182] env_steps=36400 | episode_return_mean=-192.214 | episode_len_mean=200.0
# [Episode 460724749500101812] total_reward=-49.597
# [Iter 0183] env_steps=36600 | episode_return_mean=-192.289 | episode_len_mean=200.0
# [Episode 590081512492906371] total_reward=-47.673
# [Iter 0184] env_steps=36800 | episode_return_mean=-192.310 | episode_len_mean=200.0
# [Episode 708893544472175187] total_reward=-48.372
# [Iter 0185] env_steps=37000 | episode_return_mean=-192.301 | episode_len_mean=200.0
# [Episode 487999748762231688] total_reward=-48.344
# [Iter 0186] env_steps=37200 | episode_return_mean=-192.346 | episode_len_mean=200.0
# [Episode 120910107272054743] total_reward=-48.895
# [Iter 0187] env_steps=37400 | episode_return_mean=-192.368 | episode_len_mean=200.0
# [Episode 992597648851774997] total_reward=-49.711
# [Iter 0188] env_steps=37600 | episode_return_mean=-192.451 | episode_len_mean=200.0
# [Episode 475128387433980089] total_reward=-48.207
# [Iter 0189] env_steps=37800 | episode_return_mean=-192.487 | episode_len_mean=200.0
# [Episode 766161293673828773] total_reward=-50.253
# [Iter 0190] env_steps=38000 | episode_return_mean=-192.599 | episode_len_mean=200.0
# [Episode 630097801691920488] total_reward=-48.766
# [Iter 0191] env_steps=38200 | episode_return_mean=-192.701 | episode_len_mean=200.0
# [Episode 648699265910176789] total_reward=-47.663
# [Iter 0192] env_steps=38400 | episode_return_mean=-192.689 | episode_len_mean=200.0
# [Episode 676513159103762015] total_reward=-46.342
# [Iter 0193] env_steps=38600 | episode_return_mean=-192.671 | episode_len_mean=200.0
# [Episode 210393682308316416] total_reward=-47.859
# [Iter 0194] env_steps=38800 | episode_return_mean=-192.692 | episode_len_mean=200.0
# [Episode 260274009965119325] total_reward=-47.517
# [Iter 0195] env_steps=39000 | episode_return_mean=-192.716 | episode_len_mean=200.0
# [Episode 262751120359315093] total_reward=-48.038
# [Iter 0196] env_steps=39200 | episode_return_mean=-192.813 | episode_len_mean=200.0
# [Episode 145919675533291241] total_reward=-48.620
# [Iter 0197] env_steps=39400 | episode_return_mean=-192.948 | episode_len_mean=200.0
# [Episode 791236879044659206] total_reward=-48.689
# [Iter 0198] env_steps=39600 | episode_return_mean=-192.944 | episode_len_mean=200.0
# [Episode 671649904694356243] total_reward=-48.615
# [Iter 0199] env_steps=39800 | episode_return_mean=-193.003 | episode_len_mean=200.0
# [Episode 35690731440964964] total_reward=-48.062
# [Iter 0200] env_steps=40000 | episode_return_mean=-192.979 | episode_len_mean=200.0
# [Episode 358168725510484511] total_reward=-47.017
# [Iter 0201] env_steps=40200 | episode_return_mean=-192.926 | episode_len_mean=200.0
# [Episode 386053798432486672] total_reward=-49.092
# [Iter 0202] env_steps=40400 | episode_return_mean=-193.032 | episode_len_mean=200.0
# [Episode 970416425469660561] total_reward=-46.343
# [Iter 0203] env_steps=40600 | episode_return_mean=-192.991 | episode_len_mean=200.0
# [Episode 97933350793066380] total_reward=-49.256
# [Iter 0204] env_steps=40800 | episode_return_mean=-193.058 | episode_len_mean=200.0
# [Episode 779589180905107777] total_reward=-50.060
# [Iter 0205] env_steps=41000 | episode_return_mean=-193.110 | episode_len_mean=200.0
# [Episode 497797508666975659] total_reward=-47.547
# [Iter 0206] env_steps=41200 | episode_return_mean=-193.136 | episode_len_mean=200.0
# [Episode 874889878747003110] total_reward=-47.902
# [Iter 0207] env_steps=41400 | episode_return_mean=-193.267 | episode_len_mean=200.0
# [Episode 936664974714768454] total_reward=-48.125
# [Iter 0208] env_steps=41600 | episode_return_mean=-193.255 | episode_len_mean=200.0
# [Episode 626954644964228764] total_reward=-45.962
# [Iter 0209] env_steps=41800 | episode_return_mean=-193.127 | episode_len_mean=200.0
# [Episode 968247787377728322] total_reward=-46.884
# [Iter 0210] env_steps=42000 | episode_return_mean=-193.141 | episode_len_mean=200.0
# [Episode 807569181782220171] total_reward=-46.688
# [Iter 0211] env_steps=42200 | episode_return_mean=-193.072 | episode_len_mean=200.0
# [Episode 587474067344638916] total_reward=-48.734
# [Iter 0212] env_steps=42400 | episode_return_mean=-193.130 | episode_len_mean=200.0
# [Episode 193435267627069493] total_reward=-45.619
# [Iter 0213] env_steps=42600 | episode_return_mean=-193.012 | episode_len_mean=200.0
# [Episode 93700804135553130] total_reward=-48.568
# [Iter 0214] env_steps=42800 | episode_return_mean=-193.070 | episode_len_mean=200.0
# [Episode 760606057292098211] total_reward=-47.306
# [Iter 0215] env_steps=43000 | episode_return_mean=-192.992 | episode_len_mean=200.0
# [Episode 374271744019144438] total_reward=-46.123
# [Iter 0216] env_steps=43200 | episode_return_mean=-192.884 | episode_len_mean=200.0
# [Episode 116862818920335329] total_reward=-45.967
# [Iter 0217] env_steps=43400 | episode_return_mean=-192.756 | episode_len_mean=200.0
# [Episode 915207346842532469] total_reward=-49.164
# [Iter 0218] env_steps=43600 | episode_return_mean=-192.810 | episode_len_mean=200.0
# [Episode 137045418057305230] total_reward=-46.542
# [Iter 0219] env_steps=43800 | episode_return_mean=-192.727 | episode_len_mean=200.0
# [Episode 409291003612796211] total_reward=-48.878
# [Iter 0220] env_steps=44000 | episode_return_mean=-192.748 | episode_len_mean=200.0
# [Episode 476935054975774083] total_reward=-48.729
# [Iter 0221] env_steps=44200 | episode_return_mean=-192.873 | episode_len_mean=200.0
# [Episode 195252722364033201] total_reward=-48.283
# [Iter 0222] env_steps=44400 | episode_return_mean=-192.878 | episode_len_mean=200.0
# [Episode 389037444828532652] total_reward=-46.880
# [Iter 0223] env_steps=44600 | episode_return_mean=-192.751 | episode_len_mean=200.0
# [Episode 256467641155881032] total_reward=-47.208
# [Iter 0224] env_steps=44800 | episode_return_mean=-192.740 | episode_len_mean=200.0
# [Episode 543108147810381727] total_reward=-45.883
# [Iter 0225] env_steps=45000 | episode_return_mean=-192.739 | episode_len_mean=200.0
# [Episode 457163995235691258] total_reward=-49.933
# [Iter 0226] env_steps=45200 | episode_return_mean=-192.819 | episode_len_mean=200.0
# [Episode 288536209009604704] total_reward=-47.204
# [Iter 0227] env_steps=45400 | episode_return_mean=-192.769 | episode_len_mean=200.0
# [Episode 838877597185519480] total_reward=-46.921
# [Iter 0228] env_steps=45600 | episode_return_mean=-192.663 | episode_len_mean=200.0
# [Episode 632238875803742126] total_reward=-50.215
# [Iter 0229] env_steps=45800 | episode_return_mean=-192.712 | episode_len_mean=200.0
# [Episode 935875945143148064] total_reward=-47.276
# [Iter 0230] env_steps=46000 | episode_return_mean=-192.674 | episode_len_mean=200.0
# [Episode 336973324248380623] total_reward=-47.562
# [Iter 0231] env_steps=46200 | episode_return_mean=-192.597 | episode_len_mean=200.0
# [Episode 230540532098854071] total_reward=-48.721
# [Iter 0232] env_steps=46400 | episode_return_mean=-192.617 | episode_len_mean=200.0
# [Episode 552863725357420876] total_reward=-48.441
# [Iter 0233] env_steps=46600 | episode_return_mean=-192.639 | episode_len_mean=200.0
# [Episode 720079277519214805] total_reward=-47.657
# [Iter 0234] env_steps=46800 | episode_return_mean=-192.587 | episode_len_mean=200.0
# [Episode 711111392627246773] total_reward=-46.602
# [Iter 0235] env_steps=47000 | episode_return_mean=-192.541 | episode_len_mean=200.0
# [Episode 675835925079345504] total_reward=-48.363
# [Iter 0236] env_steps=47200 | episode_return_mean=-192.590 | episode_len_mean=200.0
# [Episode 135113923665354290] total_reward=-47.298
# [Iter 0237] env_steps=47400 | episode_return_mean=-192.566 | episode_len_mean=200.0
# [Episode 629172879524868586] total_reward=-47.965
# [Iter 0238] env_steps=47600 | episode_return_mean=-192.585 | episode_len_mean=200.0
# [Episode 253570518874337527] total_reward=-47.497
# [Iter 0239] env_steps=47800 | episode_return_mean=-192.566 | episode_len_mean=200.0
# [Episode 683632345466174366] total_reward=-46.917
# [Iter 0240] env_steps=48000 | episode_return_mean=-192.446 | episode_len_mean=200.0
# [Episode 281608956333965029] total_reward=-48.583
# [Iter 0241] env_steps=48200 | episode_return_mean=-192.436 | episode_len_mean=200.0
# [Episode 460278415477504620] total_reward=-47.543
# [Iter 0242] env_steps=48400 | episode_return_mean=-192.352 | episode_len_mean=200.0
# [Episode 860658100658268266] total_reward=-47.296
# [Iter 0243] env_steps=48600 | episode_return_mean=-192.257 | episode_len_mean=200.0
# [Episode 181875052416846608] total_reward=-48.042
# [Iter 0244] env_steps=48800 | episode_return_mean=-192.308 | episode_len_mean=200.0
# [Episode 47002107956610132] total_reward=-48.472
# [Iter 0245] env_steps=49000 | episode_return_mean=-192.286 | episode_len_mean=200.0
# [Episode 582847965078826882] total_reward=-47.679
# [Iter 0246] env_steps=49200 | episode_return_mean=-192.275 | episode_len_mean=200.0
# [Episode 194636940123830633] total_reward=-47.062
# [Iter 0247] env_steps=49400 | episode_return_mean=-192.248 | episode_len_mean=200.0
# [Episode 615202772242333239] total_reward=-48.280
# [Iter 0248] env_steps=49600 | episode_return_mean=-192.185 | episode_len_mean=200.0
# [Episode 994961347240325098] total_reward=-46.889
# [Iter 0249] env_steps=49800 | episode_return_mean=-192.039 | episode_len_mean=200.0
# [Episode 928874643866276713] total_reward=-47.803
# [Iter 0250] env_steps=50000 | episode_return_mean=-191.998 | episode_len_mean=200.0
# [Episode 885716657975953623] total_reward=-45.867
# [Iter 0251] env_steps=50200 | episode_return_mean=-191.955 | episode_len_mean=200.0
# [Episode 367898246253782002] total_reward=-47.885
# [Iter 0252] env_steps=50400 | episode_return_mean=-191.947 | episode_len_mean=200.0
# [Episode 638892483460599167] total_reward=-49.026
# [Iter 0253] env_steps=50600 | episode_return_mean=-191.988 | episode_len_mean=200.0
# [Episode 559949688677916626] total_reward=-47.240
# [Iter 0254] env_steps=50800 | episode_return_mean=-191.898 | episode_len_mean=200.0
# [Episode 47022073444262935] total_reward=-46.966
# [Iter 0255] env_steps=51000 | episode_return_mean=-191.924 | episode_len_mean=200.0
# [Episode 63020578590094226] total_reward=-48.207
# [Iter 0256] env_steps=51200 | episode_return_mean=-191.943 | episode_len_mean=200.0
# [Episode 596138254539178139] total_reward=-47.238
# [Iter 0257] env_steps=51400 | episode_return_mean=-191.935 | episode_len_mean=200.0
# [Episode 543744725363930515] total_reward=-47.901
# [Iter 0258] env_steps=51600 | episode_return_mean=-191.894 | episode_len_mean=200.0
# [Episode 847789077569896918] total_reward=-46.112
# [Iter 0259] env_steps=51800 | episode_return_mean=-191.820 | episode_len_mean=200.0
# [Episode 156724337186038762] total_reward=-46.277
# [Iter 0260] env_steps=52000 | episode_return_mean=-191.719 | episode_len_mean=200.0
# [Episode 145154705899394486] total_reward=-48.086
# [Iter 0261] env_steps=52200 | episode_return_mean=-191.765 | episode_len_mean=200.0
# [Episode 808756250565166885] total_reward=-50.010
# [Iter 0262] env_steps=52400 | episode_return_mean=-191.861 | episode_len_mean=200.0
# [Episode 19804882718908277] total_reward=-48.065
# [Iter 0263] env_steps=52600 | episode_return_mean=-191.945 | episode_len_mean=200.0
# [Episode 764297105593344862] total_reward=-47.622
# [Iter 0264] env_steps=52800 | episode_return_mean=-191.904 | episode_len_mean=200.0
# [Episode 149195366537890477] total_reward=-48.205
# [Iter 0265] env_steps=53000 | episode_return_mean=-191.886 | episode_len_mean=200.0
# [Episode 890185453080393225] total_reward=-47.907
# [Iter 0266] env_steps=53200 | episode_return_mean=-191.855 | episode_len_mean=200.0
# [Episode 906535918960503768] total_reward=-47.228
# [Iter 0267] env_steps=53400 | episode_return_mean=-191.851 | episode_len_mean=200.0
# [Episode 407997385466737345] total_reward=-45.966
# [Iter 0268] env_steps=53600 | episode_return_mean=-191.723 | episode_len_mean=200.0
# [Episode 586462774630599342] total_reward=-46.312
# [Iter 0269] env_steps=53800 | episode_return_mean=-191.616 | episode_len_mean=200.0
# [Episode 162992358304795811] total_reward=-47.011
# [Iter 0270] env_steps=54000 | episode_return_mean=-191.464 | episode_len_mean=200.0
# [Episode 708333273837157781] total_reward=-47.682
# [Iter 0271] env_steps=54200 | episode_return_mean=-191.427 | episode_len_mean=200.0
# [Episode 547534085741678378] total_reward=-46.571
# [Iter 0272] env_steps=54400 | episode_return_mean=-191.397 | episode_len_mean=200.0
# [Episode 809537881759486038] total_reward=-47.312
# [Iter 0273] env_steps=54600 | episode_return_mean=-191.277 | episode_len_mean=200.0
# [Episode 637329531802797890] total_reward=-47.261
# [Iter 0274] env_steps=54800 | episode_return_mean=-191.221 | episode_len_mean=200.0
# [Episode 266125113963488017] total_reward=-47.745
# [Iter 0275] env_steps=55000 | episode_return_mean=-191.275 | episode_len_mean=200.0
# [Episode 114666045928563464] total_reward=-46.884
# [Iter 0276] env_steps=55200 | episode_return_mean=-191.190 | episode_len_mean=200.0
# [Episode 931793691755812712] total_reward=-47.923
# [Iter 0277] env_steps=55400 | episode_return_mean=-191.195 | episode_len_mean=200.0
# [Episode 648573526578413636] total_reward=-47.657
# [Iter 0278] env_steps=55600 | episode_return_mean=-191.146 | episode_len_mean=200.0
# [Episode 10584966812099085] total_reward=-47.902
# [Iter 0279] env_steps=55800 | episode_return_mean=-191.096 | episode_len_mean=200.0
# [Episode 331003506792916329] total_reward=-49.229
# [Iter 0280] env_steps=56000 | episode_return_mean=-191.114 | episode_len_mean=200.0
# [Episode 575111327935069746] total_reward=-48.846
# [Iter 0281] env_steps=56200 | episode_return_mean=-191.109 | episode_len_mean=200.0
# [Episode 160324515558990796] total_reward=-48.285
# [Iter 0282] env_steps=56400 | episode_return_mean=-191.145 | episode_len_mean=200.0
# [Episode 664625743042801359] total_reward=-48.272
# [Iter 0283] env_steps=56600 | episode_return_mean=-191.092 | episode_len_mean=200.0
# [Episode 645421676282408777] total_reward=-46.848
# [Iter 0284] env_steps=56800 | episode_return_mean=-191.059 | episode_len_mean=200.0
# [Episode 965905442387390223] total_reward=-48.951
# [Iter 0285] env_steps=57000 | episode_return_mean=-191.082 | episode_len_mean=200.0
# [Episode 549081472675823062] total_reward=-48.964
# [Iter 0286] env_steps=57200 | episode_return_mean=-191.107 | episode_len_mean=200.0
# [Episode 483332419592673140] total_reward=-46.450
# [Iter 0287] env_steps=57400 | episode_return_mean=-191.009 | episode_len_mean=200.0
# [Episode 18914766189446622] total_reward=-45.723
# [Iter 0288] env_steps=57600 | episode_return_mean=-190.850 | episode_len_mean=200.0
# [Episode 164364899711419284] total_reward=-47.521
# [Iter 0289] env_steps=57800 | episode_return_mean=-190.822 | episode_len_mean=200.0
# [Episode 38204511981223682] total_reward=-48.102
# [Iter 0290] env_steps=58000 | episode_return_mean=-190.736 | episode_len_mean=200.0
# [Episode 320120380355298546] total_reward=-46.568
# [Iter 0291] env_steps=58200 | episode_return_mean=-190.648 | episode_len_mean=200.0
# [Episode 894189623533941051] total_reward=-46.929
# [Iter 0292] env_steps=58400 | episode_return_mean=-190.619 | episode_len_mean=200.0
# [Episode 176141212014524742] total_reward=-46.983
# [Iter 0293] env_steps=58600 | episode_return_mean=-190.645 | episode_len_mean=200.0
# [Episode 779969454843642934] total_reward=-47.466
# [Iter 0294] env_steps=58800 | episode_return_mean=-190.629 | episode_len_mean=200.0
# [Episode 167729959012031463] total_reward=-49.002
# [Iter 0295] env_steps=59000 | episode_return_mean=-190.688 | episode_len_mean=200.0
# [Episode 739953179095146125] total_reward=-48.608
# [Iter 0296] env_steps=59200 | episode_return_mean=-190.711 | episode_len_mean=200.0
# [Episode 393970838665910122] total_reward=-47.116
# [Iter 0297] env_steps=59400 | episode_return_mean=-190.651 | episode_len_mean=200.0
# [Episode 853257242945003443] total_reward=-46.949
# [Iter 0298] env_steps=59600 | episode_return_mean=-190.582 | episode_len_mean=200.0
# [Episode 158325848035467580] total_reward=-49.145
# [Iter 0299] env_steps=59800 | episode_return_mean=-190.603 | episode_len_mean=200.0
# [Episode 984554369514903956] total_reward=-46.603
# [Iter 0300] env_steps=60000 | episode_return_mean=-190.544 | episode_len_mean=200.0
# [Episode 34987804519968998] total_reward=-47.487
# [Iter 0301] env_steps=60200 | episode_return_mean=-190.563 | episode_len_mean=200.0
# [Episode 187840561605371977] total_reward=-48.138
# [Iter 0302] env_steps=60400 | episode_return_mean=-190.525 | episode_len_mean=200.0
# [Episode 466003213214415161] total_reward=-48.906
# [Iter 0303] env_steps=60600 | episode_return_mean=-190.628 | episode_len_mean=200.0
# [Episode 938862392701904214] total_reward=-47.596
# [Iter 0304] env_steps=60800 | episode_return_mean=-190.561 | episode_len_mean=200.0
# [Episode 784518490256467810] total_reward=-47.842
# [Iter 0305] env_steps=61000 | episode_return_mean=-190.472 | episode_len_mean=200.0
# [Episode 567160213934159941] total_reward=-47.875
# [Iter 0306] env_steps=61200 | episode_return_mean=-190.486 | episode_len_mean=200.0
# [Episode 290456528836335956] total_reward=-47.079
# [Iter 0307] env_steps=61400 | episode_return_mean=-190.453 | episode_len_mean=200.0
# [Episode 462756461641711818] total_reward=-46.728
# [Iter 0308] env_steps=61600 | episode_return_mean=-190.397 | episode_len_mean=200.0
# [Episode 781939720561624792] total_reward=-48.749
# [Iter 0309] env_steps=61800 | episode_return_mean=-190.508 | episode_len_mean=200.0
# [Episode 869143173097341945] total_reward=-48.309
# [Iter 0310] env_steps=62000 | episode_return_mean=-190.565 | episode_len_mean=200.0
# [Episode 948490025785674544] total_reward=-46.951
# [Iter 0311] env_steps=62200 | episode_return_mean=-190.576 | episode_len_mean=200.0
# [Episode 22203911495981320] total_reward=-46.926
# [Iter 0312] env_steps=62400 | episode_return_mean=-190.503 | episode_len_mean=200.0
# [Episode 63081855055688921] total_reward=-46.816
# [Iter 0313] env_steps=62600 | episode_return_mean=-190.551 | episode_len_mean=200.0
# [Episode 697720442947530127] total_reward=-46.810
# [Iter 0314] env_steps=62800 | episode_return_mean=-190.481 | episode_len_mean=200.0
# [Episode 930625853034603536] total_reward=-48.422
# [Iter 0315] env_steps=63000 | episode_return_mean=-190.526 | episode_len_mean=200.0
# [Episode 69305616675979472] total_reward=-48.413
# [Iter 0316] env_steps=63200 | episode_return_mean=-190.617 | episode_len_mean=200.0
# [Episode 22134147123485575] total_reward=-47.171
# [Iter 0317] env_steps=63400 | episode_return_mean=-190.665 | episode_len_mean=200.0
# [Episode 233232227638383281] total_reward=-46.615
# [Iter 0318] env_steps=63600 | episode_return_mean=-190.563 | episode_len_mean=200.0
# [Episode 492015743760081732] total_reward=-46.433
# [Iter 0319] env_steps=63800 | episode_return_mean=-190.559 | episode_len_mean=200.0
# [Episode 557653917998495827] total_reward=-49.363
# [Iter 0320] env_steps=64000 | episode_return_mean=-190.578 | episode_len_mean=200.0
# [Episode 450250935218889933] total_reward=-46.848
# [Iter 0321] env_steps=64200 | episode_return_mean=-190.503 | episode_len_mean=200.0
# [Episode 226899656964892569] total_reward=-47.907
# [Iter 0322] env_steps=64400 | episode_return_mean=-190.488 | episode_len_mean=200.0
# [Episode 734632051828327556] total_reward=-47.275
# [Iter 0323] env_steps=64600 | episode_return_mean=-190.504 | episode_len_mean=200.0
# [Episode 316005431336245670] total_reward=-48.208
# [Iter 0324] env_steps=64800 | episode_return_mean=-190.544 | episode_len_mean=200.0
# [Episode 706868541658887269] total_reward=-46.544
# [Iter 0325] env_steps=65000 | episode_return_mean=-190.570 | episode_len_mean=200.0
# [Episode 109397782763490550] total_reward=-46.387
# [Iter 0326] env_steps=65200 | episode_return_mean=-190.429 | episode_len_mean=200.0
# [Episode 71384742608535901] total_reward=-47.606
# [Iter 0327] env_steps=65400 | episode_return_mean=-190.445 | episode_len_mean=200.0
# [Episode 824132301527609112] total_reward=-47.066
# [Iter 0328] env_steps=65600 | episode_return_mean=-190.450 | episode_len_mean=200.0
# [Episode 775637537700669306] total_reward=-48.947
# [Iter 0329] env_steps=65800 | episode_return_mean=-190.400 | episode_len_mean=200.0
# [Episode 870740501326318452] total_reward=-47.944
# [Iter 0330] env_steps=66000 | episode_return_mean=-190.426 | episode_len_mean=200.0
# [Episode 729975189019148059] total_reward=-47.327
# [Iter 0331] env_steps=66200 | episode_return_mean=-190.417 | episode_len_mean=200.0
# [Episode 449147182277522220] total_reward=-49.275
# [Iter 0332] env_steps=66400 | episode_return_mean=-190.439 | episode_len_mean=200.0
# [Episode 615659790682187563] total_reward=-48.095
# [Iter 0333] env_steps=66600 | episode_return_mean=-190.425 | episode_len_mean=200.0
# [Episode 956775631092152957] total_reward=-46.030
# [Iter 0334] env_steps=66800 | episode_return_mean=-190.360 | episode_len_mean=200.0
# [Episode 708676617969296511] total_reward=-46.001
# [Iter 0335] env_steps=67000 | episode_return_mean=-190.336 | episode_len_mean=200.0
# [Episode 45724416323183950] total_reward=-47.261
# [Iter 0336] env_steps=67200 | episode_return_mean=-190.292 | episode_len_mean=200.0
# [Episode 24565719209806537] total_reward=-46.891
# [Iter 0337] env_steps=67400 | episode_return_mean=-190.276 | episode_len_mean=200.0
# [Episode 660970240898260988] total_reward=-47.180
# [Iter 0338] env_steps=67600 | episode_return_mean=-190.245 | episode_len_mean=200.0
# [Episode 352044607646356361] total_reward=-47.810
# [Iter 0339] env_steps=67800 | episode_return_mean=-190.257 | episode_len_mean=200.0
# [Episode 307397660963444431] total_reward=-47.276
# [Iter 0340] env_steps=68000 | episode_return_mean=-190.271 | episode_len_mean=200.0
# [Episode 915757637511867971] total_reward=-47.896
# [Iter 0341] env_steps=68200 | episode_return_mean=-190.244 | episode_len_mean=200.0
# [Episode 179275313559129922] total_reward=-46.868
# [Iter 0342] env_steps=68400 | episode_return_mean=-190.217 | episode_len_mean=200.0
# ...
# [Episode 520414964075448585] total_reward=-49.736
# [Iter 2383] env_steps=476600 | episode_return_mean=-202.921 | episode_len_mean=200.0
# [Episode 306911920530962244] total_reward=-52.026
# [Iter 2384] env_steps=476800 | episode_return_mean=-203.031 | episode_len_mean=200.0
# [Episode 591398890429995139] total_reward=-51.811
# [Iter 2385] env_steps=477000 | episode_return_mean=-203.024 | episode_len_mean=200.0
# [Episode 695149953629115888] total_reward=-52.433
# [Iter 2386] env_steps=477200 | episode_return_mean=-203.144 | episode_len_mean=200.0
# [Episode 695445636019043356] total_reward=-52.140
# [Iter 2387] env_steps=477400 | episode_return_mean=-203.155 | episode_len_mean=200.0
# [Episode 503787561564574479] total_reward=-52.462
# [Iter 2388] env_steps=477600 | episode_return_mean=-203.194 | episode_len_mean=200.0
# [Episode 585271233304508245] total_reward=-50.359
# [Iter 2389] env_steps=477800 | episode_return_mean=-203.206 | episode_len_mean=200.0
# [Episode 415629221742911884] total_reward=-52.361
# [Iter 2390] env_steps=478000 | episode_return_mean=-203.265 | episode_len_mean=200.0
# [Episode 668608452709995197] total_reward=-51.211
# [Iter 2391] env_steps=478200 | episode_return_mean=-203.227 | episode_len_mean=200.0
# [Episode 446272761970952271] total_reward=-50.769
# [Iter 2392] env_steps=478400 | episode_return_mean=-203.247 | episode_len_mean=200.0
# [Episode 878469225144521345] total_reward=-50.722
# [Iter 2393] env_steps=478600 | episode_return_mean=-203.235 | episode_len_mean=200.0
# [Episode 87816044331314373] total_reward=-50.987
# [Iter 2394] env_steps=478800 | episode_return_mean=-203.221 | episode_len_mean=200.0
# [Episode 22723996084261368] total_reward=-50.902
# [Iter 2395] env_steps=479000 | episode_return_mean=-203.246 | episode_len_mean=200.0
# [Episode 661754507363647180] total_reward=-53.729
# [Iter 2396] env_steps=479200 | episode_return_mean=-203.376 | episode_len_mean=200.0
# [Episode 884257926462505918] total_reward=-52.076
# [Iter 2397] env_steps=479400 | episode_return_mean=-203.416 | episode_len_mean=200.0
# [Episode 441572831191620291] total_reward=-51.336
# [Iter 2398] env_steps=479600 | episode_return_mean=-203.445 | episode_len_mean=200.0
# [Episode 525452820723715783] total_reward=-52.312
# [Iter 2399] env_steps=479800 | episode_return_mean=-203.509 | episode_len_mean=200.0
# [Episode 367507321378495175] total_reward=-50.227
# [Iter 2400] env_steps=480000 | episode_return_mean=-203.517 | episode_len_mean=200.0
# [Episode 788355663005196410] total_reward=-50.595
# [Iter 2401] env_steps=480200 | episode_return_mean=-203.484 | episode_len_mean=200.0
# [Episode 929072616533196545] total_reward=-49.665
# [Iter 2402] env_steps=480400 | episode_return_mean=-203.397 | episode_len_mean=200.0
# [Episode 840766891074497046] total_reward=-49.589
# [Iter 2403] env_steps=480600 | episode_return_mean=-203.383 | episode_len_mean=200.0
# [Episode 662554540661206665] total_reward=-50.262
# [Iter 2404] env_steps=480800 | episode_return_mean=-203.386 | episode_len_mean=200.0
# [Episode 42908329614902457] total_reward=-52.669
# [Iter 2405] env_steps=481000 | episode_return_mean=-203.407 | episode_len_mean=200.0
# [Episode 656878623273845298] total_reward=-51.982
# [Iter 2406] env_steps=481200 | episode_return_mean=-203.520 | episode_len_mean=200.0
# [Episode 747493824940670468] total_reward=-51.147
# [Iter 2407] env_steps=481400 | episode_return_mean=-203.506 | episode_len_mean=200.0
# [Episode 874079363028852623] total_reward=-53.409
# [Iter 2408] env_steps=481600 | episode_return_mean=-203.626 | episode_len_mean=200.0
# [Episode 157694449334614923] total_reward=-51.644
# [Iter 2409] env_steps=481800 | episode_return_mean=-203.654 | episode_len_mean=200.0
# [Episode 899389791862036260] total_reward=-50.523
# [Iter 2410] env_steps=482000 | episode_return_mean=-203.581 | episode_len_mean=200.0
# [Episode 207313119458985352] total_reward=-50.500
# [Iter 2411] env_steps=482200 | episode_return_mean=-203.554 | episode_len_mean=200.0
# [Episode 253173714754110291] total_reward=-52.420
# [Iter 2412] env_steps=482400 | episode_return_mean=-203.648 | episode_len_mean=200.0
# [Episode 777419304144821250] total_reward=-51.587
# [Iter 2413] env_steps=482600 | episode_return_mean=-203.683 | episode_len_mean=200.0
# [Episode 360662653231481036] total_reward=-52.581
# [Iter 2414] env_steps=482800 | episode_return_mean=-203.725 | episode_len_mean=200.0
# [Episode 855679738507533057] total_reward=-52.424
# [Iter 2415] env_steps=483000 | episode_return_mean=-203.808 | episode_len_mean=200.0
# [Episode 714427462077211919] total_reward=-50.675
# [Iter 2416] env_steps=483200 | episode_return_mean=-203.857 | episode_len_mean=200.0
# [Episode 133273583541405903] total_reward=-52.844
# [Iter 2417] env_steps=483400 | episode_return_mean=-203.991 | episode_len_mean=200.0
# [Episode 718701907742720100] total_reward=-51.098
# [Iter 2418] env_steps=483600 | episode_return_mean=-203.964 | episode_len_mean=200.0
# [Episode 418768601820257510] total_reward=-51.529
# [Iter 2419] env_steps=483800 | episode_return_mean=-204.046 | episode_len_mean=200.0
# [Episode 414718798216858203] total_reward=-52.485
# [Iter 2420] env_steps=484000 | episode_return_mean=-204.113 | episode_len_mean=200.0
# [Episode 815129397581613271] total_reward=-51.961
# [Iter 2421] env_steps=484200 | episode_return_mean=-204.190 | episode_len_mean=200.0
# [Episode 799819406491665968] total_reward=-51.997
# [Iter 2422] env_steps=484400 | episode_return_mean=-204.219 | episode_len_mean=200.0
# [Episode 665538496716328744] total_reward=-50.764
# [Iter 2423] env_steps=484600 | episode_return_mean=-204.258 | episode_len_mean=200.0
# [Episode 791909091788442697] total_reward=-52.523
# [Iter 2424] env_steps=484800 | episode_return_mean=-204.371 | episode_len_mean=200.0
# [Episode 634089749626850087] total_reward=-52.022
# [Iter 2425] env_steps=485000 | episode_return_mean=-204.471 | episode_len_mean=200.0
# [Episode 780091899760285432] total_reward=-53.300
# [Iter 2426] env_steps=485200 | episode_return_mean=-204.604 | episode_len_mean=200.0
# [Episode 994531096357106033] total_reward=-52.612
# [Iter 2427] env_steps=485400 | episode_return_mean=-204.684 | episode_len_mean=200.0
# [Episode 202049612276688964] total_reward=-51.863
# [Iter 2428] env_steps=485600 | episode_return_mean=-204.754 | episode_len_mean=200.0
# [Episode 549690262236341713] total_reward=-52.304
# [Iter 2429] env_steps=485800 | episode_return_mean=-204.789 | episode_len_mean=200.0
# [Episode 395694888192877310] total_reward=-53.398
# [Iter 2430] env_steps=486000 | episode_return_mean=-204.966 | episode_len_mean=200.0
# [Episode 783533976206201900] total_reward=-52.537
# [Iter 2431] env_steps=486200 | episode_return_mean=-205.015 | episode_len_mean=200.0
# [Episode 998807481604638719] total_reward=-53.248
# [Iter 2432] env_steps=486400 | episode_return_mean=-205.130 | episode_len_mean=200.0
# [Episode 72743082659425398] total_reward=-53.175
# [Iter 2433] env_steps=486600 | episode_return_mean=-205.250 | episode_len_mean=200.0
# [Episode 933414417728069473] total_reward=-53.213
# [Iter 2434] env_steps=486800 | episode_return_mean=-205.369 | episode_len_mean=200.0
# [Episode 888901179805959822] total_reward=-51.932
# [Iter 2435] env_steps=487000 | episode_return_mean=-205.357 | episode_len_mean=200.0
# [Episode 375323729632549003] total_reward=-51.497
# [Iter 2436] env_steps=487200 | episode_return_mean=-205.416 | episode_len_mean=200.0
# [Episode 331937106598664002] total_reward=-51.691
# [Iter 2437] env_steps=487400 | episode_return_mean=-205.478 | episode_len_mean=200.0
# [Episode 896656594493695744] total_reward=-53.290
# [Iter 2438] env_steps=487600 | episode_return_mean=-205.578 | episode_len_mean=200.0
# [Episode 615193431066994105] total_reward=-52.275
# [Iter 2439] env_steps=487800 | episode_return_mean=-205.636 | episode_len_mean=200.0
# [Episode 247084847841009933] total_reward=-52.146
# [Iter 2440] env_steps=488000 | episode_return_mean=-205.695 | episode_len_mean=200.0
# [Episode 332146247825074256] total_reward=-50.867
# [Iter 2441] env_steps=488200 | episode_return_mean=-205.754 | episode_len_mean=200.0
# [Episode 668415199971262294] total_reward=-51.660
# [Iter 2442] env_steps=488400 | episode_return_mean=-205.803 | episode_len_mean=200.0
# [Episode 545665827843502928] total_reward=-50.560
# [Iter 2443] env_steps=488600 | episode_return_mean=-205.796 | episode_len_mean=200.0
# [Episode 442053336057059649] total_reward=-52.537
# [Iter 2444] env_steps=488800 | episode_return_mean=-205.902 | episode_len_mean=200.0
# [Episode 980141623832755312] total_reward=-52.521
# [Iter 2445] env_steps=489000 | episode_return_mean=-205.952 | episode_len_mean=200.0
# [Episode 473171348128435498] total_reward=-53.708
# [Iter 2446] env_steps=489200 | episode_return_mean=-206.010 | episode_len_mean=200.0
# [Episode 490082565560668280] total_reward=-51.246
# [Iter 2447] env_steps=489400 | episode_return_mean=-206.034 | episode_len_mean=200.0
# [Episode 535889646718074872] total_reward=-52.329
# [Iter 2448] env_steps=489600 | episode_return_mean=-206.088 | episode_len_mean=200.0
# [Episode 887587028581279775] total_reward=-52.051
# [Iter 2449] env_steps=489800 | episode_return_mean=-206.136 | episode_len_mean=200.0
# [Episode 753715898472697142] total_reward=-52.373
# [Iter 2450] env_steps=490000 | episode_return_mean=-206.295 | episode_len_mean=200.0
# [Episode 979469148719791461] total_reward=-53.140
# [Iter 2451] env_steps=490200 | episode_return_mean=-206.401 | episode_len_mean=200.0
# [Episode 876786103600614627] total_reward=-53.541
# [Iter 2452] env_steps=490400 | episode_return_mean=-206.510 | episode_len_mean=200.0
# [Episode 128450223437972227] total_reward=-53.508
# [Iter 2453] env_steps=490600 | episode_return_mean=-206.656 | episode_len_mean=200.0
# [Episode 289481608978024059] total_reward=-51.890
# [Iter 2454] env_steps=490800 | episode_return_mean=-206.713 | episode_len_mean=200.0
# [Episode 959886861642673352] total_reward=-51.012
# [Iter 2455] env_steps=491000 | episode_return_mean=-206.708 | episode_len_mean=200.0
# [Episode 620219738119083595] total_reward=-53.146
# [Iter 2456] env_steps=491200 | episode_return_mean=-206.760 | episode_len_mean=200.0
# [Episode 968221905611668228] total_reward=-53.443
# [Iter 2457] env_steps=491400 | episode_return_mean=-206.899 | episode_len_mean=200.0
# [Episode 44353342265036856] total_reward=-52.560
# [Iter 2458] env_steps=491600 | episode_return_mean=-206.983 | episode_len_mean=200.0
# [Episode 862280007915018911] total_reward=-53.083
# [Iter 2459] env_steps=491800 | episode_return_mean=-207.074 | episode_len_mean=200.0
# [Episode 857890724650344382] total_reward=-52.601
# [Iter 2460] env_steps=492000 | episode_return_mean=-207.176 | episode_len_mean=200.0
# [Episode 121360055444126495] total_reward=-54.005
# [Iter 2461] env_steps=492200 | episode_return_mean=-207.276 | episode_len_mean=200.0
# [Episode 96223010034836] total_reward=-52.313
# [Iter 2462] env_steps=492400 | episode_return_mean=-207.310 | episode_len_mean=200.0
# [Episode 324865643451233990] total_reward=-54.259
# [Iter 2463] env_steps=492600 | episode_return_mean=-207.402 | episode_len_mean=200.0
# [Episode 171960242720426542] total_reward=-52.912
# [Iter 2464] env_steps=492800 | episode_return_mean=-207.514 | episode_len_mean=200.0
# [Episode 491385910004023734] total_reward=-53.617
# [Iter 2465] env_steps=493000 | episode_return_mean=-207.584 | episode_len_mean=200.0
# [Episode 591738037795328470] total_reward=-54.002
# [Iter 2466] env_steps=493200 | episode_return_mean=-207.683 | episode_len_mean=200.0
# [Episode 431351676151864850] total_reward=-52.529
# [Iter 2467] env_steps=493400 | episode_return_mean=-207.725 | episode_len_mean=200.0
# [Episode 606234798401328801] total_reward=-54.303
# [Iter 2468] env_steps=493600 | episode_return_mean=-207.780 | episode_len_mean=200.0
# [Episode 956799391660383805] total_reward=-54.442
# [Iter 2469] env_steps=493800 | episode_return_mean=-207.976 | episode_len_mean=200.0
# [Episode 463198511161409641] total_reward=-54.697
# [Iter 2470] env_steps=494000 | episode_return_mean=-208.154 | episode_len_mean=200.0
# [Episode 659976117579517037] total_reward=-54.702
# [Iter 2471] env_steps=494200 | episode_return_mean=-208.276 | episode_len_mean=200.0
# [Episode 657936756927369023] total_reward=-53.924
# [Iter 2472] env_steps=494400 | episode_return_mean=-208.388 | episode_len_mean=200.0
# [Episode 215518472502113352] total_reward=-54.130
# [Iter 2473] env_steps=494600 | episode_return_mean=-208.566 | episode_len_mean=200.0
# [Episode 571845917022791845] total_reward=-51.627
# [Iter 2474] env_steps=494800 | episode_return_mean=-208.593 | episode_len_mean=200.0
# [Episode 919951222756455593] total_reward=-54.470
# [Iter 2475] env_steps=495000 | episode_return_mean=-208.649 | episode_len_mean=200.0
# [Episode 274920275554335449] total_reward=-52.461
# [Iter 2476] env_steps=495200 | episode_return_mean=-208.753 | episode_len_mean=200.0
# [Episode 25943326749222714] total_reward=-54.610
# [Iter 2477] env_steps=495400 | episode_return_mean=-208.906 | episode_len_mean=200.0
# [Episode 113783292294561913] total_reward=-54.541
# [Iter 2478] env_steps=495600 | episode_return_mean=-209.033 | episode_len_mean=200.0
# [Episode 490176106011808372] total_reward=-54.444
# [Iter 2479] env_steps=495800 | episode_return_mean=-209.162 | episode_len_mean=200.0
# [Episode 176933640745130174] total_reward=-54.090
# [Iter 2480] env_steps=496000 | episode_return_mean=-209.241 | episode_len_mean=200.0
# [Episode 343358508222439186] total_reward=-53.921
# [Iter 2481] env_steps=496200 | episode_return_mean=-209.355 | episode_len_mean=200.0
# [Episode 935108718479563961] total_reward=-53.665
# [Iter 2482] env_steps=496400 | episode_return_mean=-209.457 | episode_len_mean=200.0
# [Episode 836971170480680863] total_reward=-55.423
# [Iter 2483] env_steps=496600 | episode_return_mean=-209.684 | episode_len_mean=200.0
# [Episode 737610148749846118] total_reward=-53.793
# [Iter 2484] env_steps=496800 | episode_return_mean=-209.755 | episode_len_mean=200.0
# [Episode 220095518594486990] total_reward=-54.559
# [Iter 2485] env_steps=497000 | episode_return_mean=-209.865 | episode_len_mean=200.0
# [Episode 324080631868128060] total_reward=-53.963
# [Iter 2486] env_steps=497200 | episode_return_mean=-209.926 | episode_len_mean=200.0
# [Episode 780548988240066940] total_reward=-54.333
# [Iter 2487] env_steps=497400 | episode_return_mean=-210.014 | episode_len_mean=200.0
# [Episode 542022492201110946] total_reward=-55.483
# [Iter 2488] env_steps=497600 | episode_return_mean=-210.134 | episode_len_mean=200.0
# [Episode 834344474612306815] total_reward=-54.980
# [Iter 2489] env_steps=497800 | episode_return_mean=-210.319 | episode_len_mean=200.0
# [Episode 921138302641115748] total_reward=-55.055
# [Iter 2490] env_steps=498000 | episode_return_mean=-210.427 | episode_len_mean=200.0
# [Episode 838840025280576709] total_reward=-54.365
# [Iter 2491] env_steps=498200 | episode_return_mean=-210.553 | episode_len_mean=200.0
# [Episode 781465776539611690] total_reward=-54.566
# [Iter 2492] env_steps=498400 | episode_return_mean=-210.705 | episode_len_mean=200.0
# [Episode 994808873851956467] total_reward=-53.704
# [Iter 2493] env_steps=498600 | episode_return_mean=-210.824 | episode_len_mean=200.0
# [Episode 762035098897231740] total_reward=-54.291
# [Iter 2494] env_steps=498800 | episode_return_mean=-210.957 | episode_len_mean=200.0
# [Episode 743513887352089210] total_reward=-54.470
# [Iter 2495] env_steps=499000 | episode_return_mean=-211.099 | episode_len_mean=200.0
# [Episode 277008251345340693] total_reward=-53.792
# [Iter 2496] env_steps=499200 | episode_return_mean=-211.102 | episode_len_mean=200.0
# [Episode 636995046448990856] total_reward=-55.423
# [Iter 2497] env_steps=499400 | episode_return_mean=-211.236 | episode_len_mean=200.0
# [Episode 836556429710677669] total_reward=-54.041
# [Iter 2498] env_steps=499600 | episode_return_mean=-211.344 | episode_len_mean=200.0
# [Episode 644333338942896091] total_reward=-56.955
# [Iter 2499] env_steps=499800 | episode_return_mean=-211.530 | episode_len_mean=200.0
# [Episode 731212450846815702] total_reward=-53.064
# [Iter 2500] env_steps=500000 | episode_return_mean=-211.643 | episode_len_mean=200.0
#
# ✅ SAC Training finished.

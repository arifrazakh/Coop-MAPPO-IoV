# %%
import math
import random
from collections import defaultdict
from types import SimpleNamespace
import time
import csv  # used for episode-wise CSV logging

import argparse
import os

import matplotlib.pyplot as plt
import numpy as np

try:
    import gymnasium as gym
    from gymnasium.utils import seeding
except ImportError:
    try:
        import gym
        from gym.utils import seeding
    except ImportError:
        class _SimpleBox:
            def __init__(self, low, high, shape=None, dtype=np.float32):
                self.low = low
                self.high = high
                self.shape = shape
                self.dtype = dtype

        class _SimpleSpaces:
            Box = _SimpleBox

        class _SimpleGym:
            spaces = _SimpleSpaces()

        class _SimpleSeeding:
            @staticmethod
            def np_random(seed=None):
                if seed is None:
                    seed = random.randrange(2**31 - 1)
                rng = np.random.default_rng(seed)
                return rng, int(seed)

        gym = _SimpleGym()
        seeding = _SimpleSeeding()


# ----------------------
# Basic PHY & helper functions
# ----------------------
def rx_sensitivity_dBm(bw_hz, nf_db=7.0, snr_req_db=-5.0):
    """Thermal-noise-based RX sensitivity in dBm."""
    return -174.0 + 10.0 * np.log10(max(bw_hz, 1.0)) + nf_db + snr_req_db


MOD_ORDER = 256
BITS_PER_CODEWORD = int(np.log2(MOD_ORDER))
NR_OVERHEAD = 0.85
SNR_GAP_DB = 1.5
MAX_SE = 7.5  # peak spectral efficiency (bit/s/Hz)

# Antenna / beamforming gains per BS type
BEAM_GAIN_DB = {
    "Ma": {
        "tx_main": 8.0,   # main-lobe TX gain (dB)
        "tx_side": -3.0,  # side-lobe TX gain (dB)
        "rx": 0.0,        # UE RX gain (dB)
    }
}

UE_INTERF_RX_DB = 0.0  # interference-side RX gain at UE
MACRO_REUSE_ONE = False
MIMO_MAX_RANK = {"Ma": 4}


def spectral_efficiency_from_sinr(SINR_dB, gap_db=SNR_GAP_DB, max_se=MAX_SE):
    """Shannon-like SE with SNR gap."""
    gamma_lin = 10.0 ** (SINR_dB / 10.0) / (10.0 ** (gap_db / 10.0))
    se = np.log2(1.0 + gamma_lin)
    return float(np.clip(se, 0.0, max_se))


def mimo_rank_and_total_se(
    SINR_dB: float,
    max_layers: int,
    gap_db: float = SNR_GAP_DB,
    max_se: float = MAX_SE,
):
    """Simple MIMO rank-selection and SE aggregation."""
    sinr_lin = 10.0 ** (SINR_dB / 10.0)
    best_L = 1
    best_sum_se = spectral_efficiency_from_sinr(SINR_dB, gap_db, max_se)

    for L in range(2, max_layers + 1):
        per_layer_snr_dB = 10.0 * np.log10(max(sinr_lin / max(L, 1), 1e-12))
        se_layer = spectral_efficiency_from_sinr(
            per_layer_snr_dB, gap_db, max_se
        )
        corr_eff = max(0.5, 1.0 - 0.07 * (L - 1))  # crude correlation penalty
        sum_se = L * se_layer * corr_eff
        if sum_se > best_sum_se:
            best_sum_se = sum_se
            best_L = L

    return best_L, float(best_sum_se)


# 19-D BS observation layout (0-1 normalized)
OBS_IDX = SimpleNamespace(
    BS_TYPE=0,
    TX_NORM=1,
    CH_UTIL=2,
    COV_UTIL=3,
    LOAD_RATIO_NORM=4,
    NEARBY_POT=5,
    AVG_SPEED=6,
    REQ_P_NORM=7,
    AVG_RADIAL_V=8,
    SP_VAR=9,
    NEIGHBOR_TX_NORM=10,
    AVG_DEMAND_NORM=11,
    INTER_NORM=12,
    MEC_QUEUE_NORM=13,
    CPU_UTIL_NORM=14,
    OFFLOAD_FRAC=15,
    SERVED_RATIO_NORM=16,  # local served throughput / max possible
    BLOCK_FRAC_NORM=17,    # fraction of in-coverage users not associated
    CH_MATCH_NORM=18,      # how well channels match covered users
    OFFLOAD_MAND_FRAC=19,  # fraction of covered users with mandatory-offload tasks
)


# ----------------
# Building blocks
# ----------------
class Channel:
    def __init__(self, id, frequency, bandwidth, noise_figure_db=7.0):
        self.id = int(id)
        self.frequency = float(frequency)
        self.bandwidth = float(bandwidth)
        self.noise_figure_db = float(noise_figure_db)
        self.users = []
        self.base_station = None

    def calculate_noise_power(self):
        """Noise power in Watts for this channel."""
        k = 1.380649e-23
        T = 293.15
        N = k * T * self.bandwidth
        NF = 10.0 ** (self.noise_figure_db / 10.0)
        return N * NF


class BaseStation:
    def __init__(
        self,
        id,
        transmit_power_mW,
        height_m,
        location_xy,
        type_bs="Ma",
        mec_cpu_capacity_cycles=5e9,
    ):
        self.id = int(id)
        self.transmit_power = float(transmit_power_mW)  # total TX power in mW
        self.height = float(height_m)
        self.location = np.array(location_xy, dtype=float)
        self.type_bs = type_bs
        self.assigned_channels = []
        self.per_channel_power = {}
        self.coverage_area = float(0.0)  # coverage radius (m)

        # MEC-related attributes (compute plane)
        self.mec_cpu_capacity = float(mec_cpu_capacity_cycles)  # F_i^{max}
        self.mec_queue_cycles = 0.0     # q_t^{bs,i} [cycles]
        self.offload_frac = 1.0         # x_t^i in [0,1]
        self.cpu_util_frac = 1.0        # aggregate CPU utilization fraction
        self.last_cpu_used = 0.0        # F_used this step [cycles/s]

        # simple type-dependent caps
        self.MAX_COVERAGE = {"Ma": 2000.0}
        self.COV_MARGIN_DB = {"Ma": 3.0}
        self.SNR_REQ_DB = {"Ma": -5.0}

    # ---- 3GPP-like UMa pathloss ----
    def _pl_uma_los(self, d3d, f_ghz, h_ut=1.5):
        c = 3e8
        f_hz = f_ghz * 1e9
        h_bs = float(self.height)

        d2d = max(np.sqrt(max(d3d**2 - (h_bs - h_ut) ** 2, 1e-9)), 1.0)
        h_bs_eff = h_bs - 1.0
        h_ut_eff = h_ut - 1.0
        d_bp = 4.0 * h_bs_eff * h_ut_eff * f_hz / c

        pl1 = 28.0 + 22.0 * np.log10(d3d) + 20.0 * np.log10(f_ghz)
        if d2d <= d_bp:
            return pl1
        pl2 = (
            28.0
            + 40.0 * np.log10(d3d)
            + 20.0 * np.log10(f_ghz)
            - 9.0 * np.log10(d_bp**2 + (h_bs - h_ut) ** 2)
        )
        return pl2

    def _pl_uma_nlos(self, d3d, f_ghz, h_ut=1.5):
        pl_los = self._pl_uma_los(d3d, f_ghz, h_ut)
        pl_nlos = (
            13.54
            + 39.08 * np.log10(d3d)
            + 20.0 * np.log10(f_ghz)
            - 0.6 * (h_ut - 1.5)
        )
        return max(pl_nlos, pl_los)

    def calculate_path_loss(self, distance_m, frequency_hz, user_height=1.5):
        """Average path loss (LOS-probability weighted)."""
        d2d = float(max(distance_m, 0.1))
        f_ghz = frequency_hz / 1e9
        d3d = np.sqrt(d2d**2 + (self.height - user_height) ** 2)

        p_los = min(18.0 / d2d, 1.0) * (1.0 - np.exp(-d2d / 63.0)) + np.exp(
            -d2d / 63.0
        )
        pl_los = self._pl_uma_los(d3d, f_ghz, h_ut=user_height)
        pl_nlos = self._pl_uma_nlos(d3d, f_ghz, h_ut=user_height)

        return float(p_los * pl_los + (1.0 - p_los) * pl_nlos)

    def _eirp_dbm(self, transmit_power_mW: float) -> float:
        g = BEAM_GAIN_DB[self.type_bs]
        tx_dbm = 10.0 * np.log10(max(transmit_power_mW, 1e-15))
        return tx_dbm + g["tx_main"] + g["rx"]

    def update_coverage_area_from_power(
        self, total_transmit_power_mW, frequency_hz
    ):
        """Update coverage radius from link budget."""
        if self.per_channel_power:
            values = list(self.per_channel_power.values())
            p_ch = float(np.percentile(values, 80))
        else:
            n = max(1, len(self.assigned_channels))
            p_ch = float(total_transmit_power_mW / n)

        if self.assigned_channels:
            bw_hz = self.assigned_channels[0].bandwidth
            nf_db = self.assigned_channels[0].noise_figure_db
        else:
            bw_hz = 20e6
            nf_db = 7.0

        sens_dBm = rx_sensitivity_dBm(
            bw_hz, nf_db=nf_db, snr_req_db=self.SNR_REQ_DB[self.type_bs]
        )
        eirp_plus_grx_dbm = self._eirp_dbm(p_ch)
        path_loss_budget_dB = (
            eirp_plus_grx_dbm - sens_dBm - self.COV_MARGIN_DB[self.type_bs]
        )

        radius_m = self.find_distance_for_path_loss(
            path_loss_budget_dB, frequency_hz
        )
        cap = self.MAX_COVERAGE.get(self.type_bs, None)
        if cap is not None:
            radius_m = min(radius_m, float(cap))

        self.coverage_area = float(max(radius_m, 1.0))
        return self.coverage_area

    def find_distance_for_path_loss(self, path_loss_dB, frequency_hz):
        """Invert pathloss model via binary search."""
        d_min, d_max = 1.0, 10000.0
        tol = 0.1
        d_mid = 0.0
        for _ in range(40):
            d_mid = 0.5 * (d_min + d_max)
            PL_mid = self.calculate_path_loss(d_mid, frequency_hz)
            if abs(PL_mid - path_loss_dB) < tol:
                return d_mid
            if PL_mid < path_loss_dB:
                d_min = d_mid
            else:
                d_max = d_mid
        return d_mid

    def assign_channels(self, channels):
        self.assigned_channels = list(channels)
        for ch in self.assigned_channels:
            ch.base_station = self

    def clear_assigned_channels(self):
        for ch in self.assigned_channels:
            ch.base_station = None
            ch.users = []
        self.assigned_channels = []
        self.per_channel_power = {}

    def find_available_channel(self):
        """Find a free (unoccupied) channel, if any."""
        for ch in self.assigned_channels:
            if len(ch.users) == 0:
                return ch
        return None


class User:
    def __init__(self, id, location_xy, velocity_xy, demand_bits=1e6):
        self.id = int(id)
        self.location = np.array(location_xy, dtype=float)
        self.velocity = np.array(velocity_xy, dtype=float)
        self.height = 1.5

        # radio link properties
        self.channel = []
        self.channel_SINR = []
        self.SINR = -100.0
        self.data_rate = 0.0  # instantaneous achievable rate (Mbps)
        self.demand = float(demand_bits)  # "required" rate (Mbps-like scale)
        self.mimo_layers = []

        # service class
        self.service_class = "infotainment"

        # task model (set properly by generate_task())
        self.task_type = "light"
        self.task_cycles = 0.0
        self.task_input_Mbit = 0.0
        self.task_offload_mandatory = False

        # mobility
        self.speed = float(np.linalg.norm(self.velocity))
        self.waypoint = None
        self.pause_time = 0
        self.dir_axis = None
        self.dir_sign = 1
        self.next_intersection = None

    def clear_channel(self):
        self.channel = []
        self.channel_SINR = []
        self.SINR = -100.0
        self.mimo_layers = []
        self.data_rate = 0.0

    def calculate_data_rate(self):
        """Aggregate rate across all assigned channels with MIMO."""
        self.data_rate = 0.0
        self.mimo_layers = []

        for i, ch in enumerate(self.channel):
            bw_eff = ch.bandwidth * NR_OVERHEAD
            SINR_dB = self.channel_SINR[i]
            max_rank = MIMO_MAX_RANK[ch.base_station.type_bs]

            L, total_se = mimo_rank_and_total_se(
                SINR_dB, max_rank, gap_db=SNR_GAP_DB, max_se=MAX_SE
            )
            dr_Mbps = (bw_eff * total_se) / 1e6
            self.mimo_layers.append(L)
            self.data_rate += dr_Mbps

    def calculate_demand_from_rng(self, rng):
        """Random traffic demand model."""
        if getattr(self, "service_class", "infotainment") == "safety":
            base_mbps = rng.uniform(0.5, 2.0)
        else:
            app_types = {"video": 5.0, "gaming": 10.0, "browsing": 2.0}
            app = rng.choice(list(app_types.keys()))
            base_mbps = app_types[app] * (1.0 + rng.uniform(0.0, 0.5))
        self.demand = float(base_mbps)

    def generate_task(self, rng, heavy_ratio, ue_cpu,
                      heavy_cyc_range, heavy_data_range,
                      light_cyc_range, light_data_range):
        """
        Assign a compute task to this user.

        heavy_ratio : fraction of users that get heavy (offload-mandatory) tasks
        ue_cpu      : UE local compute budget (cycles/step)
        *_range     : (lo, hi) for task cycles / input-data Mbit
        """
        if rng.random() < heavy_ratio:
            self.task_type = "heavy"    # MUST offload
            self.task_cycles = float(rng.uniform(*heavy_cyc_range))
            self.task_input_Mbit = float(rng.uniform(*heavy_data_range))
        else:
            self.task_type = "light"    # can run locally
            self.task_cycles = float(rng.uniform(*light_cyc_range))
            self.task_input_Mbit = float(rng.uniform(*light_data_range))
        self.task_offload_mandatory = (self.task_cycles > ue_cpu)

    def calculate_latency_ms(self, num_users_on_channel: float = None):
        """Very simplified base latency model (communication-centric)."""
        if not self.channel or self.data_rate <= 0:
            return 1000.0

        avg_d = np.mean(
            [
                np.linalg.norm(self.location - ch.base_station.location)
                for ch in self.channel
            ]
        )
        prop_delay_ms = (avg_d / 3e8) * 1e3
        proc_delay = 1.0
        sched_delay = 1.0

        if num_users_on_channel is None:
            num_users_on_channel = (
                np.mean([len(ch.users) for ch in self.channel])
                if self.channel
                else 1.0
            )

        queue_delay = 1.0 + num_users_on_channel / (self.data_rate + 1e-6)

        return float(
            np.clip(
                prop_delay_ms + proc_delay + sched_delay + queue_delay,
                0.0,
                1000.0,
            )
        )


# -----------------------
# Main environment class
# -----------------------
class MultiAgentMobileNetwork:
    """Multi-agent cellular + MEC environment (Gymnasium-style MA API)."""

    metadata = {"render_modes": ["human"], "render_fps": 30}

    def __init__(
        self,
        num_base_stations=4,
        num_users=80,
        num_channels_per_carrier=50,
        area_size=2000.0,
        bs_loc=None,
        max_steps=200,
        mobility_model="manhattan",
        seed=42,
        step_duration_s=1.0,
        deadline_ms=100.0,
        safety_traffic_ratio=0.3,
    ):
        super().__init__()

        # RNGs
        self.seed(seed)

        # topology / sim parameters
        self.num_base_stations = int(num_base_stations)
        self.num_users = int(num_users)
        self.num_channels_per_carrier = int(num_channels_per_carrier)
        self.area_size = float(area_size)
        self.max_steps = int(max_steps)
        self.mobility_model = mobility_model

        # time / QoS
        self.step_duration_s = float(step_duration_s)
        self.deadline_ms = float(deadline_ms)
        self.safety_traffic_ratio = float(
            np.clip(safety_traffic_ratio, 0.0, 1.0)
        )

        # radio parameters
        self.ma_transmission_power = 40000.0  # mW (40 W)
        self.max_ma_channels = int(num_channels_per_carrier)
        self.macro_carrier_frequencies = (
            [3.5e9] if MACRO_REUSE_ONE else [3.4e9, 3.5e9, 3.6e9, 3.7e9]
        )
        self.macro_channel_bw = 180e3  # Hz

        # MEC / compute parameters
        self.mec_cpu_capacity_cycles = 50e9
        self.cycles_per_Mbit = 5e7
        self.cpu_kappa = 1e-27
        self.max_user_demand_Mbps = 10.0

        # ---- Task-model parameters (heterogeneous compute requirements) ----
        # Each user generates a task per step with compute_cycles & input_data.
        # "heavy" tasks EXCEED local UE capacity -> MUST offload to MEC.
        # "light" tasks fit on UE -> can run locally or be offloaded.
        self.heavy_task_ratio = 0.70          # 70% users get heavy tasks
        self.ue_local_cpu_cycles = 0.5e9      # UE compute budget per step (0.5 GHz)
        # Heavy tasks: 1-5 Gcycles  (well above UE capacity)
        self.heavy_task_cycles_range = (0.5e9, 2.5e9)
        self.heavy_task_data_range = (2.0, 8.0)     # input data in Mbit
        # Light tasks: 0.05-0.4 Gcycles (fit on UE)
        self.light_task_cycles_range = (0.05e9, 0.4e9)
        self.light_task_data_range = (0.2, 1.5)      # input data in Mbit
        # Penalty: attempting to run a heavy task locally -> huge delay
        self.local_heavy_penalty_ms = 4000.0

        # reward weights
        self.reward_weights = SimpleNamespace(
            w_lat=0.2,
            w_thr=0.3,
            w_dead=0.2,
            w_qoe=0.3,
            w_eng=0.05,
            w_block=0.2,
            w_fair=0.1,
        )

        # objects
        self.users = []
        self.base_stations = []

        # BS placement
        if bs_loc is None:
            bs_loc = self._default_bs_locations(
                self.num_base_stations, self.area_size
            )
        assert len(bs_loc) >= self.num_base_stations

        for i in range(self.num_base_stations):
            bs = BaseStation(
                i,
                self.ma_transmission_power,
                30.0,
                bs_loc[i],
                type_bs="Ma",
                mec_cpu_capacity_cycles=self.mec_cpu_capacity_cycles,
            )
            self.base_stations.append(bs)

        # build macro channels
        self.macro_channels = []
        ch_id = 0
        for f in self.macro_carrier_frequencies:
            for _ in range(self.num_channels_per_carrier):
                self.macro_channels.append(
                    Channel(
                        ch_id,
                        f,
                        self.macro_channel_bw,
                        noise_figure_db=7.0,
                    )
                )
                ch_id += 1

        # spawn users
        rng = self.np_random
        for u_id in range(self.num_users):
            if self.mobility_model == "manhattan":
                loc, vel = self._spawn_on_grid()
            else:
                loc = rng.uniform(0, self.area_size, 2)
                vel = rng.uniform(-5.0, 5.0, 2)

            u = User(u_id, loc, vel)
            svc = (
                "safety"
                if rng.random() < self.safety_traffic_ratio
                else "infotainment"
            )
            u.service_class = svc
            u.calculate_demand_from_rng(rng)
            u.generate_task(
                rng, self.heavy_task_ratio, self.ue_local_cpu_cycles,
                self.heavy_task_cycles_range, self.heavy_task_data_range,
                self.light_task_cycles_range, self.light_task_data_range,
            )
            self.users.append(u)

            if self.mobility_model == "manhattan":
                self._init_user_manhattan(u)

        # multi-agent API ids
        self.agents = [f"agent_{i}" for i in range(self.num_base_stations)]
        self.possible_agents = list(self.agents)
        self._agent_ids = set(self.agents)

        # action: (power_frac, channel_frac, offload_frac, cpu_frac)
        self.action_spaces = {
            a: gym.spaces.Box(
                low=np.array([0.0, 0.0, 0.0, 0.0], dtype=np.float32),
                high=np.array([1.0, 1.0, 1.0, 1.0], dtype=np.float32),
                dtype=np.float32,
            )
            for a in self.agents
        }

        # 19-D observation
        obs_dim = len(vars(OBS_IDX))
        self.observation_spaces = {
            a: gym.spaces.Box(
                low=0.0, high=1.0, shape=(obs_dim,), dtype=np.float32
            )
            for a in self.agents
        }

        # simulation state
        self.num_steps = 0
        self.current_episode_reward = 0.0
        self.assigned_channels = {}
        self.bs_carrier_frequency = {}

        self._assign_frequency_subsets()
        self.reset_user_info()

        # normalization constants
        self.energy_normalization_J = (
            self.num_base_stations
            * self.ma_transmission_power
            * 1e-3
            * self.step_duration_s
        )
        self.throughput_normalization_Mbps = (
            self.num_users * self.max_user_demand_Mbps
        )

        self.fig = None
        self._panel_axes = None

        # shared spaces for RLlib
        first_agent = self.agents[0]
        self.observation_space = self.observation_spaces[first_agent]
        self.action_space = self.action_spaces[first_agent]

    # -------------
    # RNG helpers
    # -------------
    def seed(self, seed=None):
        if seed is None:
            seed = random.randrange(2**31 - 1)
        seed_int = int(seed) & 0xFFFFFFFF
        self.np_random, _ = seeding.np_random(seed_int)
        random.seed(seed_int)
        np.random.seed(seed_int)
        return [seed_int]

    # -------------
    # Topology helpers
    # -------------
    def _default_bs_locations(self, n, L):
        """Simple grid-based macro deployment."""
        coords = []
        grid = int(math.ceil(math.sqrt(n)))
        xs = np.linspace(0.2 * L, 0.8 * L, grid)
        ys = np.linspace(0.2 * L, 0.8 * L, grid)
        for x in xs:
            for y in ys:
                coords.append((float(x), float(y)))
                if len(coords) >= n:
                    return coords[:n]
        return coords[:n]

    def _assign_frequency_subsets(self):
        """Assign each BS to a carrier (reuse pattern)."""
        idx = 0
        for bs in self.base_stations:
            if MACRO_REUSE_ONE:
                self.bs_carrier_frequency[bs.id] = (
                    self.macro_carrier_frequencies[0]
                )
            else:
                self.bs_carrier_frequency[bs.id] = (
                    self.macro_carrier_frequencies[
                        idx % len(self.macro_carrier_frequencies)
                    ]
                )
                idx += 1

    # -------------
    # Manhattan mobility
    # -------------
    def _build_road_grid(self):
        L = self.area_size
        spacing = max(50.0, float(250.0))
        self.grid_xs = np.arange(0.0, L + 1e-9, spacing)
        self.grid_ys = np.arange(0.0, L + 1e-9, spacing)

    def _spawn_on_grid(self):
        if not hasattr(self, "grid_xs"):
            self._build_road_grid()

        L = self.area_size
        if self.np_random.random() < 0.5:
            # horizontal road
            y = float(self.np_random.choice(self.grid_ys))
            x = float(self.np_random.uniform(0, L))
            dir_axis, dir_sign = "x", (1 if self.np_random.random() < 0.5 else -1)
        else:
            # vertical road
            x = float(self.np_random.choice(self.grid_xs))
            y = float(self.np_random.uniform(0, L))
            dir_axis, dir_sign = "y", (1 if self.np_random.random() < 0.5 else -1)

        speed = float(max(1.0, self.np_random.normal(12.0, 3.0)))
        if dir_axis == "x":
            vel = np.array([dir_sign * speed, 0.0], dtype=float)
        else:
            vel = np.array([0.0, dir_sign * speed], dtype=float)

        return np.array([x, y], dtype=float), vel

    def _init_user_manhattan(self, u: User):
        if not hasattr(self, "grid_xs"):
            self._build_road_grid()

        u.location = self._snap_to_grid(u.location)
        if abs(u.velocity[0]) >= abs(u.velocity[1]):
            u.dir_axis = "x"
            u.dir_sign = 1 if u.velocity[0] >= 0 else -1
        else:
            u.dir_axis = "y"
            u.dir_sign = 1 if u.velocity[1] >= 0 else -1

        u.speed = float(max(1.0, np.linalg.norm(u.velocity)))

        if u.dir_axis == "x":
            candidates = (
                self.grid_xs[self.grid_xs > u.location[0]]
                if u.dir_sign > 0
                else self.grid_xs[self.grid_xs < u.location[0]]
            )
            if u.dir_sign > 0:
                coord = candidates.min() if candidates.size else self.area_size
            else:
                coord = candidates.max() if candidates.size else 0.0
            u.next_intersection = np.array(
                [coord, self._snap_to_grid(u.location)[1]], dtype=float
            )
        else:
            candidates = (
                self.grid_ys[self.grid_ys > u.location[1]]
                if u.dir_sign > 0
                else self.grid_ys[self.grid_ys < u.location[1]]
            )
            if u.dir_sign > 0:
                coord = candidates.min() if candidates.size else self.area_size
            else:
                coord = candidates.max() if candidates.size else 0.0
            u.next_intersection = np.array(
                [self._snap_to_grid(u.location)[0], coord], dtype=float
            )
        u.pause_time = 0

    def _snap_to_grid(self, p):
        if not hasattr(self, "grid_xs"):
            self._build_road_grid()
        x = self.grid_xs[np.argmin(np.abs(self.grid_xs - p[0]))]
        y = self.grid_ys[np.argmin(np.abs(self.grid_ys - p[1]))]
        return np.array([x, y], dtype=float)

    def _advance_user_manhattan(self, u: User):
        if u.pause_time > 0:
            u.pause_time -= 1
            return

        delta = u.next_intersection - u.location
        dist = float(np.linalg.norm(delta))
        step = min(dist, u.speed)
        if dist > 1e-9:
            u.location += (delta / dist) * step

        # reached intersection or step exhausted
        if (
            np.linalg.norm(u.location - u.next_intersection) <= 1e-6
            or step == dist
        ):
            # occasional pause
            if self.np_random.random() < 0.15:
                u.pause_time = int(self.np_random.integers(0, 4))

            # turn decisions
            r = self.np_random.random()
            if r < 0.25:
                u.dir_axis = "y" if u.dir_axis == "x" else "x"
                u.dir_sign = -u.dir_sign
            elif r < 0.5:
                u.dir_axis = "y" if u.dir_axis == "x" else "x"

            u.speed = float(max(1.0, self.np_random.normal(12.0, 3.0)))

            if u.dir_axis == "x":
                if u.dir_sign > 0:
                    candidates = self.grid_xs[self.grid_xs > u.location[0]]
                    x_next = candidates.min() if candidates.size > 0 else self.area_size
                else:
                    candidates = self.grid_xs[self.grid_xs < u.location[0]]
                    x_next = candidates.max() if candidates.size > 0 else 0.0
                u.next_intersection = np.array(
                    [x_next, self._snap_to_grid(u.location)[1]], dtype=float
                )
                u.velocity = np.array([u.dir_sign * u.speed, 0.0], dtype=float)
            else:
                if u.dir_sign > 0:
                    candidates = self.grid_ys[self.grid_ys > u.location[1]]
                    y_next = candidates.min() if candidates.size > 0 else self.area_size
                else:
                    candidates = self.grid_ys[self.grid_ys < u.location[1]]
                    y_next = candidates.max() if candidates.size > 0 else 0.0
                u.next_intersection = np.array(
                    [self._snap_to_grid(u.location)[0], y_next], dtype=float
                )
                u.velocity = np.array([0.0, u.dir_sign * u.speed], dtype=float)

    # -------------
    # User / BS state helpers
    # -------------
    def reset_user_info(self):
        """Per-user association / channel bookkeeping."""
        self.user_info = {
            u.id: {
                "user": u.id,
                "ma_assigned_channel": [],
                "ma_base_station": [],
                "ma_base_station_location": [],
            }
            for u in self.users
        }

    def assign_channels_on_demand(self):
        """UE association and 1-channel assignment per UE to its best BS."""
        for u in self.users:
            u.clear_channel()

        for bs in self.base_stations:
            for ch in bs.assigned_channels:
                ch.users = []

        for u in self.users:
            best_bs, _ = self._best_bs_in_cov(u, type_filter="Ma")
            if best_bs:
                ch = best_bs.find_available_channel()
                if ch:
                    u.channel.append(ch)
                    ch.users.append(u)
                    info = self.user_info[u.id]
                    info["ma_assigned_channel"].append(ch.id)
                    info["ma_base_station"].append(best_bs.id)
                    info["ma_base_station_location"].append(
                        best_bs.location.copy()
                    )

    def _per_channel_tx_power_mW(self, bs: BaseStation):
        if bs.per_channel_power:
            vals = list(bs.per_channel_power.values())
            return float(np.mean(vals))
        n = max(1, len(bs.assigned_channels))
        return bs.transmit_power / n

    def _noise_mW_for(self, bs: BaseStation):
        """Noise (mW) for BS based on reference channel bandwidth."""
        if bs.assigned_channels:
            return bs.assigned_channels[0].calculate_noise_power() * 1e3
        # fallback
        bw_hz = self.macro_channel_bw
        k = 1.380649e-23
        T = 293.15
        NF = 10 ** (7 / 10)
        return k * T * bw_hz * NF * 1e3

    def _est_rate_one_channel_Mbps(self, u: User, bs: BaseStation):
        """Estimated per-channel rate for association decisions."""
        if not bs.assigned_channels:
            return 0.0

        f = self.bs_carrier_frequency[bs.id]
        d = float(np.linalg.norm(u.location - bs.location))
        PL_dB = bs.calculate_path_loss(d, f)

        n_ch = max(1, len(bs.assigned_channels))
        p_ch = bs.transmit_power / n_ch

        g = BEAM_GAIN_DB[bs.type_bs]
        g_tx = 10 ** (g["tx_main"] / 10.0)
        g_rx = 10 ** (g["rx"] / 10.0)

        sig_mW = p_ch * g_tx * g_rx / (10.0 ** (PL_dB / 10.0))
        noise_mW = self._noise_mW_for(bs)

        # ignore inter-cell interference in this quick estimate
        SINR = sig_mW / max(noise_mW, 1e-12)
        SINR_dB = 10.0 * np.log10(max(SINR, 1e-12))

        bw = bs.assigned_channels[0].bandwidth * NR_OVERHEAD
        _, total_se = mimo_rank_and_total_se(
            SINR_dB, MIMO_MAX_RANK[bs.type_bs], gap_db=SNR_GAP_DB, max_se=MAX_SE
        )
        return (bw * total_se) / 1e6

    def _best_bs_in_cov(self, u: User, type_filter=None):
        """Select BS with best rate*fairness score among those covering user."""
        best = None
        best_score = 0.0

        for bs in self.base_stations:
            if type_filter is not None and bs.type_bs != type_filter:
                continue
            if not bs.assigned_channels:
                continue

            d = np.linalg.norm(u.location - bs.location)
            if d > bs.coverage_area:
                continue

            r = self._est_rate_one_channel_Mbps(u, bs)
            load = (
                sum(1 for c in bs.assigned_channels if len(c.users) > 0)
                / max(1, len(bs.assigned_channels))
            )
            fairness = 1.0 - 0.5 * load
            score = r * fairness
            if score > best_score:
                best_score = score
                best = bs

        return best, best_score

    def _estimate_interference_mW(self, u: User, f, exclude_bs: BaseStation):
        """Downlink inter-cell interference (mW) from co-channel BSs."""
        co_bs = [
            b
            for b in self.base_stations
            if b is not exclude_bs and self.bs_carrier_frequency[b.id] == f
        ]
        I = 0.0
        g_rx_int = 10 ** (UE_INTERF_RX_DB / 10.0)

        for bi in co_bs:
            if not bi.assigned_channels:
                continue

            p_i = self._per_channel_tx_power_mW(bi)
            d_i = np.linalg.norm(u.location - bi.location)
            PL_i = bi.calculate_path_loss(d_i, f)

            gi = BEAM_GAIN_DB[bi.type_bs]
            g_tx_i = 10 ** (gi["tx_side"] / 10.0)

            users_in_cov_bi = [
                uu
                for uu in self.users
                if np.linalg.norm(uu.location - bi.location)
                <= bi.coverage_area
            ]
            util = min(
                1.0, len(users_in_cov_bi) / max(1, len(bi.assigned_channels))
            )

            I += (
                util
                * p_i
                * g_tx_i
                * g_rx_int
                / (10.0 ** (PL_i / 10.0))
            )

        return I

    # -------------
    # Water-filling power allocation
    # -------------
    @staticmethod
    def _waterfill(P_total, h_list, n_list, p_floor_list=None, tol=1e-6, max_it=200):
        """Classical water-filling with optional minimum powers (p_floor_list)."""
        K = len(h_list)
        if K == 0:
            return []

        h = np.asarray(h_list, dtype=float)
        n = np.asarray(n_list, dtype=float)
        p_floor = (
            np.zeros(K, dtype=float)
            if p_floor_list is None
            else np.asarray(p_floor_list, dtype=float)
        )

        mask = h > 0
        if not np.any(mask):
            return [0.0] * K

        p_floor_sum = float(np.sum(np.maximum(p_floor, 0.0)))
        if p_floor_sum > P_total and p_floor_sum > 0:
            scaled = P_total * (p_floor / p_floor_sum)
            return list(np.maximum(scaled, 0.0))

        def alloc(lmbd):
            base = 1.0 / max(lmbd, 1e-18)
            out = np.maximum(p_floor, base - n / np.maximum(h, 1e-18))
            return np.maximum(out, 0.0)

        lo, hi = 0.0, 1e12
        for _ in range(max_it):
            mid = 0.5 * (lo + hi)
            p = alloc(mid)
            s = float(np.sum(p))
            if abs(s - P_total) <= tol:
                return list(np.maximum(p, 0.0))
            if s > P_total:
                lo = mid
            else:
                hi = mid

        return list(np.maximum(alloc(hi), 0.0))

    # -------------
    # Core RL API (Gymnasium-style MA)
    # -------------
    def step(self, action_dict):
        """
        Gymnasium-style multi-agent step.

        Returns:
            obs (dict): agent_id -> observation
            rewards (dict): agent_id -> reward (float)
            terminateds (dict): agent_id -> bool, plus "__all__"
            truncateds (dict): agent_id -> bool, plus "__all__"
            infos (dict): agent_id -> info dict
        """
        start_wall = time.time()
        self.num_steps += 1

        # --------- parse / clip actions ----------
        for agent in self.agents:
            if agent not in action_dict:
                action_dict[agent] = np.array(
                    [0.5, 0.5, 0.5, 0.5], dtype=float
                )
            action_dict[agent] = np.clip(
                np.array(action_dict[agent], dtype=float),
                0.0,
                1.0,
            )

        # --------- traffic demand & task update ----------
        for u in self.users:
            if self.np_random.random() < 0.05:
                u.calculate_demand_from_rng(self.np_random)
            # Re-generate task every step (new task arrival each TTI)
            u.generate_task(
                self.np_random, self.heavy_task_ratio, self.ue_local_cpu_cycles,
                self.heavy_task_cycles_range, self.heavy_task_data_range,
                self.light_task_cycles_range, self.light_task_data_range,
            )

        # --------- clear previous associations & channel assignments ----------
        for u in self.users:
            u.clear_channel()

        for bs in self.base_stations:
            bs.clear_assigned_channels()
            # keep MEC queues across steps (do not reset)

        for ch in self.macro_channels:
            ch.users = []
            ch.base_station = None

        self.assigned_channels.clear()
        self.reset_user_info()

        # --------- resource allocation per BS: power, channels, offload, CPU ----------
        for i, bs in enumerate(self.base_stations):
            agent = f"agent_{i}"
            power_frac, channel_frac, offload_frac, cpu_frac = action_dict[
                agent
            ]

            # power allocation
            bs.transmit_power = float(
                np.clip(power_frac, 0.0, 1.0)
            ) * self.ma_transmission_power

            # channel allocation
            max_cap = int(self.max_ma_channels)
            req_ch = int(
                np.rint(
                    float(np.clip(channel_frac, 0.0, 1.0)) * max_cap
                )
            )

            if req_ch == 0 and bs.transmit_power > 1e-9:
                req_ch = 1

            freq = self.bs_carrier_frequency[bs.id]
            avail = [
                c
                for c in self.macro_channels
                if c.frequency == freq and c.base_station is None
            ]
            req_ch = min(len(avail), req_ch)

            if req_ch > 0:
                chosen = avail[:req_ch]
                bs.assign_channels(chosen)
                for ch in chosen:
                    self.assigned_channels[ch] = bs.id

            # MEC-related controls
            bs.offload_frac = float(np.clip(offload_frac, 0.0, 1.0))
            bs.cpu_util_frac = float(np.clip(cpu_frac, 0.0, 1.0))
            bs.last_cpu_used = bs.cpu_util_frac * bs.mec_cpu_capacity

            bs.update_coverage_area_from_power(bs.transmit_power, freq)

        # --------- user association and 1ch-per-user assignment ----------
        self.assign_channels_on_demand()

        # --------- per-BS water-filling ----------
        for bs in self.base_stations:
            bs.per_channel_power = {}
            ch_act = []
            H = []
            N = []
            floors = []

            for ch in bs.assigned_channels:
                if not ch.users:
                    continue

                # simple single-UE-per-channel view (first user)
                u = ch.users[0]
                f = ch.frequency
                d = float(np.linalg.norm(u.location - bs.location))
                PL_dB = bs.calculate_path_loss(d, f)

                g = BEAM_GAIN_DB[bs.type_bs]
                h_linear = (
                    10 ** (g["tx_main"] / 10.0)
                    * 10 ** (g["rx"] / 10.0)
                ) / (10.0 ** (PL_dB / 10.0))

                noise_mW = ch.calculate_noise_power() * 1e3
                I_mW = self._estimate_interference_mW(u, f, bs)

                prio = float(
                    np.clip(
                        0.5 + (u.demand / self.max_user_demand_Mbps),
                        0.5,
                        2.0,
                    )
                )
                N_eff = (noise_mW + I_mW) / prio

                ch_act.append(ch)
                H.append(h_linear)
                N.append(N_eff)
                floors.append(0.0)

            if ch_act:
                P_total = float(bs.transmit_power)
                p_list = self._waterfill(
                    P_total,
                    H,
                    N,
                    p_floor_list=floors,
                    tol=1e-6,
                    max_it=120,
                )
                for ch, p in zip(ch_act, p_list):
                    bs.per_channel_power[ch.id] = float(max(p, 0.0))
            else:
                bs.per_channel_power = {}

            f = self.bs_carrier_frequency[bs.id]
            bs.update_coverage_area_from_power(bs.transmit_power, f)

        # --------- SINR & rates ----------
        for u in self.users:
            self.calculate_SINR(u)
            u.calculate_data_rate()

        # --------- MEC queue dynamics & compute delays (task-aware) ----------
        bs_to_users = defaultdict(list)
        for u in self.users:
            if u.channel:
                bs = u.channel[0].base_station
                if bs is not None:
                    bs_to_users[bs.id].append(u)

        user_comp_delay_ms = {u.id: 0.0 for u in self.users}

        for bs in self.base_stations:
            assoc_users = bs_to_users.get(bs.id, [])

            off_frac = float(np.clip(bs.offload_frac, 0.0, 1.0))
            cpu_frac = float(np.clip(bs.cpu_util_frac, 0.0, 1.0))
            F_max = bs.mec_cpu_capacity
            F_used = cpu_frac * F_max
            bs.last_cpu_used = F_used

            # ---- Partition users into offloaded vs local ----
            offloaded = []       # (user, cycles) pairs sent to MEC
            total_new_cycles = 0.0

            for u in assoc_users:
                C = u.task_cycles  # per-user task compute requirement

                if u.task_offload_mandatory:
                    # Heavy task: MUST offload regardless of off_frac
                    offloaded.append((u, C))
                    total_new_cycles += C
                else:
                    # Light task: agent's off_frac decides
                    if self.np_random.random() < off_frac:
                        offloaded.append((u, C))
                        total_new_cycles += C
                    else:
                        # Run locally on UE — fast for light tasks
                        local_delay_s = C / max(self.ue_local_cpu_cycles, 1e-9)
                        user_comp_delay_ms[u.id] += local_delay_s * 1000.0

            # ---- MEC queue update ----
            q_prev = bs.mec_queue_cycles
            mu_cycles = F_used * self.step_duration_s
            q_after_serv = max(q_prev - mu_cycles, 0.0)
            q_next = q_after_serv + total_new_cycles

            if F_used > 0.0:
                queue_delay_s = q_after_serv / F_used
            else:
                queue_delay_s = (
                    self.deadline_ms / 1000.0 * 10.0
                )

            n_off = len(offloaded)
            for (u, C_cycles) in offloaded:
                if F_used > 0.0 and n_off > 0:
                    f_share = F_used / n_off
                    T_proc_s = C_cycles / max(f_share, 1e-9)
                    T_queue_s = queue_delay_s
                else:
                    T_proc_s = self.deadline_ms / 1000.0 * 10.0
                    T_queue_s = self.deadline_ms / 1000.0 * 10.0

                comp_ms = (T_proc_s + T_queue_s) * 1000.0
                comp_ms = float(np.clip(comp_ms, 0.0, 5000.0))
                user_comp_delay_ms[u.id] += comp_ms

            bs.mec_queue_cycles = float(q_next)

        # ---------------- BS-level throughput for fairness across BSs ----------------
        bs_served = []
        for bs in self.base_stations:
            assoc_users = bs_to_users.get(bs.id, [])
            local_served = sum(
                min(u.data_rate, u.demand) for u in assoc_users
            )
            bs_served.append(local_served)
        bs_served_arr = np.asarray(bs_served, dtype=float)
        if np.any(bs_served_arr > 0):
            jain_num_bs = float(np.sum(bs_served_arr) ** 2)
            jain_den_bs = float(
                len(bs_served_arr) * np.sum(bs_served_arr**2) + 1e-9
            )
            jain_fairness_bs = float(jain_num_bs / jain_den_bs)
        else:
            jain_fairness_bs = 0.0

        # --------- QoE metrics: throughput, latency, energy, fairness ----------
        served_rates = []
        latencies = []
        qoe_list = []
        deadline_hits = 0
        deadline_candidates = 0

        svc_stats = {
            "safety": {
                "served_rates": [],
                "latencies": [],
                "qoes": [],
                "deadline_hits": 0,
                "deadline_candidates": 0,
            },
            "infotainment": {
                "served_rates": [],
                "latencies": [],
                "qoes": [],
                "deadline_hits": 0,
                "deadline_candidates": 0,
            },
        }

        for u in self.users:
            svc = getattr(u, "service_class", "infotainment")

            served = min(u.data_rate, u.demand)
            served_rates.append(served)

            bucket = svc_stats.get(svc, None)
            if bucket is not None:
                bucket["served_rates"].append(served)

            base_lat = u.calculate_latency_ms()
            lat = base_lat + user_comp_delay_ms.get(u.id, 0.0)
            latencies.append(lat)
            if bucket is not None:
                bucket["latencies"].append(lat)

            if u.demand > 0:
                deadline_candidates += 1
                if lat <= self.deadline_ms:
                    deadline_hits += 1

                if bucket is not None:
                    bucket["deadline_candidates"] += 1
                    if lat <= self.deadline_ms:
                        bucket["deadline_hits"] += 1

            if u.demand > 0:
                thr_norm = np.clip(served / u.demand, 0.0, 1.0)
            else:
                thr_norm = 0.0
            if lat <= self.deadline_ms:
                lat_factor = 1.0
            else:
                lat_factor = max(
                    0.0,
                    1.0 - (lat - self.deadline_ms) / (5 * self.deadline_ms),
                )
            qoe = 0.5 * thr_norm + 0.5 * lat_factor
            qoe_clipped = float(np.clip(qoe, 0.0, 1.0))
            qoe_list.append(qoe_clipped)
            if bucket is not None:
                bucket["qoes"].append(qoe_clipped)

        # throughput metrics (Mbps)
        total_throughput_Mbps = float(np.sum(served_rates))
        avg_throughput_Mbps = float(
            total_throughput_Mbps / max(1, self.num_users)
        )

        # latency metrics
        if latencies:
            avg_latency_ms = float(np.mean(latencies))
            p95_latency_ms = float(np.percentile(latencies, 95))
        else:
            avg_latency_ms = 0.0
            p95_latency_ms = 0.0

        # deadline satisfaction
        if deadline_candidates > 0:
            deadline_satisfaction = float(
                deadline_hits / max(1, deadline_candidates)
            )
        else:
            deadline_satisfaction = 0.0

        # fairness (Jain's index) over users (for logging only)
        served_arr = np.asarray(served_rates, dtype=float)
        if np.any(served_arr > 0):
            jain_num_users = float(np.sum(served_arr) ** 2)
            jain_den_users = float(
                len(served_arr) * np.sum(served_arr**2) + 1e-9
            )
            jain_fairness_users = float(jain_num_users / jain_den_users)
        else:
            jain_fairness_users = 0.0

        # Use BS-level fairness in the reward
        jain_fairness = jain_fairness_bs

        # energy metrics
        total_radio_power_mW = float(
            np.sum([bs.transmit_power for bs in self.base_stations])
        )
        total_cpu_power_W = float(
            np.sum(
                [self.cpu_kappa * (bs.last_cpu_used**3) for bs in self.base_stations]
            )
        )
        step_energy_J = (
            total_radio_power_mW * 1e-3 * self.step_duration_s
            + total_cpu_power_W * self.step_duration_s
        )

        satisfied_tasks = deadline_hits
        if satisfied_tasks > 0:
            energy_per_task_J = float(step_energy_J / satisfied_tasks)
        else:
            energy_per_task_J = 0.0

        # blocking rate: users without any channel
        blocked_users = [u for u in self.users if not u.channel]
        blocking_rate = float(len(blocked_users) / max(1, self.num_users))

        # QoE statistics
        if qoe_list:
            avg_qoe = float(np.mean(qoe_list))
        else:
            avg_qoe = 0.0

        # ---------------- service-class metrics (for ITS-oriented analysis) ----------------
        def _svc_metrics(bucket):
            if not bucket["served_rates"]:
                return {
                    "avg_throughput_Mbps": 0.0,
                    "avg_latency_ms": 0.0,
                    "p95_latency_ms": 0.0,
                    "deadline_satisfaction": 0.0,
                    "avg_qoe": 0.0,
                }
            s_rates = np.asarray(bucket["served_rates"], dtype=float)
            lats = np.asarray(bucket["latencies"], dtype=float)
            qoes = np.asarray(bucket["qoes"], dtype=float)

            if lats.size > 0:
                avg_lat = float(np.mean(lats))
                p95_lat = float(np.percentile(lats, 95))
            else:
                avg_lat = 0.0
                p95_lat = 0.0

            if s_rates.size > 0:
                avg_tput = float(np.mean(s_rates))
            else:
                avg_tput = 0.0

            if bucket["deadline_candidates"] > 0:
                ds = float(
                    bucket["deadline_hits"]
                    / max(1, bucket["deadline_candidates"])
                )
            else:
                ds = 0.0

            if qoes.size > 0:
                avg_qoe_svc = float(np.mean(qoes))
            else:
                avg_qoe_svc = 0.0

            return {
                "avg_throughput_Mbps": avg_tput,
                "avg_latency_ms": avg_lat,
                "p95_latency_ms": p95_lat,
                "deadline_satisfaction": ds,
                "avg_qoe": avg_qoe_svc,
            }

        svc_safety = _svc_metrics(svc_stats["safety"])
        svc_infot = _svc_metrics(svc_stats["infotainment"])

        # ---------------- Normalized components (for logging) ----------------
        U_norm = float(
            np.clip(
                total_throughput_Mbps
                / max(1e-9, self.throughput_normalization_Mbps),
                0.0,
                1.0,
            )
        )

        if latencies:
            violations = [
                max(lat - self.deadline_ms, 0.0)
                / (5.0 * max(1.0, self.deadline_ms))
                for lat in latencies
            ]
            D_norm = float(np.clip(np.mean(violations), 0.0, 1.0))
        else:
            D_norm = 0.0

        E_norm = float(
            np.clip(
                step_energy_J / max(1e-9, 2.0 * self.energy_normalization_J),
                0.0,
                1.0,
            )
        )

        # ------------- Joint latency + throughput reward ----------------
        latency_ref_ms = self.deadline_ms if self.deadline_ms > 0 else 100.0

        if latency_ref_ms > 0:
            L_mean = avg_latency_ms / latency_ref_ms
            L_p95 = p95_latency_ms / (1.5 * latency_ref_ms)
        else:
            L_mean = 0.0
            L_p95 = 0.0

        L_norm = float(np.clip(0.7 * L_mean + 0.3 * L_p95, 0.0, 1.0))

        T_norm = U_norm
        V_fair = 1.0 - jain_fairness

        w = self.reward_weights
        positive = (
            w.w_thr * T_norm
            + w.w_lat * (1.0 - D_norm)
            + w.w_dead * deadline_satisfaction
            + w.w_qoe * avg_qoe
        )
        negative = (
            w.w_eng * E_norm
            + w.w_block * blocking_rate
            + w.w_fair * V_fair
        )
        global_reward = float(np.clip(positive - negative, -1.0, 1.0))

        rewards = {agent: global_reward for agent in self.agents}

        scenario_type = "urban" if self.mobility_model == "manhattan" else "highway_like"

        # --------- per-BS infos ----------
        infos = {}
        association_fractions = []
        channel_rewards = []

        for i, bs in enumerate(self.base_stations):
            agent = f"agent_{i}"
            users_in_cov = [
                u
                for u in self.users
                if np.linalg.norm(u.location - bs.location)
                <= bs.coverage_area
            ]
            assoc_users = [
                u
                for u in users_in_cov
                if any(ch.base_station == bs for ch in u.channel)
            ]

            assoc_frac = (
                len(assoc_users) / max(1, len(users_in_cov))
                if users_in_cov
                else 0.0
            )
            association_fractions.append(assoc_frac)

            ch_num = max(1, len(bs.assigned_channels))
            usr_num = max(1, len(users_in_cov))
            channel_rewards.append(
                1.0 - abs(ch_num - usr_num) / (ch_num + usr_num)
            )

            local_served = sum(
                min(u.data_rate, u.demand) for u in assoc_users
            )
            local_demand = sum(u.demand for u in assoc_users) + 1e-9
            local_util = (
                local_served / local_demand if local_demand > 0 else 0.0
            )

            if assoc_users:
                loc_latencies = [
                    latencies[self.users.index(u)] for u in assoc_users
                ]
                loc_avg_lat_ms = float(np.mean(loc_latencies))
            else:
                loc_avg_lat_ms = 0.0

            infos[agent] = {
                "local_data_rate_Mbps": float(
                    sum(u.data_rate for u in assoc_users)
                ),
                "local_served_throughput_Mbps": float(local_served),
                "local_demand_Mbps": float(local_demand),
                "local_power_mW": float(bs.transmit_power),
                "local_channels": int(len(bs.assigned_channels)),
                "users_in_cov": int(len(users_in_cov)),
                "assoc_users": int(len(assoc_users)),
                "local_avg_latency_ms": loc_avg_lat_ms,
                "local_util": float(local_util),
                "local_mec_queue_cycles": float(bs.mec_queue_cycles),
                "local_cpu_used_cycles_per_s": float(bs.last_cpu_used),
                "local_offload_frac": float(bs.offload_frac),
                "local_cpu_util_frac": float(bs.cpu_util_frac),
            }

        if association_fractions:
            mean_assoc_frac = float(np.mean(association_fractions))
        else:
            mean_assoc_frac = 0.0

        if channel_rewards:
            mean_channel_reward = float(np.mean(channel_rewards))
        else:
            mean_channel_reward = 0.0

        global_info = {
            "total_throughput_Mbps": total_throughput_Mbps,
            "avg_throughput_Mbps": avg_throughput_Mbps,
            "avg_latency_ms": avg_latency_ms,
            "p95_latency_ms": p95_latency_ms,
            "deadline_satisfaction": deadline_satisfaction,
            "blocking_rate": blocking_rate,
            "avg_qoe": avg_qoe,
            "qoe_per_user": qoe_list,
            "total_radio_power_mW": total_radio_power_mW,
            "total_cpu_power_W": total_cpu_power_W,
            "step_energy_J": step_energy_J,
            "energy_per_task_J": energy_per_task_J,
            "jain_fairness": jain_fairness,
            "jain_fairness_bs": jain_fairness_bs,
            "jain_fairness_users": jain_fairness_users,
            "num_users": int(self.num_users),
            "num_base_stations": int(self.num_base_stations),
            "mean_assoc_frac": mean_assoc_frac,
            "mean_channel_reward": mean_channel_reward,
            "env_step_walltime_ms": float(
                (time.time() - start_wall) * 1e3
            ),
            "U_norm": U_norm,
            "D_norm": D_norm,
            "E_norm": E_norm,
            "L_norm": L_norm,
            "V_fair": V_fair,
            "global_reward": global_reward,
            "reward_w_lat": self.reward_weights.w_lat,
            "reward_w_thr": self.reward_weights.w_thr,
            "reward_w_dead": self.reward_weights.w_dead,
            "reward_w_qoe": self.reward_weights.w_qoe,
            "reward_w_eng": self.reward_weights.w_eng,
            "reward_w_block": self.reward_weights.w_block,
            "reward_w_fair": self.reward_weights.w_fair,
            "scenario_type": scenario_type,
            "svc_safety_avg_throughput_Mbps": svc_safety["avg_throughput_Mbps"],
            "svc_safety_avg_latency_ms": svc_safety["avg_latency_ms"],
            "svc_safety_p95_latency_ms": svc_safety["p95_latency_ms"],
            "svc_safety_deadline_satisfaction": svc_safety["deadline_satisfaction"],
            "svc_safety_avg_qoe": svc_safety["avg_qoe"],
            "svc_infotainment_avg_throughput_Mbps": svc_infot["avg_throughput_Mbps"],
            "svc_infotainment_avg_latency_ms": svc_infot["avg_latency_ms"],
            "svc_infotainment_p95_latency_ms": svc_infot["p95_latency_ms"],
            "svc_infotainment_deadline_satisfaction": svc_infot["deadline_satisfaction"],
            "svc_infotainment_avg_qoe": svc_infot["avg_qoe"],
            "qoe_safety": svc_stats["safety"]["qoes"],
            "qoe_infotainment": svc_stats["infotainment"]["qoes"],
        }

        for agent in self.agents:
            infos[agent].update(global_info)

        self.current_episode_reward += global_reward

        # Gymnasium-style: terminateds / truncateds
        done_all = self.num_steps >= self.max_steps

        terminateds = {agent: False for agent in self.agents}
        truncateds = {agent: done_all for agent in self.agents}
        terminateds["__all__"] = False
        truncateds["__all__"] = done_all

        obs = self.get_observation()
        self.update_user_location()

        # step() -> obs, rewards, terminateds, truncateds, infos
        return obs, rewards, terminateds, truncateds, infos

    def reset(self, *, seed=None, options=None):
        """
        Gymnasium-style reset.

        Returns:
            obs (dict): agent_id -> observation
            infos (dict): agent_id -> info dict (empty at reset)
        """
        if seed is not None:
            self.seed(seed)

        self.num_steps = 0
        self.current_episode_reward = 0.0

        # reset users
        for u in self.users:
            if self.mobility_model == "manhattan":
                loc, vel = self._spawn_on_grid()
                u.location = loc
                u.velocity = vel
                self._init_user_manhattan(u)
            else:
                u.location = self.np_random.uniform(0, self.area_size, 2)
                u.waypoint = self.np_random.uniform(0, self.area_size, 2)

            svc = (
                "safety"
                if self.np_random.random() < self.safety_traffic_ratio
                else "infotainment"
            )
            u.service_class = svc
            u.calculate_demand_from_rng(self.np_random)
            u.generate_task(
                self.np_random, self.heavy_task_ratio, self.ue_local_cpu_cycles,
                self.heavy_task_cycles_range, self.heavy_task_data_range,
                self.light_task_cycles_range, self.light_task_data_range,
            )

            u.data_rate = 0.0
            u.SINR = -100.0
            u.clear_channel()

        # reset channels & BSs
        for ch in self.macro_channels:
            ch.users = []
            ch.base_station = None

        self.assigned_channels.clear()

        for bs in self.base_stations:
            bs.clear_assigned_channels()
            bs.transmit_power = self.ma_transmission_power
            bs.mec_queue_cycles = 0.0
            bs.offload_frac = 1.0
            bs.cpu_util_frac = 1.0
            bs.last_cpu_used = bs.mec_cpu_capacity

        # simple initial allocation: 1 channel per BS if available
        for bs in self.base_stations:
            freq = self.bs_carrier_frequency[bs.id]
            avail = [
                c
                for c in self.macro_channels
                if c.frequency == freq and c.base_station is None
            ]
            if avail:
                chosen = [avail[0]]
                bs.assign_channels(chosen)
                self.assigned_channels[avail[0]] = bs.id
            bs.update_coverage_area_from_power(
                bs.transmit_power, self.bs_carrier_frequency[bs.id]
            )

        self.reset_user_info()
        self.prev_assoc_by_user = {u.id: {"Ma": None} for u in self.users}

        obs = self.get_observation()
        infos = {agent: {} for agent in self.agents}
        return obs, infos

    # -------------
    # Observation & global state
    # -------------
    def get_observation(self):
        obs = {}
        max_speed = 25.0

        for i, bs in enumerate(self.base_stations):
            agent = f"agent_{i}"
            users_in_cov = [
                u
                for u in self.users
                if np.linalg.norm(u.location - bs.location)
                <= bs.coverage_area
            ]

            max_power = self.ma_transmission_power
            max_ch_for_bs = float(max(1, self.max_ma_channels))

            bs_type = 0.5
            tx_norm = np.clip(bs.transmit_power / max_power, 0.0, 1.0)

            used = sum(1 for c in bs.assigned_channels if len(c.users) > 0)
            ch_util = np.clip(used / max_ch_for_bs, 0.0, 1.0)

            cov_util = len(users_in_cov) / max(1, self.num_users)

            load_ratio = (
                len(users_in_cov)
                / max(1, len(bs.assigned_channels))
                if bs.assigned_channels
                else 0.0
            )
            load_ratio_norm = float(np.clip(load_ratio / 2.0, 0.0, 1.0))

            nearby_pot = len(
                [
                    u
                    for u in self.users
                    if np.linalg.norm(u.location - bs.location)
                    <= bs.coverage_area * 1.5
                ]
            ) / max(1, self.num_users)

            avg_speed = np.clip(
                (
                    sum(u.speed for u in users_in_cov) / len(users_in_cov)
                    if users_in_cov
                    else 0.0
                )
                / max_speed,
                0.0,
                1.0,
            )

            # approximate required power so that edge user meets SNR target
            if users_in_cov:
                max_dist = max(
                    np.linalg.norm(u.location - bs.location)
                    for u in users_in_cov
                )
                req_p_per_ch = self.calculate_required_power_for_distance(
                    max_dist, bs
                )
                req_total = req_p_per_ch * max(
                    1, len(bs.assigned_channels)
                )
            else:
                req_total = 0.0

            req_p_norm = np.clip(
                req_total / max_power if max_power > 0 else 0.0, 0.0, 1.0
            )

            # radial velocity statistics
            avg_radial_v = 0.5
            if users_in_cov:
                comps = []
                for u in users_in_cov:
                    vec = bs.location - u.location
                    dist = np.linalg.norm(vec)
                    if dist > 1e-6:
                        comp = np.dot(u.velocity, vec / dist)
                        comps.append(comp)
                if comps:
                    avg_radial = float(np.mean(comps))
                    avg_radial_v = float(
                        np.clip((avg_radial / max_speed + 1) / 2.0, 0.0, 1.0)
                    )

            sp_var = np.clip(
                np.var([u.speed for u in users_in_cov])
                / ((max_speed**2) / 4.0)
                if len(users_in_cov) > 1
                else 0.0,
                0.0,
                1.0,
            )

            # coarse interference estimate
            f = self.bs_carrier_frequency[bs.id]
            co_bs = [
                o
                for o in self.base_stations
                if o is not bs and self.bs_carrier_frequency[o.id] == f
            ]

            sampled_users = users_in_cov[: min(len(users_in_cov), 8)]
            I_b = 0.0
            g_rx = 10.0 ** (UE_INTERF_RX_DB / 10.0)

            for b2 in co_bs:
                if not b2.assigned_channels:
                    continue
                p_i = self._per_channel_tx_power_mW(b2)
                gi = BEAM_GAIN_DB[b2.type_bs]
                g_tx_i = 10.0 ** (gi["tx_side"] / 10.0)

                users_in_cov_b2 = [
                    uu
                    for uu in self.users
                    if np.linalg.norm(uu.location - b2.location)
                    <= b2.coverage_area
                ]
                util = min(
                    1.0,
                    len(users_in_cov_b2) / max(1, len(b2.assigned_channels)),
                )

                if sampled_users:
                    acc = 0.0
                    for uu in sampled_users:
                        d_i = np.linalg.norm(uu.location - b2.location)
                        PL_i = b2.calculate_path_loss(d_i, f)
                        acc += (
                            p_i
                            * g_tx_i
                            * g_rx
                            / (10.0 ** (PL_i / 10.0))
                        )
                    I_b += util * (acc / len(sampled_users))

            I_dBm = 10.0 * np.log10(max(I_b, 1e-12))
            inter_norm = np.clip((I_dBm + 120.0) / 120.0, 0.0, 1.0)

            avg_demand_norm = (
                float(
                    np.clip(
                        np.mean(
                            [u.demand for u in users_in_cov]
                        )
                        / self.max_user_demand_Mbps,
                        0.0,
                        1.0,
                    )
                )
                if users_in_cov
                else 0.0
            )

            neigh = [
                o.transmit_power / max(1.0, self.ma_transmission_power)
                for o in self.base_stations
                if o is not bs
                and np.linalg.norm(bs.location - o.location) < 1000.0
            ]
            neighbor_tx_norm = float(np.mean(neigh)) if neigh else 0.0

            mec_queue_norm = float(
                np.clip(
                    bs.mec_queue_cycles
                    / max(
                        1.0,
                        bs.mec_cpu_capacity
                        * self.step_duration_s
                        * 10.0,
                    ),
                    0.0,
                    1.0,
                )
            )
            cpu_util_norm = float(
                np.clip(
                    bs.last_cpu_used / max(1.0, bs.mec_cpu_capacity),
                    0.0,
                    1.0,
                )
            )
            offload_norm = float(np.clip(bs.offload_frac, 0.0, 1.0))

            assoc_users = [
                u
                for u in users_in_cov
                if any(ch.base_station == bs for ch in u.channel)
            ]

            if assoc_users:
                local_served = sum(
                    min(u.data_rate, u.demand) for u in assoc_users
                )
                max_served = len(assoc_users) * self.max_user_demand_Mbps
                served_ratio_norm = float(
                    np.clip(
                        local_served / max(1e-9, max_served),
                        0.0,
                        1.0,
                    )
                )
            else:
                served_ratio_norm = 0.0

            if users_in_cov:
                blocked_local = len(
                    [
                        u
                        for u in users_in_cov
                        if not any(ch.base_station == bs for ch in u.channel)
                    ]
                )
                block_frac_norm = float(
                    np.clip(
                        blocked_local / max(1, len(users_in_cov)), 0.0, 1.0
                    )
                )
            else:
                block_frac_norm = 0.0

            ch_num = len(bs.assigned_channels)
            usr_num = len(users_in_cov)
            if ch_num + usr_num > 0:
                ch_match_norm = float(
                    1.0
                    - min(1.0, abs(ch_num - usr_num) / (ch_num + usr_num))
                )
            else:
                ch_match_norm = 1.0

            # fraction of covered users whose tasks MUST be offloaded
            if users_in_cov:
                offload_mand_frac = float(
                    np.mean([1.0 if u.task_offload_mandatory else 0.0
                             for u in users_in_cov])
                )
            else:
                offload_mand_frac = 0.0

            vec_obs = np.array(
                [
                    bs_type,
                    tx_norm,
                    ch_util,
                    cov_util,
                    load_ratio_norm,
                    nearby_pot,
                    avg_speed,
                    req_p_norm,
                    avg_radial_v,
                    sp_var,
                    neighbor_tx_norm,
                    avg_demand_norm,
                    inter_norm,
                    mec_queue_norm,
                    cpu_util_norm,
                    offload_norm,
                    served_ratio_norm,
                    block_frac_norm,
                    ch_match_norm,
                    offload_mand_frac,
                ],
                dtype=np.float32,
            )
            obs[agent] = vec_obs

        return obs

    def get_global_state(self):
        """Optional centralized critic state."""
        per_bs = []
        for bs in self.base_stations:
            users_in_cov = [
                u
                for u in self.users
                if np.linalg.norm(u.location - bs.location)
                <= bs.coverage_area
            ]
            assoc_users = [
                u
                for u in users_in_cov
                if any(ch.base_station == bs for ch in u.channel)
            ]
            mean_rate = (
                float(np.mean([u.data_rate for u in assoc_users]))
                if assoc_users
                else 0.0
            )
            served_frac = (
                float(
                    sum(
                        min(u.data_rate, u.demand) for u in assoc_users
                    )
                    / max(
                        1e-9,
                        sum(u.demand for u in assoc_users),
                    )
                )
                if assoc_users
                else 0.0
            )
            per_bs.extend(
                [
                    bs.transmit_power,
                    len(bs.assigned_channels),
                    mean_rate,
                    served_frac,
                    bs.mec_queue_cycles,
                    bs.last_cpu_used,
                ]
            )
        return np.array(per_bs, dtype=np.float32)

    # -------------
    # PHY helpers
    # -------------
    def calculate_SINR(self, user: User):
        """Populate user.channel_SINR and aggregate SINR."""
        user.channel_SINR = []
        user.SINR = -100.0

        for ch in user.channel:
            bs = ch.base_station
            if bs is None:
                user.channel_SINR.append(-100.0)
                continue

            d = np.linalg.norm(user.location - bs.location)
            PL_dB = bs.calculate_path_loss(d, ch.frequency)

            p_tx_ch = bs.per_channel_power.get(ch.id, None)
            if p_tx_ch is None:
                n = max(1, len(bs.assigned_channels))
                p_tx_ch = bs.transmit_power / n

            g = BEAM_GAIN_DB[bs.type_bs]
            g_tx_main = 10.0 ** (g["tx_main"] / 10.0)
            g_rx_sig = 10.0 ** (g["rx"] / 10.0)

            signal_mW = (
                p_tx_ch * g_tx_main * g_rx_sig / (10.0 ** (PL_dB / 10.0))
            )

            interference_mW = self._estimate_interference_mW(
                user, ch.frequency, bs
            )
            noise_mW = ch.calculate_noise_power() * 1e3

            denom = max(interference_mW + noise_mW, 1e-15)
            SINR_lin = signal_mW / denom if signal_mW > 0 else 0.0
            if SINR_lin > 0:
                SINR_dB = 10.0 * np.log10(SINR_lin)
            else:
                SINR_dB = -100.0

            SINR_dB = float(np.clip(SINR_dB, -100.0, 60.0))
            user.channel_SINR.append(SINR_dB)

        if user.channel_SINR:
            s_ma = np.mean([10.0 ** (x / 10.0) for x in user.channel_SINR])
            user.SINR = 10.0 * np.log10(s_ma) if s_ma > 0 else -100.0
        else:
            user.SINR = -100.0

    def calculate_required_power_for_distance(
        self, distance_m, base_station: BaseStation
    ):
        """Required TX power (mW) so that UE at distance_m hits target SNR."""
        f = self.bs_carrier_frequency[base_station.id]
        pl_dB = base_station.calculate_path_loss(distance_m, f)

        if base_station.assigned_channels:
            bw_hz = base_station.assigned_channels[0].bandwidth
            nf_db = base_station.assigned_channels[0].noise_figure_db
        else:
            bw_hz = self.macro_channel_bw
            nf_db = 7.0

        sens_dBm = rx_sensitivity_dBm(
            bw_hz, nf_db=nf_db, snr_req_db=-5.0
        )
        g = BEAM_GAIN_DB[base_station.type_bs]
        req_tx_dBm = sens_dBm + pl_dB - (g["tx_main"] + g["rx"])

        return 10.0 ** (req_tx_dBm / 10.0)

    # -------------
    # Mobility update
    # -------------
    def update_user_location(self):
        if self.mobility_model == "manhattan":
            if not hasattr(self, "grid_xs"):
                self._build_road_grid()
            for u in self.users:
                self._advance_user_manhattan(u)
                u.location = np.clip(u.location, 0.0, self.area_size)
        else:
            L = self.area_size
            for u in self.users:
                if u.pause_time > 0:
                    u.pause_time -= 1
                    continue

                if u.waypoint is None:
                    u.waypoint = self.np_random.uniform(0, L, 2)

                delta = u.waypoint - u.location
                dist = np.linalg.norm(delta)

                if dist <= u.speed:
                    u.location = u.waypoint
                    u.pause_time = int(self.np_random.integers(0, 10))
                    u.waypoint = self.np_random.uniform(0, L, 2)
                else:
                    direction = delta / dist if dist > 0 else np.zeros(2)
                    u.velocity = direction * u.speed
                    u.location = np.clip(u.location + u.velocity, 0.0, L)

    # -------------
    # Rendering
    # -------------
    def render(self, mode="human"):
        if mode != "human":
            return

        if self.fig is None:
            self.fig, self._panel_axes = plt.subplots(1, 1, figsize=(8, 8))

        ax = self._panel_axes
        ax.clear()

        L = self.area_size
        ax.set_xlim(0, L)
        ax.set_ylim(0, L)
        ax.set_aspect("equal")

        # BSs and coverage
        for bs in self.base_stations:
            circle = plt.Circle(
                (bs.location[0], bs.location[1]),
                bs.coverage_area,
                color="C0",
                alpha=0.12,
            )
            ax.add_patch(circle)
            ax.scatter(
                bs.location[0], bs.location[1], marker="^", c="C0", s=80
            )
            ax.text(
                bs.location[0] + 5,
                bs.location[1] + 5,
                f"BS{bs.id}",
                fontsize=8,
            )

        # users and serving links
        for u in self.users:
            ax.plot(u.location[0], u.location[1], "ro", ms=4)
            for ch in u.channel:
                bs = ch.base_station
                if bs is None:
                    continue
                ax.plot(
                    [u.location[0], bs.location[0]],
                    [u.location[1], bs.location[1]],
                    "k-",
                    lw=0.6,
                    alpha=0.6,
                )

        plt.pause(0.001)

    def close(self):
        try:
            if self.fig is not None:
                plt.close(self.fig)
        except Exception:
            pass
        self.fig = None


# ==========================
# Heuristic controller + episode-wise CSV logging
# ==========================
class HeuristicEpisodeLogger:
    """
    Write one row per episode to CSV.

    The row contains episode-level means of all scalar info metrics captured from
    the first agent's info dict (matching the original PPO callback behavior as
    closely as possible), plus episode_id, episode_len, and episode_return.
    """

    def __init__(self, csv_path):
        self.csv_path = csv_path
        self.fieldnames = None
        self.header_written = False

        if os.path.exists(self.csv_path):
            try:
                with open(self.csv_path, "r", newline="") as f:
                    reader = csv.reader(f)
                    header = next(reader, None)
                    if header:
                        self.fieldnames = header
                        self.header_written = True
            except Exception:
                self.fieldnames = None
                self.header_written = os.path.getsize(self.csv_path) > 0

    def log_episode(self, episode_id, episode_len, episode_return, scalar_traces):
        row = {
            "episode_id": int(episode_id),
            "episode_len": int(episode_len),
            "episode_return": float(episode_return),
        }
        for k, values in scalar_traces.items():
            if values:
                row[k] = float(np.mean(values))

        if self.fieldnames is None:
            self.fieldnames = list(row.keys())

        for h in self.fieldnames:
            row.setdefault(h, "")

        with open(self.csv_path, "a", newline="") as f:
            writer = csv.DictWriter(
                f,
                fieldnames=self.fieldnames,
                extrasaction="ignore",
            )
            if not self.header_written or os.path.getsize(self.csv_path) == 0:
                writer.writeheader()
                self.header_written = True
            writer.writerow(row)


# ==========================
# Heuristic policy
# ==========================
def heuristic_action_for_agent(env: MultiAgentMobileNetwork, agent_id: str, obs_vec):
    """
    Deterministic rule-based controller.

    Action layout:
        [power_frac, channel_frac, offload_frac, cpu_frac]

    The rule uses the current per-BS observation only, so the controller remains
    comparable to the original decentralized PPO setting.
    """
    tx_norm = float(obs_vec[OBS_IDX.TX_NORM])
    ch_util = float(obs_vec[OBS_IDX.CH_UTIL])
    cov_util = float(obs_vec[OBS_IDX.COV_UTIL])
    load_ratio_norm = float(obs_vec[OBS_IDX.LOAD_RATIO_NORM])
    nearby_pot = float(obs_vec[OBS_IDX.NEARBY_POT])
    avg_speed = float(obs_vec[OBS_IDX.AVG_SPEED])
    req_p_norm = float(obs_vec[OBS_IDX.REQ_P_NORM])
    inter_norm = float(obs_vec[OBS_IDX.INTER_NORM])
    mec_queue_norm = float(obs_vec[OBS_IDX.MEC_QUEUE_NORM])
    cpu_util_norm = float(obs_vec[OBS_IDX.CPU_UTIL_NORM])
    avg_demand_norm = float(obs_vec[OBS_IDX.AVG_DEMAND_NORM])
    served_ratio_norm = float(obs_vec[OBS_IDX.SERVED_RATIO_NORM])
    block_frac_norm = float(obs_vec[OBS_IDX.BLOCK_FRAC_NORM])
    ch_match_norm = float(obs_vec[OBS_IDX.CH_MATCH_NORM])
    offload_mand_frac = float(obs_vec[OBS_IDX.OFFLOAD_MAND_FRAC])

    # Estimate local pressure from current coverage / demand / blocking.
    est_users_in_cov = cov_util * env.num_users
    est_nearby_users = nearby_pot * env.num_users
    demand_pressure = 0.55 * est_users_in_cov + 0.45 * est_nearby_users

    # ----- channel fraction -----
    desired_channels = (
        1.0
        + demand_pressure * (0.70 + 0.30 * avg_demand_norm)
        + 12.0 * block_frac_norm
        + 8.0 * (1.0 - ch_match_norm)
        + 4.0 * load_ratio_norm
    )
    channel_frac = desired_channels / max(1.0, float(env.max_ma_channels))
    channel_frac = float(np.clip(channel_frac, 0.05, 1.0))

    # ----- power fraction -----
    power_frac = (
        0.30
        + 0.28 * req_p_norm
        + 0.14 * inter_norm
        + 0.10 * avg_demand_norm
        + 0.10 * block_frac_norm
        + 0.08 * load_ratio_norm
        + 0.05 * (1.0 - served_ratio_norm)
        + 0.03 * avg_speed
    )
    if est_users_in_cov < 1.0:
        power_frac *= 0.70
    power_frac = float(np.clip(power_frac, 0.10, 1.0))

    # ----- offload fraction -----
    # Heavy tasks are forced to offload by the environment regardless. This
    # action mostly controls light-task offloading.
    offload_frac = (
        0.10
        + 0.50 * offload_mand_frac
        + 0.15 * avg_demand_norm
        + 0.08 * (1.0 - served_ratio_norm)
        + 0.07 * block_frac_norm
        - 0.28 * mec_queue_norm
    )
    if mec_queue_norm > 0.80 and offload_mand_frac < 0.40:
        offload_frac *= 0.50
    offload_frac = float(np.clip(offload_frac, 0.05, 0.98))

    # ----- CPU utilization fraction -----
    cpu_frac = (
        0.28
        + 0.48 * mec_queue_norm
        + 0.20 * offload_mand_frac
        + 0.08 * avg_demand_norm
        + 0.05 * offload_frac
    )
    if mec_queue_norm < 0.10 and offload_mand_frac < 0.20 and cpu_util_norm > 0.50:
        cpu_frac *= 0.80
    cpu_frac = float(np.clip(cpu_frac, 0.20, 1.0))

    # Small smoothing towards previous operating point to avoid abrupt swings.
    agent_idx = int(agent_id.split("_")[-1])
    bs = env.base_stations[agent_idx]
    prev_power = bs.transmit_power / max(1.0, env.ma_transmission_power)
    prev_channels = len(bs.assigned_channels) / max(1.0, float(env.max_ma_channels))
    prev_offload = bs.offload_frac
    prev_cpu = bs.cpu_util_frac

    alpha = 0.70  # favor new decision, keep 30% of previous level
    power_frac = alpha * power_frac + (1.0 - alpha) * prev_power
    channel_frac = alpha * channel_frac + (1.0 - alpha) * prev_channels
    offload_frac = alpha * offload_frac + (1.0 - alpha) * prev_offload
    cpu_frac = alpha * cpu_frac + (1.0 - alpha) * prev_cpu

    return np.array(
        [power_frac, channel_frac, offload_frac, cpu_frac],
        dtype=np.float32,
    )



def build_heuristic_action_dict(env: MultiAgentMobileNetwork, obs_dict):
    return {
        agent_id: heuristic_action_for_agent(env, agent_id, obs_dict[agent_id])
        for agent_id in env.agents
    }


# ==========================
# Experiment runner
# ==========================
def run_heuristic_baseline(
    env: MultiAgentMobileNetwork,
    total_target_env_steps: int,
    csv_path: str,
    log_every_episode: int = 1,
    render: bool = False,
    seed_offset: int = 0,
):
    logger = HeuristicEpisodeLogger(csv_path)

    total_env_steps = 0
    episode_idx = 0

    while total_env_steps < total_target_env_steps:
        obs, _ = env.reset(seed=seed_offset + episode_idx)
        done = False
        episode_return = 0.0
        episode_len = 0
        scalar_traces = defaultdict(list)

        while not done:
            action_dict = build_heuristic_action_dict(env, obs)
            obs, rewards, terminateds, truncateds, infos = env.step(action_dict)

            reward_vals = list(rewards.values())
            step_reward = float(np.mean(reward_vals)) if reward_vals else 0.0
            episode_return += step_reward
            episode_len += 1
            total_env_steps += 1

            # Match the old PPO callback behavior: log scalar info fields from the
            # first agent's info dict. Global metrics are identical across agents.
            first_agent = env.agents[0]
            info = infos.get(first_agent, {})
            for k, v in info.items():
                if isinstance(v, (int, float)):
                    scalar_traces[k].append(float(v))

            done = bool(terminateds.get("__all__", False) or truncateds.get("__all__", False))

            if render:
                env.render()

            if total_env_steps >= total_target_env_steps:
                done = True

        logger.log_episode(
            episode_id=episode_idx,
            episode_len=episode_len,
            episode_return=episode_return,
            scalar_traces=scalar_traces,
        )

        if episode_idx % log_every_episode == 0:
            avg_latency = float(np.mean(scalar_traces.get("avg_latency_ms", [0.0])))
            p95_latency = float(np.mean(scalar_traces.get("p95_latency_ms", [0.0])))
            avg_tput = float(np.mean(scalar_traces.get("avg_throughput_Mbps", [0.0])))
            dsr = float(np.mean(scalar_traces.get("deadline_satisfaction", [0.0])))
            blocking = float(np.mean(scalar_traces.get("blocking_rate", [0.0])))
            energy = float(np.mean(scalar_traces.get("step_energy_J", [0.0])))
            fairness = float(np.mean(scalar_traces.get("jain_fairness", [0.0])))
            print(
                f"[Episode {episode_idx:04d}] "
                f"steps={episode_len:3d} | total_env_steps={total_env_steps:7d} | "
                f"return={episode_return:8.3f} | tput={avg_tput:6.3f} Mbps | "
                f"lat={avg_latency:7.3f} ms | p95={p95_latency:7.3f} ms | "
                f"dsr={dsr:5.3f} | block={blocking:5.3f} | "
                f"fair={fairness:5.3f} | E={energy:7.3f} J"
            )

        episode_idx += 1

    return {
        "episodes": episode_idx,
        "total_env_steps": total_env_steps,
        "csv_path": csv_path,
    }


# ==========================
# Main
# ==========================
def parse_args(args=None):
    parser = argparse.ArgumentParser(
        description="Heuristic baseline for the multi-agent mobile network environment."
    )
    parser.add_argument("--num-base-stations", type=int, default=4)
    parser.add_argument("--num-users", type=int, default=100)
    parser.add_argument("--num-channels-per-carrier", type=int, default=100)
    parser.add_argument("--area-size", type=float, default=5000.0)
    parser.add_argument("--max-steps", type=int, default=200)
    parser.add_argument("--mobility-model", type=str, default="manhattan")
    parser.add_argument("--seed", type=int, default=42)
    parser.add_argument("--step-duration-s", type=float, default=1.0)
    parser.add_argument("--deadline-ms", type=float, default=100.0)
    parser.add_argument("--safety-traffic-ratio", type=float, default=0.3)
    parser.add_argument(
        "--total-target-env-steps",
        type=int,
        default=500_000,
        help="Total environment steps to simulate across episodes.",
    )
    parser.add_argument(
        "--csv-name",
        type=str,
        default="heuristic_episode_metrics.csv",
        help="CSV filename for episode-wise metrics.",
    )
    parser.add_argument("--render", action="store_true")
    parser.add_argument("--log-every-episode", type=int, default=1)
    # Jupyter/IPython launches scripts with extra arguments such as
    # ``-f /path/to/kernel.json``. We ignore unknown arguments so the same file
    # runs both from a terminal and inside notebooks.
    parsed_args, _ = parser.parse_known_args(args=args)
    return parsed_args


if __name__ == "__main__":
    args = parse_args()

    bs_locs = [(1250, 1400), (3750, 1400), (1250, 3550), (3750, 3550)]
    if args.num_base_stations != 4:
        bs_locs = None

    env = MultiAgentMobileNetwork(
        num_base_stations=args.num_base_stations,
        num_users=args.num_users,
        num_channels_per_carrier=args.num_channels_per_carrier,
        area_size=args.area_size,
        bs_loc=bs_locs,
        max_steps=args.max_steps,
        mobility_model=args.mobility_model,
        seed=args.seed,
        step_duration_s=args.step_duration_s,
        deadline_ms=args.deadline_ms,
        safety_traffic_ratio=args.safety_traffic_ratio,
    )

    out_csv = os.path.join(os.getcwd(), args.csv_name)
    summary = run_heuristic_baseline(
        env=env,
        total_target_env_steps=args.total_target_env_steps,
        csv_path=out_csv,
        log_every_episode=max(1, args.log_every_episode),
        render=args.render,
        seed_offset=args.seed,
    )

    print("\n✅ Heuristic simulation finished.")
    print(f"Episodes completed   : {summary['episodes']}")
    print(f"Total env steps      : {summary['total_env_steps']}")
    print(f"Episode metrics file : {summary['csv_path']}")

    env.close()
# Out:
# [Episode 0000] steps=200 | total_env_steps=    200 | return=   8.535 | tput= 1.018 Mbps | lat=2043.982 ms | p95=4377.978 ms | dsr=0.008 | block=0.015 | fair=0.965 | E=87083.849 J
# [Episode 0001] steps=200 | total_env_steps=    400 | return=   6.484 | tput= 0.970 Mbps | lat=2298.064 ms | p95=4875.494 ms | dsr=0.012 | block=0.023 | fair=0.963 | E=94854.250 J
# [Episode 0002] steps=200 | total_env_steps=    600 | return=   8.305 | tput= 0.944 Mbps | lat=1929.312 ms | p95=3668.308 ms | dsr=0.007 | block=0.007 | fair=0.977 | E=82425.153 J
# [Episode 0003] steps=200 | total_env_steps=    800 | return=   8.138 | tput= 1.032 Mbps | lat=1674.208 ms | p95=3744.279 ms | dsr=0.012 | block=0.025 | fair=0.972 | E=81426.804 J
# [Episode 0004] steps=200 | total_env_steps=   1000 | return=  11.243 | tput= 1.079 Mbps | lat=2203.335 ms | p95=4476.484 ms | dsr=0.014 | block=0.016 | fair=0.973 | E=87593.406 J
# [Episode 0005] steps=200 | total_env_steps=   1200 | return=   6.891 | tput= 0.957 Mbps | lat=2000.713 ms | p95=4236.518 ms | dsr=0.009 | block=0.020 | fair=0.972 | E=85254.662 J
# [Episode 0006] steps=200 | total_env_steps=   1400 | return=   5.109 | tput= 0.878 Mbps | lat=1979.160 ms | p95=3958.126 ms | dsr=0.009 | block=0.023 | fair=0.939 | E=85157.421 J
# [Episode 0007] steps=200 | total_env_steps=   1600 | return=  10.091 | tput= 1.008 Mbps | lat=2067.440 ms | p95=4374.966 ms | dsr=0.011 | block=0.010 | fair=0.992 | E=86064.870 J
# [Episode 0008] steps=200 | total_env_steps=   1800 | return=   7.295 | tput= 0.914 Mbps | lat=1744.696 ms | p95=3496.891 ms | dsr=0.006 | block=0.025 | fair=0.984 | E=79937.541 J
# [Episode 0009] steps=200 | total_env_steps=   2000 | return=   9.576 | tput= 0.940 Mbps | lat=2287.441 ms | p95=4880.502 ms | dsr=0.012 | block=0.016 | fair=0.966 | E=88856.525 J
# [Episode 0010] steps=200 | total_env_steps=   2200 | return=   8.100 | tput= 0.985 Mbps | lat=1798.613 ms | p95=3724.411 ms | dsr=0.007 | block=0.013 | fair=0.982 | E=82321.436 J
# [Episode 0011] steps=200 | total_env_steps=   2400 | return=   8.849 | tput= 0.984 Mbps | lat=2481.328 ms | p95=4633.325 ms | dsr=0.010 | block=0.015 | fair=0.970 | E=91846.508 J
# [Episode 0012] steps=200 | total_env_steps=   2600 | return=   8.653 | tput= 0.902 Mbps | lat=2232.544 ms | p95=4573.285 ms | dsr=0.014 | block=0.014 | fair=0.966 | E=89653.571 J
# [Episode 0013] steps=200 | total_env_steps=   2800 | return=   8.996 | tput= 1.037 Mbps | lat=1918.780 ms | p95=3875.614 ms | dsr=0.008 | block=0.027 | fair=0.963 | E=83180.961 J
# [Episode 0014] steps=200 | total_env_steps=   3000 | return=   9.135 | tput= 1.084 Mbps | lat=1874.435 ms | p95=3887.278 ms | dsr=0.007 | block=0.012 | fair=0.976 | E=85227.996 J
# [Episode 0015] steps=200 | total_env_steps=   3200 | return=   8.944 | tput= 0.952 Mbps | lat=2170.507 ms | p95=4460.708 ms | dsr=0.012 | block=0.027 | fair=0.970 | E=88203.618 J
# [Episode 0016] steps=200 | total_env_steps=   3400 | return=   9.016 | tput= 0.967 Mbps | lat=2207.677 ms | p95=4825.179 ms | dsr=0.013 | block=0.019 | fair=0.957 | E=89763.061 J
# [Episode 0017] steps=200 | total_env_steps=   3600 | return=   7.412 | tput= 0.942 Mbps | lat=2358.232 ms | p95=4527.140 ms | dsr=0.013 | block=0.023 | fair=0.980 | E=93291.412 J
# [Episode 0018] steps=200 | total_env_steps=   3800 | return=   8.177 | tput= 0.976 Mbps | lat=1886.582 ms | p95=4153.478 ms | dsr=0.006 | block=0.023 | fair=0.985 | E=81570.203 J
# [Episode 0019] steps=200 | total_env_steps=   4000 | return=   8.387 | tput= 1.028 Mbps | lat=2022.835 ms | p95=4301.788 ms | dsr=0.008 | block=0.016 | fair=0.977 | E=86397.243 J
# [Episode 0020] steps=200 | total_env_steps=   4200 | return=   7.791 | tput= 1.056 Mbps | lat=2320.088 ms | p95=4663.130 ms | dsr=0.011 | block=0.011 | fair=0.960 | E=91836.969 J
# [Episode 0021] steps=200 | total_env_steps=   4400 | return=   8.599 | tput= 0.999 Mbps | lat=1850.053 ms | p95=3557.283 ms | dsr=0.008 | block=0.012 | fair=0.967 | E=80640.119 J
# [Episode 0022] steps=200 | total_env_steps=   4600 | return=   8.161 | tput= 0.967 Mbps | lat=1907.312 ms | p95=3851.411 ms | dsr=0.008 | block=0.021 | fair=0.986 | E=82905.179 J
# [Episode 0023] steps=200 | total_env_steps=   4800 | return=   8.563 | tput= 0.980 Mbps | lat=1855.129 ms | p95=3892.063 ms | dsr=0.005 | block=0.012 | fair=0.983 | E=81380.407 J
# [Episode 0024] steps=200 | total_env_steps=   5000 | return=   8.188 | tput= 1.049 Mbps | lat=1632.135 ms | p95=3408.804 ms | dsr=0.007 | block=0.020 | fair=0.981 | E=80827.561 J
# [Episode 0025] steps=200 | total_env_steps=   5200 | return=  10.267 | tput= 1.060 Mbps | lat=2124.084 ms | p95=4563.917 ms | dsr=0.011 | block=0.015 | fair=0.980 | E=87360.734 J
# [Episode 0026] steps=200 | total_env_steps=   5400 | return=   5.487 | tput= 0.930 Mbps | lat=1461.140 ms | p95=2858.459 ms | dsr=0.006 | block=0.022 | fair=0.981 | E=80276.472 J
# [Episode 0027] steps=200 | total_env_steps=   5600 | return=   7.571 | tput= 0.949 Mbps | lat=1671.485 ms | p95=3527.147 ms | dsr=0.007 | block=0.027 | fair=0.987 | E=80557.924 J
# [Episode 0028] steps=200 | total_env_steps=   5800 | return=   6.423 | tput= 0.907 Mbps | lat=1754.480 ms | p95=3672.196 ms | dsr=0.008 | block=0.022 | fair=0.983 | E=82359.555 J
# [Episode 0029] steps=200 | total_env_steps=   6000 | return=   8.399 | tput= 0.976 Mbps | lat=2143.117 ms | p95=4274.269 ms | dsr=0.010 | block=0.015 | fair=0.970 | E=87281.872 J
# [Episode 0030] steps=200 | total_env_steps=   6200 | return=   8.907 | tput= 1.065 Mbps | lat=1809.348 ms | p95=4346.159 ms | dsr=0.012 | block=0.021 | fair=0.981 | E=86625.178 J
# [Episode 0031] steps=200 | total_env_steps=   6400 | return=   9.312 | tput= 0.962 Mbps | lat=2096.639 ms | p95=4870.860 ms | dsr=0.015 | block=0.027 | fair=0.970 | E=92039.300 J
# [Episode 0032] steps=200 | total_env_steps=   6600 | return=   9.171 | tput= 0.886 Mbps | lat=2229.583 ms | p95=4954.788 ms | dsr=0.014 | block=0.010 | fair=0.957 | E=94126.444 J
# [Episode 0033] steps=200 | total_env_steps=   6800 | return=   9.088 | tput= 1.012 Mbps | lat=2089.706 ms | p95=4516.902 ms | dsr=0.011 | block=0.016 | fair=0.969 | E=84931.412 J
# [Episode 0034] steps=200 | total_env_steps=   7000 | return=   7.237 | tput= 0.988 Mbps | lat=1975.140 ms | p95=4396.970 ms | dsr=0.010 | block=0.016 | fair=0.963 | E=84296.982 J
# [Episode 0035] steps=200 | total_env_steps=   7200 | return=   9.768 | tput= 1.055 Mbps | lat=2140.000 ms | p95=4443.866 ms | dsr=0.008 | block=0.012 | fair=0.981 | E=85862.663 J
# [Episode 0036] steps=200 | total_env_steps=   7400 | return=   9.807 | tput= 1.015 Mbps | lat=2025.378 ms | p95=4866.678 ms | dsr=0.012 | block=0.015 | fair=0.964 | E=89937.637 J
# [Episode 0037] steps=200 | total_env_steps=   7600 | return=   9.110 | tput= 0.951 Mbps | lat=1930.717 ms | p95=4816.946 ms | dsr=0.016 | block=0.022 | fair=0.980 | E=89042.178 J
# [Episode 0038] steps=200 | total_env_steps=   7800 | return=   5.660 | tput= 0.890 Mbps | lat=1581.348 ms | p95=3099.706 ms | dsr=0.008 | block=0.026 | fair=0.950 | E=79766.218 J
# [Episode 0039] steps=200 | total_env_steps=   8000 | return=   8.152 | tput= 0.939 Mbps | lat=1911.607 ms | p95=4085.822 ms | dsr=0.010 | block=0.021 | fair=0.980 | E=82122.222 J
# [Episode 0040] steps=200 | total_env_steps=   8200 | return=   8.076 | tput= 0.948 Mbps | lat=2105.853 ms | p95=4239.738 ms | dsr=0.010 | block=0.012 | fair=0.981 | E=85660.561 J
# [Episode 0041] steps=200 | total_env_steps=   8400 | return=  10.417 | tput= 1.126 Mbps | lat=1723.639 ms | p95=3392.899 ms | dsr=0.005 | block=0.020 | fair=0.991 | E=80371.957 J
# [Episode 0042] steps=200 | total_env_steps=   8600 | return=   9.092 | tput= 1.006 Mbps | lat=2447.926 ms | p95=4872.715 ms | dsr=0.012 | block=0.018 | fair=0.985 | E=94459.710 J
# [Episode 0043] steps=200 | total_env_steps=   8800 | return=   9.482 | tput= 1.082 Mbps | lat=2135.565 ms | p95=4723.538 ms | dsr=0.013 | block=0.012 | fair=0.942 | E=89381.201 J
# [Episode 0044] steps=200 | total_env_steps=   9000 | return=   9.898 | tput= 1.089 Mbps | lat=1993.386 ms | p95=4671.229 ms | dsr=0.016 | block=0.020 | fair=0.973 | E=86372.051 J
# [Episode 0045] steps=200 | total_env_steps=   9200 | return=   7.943 | tput= 0.982 Mbps | lat=2486.886 ms | p95=4935.895 ms | dsr=0.017 | block=0.031 | fair=0.950 | E=97025.892 J
# [Episode 0046] steps=200 | total_env_steps=   9400 | return=   9.470 | tput= 1.059 Mbps | lat=2242.699 ms | p95=4749.421 ms | dsr=0.014 | block=0.013 | fair=0.952 | E=94186.513 J
# [Episode 0047] steps=200 | total_env_steps=   9600 | return=   7.112 | tput= 0.968 Mbps | lat=2546.046 ms | p95=4817.765 ms | dsr=0.015 | block=0.021 | fair=0.929 | E=96573.847 J
# [Episode 0048] steps=200 | total_env_steps=   9800 | return=   8.827 | tput= 1.008 Mbps | lat=2118.896 ms | p95=4877.423 ms | dsr=0.011 | block=0.020 | fair=0.977 | E=90254.619 J
# [Episode 0049] steps=200 | total_env_steps=  10000 | return=  10.352 | tput= 1.046 Mbps | lat=2748.165 ms | p95=4819.821 ms | dsr=0.017 | block=0.011 | fair=0.965 | E=107856.540 J
# [Episode 0050] steps=200 | total_env_steps=  10200 | return=   8.523 | tput= 1.014 Mbps | lat=2017.918 ms | p95=4383.190 ms | dsr=0.009 | block=0.012 | fair=0.979 | E=85674.709 J
# [Episode 0051] steps=200 | total_env_steps=  10400 | return=   8.903 | tput= 1.040 Mbps | lat=2165.859 ms | p95=4732.480 ms | dsr=0.014 | block=0.017 | fair=0.976 | E=88971.759 J
# [Episode 0052] steps=200 | total_env_steps=  10600 | return=   7.505 | tput= 0.933 Mbps | lat=2041.063 ms | p95=4937.432 ms | dsr=0.020 | block=0.022 | fair=0.976 | E=98313.377 J
# [Episode 0053] steps=200 | total_env_steps=  10800 | return=   7.920 | tput= 0.932 Mbps | lat=1986.287 ms | p95=4785.976 ms | dsr=0.015 | block=0.017 | fair=0.944 | E=88371.947 J
# [Episode 0054] steps=200 | total_env_steps=  11000 | return=   8.440 | tput= 0.975 Mbps | lat=2018.694 ms | p95=4158.939 ms | dsr=0.007 | block=0.012 | fair=0.951 | E=82997.463 J
# [Episode 0055] steps=200 | total_env_steps=  11200 | return=   8.187 | tput= 0.946 Mbps | lat=2256.943 ms | p95=4774.988 ms | dsr=0.018 | block=0.025 | fair=0.958 | E=94333.924 J
# [Episode 0056] steps=200 | total_env_steps=  11400 | return=   6.673 | tput= 1.009 Mbps | lat=2832.657 ms | p95=4937.690 ms | dsr=0.017 | block=0.018 | fair=0.878 | E=106168.460 J
# [Episode 0057] steps=200 | total_env_steps=  11600 | return=   9.532 | tput= 1.015 Mbps | lat=2483.589 ms | p95=4815.477 ms | dsr=0.016 | block=0.021 | fair=0.954 | E=93597.815 J
# [Episode 0058] steps=200 | total_env_steps=  11800 | return=   8.851 | tput= 1.069 Mbps | lat=2152.940 ms | p95=4149.492 ms | dsr=0.012 | block=0.018 | fair=0.978 | E=89679.273 J
# [Episode 0059] steps=200 | total_env_steps=  12000 | return=   7.872 | tput= 0.878 Mbps | lat=2161.962 ms | p95=4355.705 ms | dsr=0.012 | block=0.016 | fair=0.985 | E=87406.843 J
# [Episode 0060] steps=200 | total_env_steps=  12200 | return=  11.627 | tput= 1.222 Mbps | lat=2027.755 ms | p95=4305.448 ms | dsr=0.014 | block=0.014 | fair=0.981 | E=87674.709 J
# [Episode 0061] steps=200 | total_env_steps=  12400 | return=   8.438 | tput= 0.959 Mbps | lat=2062.134 ms | p95=4703.189 ms | dsr=0.014 | block=0.019 | fair=0.977 | E=87128.067 J
# [Episode 0062] steps=200 | total_env_steps=  12600 | return=   8.241 | tput= 1.035 Mbps | lat=2181.369 ms | p95=4262.783 ms | dsr=0.008 | block=0.011 | fair=0.990 | E=86241.635 J
# [Episode 0063] steps=200 | total_env_steps=  12800 | return=   8.898 | tput= 1.006 Mbps | lat=1898.643 ms | p95=4235.052 ms | dsr=0.013 | block=0.021 | fair=0.990 | E=85678.453 J
# [Episode 0064] steps=200 | total_env_steps=  13000 | return=   6.274 | tput= 0.922 Mbps | lat=2303.203 ms | p95=4422.456 ms | dsr=0.009 | block=0.020 | fair=0.947 | E=87866.732 J
# [Episode 0065] steps=200 | total_env_steps=  13200 | return=   8.895 | tput= 0.948 Mbps | lat=1922.588 ms | p95=4457.384 ms | dsr=0.011 | block=0.028 | fair=0.991 | E=83913.131 J
# [Episode 0066] steps=200 | total_env_steps=  13400 | return=   8.233 | tput= 0.991 Mbps | lat=2108.489 ms | p95=4793.351 ms | dsr=0.012 | block=0.033 | fair=0.970 | E=87276.295 J
# [Episode 0067] steps=200 | total_env_steps=  13600 | return=   8.040 | tput= 0.931 Mbps | lat=2241.064 ms | p95=4875.265 ms | dsr=0.013 | block=0.019 | fair=0.939 | E=92022.265 J
# [Episode 0068] steps=200 | total_env_steps=  13800 | return=   8.996 | tput= 0.980 Mbps | lat=2262.741 ms | p95=4531.014 ms | dsr=0.012 | block=0.024 | fair=0.979 | E=88788.276 J
# [Episode 0069] steps=200 | total_env_steps=  14000 | return=   9.245 | tput= 0.926 Mbps | lat=1987.056 ms | p95=4783.331 ms | dsr=0.013 | block=0.023 | fair=0.973 | E=88622.769 J
# [Episode 0070] steps=200 | total_env_steps=  14200 | return=   8.047 | tput= 1.003 Mbps | lat=2200.507 ms | p95=4624.545 ms | dsr=0.010 | block=0.027 | fair=0.945 | E=87828.319 J
# [Episode 0071] steps=200 | total_env_steps=  14400 | return=   7.586 | tput= 0.930 Mbps | lat=2266.358 ms | p95=4842.097 ms | dsr=0.013 | block=0.014 | fair=0.883 | E=89909.153 J
# [Episode 0072] steps=200 | total_env_steps=  14600 | return=   7.448 | tput= 0.961 Mbps | lat=1887.130 ms | p95=3704.255 ms | dsr=0.005 | block=0.008 | fair=0.966 | E=82550.895 J
# [Episode 0073] steps=200 | total_env_steps=  14800 | return=   8.832 | tput= 1.050 Mbps | lat=2103.493 ms | p95=4548.307 ms | dsr=0.011 | block=0.019 | fair=0.965 | E=86911.515 J
# [Episode 0074] steps=200 | total_env_steps=  15000 | return=   8.792 | tput= 0.946 Mbps | lat=1977.695 ms | p95=3974.528 ms | dsr=0.007 | block=0.015 | fair=0.978 | E=81536.833 J
# [Episode 0075] steps=200 | total_env_steps=  15200 | return=   9.377 | tput= 0.981 Mbps | lat=2093.161 ms | p95=4555.646 ms | dsr=0.009 | block=0.013 | fair=0.980 | E=87279.846 J
# [Episode 0076] steps=200 | total_env_steps=  15400 | return=   7.012 | tput= 0.953 Mbps | lat=2004.739 ms | p95=4154.952 ms | dsr=0.011 | block=0.018 | fair=0.975 | E=87887.556 J
# [Episode 0077] steps=200 | total_env_steps=  15600 | return=   8.707 | tput= 0.979 Mbps | lat=2080.512 ms | p95=4910.070 ms | dsr=0.021 | block=0.026 | fair=0.952 | E=100135.029 J
# [Episode 0078] steps=200 | total_env_steps=  15800 | return=   8.384 | tput= 1.050 Mbps | lat=1875.107 ms | p95=3794.287 ms | dsr=0.008 | block=0.017 | fair=0.991 | E=82573.912 J
# [Episode 0079] steps=200 | total_env_steps=  16000 | return=   7.881 | tput= 0.927 Mbps | lat=2021.168 ms | p95=4756.151 ms | dsr=0.012 | block=0.019 | fair=0.977 | E=87995.205 J
# [Episode 0080] steps=200 | total_env_steps=  16200 | return=   9.835 | tput= 1.094 Mbps | lat=2005.928 ms | p95=4203.001 ms | dsr=0.007 | block=0.013 | fair=0.946 | E=83669.936 J
# [Episode 0081] steps=200 | total_env_steps=  16400 | return=   7.869 | tput= 1.080 Mbps | lat=2224.555 ms | p95=4456.338 ms | dsr=0.012 | block=0.011 | fair=0.928 | E=91444.144 J
# [Episode 0082] steps=200 | total_env_steps=  16600 | return=   6.954 | tput= 0.890 Mbps | lat=1933.080 ms | p95=4870.897 ms | dsr=0.016 | block=0.029 | fair=0.956 | E=89756.635 J
# [Episode 0083] steps=200 | total_env_steps=  16800 | return=   7.401 | tput= 0.857 Mbps | lat=2360.187 ms | p95=4531.120 ms | dsr=0.011 | block=0.017 | fair=0.972 | E=89474.812 J
# [Episode 0084] steps=200 | total_env_steps=  17000 | return=   9.128 | tput= 0.968 Mbps | lat=2418.823 ms | p95=4946.594 ms | dsr=0.014 | block=0.030 | fair=0.985 | E=95879.058 J
# [Episode 0085] steps=200 | total_env_steps=  17200 | return=   6.841 | tput= 0.941 Mbps | lat=2336.283 ms | p95=4848.737 ms | dsr=0.010 | block=0.026 | fair=0.946 | E=92563.567 J
# [Episode 0086] steps=200 | total_env_steps=  17400 | return=   7.931 | tput= 1.033 Mbps | lat=2550.512 ms | p95=4900.935 ms | dsr=0.016 | block=0.019 | fair=0.917 | E=102038.074 J
# [Episode 0087] steps=200 | total_env_steps=  17600 | return=  10.334 | tput= 1.057 Mbps | lat=2528.217 ms | p95=4792.024 ms | dsr=0.017 | block=0.025 | fair=0.983 | E=95290.642 J
# [Episode 0088] steps=200 | total_env_steps=  17800 | return=   7.434 | tput= 0.940 Mbps | lat=2474.636 ms | p95=4946.152 ms | dsr=0.015 | block=0.019 | fair=0.933 | E=99220.223 J
# [Episode 0089] steps=200 | total_env_steps=  18000 | return=   8.563 | tput= 1.010 Mbps | lat=1894.077 ms | p95=4116.396 ms | dsr=0.007 | block=0.018 | fair=0.969 | E=84555.587 J
# [Episode 0090] steps=200 | total_env_steps=  18200 | return=  11.246 | tput= 1.152 Mbps | lat=1968.535 ms | p95=4889.221 ms | dsr=0.016 | block=0.017 | fair=0.967 | E=91719.124 J
# [Episode 0091] steps=200 | total_env_steps=  18400 | return=   8.187 | tput= 0.967 Mbps | lat=2033.191 ms | p95=4892.358 ms | dsr=0.012 | block=0.013 | fair=0.949 | E=87281.917 J
# [Episode 0092] steps=200 | total_env_steps=  18600 | return=  10.253 | tput= 1.079 Mbps | lat=1746.831 ms | p95=4043.790 ms | dsr=0.008 | block=0.023 | fair=0.981 | E=80657.350 J
# [Episode 0093] steps=200 | total_env_steps=  18800 | return=   8.388 | tput= 0.961 Mbps | lat=2055.590 ms | p95=4340.613 ms | dsr=0.008 | block=0.018 | fair=0.978 | E=84763.313 J
# [Episode 0094] steps=200 | total_env_steps=  19000 | return=   9.518 | tput= 0.987 Mbps | lat=1991.238 ms | p95=4235.113 ms | dsr=0.010 | block=0.033 | fair=0.995 | E=84121.673 J
# [Episode 0095] steps=200 | total_env_steps=  19200 | return=   8.990 | tput= 1.068 Mbps | lat=2191.811 ms | p95=4407.469 ms | dsr=0.011 | block=0.005 | fair=0.981 | E=90093.912 J
# [Episode 0096] steps=200 | total_env_steps=  19400 | return=  10.175 | tput= 1.024 Mbps | lat=1994.979 ms | p95=4852.056 ms | dsr=0.014 | block=0.011 | fair=0.938 | E=89077.126 J
# [Episode 0097] steps=200 | total_env_steps=  19600 | return=   9.562 | tput= 1.045 Mbps | lat=1990.722 ms | p95=4033.118 ms | dsr=0.009 | block=0.014 | fair=0.984 | E=84535.571 J
# [Episode 0098] steps=200 | total_env_steps=  19800 | return=   8.381 | tput= 0.991 Mbps | lat=1852.841 ms | p95=3751.316 ms | dsr=0.007 | block=0.019 | fair=0.981 | E=81563.551 J
# [Episode 0099] steps=200 | total_env_steps=  20000 | return=   8.625 | tput= 0.918 Mbps | lat=2011.473 ms | p95=4223.451 ms | dsr=0.008 | block=0.017 | fair=0.965 | E=82685.682 J
# [Episode 0100] steps=200 | total_env_steps=  20200 | return=   6.694 | tput= 0.969 Mbps | lat=2137.643 ms | p95=4881.169 ms | dsr=0.012 | block=0.015 | fair=0.943 | E=93425.068 J
# [Episode 0101] steps=200 | total_env_steps=  20400 | return=   6.931 | tput= 1.015 Mbps | lat=1587.493 ms | p95=3507.317 ms | dsr=0.009 | block=0.029 | fair=0.953 | E=79222.171 J
# [Episode 0102] steps=200 | total_env_steps=  20600 | return=   6.209 | tput= 0.947 Mbps | lat=1609.317 ms | p95=3225.487 ms | dsr=0.007 | block=0.026 | fair=0.990 | E=79882.678 J
# [Episode 0103] steps=200 | total_env_steps=  20800 | return=   7.256 | tput= 1.030 Mbps | lat=1446.007 ms | p95=2809.487 ms | dsr=0.008 | block=0.034 | fair=0.952 | E=78104.356 J
# [Episode 0104] steps=200 | total_env_steps=  21000 | return=   9.022 | tput= 1.025 Mbps | lat=1855.457 ms | p95=3874.832 ms | dsr=0.009 | block=0.027 | fair=0.968 | E=81298.935 J
# [Episode 0105] steps=200 | total_env_steps=  21200 | return=   8.160 | tput= 0.960 Mbps | lat=1965.564 ms | p95=4119.963 ms | dsr=0.006 | block=0.016 | fair=0.959 | E=82673.864 J
# [Episode 0106] steps=200 | total_env_steps=  21400 | return=   6.805 | tput= 0.942 Mbps | lat=1885.087 ms | p95=3705.057 ms | dsr=0.007 | block=0.014 | fair=0.988 | E=84262.928 J
# [Episode 0107] steps=200 | total_env_steps=  21600 | return=   8.707 | tput= 1.084 Mbps | lat=2138.150 ms | p95=4680.358 ms | dsr=0.011 | block=0.018 | fair=0.954 | E=89915.036 J
# [Episode 0108] steps=200 | total_env_steps=  21800 | return=   8.907 | tput= 1.044 Mbps | lat=2244.223 ms | p95=4868.471 ms | dsr=0.013 | block=0.016 | fair=0.983 | E=90416.581 J
# [Episode 0109] steps=200 | total_env_steps=  22000 | return=   7.048 | tput= 0.951 Mbps | lat=2249.873 ms | p95=4690.531 ms | dsr=0.012 | block=0.030 | fair=0.933 | E=89312.390 J
# [Episode 0110] steps=200 | total_env_steps=  22200 | return=  10.285 | tput= 1.118 Mbps | lat=1634.779 ms | p95=3804.999 ms | dsr=0.007 | block=0.018 | fair=0.991 | E=80946.654 J
# [Episode 0111] steps=200 | total_env_steps=  22400 | return=   6.185 | tput= 0.902 Mbps | lat=1616.348 ms | p95=3695.911 ms | dsr=0.009 | block=0.028 | fair=0.977 | E=80192.769 J
# [Episode 0112] steps=200 | total_env_steps=  22600 | return=   8.923 | tput= 1.024 Mbps | lat=2180.864 ms | p95=4798.315 ms | dsr=0.015 | block=0.012 | fair=0.953 | E=100301.118 J
# [Episode 0113] steps=200 | total_env_steps=  22800 | return=   7.984 | tput= 0.955 Mbps | lat=2185.593 ms | p95=4104.768 ms | dsr=0.009 | block=0.014 | fair=0.995 | E=86648.980 J
# [Episode 0114] steps=200 | total_env_steps=  23000 | return=   8.428 | tput= 1.072 Mbps | lat=2129.806 ms | p95=4903.290 ms | dsr=0.016 | block=0.019 | fair=0.939 | E=93493.705 J
# [Episode 0115] steps=200 | total_env_steps=  23200 | return=   9.555 | tput= 1.056 Mbps | lat=2019.944 ms | p95=4492.988 ms | dsr=0.011 | block=0.017 | fair=0.983 | E=86792.452 J
# [Episode 0116] steps=200 | total_env_steps=  23400 | return=  10.072 | tput= 1.115 Mbps | lat=1951.530 ms | p95=4381.439 ms | dsr=0.008 | block=0.016 | fair=0.966 | E=82515.928 J
# [Episode 0117] steps=200 | total_env_steps=  23600 | return=   9.464 | tput= 1.067 Mbps | lat=2073.339 ms | p95=4277.763 ms | dsr=0.010 | block=0.013 | fair=0.954 | E=85468.701 J
# [Episode 0118] steps=200 | total_env_steps=  23800 | return=   8.161 | tput= 1.019 Mbps | lat=1681.090 ms | p95=3417.060 ms | dsr=0.007 | block=0.010 | fair=0.967 | E=80653.604 J
# [Episode 0119] steps=200 | total_env_steps=  24000 | return=   9.584 | tput= 1.048 Mbps | lat=2011.146 ms | p95=4381.370 ms | dsr=0.012 | block=0.022 | fair=0.951 | E=86156.299 J
# [Episode 0120] steps=200 | total_env_steps=  24200 | return=   9.809 | tput= 1.002 Mbps | lat=2066.195 ms | p95=4587.779 ms | dsr=0.011 | block=0.007 | fair=0.966 | E=85262.926 J
# [Episode 0121] steps=200 | total_env_steps=  24400 | return=   8.324 | tput= 1.020 Mbps | lat=2291.856 ms | p95=4786.285 ms | dsr=0.015 | block=0.026 | fair=0.972 | E=94276.328 J
# [Episode 0122] steps=200 | total_env_steps=  24600 | return=   7.838 | tput= 1.011 Mbps | lat=2116.420 ms | p95=4579.800 ms | dsr=0.015 | block=0.029 | fair=0.932 | E=88031.256 J
# [Episode 0123] steps=200 | total_env_steps=  24800 | return=   9.479 | tput= 0.997 Mbps | lat=2044.311 ms | p95=4381.222 ms | dsr=0.009 | block=0.014 | fair=0.985 | E=85247.606 J
# [Episode 0124] steps=200 | total_env_steps=  25000 | return=  10.223 | tput= 1.089 Mbps | lat=2024.880 ms | p95=4818.959 ms | dsr=0.015 | block=0.019 | fair=0.969 | E=92805.769 J
# [Episode 0125] steps=200 | total_env_steps=  25200 | return=   8.298 | tput= 0.998 Mbps | lat=2154.409 ms | p95=4565.872 ms | dsr=0.015 | block=0.017 | fair=0.977 | E=90786.677 J
# [Episode 0126] steps=200 | total_env_steps=  25400 | return=   8.972 | tput= 0.915 Mbps | lat=2686.097 ms | p95=4856.851 ms | dsr=0.015 | block=0.006 | fair=0.984 | E=102823.017 J
# [Episode 0127] steps=200 | total_env_steps=  25600 | return=   9.148 | tput= 0.946 Mbps | lat=2024.013 ms | p95=4659.439 ms | dsr=0.010 | block=0.016 | fair=0.976 | E=85526.893 J
# [Episode 0128] steps=200 | total_env_steps=  25800 | return=   9.399 | tput= 1.073 Mbps | lat=2243.122 ms | p95=4675.418 ms | dsr=0.011 | block=0.015 | fair=0.977 | E=89927.818 J
# [Episode 0129] steps=200 | total_env_steps=  26000 | return=   9.616 | tput= 1.112 Mbps | lat=1603.130 ms | p95=3196.906 ms | dsr=0.007 | block=0.016 | fair=0.978 | E=79267.679 J
# [Episode 0130] steps=200 | total_env_steps=  26200 | return=  10.225 | tput= 1.066 Mbps | lat=1846.247 ms | p95=4242.767 ms | dsr=0.008 | block=0.018 | fair=0.992 | E=83094.809 J
# [Episode 0131] steps=200 | total_env_steps=  26400 | return=   9.492 | tput= 1.063 Mbps | lat=1997.757 ms | p95=4033.617 ms | dsr=0.009 | block=0.017 | fair=0.974 | E=84594.217 J
# [Episode 0132] steps=200 | total_env_steps=  26600 | return=   7.776 | tput= 1.003 Mbps | lat=1593.997 ms | p95=3307.763 ms | dsr=0.006 | block=0.015 | fair=0.976 | E=79688.035 J
# [Episode 0133] steps=200 | total_env_steps=  26800 | return=   7.387 | tput= 0.980 Mbps | lat=1833.832 ms | p95=3489.830 ms | dsr=0.008 | block=0.010 | fair=0.976 | E=83169.362 J
# [Episode 0134] steps=200 | total_env_steps=  27000 | return=   8.670 | tput= 1.020 Mbps | lat=1895.364 ms | p95=3933.521 ms | dsr=0.008 | block=0.019 | fair=0.971 | E=82424.112 J
# [Episode 0135] steps=200 | total_env_steps=  27200 | return=   9.453 | tput= 1.004 Mbps | lat=1933.306 ms | p95=4707.886 ms | dsr=0.012 | block=0.017 | fair=0.974 | E=85894.180 J
# [Episode 0136] steps=200 | total_env_steps=  27400 | return=   8.256 | tput= 1.046 Mbps | lat=1615.812 ms | p95=3253.360 ms | dsr=0.007 | block=0.023 | fair=0.980 | E=79087.659 J
# [Episode 0137] steps=200 | total_env_steps=  27600 | return=   7.968 | tput= 0.892 Mbps | lat=2415.505 ms | p95=4803.992 ms | dsr=0.018 | block=0.023 | fair=0.963 | E=101443.845 J
# [Episode 0138] steps=200 | total_env_steps=  27800 | return=   9.182 | tput= 1.025 Mbps | lat=1975.016 ms | p95=3946.642 ms | dsr=0.007 | block=0.017 | fair=0.978 | E=82861.383 J
# [Episode 0139] steps=200 | total_env_steps=  28000 | return=   9.156 | tput= 1.094 Mbps | lat=2215.481 ms | p95=4550.391 ms | dsr=0.012 | block=0.016 | fair=0.957 | E=90250.176 J
# [Episode 0140] steps=200 | total_env_steps=  28200 | return=   7.634 | tput= 0.935 Mbps | lat=1950.413 ms | p95=4423.545 ms | dsr=0.011 | block=0.021 | fair=0.974 | E=84891.674 J
# [Episode 0141] steps=200 | total_env_steps=  28400 | return=  10.454 | tput= 1.116 Mbps | lat=2445.630 ms | p95=4656.388 ms | dsr=0.014 | block=0.013 | fair=0.934 | E=93723.813 J
# [Episode 0142] steps=200 | total_env_steps=  28600 | return=   9.320 | tput= 1.014 Mbps | lat=2134.865 ms | p95=4606.993 ms | dsr=0.013 | block=0.021 | fair=0.980 | E=86889.250 J
# [Episode 0143] steps=200 | total_env_steps=  28800 | return=   9.742 | tput= 1.039 Mbps | lat=1962.449 ms | p95=4707.019 ms | dsr=0.010 | block=0.012 | fair=0.987 | E=86553.480 J
# [Episode 0144] steps=200 | total_env_steps=  29000 | return=   5.231 | tput= 0.788 Mbps | lat=2380.923 ms | p95=4808.908 ms | dsr=0.010 | block=0.025 | fair=0.945 | E=92360.403 J
# [Episode 0145] steps=200 | total_env_steps=  29200 | return=   9.764 | tput= 0.980 Mbps | lat=1968.375 ms | p95=4783.482 ms | dsr=0.013 | block=0.010 | fair=0.978 | E=88327.327 J
# [Episode 0146] steps=200 | total_env_steps=  29400 | return=   8.083 | tput= 0.943 Mbps | lat=2104.542 ms | p95=4782.116 ms | dsr=0.015 | block=0.015 | fair=0.975 | E=88868.460 J
# [Episode 0147] steps=200 | total_env_steps=  29600 | return=   7.684 | tput= 0.948 Mbps | lat=2113.642 ms | p95=4965.064 ms | dsr=0.017 | block=0.021 | fair=0.941 | E=96909.272 J
# [Episode 0148] steps=200 | total_env_steps=  29800 | return=   9.044 | tput= 1.023 Mbps | lat=2057.028 ms | p95=4716.601 ms | dsr=0.013 | block=0.020 | fair=0.981 | E=87609.836 J
# [Episode 0149] steps=200 | total_env_steps=  30000 | return=   8.871 | tput= 1.123 Mbps | lat=2188.899 ms | p95=4852.059 ms | dsr=0.014 | block=0.019 | fair=0.953 | E=91023.257 J
# [Episode 0150] steps=200 | total_env_steps=  30200 | return=   8.956 | tput= 0.938 Mbps | lat=2328.313 ms | p95=4694.753 ms | dsr=0.013 | block=0.025 | fair=0.965 | E=89342.198 J
# [Episode 0151] steps=200 | total_env_steps=  30400 | return=   9.198 | tput= 1.111 Mbps | lat=1986.781 ms | p95=4318.044 ms | dsr=0.011 | block=0.026 | fair=0.967 | E=85569.920 J
# [Episode 0152] steps=200 | total_env_steps=  30600 | return=   7.215 | tput= 0.973 Mbps | lat=1819.430 ms | p95=3628.134 ms | dsr=0.009 | block=0.036 | fair=0.944 | E=80109.711 J
# [Episode 0153] steps=200 | total_env_steps=  30800 | return=   9.377 | tput= 0.961 Mbps | lat=2015.023 ms | p95=4626.166 ms | dsr=0.012 | block=0.018 | fair=0.948 | E=83503.830 J
# [Episode 0154] steps=200 | total_env_steps=  31000 | return=   9.791 | tput= 0.984 Mbps | lat=2172.901 ms | p95=4872.968 ms | dsr=0.012 | block=0.021 | fair=0.977 | E=91671.553 J
# [Episode 0155] steps=200 | total_env_steps=  31200 | return=   8.690 | tput= 1.050 Mbps | lat=2025.625 ms | p95=4375.028 ms | dsr=0.013 | block=0.018 | fair=0.952 | E=86459.953 J
# [Episode 0156] steps=200 | total_env_steps=  31400 | return=  10.565 | tput= 1.166 Mbps | lat=1962.385 ms | p95=3953.436 ms | dsr=0.009 | block=0.007 | fair=0.990 | E=86879.421 J
# [Episode 0157] steps=200 | total_env_steps=  31600 | return=   7.934 | tput= 0.996 Mbps | lat=1600.639 ms | p95=3351.600 ms | dsr=0.010 | block=0.023 | fair=0.986 | E=81126.887 J
# [Episode 0158] steps=200 | total_env_steps=  31800 | return=   6.730 | tput= 0.917 Mbps | lat=1987.138 ms | p95=4422.018 ms | dsr=0.012 | block=0.025 | fair=0.969 | E=88424.862 J
# [Episode 0159] steps=200 | total_env_steps=  32000 | return=   7.742 | tput= 0.945 Mbps | lat=1649.062 ms | p95=3420.693 ms | dsr=0.006 | block=0.024 | fair=0.963 | E=79583.972 J
# [Episode 0160] steps=200 | total_env_steps=  32200 | return=   8.725 | tput= 1.050 Mbps | lat=2058.026 ms | p95=4786.799 ms | dsr=0.013 | block=0.021 | fair=0.928 | E=88189.376 J
# [Episode 0161] steps=200 | total_env_steps=  32400 | return=   7.606 | tput= 0.920 Mbps | lat=1867.662 ms | p95=4016.892 ms | dsr=0.007 | block=0.017 | fair=0.987 | E=84191.262 J
# [Episode 0162] steps=200 | total_env_steps=  32600 | return=   7.683 | tput= 0.960 Mbps | lat=1760.209 ms | p95=3904.102 ms | dsr=0.008 | block=0.019 | fair=0.990 | E=84644.048 J
# [Episode 0163] steps=200 | total_env_steps=  32800 | return=   9.195 | tput= 1.042 Mbps | lat=1793.952 ms | p95=4192.083 ms | dsr=0.011 | block=0.026 | fair=0.979 | E=82342.879 J
# [Episode 0164] steps=200 | total_env_steps=  33000 | return=   9.433 | tput= 1.088 Mbps | lat=2022.993 ms | p95=4270.720 ms | dsr=0.010 | block=0.019 | fair=0.959 | E=86110.282 J
# [Episode 0165] steps=200 | total_env_steps=  33200 | return=   8.987 | tput= 1.017 Mbps | lat=2479.777 ms | p95=4857.035 ms | dsr=0.016 | block=0.016 | fair=0.979 | E=97879.486 J
# [Episode 0166] steps=200 | total_env_steps=  33400 | return=   8.408 | tput= 1.027 Mbps | lat=1849.013 ms | p95=3982.246 ms | dsr=0.010 | block=0.013 | fair=0.980 | E=83624.185 J
# [Episode 0167] steps=200 | total_env_steps=  33600 | return=  11.004 | tput= 1.075 Mbps | lat=2120.095 ms | p95=4597.111 ms | dsr=0.010 | block=0.016 | fair=0.973 | E=85973.072 J
# [Episode 0168] steps=200 | total_env_steps=  33800 | return=   8.153 | tput= 1.002 Mbps | lat=2081.921 ms | p95=4104.069 ms | dsr=0.008 | block=0.017 | fair=0.971 | E=88336.059 J
# [Episode 0169] steps=200 | total_env_steps=  34000 | return=   9.360 | tput= 1.077 Mbps | lat=2405.644 ms | p95=4761.751 ms | dsr=0.015 | block=0.018 | fair=0.949 | E=97032.355 J
# [Episode 0170] steps=200 | total_env_steps=  34200 | return=   7.133 | tput= 0.942 Mbps | lat=2187.244 ms | p95=4773.060 ms | dsr=0.012 | block=0.023 | fair=0.968 | E=89577.032 J
# [Episode 0171] steps=200 | total_env_steps=  34400 | return=   7.069 | tput= 1.022 Mbps | lat=2185.733 ms | p95=4533.383 ms | dsr=0.015 | block=0.034 | fair=0.948 | E=93443.080 J
# [Episode 0172] steps=200 | total_env_steps=  34600 | return=   9.631 | tput= 0.970 Mbps | lat=2189.666 ms | p95=4945.201 ms | dsr=0.012 | block=0.009 | fair=0.972 | E=93033.001 J
# [Episode 0173] steps=200 | total_env_steps=  34800 | return=   6.545 | tput= 0.887 Mbps | lat=1915.975 ms | p95=3927.805 ms | dsr=0.008 | block=0.021 | fair=0.969 | E=83121.139 J
# [Episode 0174] steps=200 | total_env_steps=  35000 | return=   7.814 | tput= 1.042 Mbps | lat=1859.257 ms | p95=3977.969 ms | dsr=0.008 | block=0.022 | fair=0.976 | E=85216.984 J
# [Episode 0175] steps=200 | total_env_steps=  35200 | return=   7.649 | tput= 0.895 Mbps | lat=1919.801 ms | p95=4708.998 ms | dsr=0.011 | block=0.020 | fair=0.951 | E=85628.574 J
# [Episode 0176] steps=200 | total_env_steps=  35400 | return=   8.519 | tput= 1.102 Mbps | lat=2007.909 ms | p95=3950.667 ms | dsr=0.008 | block=0.011 | fair=0.979 | E=87055.237 J
# [Episode 0177] steps=200 | total_env_steps=  35600 | return=   7.485 | tput= 1.028 Mbps | lat=1946.179 ms | p95=3857.906 ms | dsr=0.009 | block=0.022 | fair=0.991 | E=87102.530 J
# [Episode 0178] steps=200 | total_env_steps=  35800 | return=   7.645 | tput= 0.915 Mbps | lat=1876.007 ms | p95=4329.455 ms | dsr=0.011 | block=0.026 | fair=0.982 | E=85773.572 J
# [Episode 0179] steps=200 | total_env_steps=  36000 | return=   8.277 | tput= 1.015 Mbps | lat=1927.012 ms | p95=4312.340 ms | dsr=0.012 | block=0.010 | fair=0.946 | E=83430.135 J
# [Episode 0180] steps=200 | total_env_steps=  36200 | return=   9.810 | tput= 1.019 Mbps | lat=2134.260 ms | p95=4950.746 ms | dsr=0.019 | block=0.019 | fair=0.953 | E=101328.637 J
# [Episode 0181] steps=200 | total_env_steps=  36400 | return=   9.250 | tput= 1.085 Mbps | lat=1970.338 ms | p95=3664.750 ms | dsr=0.008 | block=0.011 | fair=0.949 | E=83136.820 J
# [Episode 0182] steps=200 | total_env_steps=  36600 | return=   8.860 | tput= 0.925 Mbps | lat=2156.888 ms | p95=4826.771 ms | dsr=0.018 | block=0.020 | fair=0.975 | E=99697.994 J
# [Episode 0183] steps=200 | total_env_steps=  36800 | return=   6.771 | tput= 0.976 Mbps | lat=2147.525 ms | p95=4960.770 ms | dsr=0.018 | block=0.024 | fair=0.894 | E=104522.548 J
# [Episode 0184] steps=200 | total_env_steps=  37000 | return=   8.467 | tput= 1.002 Mbps | lat=1851.113 ms | p95=3560.129 ms | dsr=0.004 | block=0.009 | fair=0.985 | E=82013.843 J
# [Episode 0185] steps=200 | total_env_steps=  37200 | return=   9.029 | tput= 0.994 Mbps | lat=2062.217 ms | p95=4052.486 ms | dsr=0.005 | block=0.006 | fair=0.974 | E=84161.638 J
# [Episode 0186] steps=200 | total_env_steps=  37400 | return=   6.684 | tput= 0.947 Mbps | lat=1880.013 ms | p95=3904.752 ms | dsr=0.010 | block=0.029 | fair=0.974 | E=83008.523 J
# [Episode 0187] steps=200 | total_env_steps=  37600 | return=   7.918 | tput= 0.945 Mbps | lat=2154.143 ms | p95=4296.855 ms | dsr=0.014 | block=0.018 | fair=0.995 | E=91081.390 J
# [Episode 0188] steps=200 | total_env_steps=  37800 | return=   5.785 | tput= 0.900 Mbps | lat=2084.549 ms | p95=4049.310 ms | dsr=0.011 | block=0.031 | fair=0.968 | E=86442.314 J
# [Episode 0189] steps=200 | total_env_steps=  38000 | return=   9.451 | tput= 1.001 Mbps | lat=1986.752 ms | p95=4293.530 ms | dsr=0.010 | block=0.018 | fair=0.988 | E=83748.409 J
# [Episode 0190] steps=200 | total_env_steps=  38200 | return=   7.148 | tput= 0.982 Mbps | lat=1973.190 ms | p95=3927.737 ms | dsr=0.011 | block=0.020 | fair=0.957 | E=86999.765 J
# [Episode 0191] steps=200 | total_env_steps=  38400 | return=   6.155 | tput= 0.937 Mbps | lat=1809.345 ms | p95=3863.207 ms | dsr=0.007 | block=0.023 | fair=0.963 | E=82284.937 J
# [Episode 0192] steps=200 | total_env_steps=  38600 | return=   8.853 | tput= 0.956 Mbps | lat=2241.951 ms | p95=4930.752 ms | dsr=0.012 | block=0.018 | fair=0.936 | E=93859.964 J
# [Episode 0193] steps=200 | total_env_steps=  38800 | return=   8.954 | tput= 1.176 Mbps | lat=2330.628 ms | p95=4623.740 ms | dsr=0.016 | block=0.024 | fair=0.949 | E=95531.357 J
# [Episode 0194] steps=200 | total_env_steps=  39000 | return=   9.802 | tput= 1.007 Mbps | lat=1989.937 ms | p95=4067.051 ms | dsr=0.008 | block=0.018 | fair=0.984 | E=82753.307 J
# [Episode 0195] steps=200 | total_env_steps=  39200 | return=   8.959 | tput= 0.974 Mbps | lat=1765.081 ms | p95=3593.080 ms | dsr=0.007 | block=0.015 | fair=0.981 | E=80435.492 J
# [Episode 0196] steps=200 | total_env_steps=  39400 | return=   7.877 | tput= 1.013 Mbps | lat=2093.556 ms | p95=4671.071 ms | dsr=0.015 | block=0.038 | fair=0.954 | E=86679.629 J
# [Episode 0197] steps=200 | total_env_steps=  39600 | return=   7.313 | tput= 0.955 Mbps | lat=2476.655 ms | p95=4844.823 ms | dsr=0.015 | block=0.023 | fair=0.952 | E=94085.944 J
# [Episode 0198] steps=200 | total_env_steps=  39800 | return=   8.158 | tput= 0.911 Mbps | lat=2813.506 ms | p95=4927.647 ms | dsr=0.019 | block=0.017 | fair=0.913 | E=110599.182 J
# [Episode 0199] steps=200 | total_env_steps=  40000 | return=   6.400 | tput= 0.933 Mbps | lat=2272.849 ms | p95=4763.522 ms | dsr=0.013 | block=0.017 | fair=0.893 | E=92726.207 J
# [Episode 0200] steps=200 | total_env_steps=  40200 | return=   7.676 | tput= 1.054 Mbps | lat=2538.125 ms | p95=4920.816 ms | dsr=0.016 | block=0.022 | fair=0.919 | E=98004.320 J
# [Episode 0201] steps=200 | total_env_steps=  40400 | return=   6.696 | tput= 0.914 Mbps | lat=1596.285 ms | p95=3528.097 ms | dsr=0.006 | block=0.019 | fair=0.988 | E=78997.804 J
# [Episode 0202] steps=200 | total_env_steps=  40600 | return=   7.682 | tput= 1.017 Mbps | lat=2431.523 ms | p95=4769.961 ms | dsr=0.012 | block=0.023 | fair=0.952 | E=93469.822 J
# [Episode 0203] steps=200 | total_env_steps=  40800 | return=   7.924 | tput= 1.012 Mbps | lat=2039.903 ms | p95=4442.295 ms | dsr=0.011 | block=0.026 | fair=0.982 | E=87280.919 J
# [Episode 0204] steps=200 | total_env_steps=  41000 | return=   8.136 | tput= 0.961 Mbps | lat=1995.936 ms | p95=4833.983 ms | dsr=0.013 | block=0.024 | fair=0.944 | E=86381.885 J
# [Episode 0205] steps=200 | total_env_steps=  41200 | return=   8.099 | tput= 0.989 Mbps | lat=1867.347 ms | p95=4577.324 ms | dsr=0.012 | block=0.019 | fair=0.966 | E=86137.024 J
# [Episode 0206] steps=200 | total_env_steps=  41400 | return=   9.005 | tput= 0.980 Mbps | lat=1852.540 ms | p95=4528.399 ms | dsr=0.013 | block=0.022 | fair=0.978 | E=85387.237 J
# [Episode 0207] steps=200 | total_env_steps=  41600 | return=   8.134 | tput= 0.969 Mbps | lat=2279.160 ms | p95=4680.973 ms | dsr=0.018 | block=0.031 | fair=0.987 | E=93767.418 J
# [Episode 0208] steps=200 | total_env_steps=  41800 | return=   9.597 | tput= 1.105 Mbps | lat=2410.264 ms | p95=4799.475 ms | dsr=0.013 | block=0.008 | fair=0.966 | E=93642.855 J
# [Episode 0209] steps=200 | total_env_steps=  42000 | return=   7.121 | tput= 0.914 Mbps | lat=2012.757 ms | p95=4571.869 ms | dsr=0.011 | block=0.034 | fair=0.979 | E=84715.504 J
# [Episode 0210] steps=200 | total_env_steps=  42200 | return=   8.554 | tput= 1.039 Mbps | lat=1614.151 ms | p95=3136.300 ms | dsr=0.008 | block=0.029 | fair=0.991 | E=80212.981 J
# [Episode 0211] steps=200 | total_env_steps=  42400 | return=   7.430 | tput= 0.884 Mbps | lat=1909.798 ms | p95=3831.431 ms | dsr=0.008 | block=0.030 | fair=0.985 | E=81609.292 J
# [Episode 0212] steps=200 | total_env_steps=  42600 | return=   7.197 | tput= 0.897 Mbps | lat=1912.631 ms | p95=3963.096 ms | dsr=0.008 | block=0.024 | fair=0.974 | E=82290.038 J
# [Episode 0213] steps=200 | total_env_steps=  42800 | return=   9.079 | tput= 1.029 Mbps | lat=1800.315 ms | p95=4400.804 ms | dsr=0.012 | block=0.032 | fair=0.989 | E=83200.105 J
# [Episode 0214] steps=200 | total_env_steps=  43000 | return=   8.217 | tput= 0.881 Mbps | lat=2270.001 ms | p95=4862.050 ms | dsr=0.014 | block=0.024 | fair=0.949 | E=93495.146 J
# [Episode 0215] steps=200 | total_env_steps=  43200 | return=   9.933 | tput= 1.087 Mbps | lat=2028.844 ms | p95=4829.280 ms | dsr=0.010 | block=0.009 | fair=0.979 | E=88140.250 J
# [Episode 0216] steps=200 | total_env_steps=  43400 | return=   8.622 | tput= 1.000 Mbps | lat=1834.565 ms | p95=3681.627 ms | dsr=0.007 | block=0.015 | fair=0.991 | E=81994.296 J
# [Episode 0217] steps=200 | total_env_steps=  43600 | return=   7.858 | tput= 0.966 Mbps | lat=2071.037 ms | p95=4916.218 ms | dsr=0.012 | block=0.015 | fair=0.962 | E=89463.228 J
# [Episode 0218] steps=200 | total_env_steps=  43800 | return=   9.546 | tput= 0.972 Mbps | lat=1875.275 ms | p95=4640.635 ms | dsr=0.012 | block=0.021 | fair=0.984 | E=84066.437 J
# [Episode 0219] steps=200 | total_env_steps=  44000 | return=   7.833 | tput= 0.967 Mbps | lat=2008.575 ms | p95=4424.928 ms | dsr=0.011 | block=0.020 | fair=0.952 | E=86949.178 J
# [Episode 0220] steps=200 | total_env_steps=  44200 | return=   8.996 | tput= 1.022 Mbps | lat=2234.860 ms | p95=4934.553 ms | dsr=0.015 | block=0.014 | fair=0.936 | E=95873.810 J
# [Episode 0221] steps=200 | total_env_steps=  44400 | return=   7.707 | tput= 0.849 Mbps | lat=2042.190 ms | p95=4215.260 ms | dsr=0.010 | block=0.013 | fair=0.971 | E=84488.729 J
# [Episode 0222] steps=200 | total_env_steps=  44600 | return=   7.313 | tput= 0.999 Mbps | lat=2101.909 ms | p95=4107.326 ms | dsr=0.007 | block=0.006 | fair=0.972 | E=87768.288 J
# [Episode 0223] steps=200 | total_env_steps=  44800 | return=   8.333 | tput= 1.037 Mbps | lat=1836.411 ms | p95=3702.071 ms | dsr=0.008 | block=0.020 | fair=0.982 | E=82843.674 J
# [Episode 0224] steps=200 | total_env_steps=  45000 | return=   6.543 | tput= 0.879 Mbps | lat=1926.533 ms | p95=4319.821 ms | dsr=0.010 | block=0.023 | fair=0.958 | E=85018.788 J
# [Episode 0225] steps=200 | total_env_steps=  45200 | return=   8.913 | tput= 0.924 Mbps | lat=2047.219 ms | p95=4812.011 ms | dsr=0.019 | block=0.034 | fair=0.970 | E=91123.593 J
# [Episode 0226] steps=200 | total_env_steps=  45400 | return=   9.531 | tput= 1.022 Mbps | lat=1939.677 ms | p95=4080.313 ms | dsr=0.009 | block=0.019 | fair=0.985 | E=83009.526 J
# [Episode 0227] steps=200 | total_env_steps=  45600 | return=  11.279 | tput= 1.039 Mbps | lat=1973.394 ms | p95=4778.880 ms | dsr=0.010 | block=0.004 | fair=0.988 | E=87737.671 J
# [Episode 0228] steps=200 | total_env_steps=  45800 | return=  11.196 | tput= 0.980 Mbps | lat=1957.966 ms | p95=4790.298 ms | dsr=0.010 | block=0.014 | fair=0.974 | E=85492.729 J
# [Episode 0229] steps=200 | total_env_steps=  46000 | return=   8.691 | tput= 1.048 Mbps | lat=2100.831 ms | p95=4630.791 ms | dsr=0.010 | block=0.008 | fair=0.961 | E=89001.549 J
# [Episode 0230] steps=200 | total_env_steps=  46200 | return=   9.247 | tput= 1.076 Mbps | lat=2260.162 ms | p95=4685.754 ms | dsr=0.013 | block=0.016 | fair=0.962 | E=90153.288 J
# [Episode 0231] steps=200 | total_env_steps=  46400 | return=  11.556 | tput= 1.113 Mbps | lat=2029.716 ms | p95=4930.560 ms | dsr=0.013 | block=0.013 | fair=0.985 | E=94120.927 J
# [Episode 0232] steps=200 | total_env_steps=  46600 | return=   9.290 | tput= 1.041 Mbps | lat=1914.715 ms | p95=4445.198 ms | dsr=0.011 | block=0.017 | fair=0.981 | E=84135.082 J
# [Episode 0233] steps=200 | total_env_steps=  46800 | return=   9.164 | tput= 0.943 Mbps | lat=2114.934 ms | p95=4953.282 ms | dsr=0.025 | block=0.019 | fair=0.910 | E=117407.478 J
# [Episode 0234] steps=200 | total_env_steps=  47000 | return=   8.852 | tput= 0.969 Mbps | lat=2348.816 ms | p95=4905.495 ms | dsr=0.018 | block=0.013 | fair=0.925 | E=105003.274 J
# [Episode 0235] steps=200 | total_env_steps=  47200 | return=   8.360 | tput= 0.993 Mbps | lat=1873.136 ms | p95=3980.326 ms | dsr=0.009 | block=0.019 | fair=0.986 | E=84062.570 J
# [Episode 0236] steps=200 | total_env_steps=  47400 | return=   7.049 | tput= 0.937 Mbps | lat=1891.443 ms | p95=3909.991 ms | dsr=0.009 | block=0.030 | fair=0.965 | E=81438.435 J
# [Episode 0237] steps=200 | total_env_steps=  47600 | return=   9.091 | tput= 1.036 Mbps | lat=1980.645 ms | p95=4169.598 ms | dsr=0.011 | block=0.021 | fair=0.983 | E=86995.224 J
# [Episode 0238] steps=200 | total_env_steps=  47800 | return=   9.130 | tput= 1.070 Mbps | lat=2523.452 ms | p95=4572.383 ms | dsr=0.012 | block=0.012 | fair=0.965 | E=96084.866 J
# [Episode 0239] steps=200 | total_env_steps=  48000 | return=   9.531 | tput= 1.016 Mbps | lat=2103.074 ms | p95=4135.441 ms | dsr=0.009 | block=0.014 | fair=0.986 | E=84412.442 J
# [Episode 0240] steps=200 | total_env_steps=  48200 | return=   8.068 | tput= 1.045 Mbps | lat=1816.817 ms | p95=4040.874 ms | dsr=0.013 | block=0.026 | fair=0.965 | E=84808.705 J
# [Episode 0241] steps=200 | total_env_steps=  48400 | return=   6.979 | tput= 0.998 Mbps | lat=2055.755 ms | p95=4395.965 ms | dsr=0.012 | block=0.023 | fair=0.966 | E=88615.969 J
# [Episode 0242] steps=200 | total_env_steps=  48600 | return=  10.168 | tput= 1.041 Mbps | lat=2032.904 ms | p95=4754.778 ms | dsr=0.013 | block=0.009 | fair=0.986 | E=89157.215 J
# [Episode 0243] steps=200 | total_env_steps=  48800 | return=   7.233 | tput= 0.984 Mbps | lat=1784.141 ms | p95=3821.195 ms | dsr=0.008 | block=0.014 | fair=0.976 | E=83713.546 J
# [Episode 0244] steps=200 | total_env_steps=  49000 | return=   9.730 | tput= 0.975 Mbps | lat=2358.702 ms | p95=4675.294 ms | dsr=0.011 | block=0.015 | fair=0.963 | E=88871.938 J
# [Episode 0245] steps=200 | total_env_steps=  49200 | return=   9.089 | tput= 1.002 Mbps | lat=2448.565 ms | p95=4940.439 ms | dsr=0.017 | block=0.020 | fair=0.931 | E=100173.223 J
# [Episode 0246] steps=200 | total_env_steps=  49400 | return=   8.130 | tput= 1.031 Mbps | lat=1997.608 ms | p95=4198.313 ms | dsr=0.010 | block=0.014 | fair=0.946 | E=85145.198 J
# [Episode 0247] steps=200 | total_env_steps=  49600 | return=   7.201 | tput= 1.028 Mbps | lat=1627.856 ms | p95=3417.744 ms | dsr=0.010 | block=0.034 | fair=0.984 | E=82210.934 J
# [Episode 0248] steps=200 | total_env_steps=  49800 | return=   6.706 | tput= 0.963 Mbps | lat=1591.403 ms | p95=3171.713 ms | dsr=0.007 | block=0.018 | fair=0.979 | E=79576.741 J
# [Episode 0249] steps=200 | total_env_steps=  50000 | return=   9.968 | tput= 1.131 Mbps | lat=2532.477 ms | p95=4741.198 ms | dsr=0.013 | block=0.012 | fair=0.969 | E=94787.676 J
# [Episode 0250] steps=200 | total_env_steps=  50200 | return=   9.660 | tput= 1.140 Mbps | lat=2032.614 ms | p95=4482.234 ms | dsr=0.014 | block=0.025 | fair=0.933 | E=86515.925 J
# [Episode 0251] steps=200 | total_env_steps=  50400 | return=   9.136 | tput= 0.954 Mbps | lat=1843.618 ms | p95=4090.659 ms | dsr=0.013 | block=0.031 | fair=0.986 | E=81153.304 J
# [Episode 0252] steps=200 | total_env_steps=  50600 | return=   9.017 | tput= 0.961 Mbps | lat=2080.634 ms | p95=4288.475 ms | dsr=0.009 | block=0.012 | fair=0.947 | E=83461.600 J
# [Episode 0253] steps=200 | total_env_steps=  50800 | return=   8.184 | tput= 0.915 Mbps | lat=2096.800 ms | p95=4564.838 ms | dsr=0.015 | block=0.034 | fair=0.966 | E=85266.673 J
# [Episode 0254] steps=200 | total_env_steps=  51000 | return=  10.188 | tput= 1.112 Mbps | lat=2726.155 ms | p95=4905.801 ms | dsr=0.017 | block=0.023 | fair=0.907 | E=100619.842 J
# [Episode 0255] steps=200 | total_env_steps=  51200 | return=   8.421 | tput= 1.058 Mbps | lat=2294.541 ms | p95=4476.636 ms | dsr=0.009 | block=0.009 | fair=0.942 | E=91527.640 J
# [Episode 0256] steps=200 | total_env_steps=  51400 | return=   6.161 | tput= 0.957 Mbps | lat=1396.309 ms | p95=2716.291 ms | dsr=0.006 | block=0.039 | fair=0.986 | E=76182.440 J
# [Episode 0257] steps=200 | total_env_steps=  51600 | return=   9.316 | tput= 0.990 Mbps | lat=1930.582 ms | p95=4353.417 ms | dsr=0.008 | block=0.013 | fair=0.980 | E=83391.630 J
# [Episode 0258] steps=200 | total_env_steps=  51800 | return=   8.146 | tput= 1.037 Mbps | lat=1845.391 ms | p95=4108.788 ms | dsr=0.008 | block=0.020 | fair=0.993 | E=83121.870 J
# [Episode 0259] steps=200 | total_env_steps=  52000 | return=   9.749 | tput= 1.150 Mbps | lat=1922.618 ms | p95=3975.690 ms | dsr=0.011 | block=0.016 | fair=0.967 | E=85135.158 J
# [Episode 0260] steps=200 | total_env_steps=  52200 | return=   8.962 | tput= 1.117 Mbps | lat=1642.141 ms | p95=3112.587 ms | dsr=0.003 | block=0.015 | fair=0.973 | E=79039.668 J
# [Episode 0261] steps=200 | total_env_steps=  52400 | return=   8.230 | tput= 0.963 Mbps | lat=1848.229 ms | p95=4458.025 ms | dsr=0.012 | block=0.015 | fair=0.980 | E=86306.729 J
# [Episode 0262] steps=200 | total_env_steps=  52600 | return=   8.345 | tput= 1.008 Mbps | lat=1985.371 ms | p95=4053.452 ms | dsr=0.006 | block=0.021 | fair=0.978 | E=82899.105 J
# [Episode 0263] steps=200 | total_env_steps=  52800 | return=   9.415 | tput= 0.959 Mbps | lat=2277.533 ms | p95=4418.564 ms | dsr=0.008 | block=0.011 | fair=0.970 | E=85934.843 J
# [Episode 0264] steps=200 | total_env_steps=  53000 | return=   8.233 | tput= 0.969 Mbps | lat=1971.300 ms | p95=3982.129 ms | dsr=0.007 | block=0.014 | fair=0.988 | E=81341.743 J
# [Episode 0265] steps=200 | total_env_steps=  53200 | return=   7.096 | tput= 0.953 Mbps | lat=2121.010 ms | p95=4975.530 ms | dsr=0.018 | block=0.029 | fair=0.887 | E=101902.292 J
# [Episode 0266] steps=200 | total_env_steps=  53400 | return=   8.717 | tput= 1.053 Mbps | lat=2275.604 ms | p95=4565.730 ms | dsr=0.011 | block=0.016 | fair=0.974 | E=91144.309 J
# [Episode 0267] steps=200 | total_env_steps=  53600 | return=   7.839 | tput= 0.943 Mbps | lat=1902.132 ms | p95=4123.741 ms | dsr=0.010 | block=0.019 | fair=0.986 | E=83973.963 J
# ...
# [Episode 2412] steps=200 | total_env_steps= 482600 | return=   8.074 | tput= 1.053 Mbps | lat=1770.002 ms | p95=3496.419 ms | dsr=0.006 | block=0.018 | fair=0.974 | E=82165.479 J
# [Episode 2413] steps=200 | total_env_steps= 482800 | return=   9.367 | tput= 1.037 Mbps | lat=2311.373 ms | p95=4896.563 ms | dsr=0.019 | block=0.015 | fair=0.977 | E=100328.443 J
# [Episode 2414] steps=200 | total_env_steps= 483000 | return=   6.565 | tput= 0.880 Mbps | lat=1753.504 ms | p95=3971.466 ms | dsr=0.008 | block=0.021 | fair=0.962 | E=81552.860 J
# [Episode 2415] steps=200 | total_env_steps= 483200 | return=   7.931 | tput= 1.024 Mbps | lat=2658.859 ms | p95=4813.172 ms | dsr=0.011 | block=0.018 | fair=0.910 | E=94880.095 J
# [Episode 2416] steps=200 | total_env_steps= 483400 | return=   8.703 | tput= 1.042 Mbps | lat=2297.425 ms | p95=4454.746 ms | dsr=0.015 | block=0.030 | fair=0.978 | E=91826.905 J
# [Episode 2417] steps=200 | total_env_steps= 483600 | return=   7.216 | tput= 0.833 Mbps | lat=2409.574 ms | p95=4773.231 ms | dsr=0.011 | block=0.019 | fair=0.972 | E=89032.793 J
# [Episode 2418] steps=200 | total_env_steps= 483800 | return=   7.592 | tput= 0.965 Mbps | lat=1997.298 ms | p95=4546.324 ms | dsr=0.009 | block=0.026 | fair=0.988 | E=85348.866 J
# [Episode 2419] steps=200 | total_env_steps= 484000 | return=   9.250 | tput= 1.131 Mbps | lat=1985.409 ms | p95=3843.869 ms | dsr=0.008 | block=0.014 | fair=0.974 | E=86093.865 J
# [Episode 2420] steps=200 | total_env_steps= 484200 | return=   8.720 | tput= 1.010 Mbps | lat=2346.135 ms | p95=4914.533 ms | dsr=0.013 | block=0.014 | fair=0.972 | E=93840.070 J
# [Episode 2421] steps=200 | total_env_steps= 484400 | return=   8.625 | tput= 0.989 Mbps | lat=2258.791 ms | p95=4666.317 ms | dsr=0.012 | block=0.018 | fair=0.983 | E=89017.178 J
# [Episode 2422] steps=200 | total_env_steps= 484600 | return=   8.780 | tput= 1.048 Mbps | lat=2257.322 ms | p95=4350.007 ms | dsr=0.007 | block=0.005 | fair=0.944 | E=89481.822 J
# [Episode 2423] steps=200 | total_env_steps= 484800 | return=   8.825 | tput= 0.968 Mbps | lat=1950.254 ms | p95=4059.294 ms | dsr=0.008 | block=0.021 | fair=0.985 | E=83236.751 J
# [Episode 2424] steps=200 | total_env_steps= 485000 | return=   8.941 | tput= 0.987 Mbps | lat=2082.588 ms | p95=4803.133 ms | dsr=0.011 | block=0.013 | fair=0.965 | E=87601.886 J
# [Episode 2425] steps=200 | total_env_steps= 485200 | return=   8.948 | tput= 1.068 Mbps | lat=1580.501 ms | p95=3163.501 ms | dsr=0.007 | block=0.028 | fair=0.969 | E=78749.431 J
# [Episode 2426] steps=200 | total_env_steps= 485400 | return=   8.886 | tput= 0.921 Mbps | lat=2079.995 ms | p95=4616.241 ms | dsr=0.011 | block=0.012 | fair=0.989 | E=87078.570 J
# [Episode 2427] steps=200 | total_env_steps= 485600 | return=   8.518 | tput= 0.990 Mbps | lat=1736.263 ms | p95=4021.684 ms | dsr=0.009 | block=0.025 | fair=0.971 | E=79417.901 J
# [Episode 2428] steps=200 | total_env_steps= 485800 | return=   7.804 | tput= 0.970 Mbps | lat=1881.155 ms | p95=3612.538 ms | dsr=0.005 | block=0.019 | fair=0.985 | E=81087.547 J
# [Episode 2429] steps=200 | total_env_steps= 486000 | return=   9.882 | tput= 1.037 Mbps | lat=1897.705 ms | p95=4342.912 ms | dsr=0.007 | block=0.015 | fair=0.971 | E=82079.536 J
# [Episode 2430] steps=200 | total_env_steps= 486200 | return=   8.871 | tput= 0.982 Mbps | lat=2426.673 ms | p95=4704.382 ms | dsr=0.015 | block=0.017 | fair=0.984 | E=95794.191 J
# [Episode 2431] steps=200 | total_env_steps= 486400 | return=   6.576 | tput= 0.908 Mbps | lat=2034.534 ms | p95=3821.063 ms | dsr=0.009 | block=0.025 | fair=0.968 | E=85673.464 J
# [Episode 2432] steps=200 | total_env_steps= 486600 | return=   8.160 | tput= 0.952 Mbps | lat=1990.051 ms | p95=4316.685 ms | dsr=0.009 | block=0.020 | fair=0.980 | E=85649.709 J
# [Episode 2433] steps=200 | total_env_steps= 486800 | return=  10.325 | tput= 1.099 Mbps | lat=2311.542 ms | p95=4628.060 ms | dsr=0.013 | block=0.011 | fair=0.969 | E=89896.472 J
# [Episode 2434] steps=200 | total_env_steps= 487000 | return=  12.065 | tput= 1.129 Mbps | lat=2149.768 ms | p95=4631.404 ms | dsr=0.011 | block=0.011 | fair=0.984 | E=87836.779 J
# [Episode 2435] steps=200 | total_env_steps= 487200 | return=   8.913 | tput= 0.992 Mbps | lat=1823.798 ms | p95=3853.919 ms | dsr=0.007 | block=0.024 | fair=0.979 | E=81506.038 J
# [Episode 2436] steps=200 | total_env_steps= 487400 | return=   6.797 | tput= 1.001 Mbps | lat=1951.139 ms | p95=4157.824 ms | dsr=0.010 | block=0.021 | fair=0.970 | E=86775.668 J
# [Episode 2437] steps=200 | total_env_steps= 487600 | return=   9.876 | tput= 1.098 Mbps | lat=1852.184 ms | p95=4421.339 ms | dsr=0.009 | block=0.014 | fair=0.980 | E=83579.216 J
# [Episode 2438] steps=200 | total_env_steps= 487800 | return=   8.209 | tput= 0.986 Mbps | lat=2178.729 ms | p95=4872.885 ms | dsr=0.015 | block=0.022 | fair=0.942 | E=91423.218 J
# [Episode 2439] steps=200 | total_env_steps= 488000 | return=   8.530 | tput= 1.076 Mbps | lat=1906.415 ms | p95=3820.893 ms | dsr=0.008 | block=0.006 | fair=0.987 | E=85055.828 J
# [Episode 2440] steps=200 | total_env_steps= 488200 | return=   8.426 | tput= 0.944 Mbps | lat=2190.933 ms | p95=4549.214 ms | dsr=0.012 | block=0.012 | fair=0.988 | E=88563.823 J
# [Episode 2441] steps=200 | total_env_steps= 488400 | return=   9.500 | tput= 1.022 Mbps | lat=2397.604 ms | p95=4863.995 ms | dsr=0.013 | block=0.023 | fair=0.970 | E=93513.300 J
# [Episode 2442] steps=200 | total_env_steps= 488600 | return=   8.297 | tput= 0.934 Mbps | lat=2118.360 ms | p95=4637.226 ms | dsr=0.012 | block=0.016 | fair=0.979 | E=86982.283 J
# [Episode 2443] steps=200 | total_env_steps= 488800 | return=   7.517 | tput= 0.971 Mbps | lat=1599.651 ms | p95=3411.737 ms | dsr=0.008 | block=0.029 | fair=0.976 | E=79370.181 J
# [Episode 2444] steps=200 | total_env_steps= 489000 | return=  10.474 | tput= 1.114 Mbps | lat=2070.098 ms | p95=4838.330 ms | dsr=0.011 | block=0.019 | fair=0.976 | E=91150.147 J
# [Episode 2445] steps=200 | total_env_steps= 489200 | return=   9.137 | tput= 1.063 Mbps | lat=1810.410 ms | p95=3934.924 ms | dsr=0.009 | block=0.014 | fair=0.985 | E=83508.514 J
# [Episode 2446] steps=200 | total_env_steps= 489400 | return=   8.383 | tput= 1.057 Mbps | lat=1586.169 ms | p95=3463.189 ms | dsr=0.008 | block=0.030 | fair=0.977 | E=77767.363 J
# [Episode 2447] steps=200 | total_env_steps= 489600 | return=   9.786 | tput= 1.056 Mbps | lat=1955.093 ms | p95=4649.890 ms | dsr=0.010 | block=0.015 | fair=0.980 | E=86497.337 J
# [Episode 2448] steps=200 | total_env_steps= 489800 | return=   9.696 | tput= 1.201 Mbps | lat=2049.667 ms | p95=4202.237 ms | dsr=0.012 | block=0.019 | fair=0.954 | E=87254.627 J
# [Episode 2449] steps=200 | total_env_steps= 490000 | return=   8.183 | tput= 1.041 Mbps | lat=1866.410 ms | p95=4204.344 ms | dsr=0.011 | block=0.021 | fair=0.964 | E=83878.545 J
# [Episode 2450] steps=200 | total_env_steps= 490200 | return=   8.734 | tput= 1.019 Mbps | lat=2069.538 ms | p95=4886.575 ms | dsr=0.014 | block=0.024 | fair=0.972 | E=92552.216 J
# [Episode 2451] steps=200 | total_env_steps= 490400 | return=   8.976 | tput= 0.996 Mbps | lat=1820.423 ms | p95=4067.897 ms | dsr=0.008 | block=0.024 | fair=0.983 | E=81037.895 J
# [Episode 2452] steps=200 | total_env_steps= 490600 | return=   9.271 | tput= 1.002 Mbps | lat=1942.032 ms | p95=4211.714 ms | dsr=0.009 | block=0.017 | fair=0.978 | E=82885.305 J
# [Episode 2453] steps=200 | total_env_steps= 490800 | return=   8.824 | tput= 0.956 Mbps | lat=1844.311 ms | p95=4220.221 ms | dsr=0.009 | block=0.025 | fair=0.972 | E=83109.622 J
# [Episode 2454] steps=200 | total_env_steps= 491000 | return=   8.899 | tput= 0.966 Mbps | lat=1907.579 ms | p95=4015.021 ms | dsr=0.010 | block=0.022 | fair=0.980 | E=83577.723 J
# [Episode 2455] steps=200 | total_env_steps= 491200 | return=   9.659 | tput= 1.012 Mbps | lat=1814.529 ms | p95=3971.282 ms | dsr=0.007 | block=0.021 | fair=0.972 | E=81400.901 J
# [Episode 2456] steps=200 | total_env_steps= 491400 | return=  12.551 | tput= 1.165 Mbps | lat=2204.930 ms | p95=4920.822 ms | dsr=0.015 | block=0.010 | fair=0.974 | E=96036.746 J
# [Episode 2457] steps=200 | total_env_steps= 491600 | return=   7.422 | tput= 1.032 Mbps | lat=1895.917 ms | p95=3718.088 ms | dsr=0.011 | block=0.022 | fair=0.973 | E=85723.016 J
# [Episode 2458] steps=200 | total_env_steps= 491800 | return=   7.742 | tput= 1.007 Mbps | lat=1620.489 ms | p95=3248.876 ms | dsr=0.007 | block=0.026 | fair=0.990 | E=79904.039 J
# [Episode 2459] steps=200 | total_env_steps= 492000 | return=   7.087 | tput= 0.955 Mbps | lat=2294.770 ms | p95=4717.038 ms | dsr=0.011 | block=0.018 | fair=0.941 | E=90695.521 J
# [Episode 2460] steps=200 | total_env_steps= 492200 | return=  10.111 | tput= 1.106 Mbps | lat=2104.953 ms | p95=4947.214 ms | dsr=0.019 | block=0.014 | fair=0.940 | E=103284.747 J
# [Episode 2461] steps=200 | total_env_steps= 492400 | return=   7.429 | tput= 0.947 Mbps | lat=2128.068 ms | p95=4735.969 ms | dsr=0.013 | block=0.020 | fair=0.966 | E=89421.390 J
# [Episode 2462] steps=200 | total_env_steps= 492600 | return=   8.851 | tput= 0.934 Mbps | lat=1933.883 ms | p95=4217.309 ms | dsr=0.009 | block=0.023 | fair=0.993 | E=83154.913 J
# [Episode 2463] steps=200 | total_env_steps= 492800 | return=   8.603 | tput= 0.961 Mbps | lat=2196.401 ms | p95=4257.610 ms | dsr=0.011 | block=0.022 | fair=0.973 | E=85117.771 J
# [Episode 2464] steps=200 | total_env_steps= 493000 | return=   9.336 | tput= 0.993 Mbps | lat=2223.955 ms | p95=4895.553 ms | dsr=0.014 | block=0.025 | fair=0.972 | E=88989.275 J
# [Episode 2465] steps=200 | total_env_steps= 493200 | return=   5.402 | tput= 0.919 Mbps | lat=2337.891 ms | p95=4863.739 ms | dsr=0.014 | block=0.014 | fair=0.914 | E=104673.697 J
# [Episode 2466] steps=200 | total_env_steps= 493400 | return=   8.281 | tput= 1.106 Mbps | lat=1682.669 ms | p95=3561.510 ms | dsr=0.005 | block=0.021 | fair=0.978 | E=80510.106 J
# [Episode 2467] steps=200 | total_env_steps= 493600 | return=   7.573 | tput= 0.909 Mbps | lat=1997.013 ms | p95=4328.213 ms | dsr=0.011 | block=0.025 | fair=0.979 | E=84497.332 J
# [Episode 2468] steps=200 | total_env_steps= 493800 | return=   8.969 | tput= 1.002 Mbps | lat=1848.124 ms | p95=4211.512 ms | dsr=0.011 | block=0.031 | fair=0.989 | E=82965.748 J
# [Episode 2469] steps=200 | total_env_steps= 494000 | return=   7.996 | tput= 0.941 Mbps | lat=2591.220 ms | p95=4911.228 ms | dsr=0.011 | block=0.023 | fair=0.963 | E=98140.038 J
# [Episode 2470] steps=200 | total_env_steps= 494200 | return=   7.931 | tput= 0.981 Mbps | lat=1876.471 ms | p95=4706.026 ms | dsr=0.013 | block=0.018 | fair=0.979 | E=87367.929 J
# [Episode 2471] steps=200 | total_env_steps= 494400 | return=   7.427 | tput= 0.924 Mbps | lat=2200.904 ms | p95=4657.410 ms | dsr=0.013 | block=0.030 | fair=0.958 | E=86840.528 J
# [Episode 2472] steps=200 | total_env_steps= 494600 | return=   8.597 | tput= 0.986 Mbps | lat=2109.740 ms | p95=4272.150 ms | dsr=0.009 | block=0.018 | fair=0.987 | E=84713.114 J
# [Episode 2473] steps=200 | total_env_steps= 494800 | return=   9.116 | tput= 1.032 Mbps | lat=2222.010 ms | p95=4351.656 ms | dsr=0.012 | block=0.017 | fair=0.988 | E=88890.877 J
# [Episode 2474] steps=200 | total_env_steps= 495000 | return=   7.919 | tput= 0.996 Mbps | lat=1818.348 ms | p95=3852.559 ms | dsr=0.007 | block=0.024 | fair=0.984 | E=84042.181 J
# [Episode 2475] steps=200 | total_env_steps= 495200 | return=   6.877 | tput= 0.918 Mbps | lat=1580.130 ms | p95=3026.939 ms | dsr=0.006 | block=0.024 | fair=0.985 | E=79024.902 J
# [Episode 2476] steps=200 | total_env_steps= 495400 | return=   7.122 | tput= 0.969 Mbps | lat=1841.892 ms | p95=3574.073 ms | dsr=0.010 | block=0.027 | fair=0.976 | E=84382.494 J
# [Episode 2477] steps=200 | total_env_steps= 495600 | return=   8.735 | tput= 0.950 Mbps | lat=2340.933 ms | p95=4764.152 ms | dsr=0.012 | block=0.025 | fair=0.969 | E=90193.358 J
# [Episode 2478] steps=200 | total_env_steps= 495800 | return=   7.631 | tput= 0.979 Mbps | lat=2067.791 ms | p95=4847.616 ms | dsr=0.014 | block=0.024 | fair=0.934 | E=92958.992 J
# [Episode 2479] steps=200 | total_env_steps= 496000 | return=   8.989 | tput= 0.964 Mbps | lat=2112.679 ms | p95=4336.474 ms | dsr=0.011 | block=0.012 | fair=0.987 | E=88561.155 J
# [Episode 2480] steps=200 | total_env_steps= 496200 | return=   8.526 | tput= 0.944 Mbps | lat=2028.000 ms | p95=4932.386 ms | dsr=0.022 | block=0.028 | fair=0.967 | E=98366.644 J
# [Episode 2481] steps=200 | total_env_steps= 496400 | return=   8.626 | tput= 0.999 Mbps | lat=1836.160 ms | p95=4352.925 ms | dsr=0.009 | block=0.028 | fair=0.978 | E=83801.998 J
# [Episode 2482] steps=200 | total_env_steps= 496600 | return=  10.298 | tput= 1.038 Mbps | lat=1921.391 ms | p95=4737.293 ms | dsr=0.011 | block=0.015 | fair=0.981 | E=84478.173 J
# [Episode 2483] steps=200 | total_env_steps= 496800 | return=   8.138 | tput= 1.015 Mbps | lat=2253.291 ms | p95=4910.611 ms | dsr=0.013 | block=0.036 | fair=0.969 | E=90536.640 J
# [Episode 2484] steps=200 | total_env_steps= 497000 | return=   6.397 | tput= 0.908 Mbps | lat=1719.000 ms | p95=3438.634 ms | dsr=0.010 | block=0.018 | fair=0.950 | E=81656.650 J
# [Episode 2485] steps=200 | total_env_steps= 497200 | return=   7.145 | tput= 0.943 Mbps | lat=1946.879 ms | p95=4675.706 ms | dsr=0.013 | block=0.031 | fair=0.948 | E=85936.366 J
# [Episode 2486] steps=200 | total_env_steps= 497400 | return=   9.580 | tput= 1.018 Mbps | lat=1982.688 ms | p95=4687.530 ms | dsr=0.015 | block=0.018 | fair=0.977 | E=86673.624 J
# [Episode 2487] steps=200 | total_env_steps= 497600 | return=   9.242 | tput= 1.055 Mbps | lat=2283.997 ms | p95=4422.554 ms | dsr=0.010 | block=0.019 | fair=0.989 | E=88236.709 J
# [Episode 2488] steps=200 | total_env_steps= 497800 | return=   8.196 | tput= 1.091 Mbps | lat=2228.371 ms | p95=4338.436 ms | dsr=0.011 | block=0.016 | fair=0.943 | E=89979.002 J
# [Episode 2489] steps=200 | total_env_steps= 498000 | return=   8.418 | tput= 1.086 Mbps | lat=2265.273 ms | p95=4685.509 ms | dsr=0.014 | block=0.037 | fair=0.939 | E=90112.951 J
# [Episode 2490] steps=200 | total_env_steps= 498200 | return=   6.339 | tput= 0.987 Mbps | lat=2037.257 ms | p95=4237.985 ms | dsr=0.010 | block=0.018 | fair=0.954 | E=88596.840 J
# [Episode 2491] steps=200 | total_env_steps= 498400 | return=   7.180 | tput= 0.957 Mbps | lat=1979.561 ms | p95=4375.955 ms | dsr=0.012 | block=0.032 | fair=0.964 | E=86478.063 J
# [Episode 2492] steps=200 | total_env_steps= 498600 | return=   6.957 | tput= 1.014 Mbps | lat=2109.366 ms | p95=4729.488 ms | dsr=0.011 | block=0.027 | fair=0.951 | E=94136.055 J
# [Episode 2493] steps=200 | total_env_steps= 498800 | return=   9.167 | tput= 1.039 Mbps | lat=2047.266 ms | p95=4420.326 ms | dsr=0.013 | block=0.024 | fair=0.978 | E=86781.715 J
# [Episode 2494] steps=200 | total_env_steps= 499000 | return=   7.732 | tput= 0.984 Mbps | lat=1905.899 ms | p95=3909.795 ms | dsr=0.009 | block=0.014 | fair=0.960 | E=84438.633 J
# [Episode 2495] steps=200 | total_env_steps= 499200 | return=   8.713 | tput= 0.968 Mbps | lat=2233.042 ms | p95=4493.706 ms | dsr=0.012 | block=0.020 | fair=0.962 | E=87318.252 J
# [Episode 2496] steps=200 | total_env_steps= 499400 | return=   8.218 | tput= 0.946 Mbps | lat=1686.873 ms | p95=3659.495 ms | dsr=0.009 | block=0.026 | fair=0.965 | E=79452.947 J
# [Episode 2497] steps=200 | total_env_steps= 499600 | return=   8.414 | tput= 0.958 Mbps | lat=1868.241 ms | p95=3551.768 ms | dsr=0.005 | block=0.023 | fair=0.985 | E=80779.701 J
# [Episode 2498] steps=200 | total_env_steps= 499800 | return=   8.386 | tput= 1.025 Mbps | lat=1935.800 ms | p95=4130.368 ms | dsr=0.012 | block=0.033 | fair=0.949 | E=85579.256 J
# [Episode 2499] steps=200 | total_env_steps= 500000 | return=   7.843 | tput= 0.987 Mbps | lat=2257.524 ms | p95=4598.978 ms | dsr=0.015 | block=0.026 | fair=0.977 | E=91395.969 J
#
# ✅ Heuristic simulation finished.
# Episodes completed   : 2500
# Total env steps      : 500000
# Episode metrics file : /home/umb/Desktop/wr/multi/heuristic_episode_metrics.csv
